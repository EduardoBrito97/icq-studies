# %%
normalize_axis = 1
load_inputvector_env_state = True
use_exponential_on_input = True

# %% [markdown]
# # Blobs

# %%
# %%time
# %run Experimento-Artificial-Blobs-20-10-Fold.ipynb
# Out:
# Intel(R) Extension for Scikit-learn* enabled (https://github.com/intel/scikit-learn-intelex)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #0
# Mean negativities for all classes: [0.2897812907135737]
# Mean entropies for all classes: [1.878032272283972e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.59      0.95      0.73        20
#          1.0       0.88      0.35      0.50        20
#
#     accuracy                           0.65        40
#    macro avg       0.73      0.65      0.62        40
# weighted avg       0.73      0.65      0.62        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #1
# Mean negativities for all classes: [0.30776299113531924]
# Mean entropies for all classes: [2.6346716576520943e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.66      0.95      0.78        20
#          1.0       0.91      0.50      0.65        20
#
#     accuracy                           0.73        40
#    macro avg       0.78      0.72      0.71        40
# weighted avg       0.78      0.72      0.71        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #2
# Mean negativities for all classes: [0.29176691409251354]
# Mean entropies for all classes: [2.8247549136906186e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.61      0.95      0.75        20
#          1.0       0.89      0.40      0.55        20
#
#     accuracy                           0.68        40
#    macro avg       0.75      0.68      0.65        40
# weighted avg       0.75      0.68      0.65        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #3
# Mean negativities for all classes: [0.33184568036041884]
# Mean entropies for all classes: [1.5626764336135273e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.62      1.00      0.77        20
#          1.0       1.00      0.40      0.57        20
#
#     accuracy                           0.70        40
#    macro avg       0.81      0.70      0.67        40
# weighted avg       0.81      0.70      0.67        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #4
# Mean negativities for all classes: [0.2844521541815606]
# Mean entropies for all classes: [2.6079451744914788e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.61      1.00      0.75        20
#          1.0       1.00      0.35      0.52        20
#
#     accuracy                           0.68        40
#    macro avg       0.80      0.68      0.64        40
# weighted avg       0.80      0.68      0.64        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #5
# Mean negativities for all classes: [0.2639760265457558]
# Mean entropies for all classes: [-3.5664991787434556e-16]
#               precision    recall  f1-score   support
#
#          0.0       0.61      0.95      0.75        20
#          1.0       0.89      0.40      0.55        20
#
#     accuracy                           0.68        40
#    macro avg       0.75      0.68      0.65        40
# weighted avg       0.75      0.68      0.65        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #6
# Mean negativities for all classes: [0.3408525610225126]
# Mean entropies for all classes: [2.4801201250745988e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.56      0.95      0.70        20
#          1.0       0.83      0.25      0.38        20
#
#     accuracy                           0.60        40
#    macro avg       0.70      0.60      0.54        40
# weighted avg       0.70      0.60      0.54        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #7
# Mean negativities for all classes: [0.23245664447648368]
# Mean entropies for all classes: [5.121405442733083e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.57      0.85      0.68        20
#          1.0       0.70      0.35      0.47        20
#
#     accuracy                           0.60        40
#    macro avg       0.63      0.60      0.57        40
# weighted avg       0.63      0.60      0.57        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #8
# Mean negativities for all classes: [0.3070606134002575]
# Mean entropies for all classes: [5.357972246911813e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.71      0.85      0.77        20
#          1.0       0.81      0.65      0.72        20
#
#     accuracy                           0.75        40
#    macro avg       0.76      0.75      0.75        40
# weighted avg       0.76      0.75      0.75        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #9
# Mean negativities for all classes: [0.28311566603862515]
# Mean entropies for all classes: [2.646691048427437e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.51      0.90      0.65        20
#          1.0       0.60      0.15      0.24        20
#
#     accuracy                           0.53        40
#    macro avg       0.56      0.53      0.45        40
# weighted avg       0.56      0.53      0.45        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.6575 F1-Scores = 0.6241730312128763 Negativity = [0.2897812907135737, 0.30776299113531924] Entropy = [1.878032272283972e-15, 2.6346716576520943e-15]
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #0
# Mean negativities for all classes: [0.3056036813943416]
# Mean entropies for all classes: [-3.0366741131531273e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.57      1.00      0.73        20
#          1.0       1.00      0.25      0.40        20
#
#     accuracy                           0.62        40
#    macro avg       0.79      0.62      0.56        40
# weighted avg       0.79      0.62      0.56        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #1
# Mean negativities for all classes: [0.29419504734700946]
# Mean entropies for all classes: [3.0375966037515954e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.59      1.00      0.74        20
#          1.0       1.00      0.30      0.46        20
#
#     accuracy                           0.65        40
#    macro avg       0.79      0.65      0.60        40
# weighted avg       0.79      0.65      0.60        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #2
# Mean negativities for all classes: [0.30339978797835593]
# Mean entropies for all classes: [3.4848222443667617e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.60      0.90      0.72        20
#          1.0       0.80      0.40      0.53        20
#
#     accuracy                           0.65        40
#    macro avg       0.70      0.65      0.63        40
# weighted avg       0.70      0.65      0.63        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #3
# Mean negativities for all classes: [0.29669594284503986]
# Mean entropies for all classes: [2.7266816116186385e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.66      0.95      0.78        20
#          1.0       0.91      0.50      0.65        20
#
#     accuracy                           0.73        40
#    macro avg       0.78      0.72      0.71        40
# weighted avg       0.78      0.72      0.71        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #4
# Mean negativities for all classes: [0.3273538393281349]
# Mean entropies for all classes: [2.0962599490226734e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.59      0.95      0.73        20
#          1.0       0.88      0.35      0.50        20
#
#     accuracy                           0.65        40
#    macro avg       0.73      0.65      0.62        40
# weighted avg       0.73      0.65      0.62        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #5
# Mean negativities for all classes: [0.31526823538509136]
# Mean entropies for all classes: [4.31550838729342e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.58      0.95      0.72        20
#          1.0       0.86      0.30      0.44        20
#
#     accuracy                           0.62        40
#    macro avg       0.72      0.62      0.58        40
# weighted avg       0.72      0.62      0.58        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #6
# Mean negativities for all classes: [0.09585759347374248]
# Mean entropies for all classes: [7.074639537829205e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.54      0.75      0.63        20
#          1.0       0.58      0.35      0.44        20
#
#     accuracy                           0.55        40
#    macro avg       0.56      0.55      0.53        40
# weighted avg       0.56      0.55      0.53        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #7
# Mean negativities for all classes: [0.24743720103798017]
# Mean entropies for all classes: [2.6945667061684818e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.59      0.95      0.73        20
#          1.0       0.88      0.35      0.50        20
#
#     accuracy                           0.65        40
#    macro avg       0.73      0.65      0.62        40
# weighted avg       0.73      0.65      0.62        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #8
# Mean negativities for all classes: [0.3133827409157678]
# Mean entropies for all classes: [2.0803778155225025e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.66      0.95      0.78        20
#          1.0       0.91      0.50      0.65        20
#
#     accuracy                           0.73        40
#    macro avg       0.78      0.72      0.71        40
# weighted avg       0.78      0.72      0.71        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #9
# Mean negativities for all classes: [0.348770555844513]
# Mean entropies for all classes: [2.997449223212507e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.59      1.00      0.74        20
#          1.0       1.00      0.30      0.46        20
#
#     accuracy                           0.65        40
#    macro avg       0.79      0.65      0.60        40
# weighted avg       0.79      0.65      0.60        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.65 F1-Scores = 0.6155985746015635 Negativity = [0.3056036813943416, 0.29419504734700946] Entropy = [-3.0366741131531273e-15, 3.0375966037515954e-15]
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #0
# Mean negativities for all classes: [0.32989229906521317]
# Mean entropies for all classes: [3.2378446624337587e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.65      1.00      0.78        20
#          1.0       1.00      0.45      0.62        20
#
#     accuracy                           0.73        40
#    macro avg       0.82      0.72      0.70        40
# weighted avg       0.82      0.72      0.70        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #1
# Mean negativities for all classes: [0.3091885746331973]
# Mean entropies for all classes: [2.6044702045362676e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.59      0.95      0.73        20
#          1.0       0.88      0.35      0.50        20
#
#     accuracy                           0.65        40
#    macro avg       0.73      0.65      0.62        40
# weighted avg       0.73      0.65      0.62        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #2
# Mean negativities for all classes: [0.2984666741093548]
# Mean entropies for all classes: [2.856613039907789e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.59      0.95      0.73        20
#          1.0       0.88      0.35      0.50        20
#
#     accuracy                           0.65        40
#    macro avg       0.73      0.65      0.62        40
# weighted avg       0.73      0.65      0.62        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #3
# Mean negativities for all classes: [0.29364088794001086]
# Mean entropies for all classes: [3.0466120937955806e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.55      0.85      0.67        20
#          1.0       0.67      0.30      0.41        20
#
#     accuracy                           0.57        40
#    macro avg       0.61      0.57      0.54        40
# weighted avg       0.61      0.57      0.54        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #4
# Mean negativities for all classes: [0.3004027822792848]
# Mean entropies for all classes: [1.0531589698168617e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.62      1.00      0.77        20
#          1.0       1.00      0.40      0.57        20
#
#     accuracy                           0.70        40
#    macro avg       0.81      0.70      0.67        40
# weighted avg       0.81      0.70      0.67        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #5
# Mean negativities for all classes: [0.31330437647235637]
# Mean entropies for all classes: [4.207689397558343e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.53      0.85      0.65        20
#          1.0       0.62      0.25      0.36        20
#
#     accuracy                           0.55        40
#    macro avg       0.58      0.55      0.51        40
# weighted avg       0.58      0.55      0.51        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #6
# Mean negativities for all classes: [0.3130200942919581]
# Mean entropies for all classes: [2.107445387533896e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.65      1.00      0.78        20
#          1.0       1.00      0.45      0.62        20
#
#     accuracy                           0.73        40
#    macro avg       0.82      0.72      0.70        40
# weighted avg       0.82      0.72      0.70        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #7
# Mean negativities for all classes: [0.2549537958090362]
# Mean entropies for all classes: [-7.18052380092293e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.60      0.90      0.72        20
#          1.0       0.80      0.40      0.53        20
#
#     accuracy                           0.65        40
#    macro avg       0.70      0.65      0.63        40
# weighted avg       0.70      0.65      0.63        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #8
# Mean negativities for all classes: [0.3050856451576394]
# Mean entropies for all classes: [2.843110578663055e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.64      0.90      0.75        20
#          1.0       0.83      0.50      0.62        20
#
#     accuracy                           0.70        40
#    macro avg       0.74      0.70      0.69        40
# weighted avg       0.74      0.70      0.69        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #9
# Mean negativities for all classes: [0.2829563728650598]
# Mean entropies for all classes: [3.78662263452745e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.69      0.90      0.78        20
#          1.0       0.86      0.60      0.71        20
#
#     accuracy                           0.75        40
#    macro avg       0.77      0.75      0.74        40
# weighted avg       0.77      0.75      0.74        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.6675 F1-Scores = 0.6410238863276829 Negativity = [0.32989229906521317, 0.3091885746331973] Entropy = [3.2378446624337587e-15, 2.6044702045362676e-15]
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #0
# Mean negativities for all classes: [0.3360182611143979]
# Mean entropies for all classes: [1.4933493698493936e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.61      1.00      0.75        20
#          1.0       1.00      0.35      0.52        20
#
#     accuracy                           0.68        40
#    macro avg       0.80      0.68      0.64        40
# weighted avg       0.80      0.68      0.64        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #1
# Mean negativities for all classes: [0.29009554909012597]
# Mean entropies for all classes: [2.5051137141316155e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.59      0.95      0.73        20
#          1.0       0.88      0.35      0.50        20
#
#     accuracy                           0.65        40
#    macro avg       0.73      0.65      0.62        40
# weighted avg       0.73      0.65      0.62        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #2
# Mean negativities for all classes: [0.2677222985688088]
# Mean entropies for all classes: [2.7619760831833723e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.61      1.00      0.75        20
#          1.0       1.00      0.35      0.52        20
#
#     accuracy                           0.68        40
#    macro avg       0.80      0.68      0.64        40
# weighted avg       0.80      0.68      0.64        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #3
# Mean negativities for all classes: [0.3298253832749614]
# Mean entropies for all classes: [4.989970673402125e-16]
#               precision    recall  f1-score   support
#
#          0.0       0.62      1.00      0.77        20
#          1.0       1.00      0.40      0.57        20
#
#     accuracy                           0.70        40
#    macro avg       0.81      0.70      0.67        40
# weighted avg       0.81      0.70      0.67        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #4
# Mean negativities for all classes: [0.2705330355096778]
# Mean entropies for all classes: [1.0959792277421751e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.59      1.00      0.74        20
#          1.0       1.00      0.30      0.46        20
#
#     accuracy                           0.65        40
#    macro avg       0.79      0.65      0.60        40
# weighted avg       0.79      0.65      0.60        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #5
# Mean negativities for all classes: [0.28972820496096346]
# Mean entropies for all classes: [2.4545100622229155e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.55      0.90      0.68        20
#          1.0       0.71      0.25      0.37        20
#
#     accuracy                           0.57        40
#    macro avg       0.63      0.57      0.52        40
# weighted avg       0.63      0.57      0.52        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #6
# Mean negativities for all classes: [0.2888893573247337]
# Mean entropies for all classes: [2.5739142972073433e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.60      0.90      0.72        20
#          1.0       0.80      0.40      0.53        20
#
#     accuracy                           0.65        40
#    macro avg       0.70      0.65      0.63        40
# weighted avg       0.70      0.65      0.63        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #7
# Mean negativities for all classes: [0.2843838162044693]
# Mean entropies for all classes: [2.4870487205715714e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.54      0.95      0.69        20
#          1.0       0.80      0.20      0.32        20
#
#     accuracy                           0.57        40
#    macro avg       0.67      0.57      0.51        40
# weighted avg       0.67      0.57      0.51        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #8
# Mean negativities for all classes: [0.2008374551777647]
# Mean entropies for all classes: [4.8294167482525036e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.66      0.95      0.78        20
#          1.0       0.91      0.50      0.65        20
#
#     accuracy                           0.73        40
#    macro avg       0.78      0.72      0.71        40
# weighted avg       0.78      0.72      0.71        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #9
# Mean negativities for all classes: [0.2951746354863019]
# Mean entropies for all classes: [4.110684634209248e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.63      0.85      0.72        20
#          1.0       0.77      0.50      0.61        20
#
#     accuracy                           0.68        40
#    macro avg       0.70      0.68      0.66        40
# weighted avg       0.70      0.68      0.66        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.655 F1-Scores = 0.6192086603212296 Negativity = [0.3360182611143979, 0.29009554909012597] Entropy = [1.4933493698493936e-15, 2.5051137141316155e-15]
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #0
# Mean negativities for all classes: [0.28775677566456037]
# Mean entropies for all classes: [2.8708296703779533e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.63      0.95      0.76        20
#          1.0       0.90      0.45      0.60        20
#
#     accuracy                           0.70        40
#    macro avg       0.77      0.70      0.68        40
# weighted avg       0.77      0.70      0.68        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #1
# Mean negativities for all classes: [0.2836698540428878]
# Mean entropies for all classes: [1.3771722268105623e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.56      0.95      0.70        20
#          1.0       0.83      0.25      0.38        20
#
#     accuracy                           0.60        40
#    macro avg       0.70      0.60      0.54        40
# weighted avg       0.70      0.60      0.54        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #2
# Mean negativities for all classes: [0.3187060561210153]
# Mean entropies for all classes: [2.530409966319008e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.58      0.90      0.71        20
#          1.0       0.78      0.35      0.48        20
#
#     accuracy                           0.62        40
#    macro avg       0.68      0.62      0.59        40
# weighted avg       0.68      0.62      0.59        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #3
# Mean negativities for all classes: [0.2993252881785476]
# Mean entropies for all classes: [1.0344384765920714e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.56      0.90      0.69        20
#          1.0       0.75      0.30      0.43        20
#
#     accuracy                           0.60        40
#    macro avg       0.66      0.60      0.56        40
# weighted avg       0.66      0.60      0.56        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #4
# Mean negativities for all classes: [0.27314896982775094]
# Mean entropies for all classes: [2.909322477542933e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.57      1.00      0.73        20
#          1.0       1.00      0.25      0.40        20
#
#     accuracy                           0.62        40
#    macro avg       0.79      0.62      0.56        40
# weighted avg       0.79      0.62      0.56        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #5
# Mean negativities for all classes: [0.30503530715627847]
# Mean entropies for all classes: [2.557459933271359e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.61      1.00      0.75        20
#          1.0       1.00      0.35      0.52        20
#
#     accuracy                           0.68        40
#    macro avg       0.80      0.68      0.64        40
# weighted avg       0.80      0.68      0.64        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #6
# Mean negativities for all classes: [0.2786262679523476]
# Mean entropies for all classes: [4.707740555532025e-16]
#               precision    recall  f1-score   support
#
#          0.0       0.56      0.90      0.69        20
#          1.0       0.75      0.30      0.43        20
#
#     accuracy                           0.60        40
#    macro avg       0.66      0.60      0.56        40
# weighted avg       0.66      0.60      0.56        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #7
# Mean negativities for all classes: [0.3329125143465014]
# Mean entropies for all classes: [6.980039097932414e-16]
#               precision    recall  f1-score   support
#
#          0.0       0.61      1.00      0.75        20
#          1.0       1.00      0.35      0.52        20
#
#     accuracy                           0.68        40
#    macro avg       0.80      0.68      0.64        40
# weighted avg       0.80      0.68      0.64        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #8
# Mean negativities for all classes: [0.3299093099380831]
# Mean entropies for all classes: [1.2803718383628387e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.56      1.00      0.71        20
#          1.0       1.00      0.20      0.33        20
#
#     accuracy                           0.60        40
#    macro avg       0.78      0.60      0.52        40
# weighted avg       0.78      0.60      0.52        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #9
# Mean negativities for all classes: [0.30557039388217905]
# Mean entropies for all classes: [2.758683245068741e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.57      1.00      0.73        20
#          1.0       1.00      0.25      0.40        20
#
#     accuracy                           0.62        40
#    macro avg       0.79      0.62      0.56        40
# weighted avg       0.79      0.62      0.56        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.6325 F1-Scores = 0.5863676902586925 Negativity = [0.28775677566456037, 0.2836698540428878] Entropy = [2.8708296703779533e-15, 1.3771722268105623e-14]
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #0
# Mean negativities for all classes: [0.23773590926528249]
# Mean entropies for all classes: [-1.9416909099619075e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.59      0.95      0.73        20
#          1.0       0.88      0.35      0.50        20
#
#     accuracy                           0.65        40
#    macro avg       0.73      0.65      0.62        40
# weighted avg       0.73      0.65      0.62        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #1
# Mean negativities for all classes: [0.3087650173730348]
# Mean entropies for all classes: [2.7779353301775655e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.56      0.90      0.69        20
#          1.0       0.75      0.30      0.43        20
#
#     accuracy                           0.60        40
#    macro avg       0.66      0.60      0.56        40
# weighted avg       0.66      0.60      0.56        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #2
# Mean negativities for all classes: [0.25141980614514087]
# Mean entropies for all classes: [3.1583855821588445e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.62      1.00      0.77        20
#          1.0       1.00      0.40      0.57        20
#
#     accuracy                           0.70        40
#    macro avg       0.81      0.70      0.67        40
# weighted avg       0.81      0.70      0.67        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #3
# Mean negativities for all classes: [0.31677540647503505]
# Mean entropies for all classes: [4.281954598124921e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.59      1.00      0.74        20
#          1.0       1.00      0.30      0.46        20
#
#     accuracy                           0.65        40
#    macro avg       0.79      0.65      0.60        40
# weighted avg       0.79      0.65      0.60        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #4
# Mean negativities for all classes: [0.3117861763049795]
# Mean entropies for all classes: [2.82640181685568e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.62      1.00      0.77        20
#          1.0       1.00      0.40      0.57        20
#
#     accuracy                           0.70        40
#    macro avg       0.81      0.70      0.67        40
# weighted avg       0.81      0.70      0.67        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #5
# Mean negativities for all classes: [0.3212289742268249]
# Mean entropies for all classes: [2.699391258975929e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.57      1.00      0.73        20
#          1.0       1.00      0.25      0.40        20
#
#     accuracy                           0.62        40
#    macro avg       0.79      0.62      0.56        40
# weighted avg       0.79      0.62      0.56        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #6
# Mean negativities for all classes: [0.29857923494306354]
# Mean entropies for all classes: [2.8902549300938223e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.56      0.90      0.69        20
#          1.0       0.75      0.30      0.43        20
#
#     accuracy                           0.60        40
#    macro avg       0.66      0.60      0.56        40
# weighted avg       0.66      0.60      0.56        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #7
# Mean negativities for all classes: [0.28661399488289313]
# Mean entropies for all classes: [3.177167093072807e-16]
#               precision    recall  f1-score   support
#
#          0.0       0.59      0.95      0.73        20
#          1.0       0.88      0.35      0.50        20
#
#     accuracy                           0.65        40
#    macro avg       0.73      0.65      0.62        40
# weighted avg       0.73      0.65      0.62        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #8
# Mean negativities for all classes: [0.18221912077682081]
# Mean entropies for all classes: [1.2772115891998393e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.59      0.95      0.73        20
#          1.0       0.88      0.35      0.50        20
#
#     accuracy                           0.65        40
#    macro avg       0.73      0.65      0.62        40
# weighted avg       0.73      0.65      0.62        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #9
# Mean negativities for all classes: [0.35367896684097716]
# Mean entropies for all classes: [3.981116280722814e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.57      1.00      0.73        20
#          1.0       1.00      0.25      0.40        20
#
#     accuracy                           0.62        40
#    macro avg       0.79      0.62      0.56        40
# weighted avg       0.79      0.62      0.56        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.6450000000000001 F1-Scores = 0.6036104636104637 Negativity = [0.23773590926528249, 0.3087650173730348] Entropy = [-1.9416909099619075e-15, 2.7779353301775655e-15]
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #0
# Mean negativities for all classes: [0.30988425818837156]
# Mean entropies for all classes: [1.0330275245009386e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.57      1.00      0.73        20
#          1.0       1.00      0.25      0.40        20
#
#     accuracy                           0.62        40
#    macro avg       0.79      0.62      0.56        40
# weighted avg       0.79      0.62      0.56        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #1
# Mean negativities for all classes: [0.34149635572642484]
# Mean entropies for all classes: [2.708697413440959e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.56      1.00      0.71        20
#          1.0       1.00      0.20      0.33        20
#
#     accuracy                           0.60        40
#    macro avg       0.78      0.60      0.52        40
# weighted avg       0.78      0.60      0.52        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #2
# Mean negativities for all classes: [0.24790692493348304]
# Mean entropies for all classes: [-8.704984621329398e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.61      1.00      0.75        20
#          1.0       1.00      0.35      0.52        20
#
#     accuracy                           0.68        40
#    macro avg       0.80      0.68      0.64        40
# weighted avg       0.80      0.68      0.64        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #3
# Mean negativities for all classes: [0.3027996201666325]
# Mean entropies for all classes: [3.2739115668703364e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.51      0.90      0.65        20
#          1.0       0.60      0.15      0.24        20
#
#     accuracy                           0.53        40
#    macro avg       0.56      0.53      0.45        40
# weighted avg       0.56      0.53      0.45        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #4
# Mean negativities for all classes: [0.3049300753200705]
# Mean entropies for all classes: [3.2959180145193586e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.61      0.85      0.71        20
#          1.0       0.75      0.45      0.56        20
#
#     accuracy                           0.65        40
#    macro avg       0.68      0.65      0.64        40
# weighted avg       0.68      0.65      0.64        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #5
# Mean negativities for all classes: [0.27202852892677154]
# Mean entropies for all classes: [5.300298380085351e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.64      0.90      0.75        20
# ...
# Mean entropies for all classes: [3.094176003771576e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.61      0.95      0.75        20
#          1.0       0.89      0.40      0.55        20
#
#     accuracy                           0.68        40
#    macro avg       0.75      0.68      0.65        40
# weighted avg       0.75      0.68      0.65        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #2
# Mean negativities for all classes: [0.2927727431953504]
# Mean entropies for all classes: [2.5156870808369773e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.59      0.85      0.69        20
#          1.0       0.73      0.40      0.52        20
#
#     accuracy                           0.62        40
#    macro avg       0.66      0.62      0.61        40
# weighted avg       0.66      0.62      0.61        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #3
# Mean negativities for all classes: [0.30431584831591907]
# Mean entropies for all classes: [2.5961175505236022e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.53      0.90      0.67        20
#          1.0       0.67      0.20      0.31        20
#
#     accuracy                           0.55        40
#    macro avg       0.60      0.55      0.49        40
# weighted avg       0.60      0.55      0.49        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #4
# Mean negativities for all classes: [0.3212086921858093]
# Mean entropies for all classes: [3.101161431987534e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.59      1.00      0.74        20
#          1.0       1.00      0.30      0.46        20
#
#     accuracy                           0.65        40
#    macro avg       0.79      0.65      0.60        40
# weighted avg       0.79      0.65      0.60        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #5
# Mean negativities for all classes: [0.2839002028912946]
# Mean entropies for all classes: [2.9079821900402236e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.55      0.80      0.65        20
#          1.0       0.64      0.35      0.45        20
#
#     accuracy                           0.57        40
#    macro avg       0.59      0.57      0.55        40
# weighted avg       0.59      0.57      0.55        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #6
# Mean negativities for all classes: [0.3442867184432579]
# Mean entropies for all classes: [4.918856700470616e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.61      1.00      0.75        20
#          1.0       1.00      0.35      0.52        20
#
#     accuracy                           0.68        40
#    macro avg       0.80      0.68      0.64        40
# weighted avg       0.80      0.68      0.64        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #7
# Mean negativities for all classes: [0.3020361811760105]
# Mean entropies for all classes: [2.5998418670607837e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.65      1.00      0.78        20
#          1.0       1.00      0.45      0.62        20
#
#     accuracy                           0.73        40
#    macro avg       0.82      0.72      0.70        40
# weighted avg       0.82      0.72      0.70        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #8
# Mean negativities for all classes: [0.33890602116428503]
# Mean entropies for all classes: [1.7024808268654796e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.57      1.00      0.73        20
#          1.0       1.00      0.25      0.40        20
#
#     accuracy                           0.62        40
#    macro avg       0.79      0.62      0.56        40
# weighted avg       0.79      0.62      0.56        40
#
# -------------------------------------------------------------------------------------------------------------------
# K-Fold #9
# Mean negativities for all classes: [0.32384610227001637]
# Mean entropies for all classes: [1.1316533665439881e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.61      1.00      0.75        20
#          1.0       1.00      0.35      0.52        20
#
#     accuracy                           0.68        40
#    macro avg       0.80      0.68      0.64        40
# weighted avg       0.80      0.68      0.64        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.6399999999999999 F1-Scores = 0.6014156874267707 Negativity = [0.3467698378027876, 0.33809773284903527] Entropy = [2.6555480199559787e-15, 3.094176003771576e-15]
# CPU times: total: 13.9 s
# Wall time: 7h 25min 20s
# Media Score dos N K-Fold 0.6496250000000001
# Maior Score dos K-Fold 0.6725000000000001
# Menor Score dos K-Fold 0.6325
#
#
# [[0.65, 0.725, 0.675, 0.7, 0.675, 0.675, 0.6, 0.6, 0.75, 0.525], [0.625, 0.65, 0.65, 0.725, 0.65, 0.625, 0.55, 0.65, 0.725, 0.65], [0.725, 0.65, 0.65, 0.575, 0.7, 0.55, 0.725, 0.65, 0.7, 0.75], [0.675, 0.65, 0.675, 0.7, 0.65, 0.575, 0.65, 0.575, 0.725, 0.675], [0.7, 0.6, 0.625, 0.6, 0.625, 0.675, 0.6, 0.675, 0.6, 0.625], [0.65, 0.6

# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished

# %% [markdown]
# # Circles

# %%
# %%time
# %run Experimento-Artificial-Circles-20-10-Fold.ipynb
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #0
# Mean negativities for all classes: [0.0034689775474811696]
# Mean entropies for all classes: [2.949710076632501e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.22      0.10      0.14        20
#          1.0       0.42      0.65      0.51        20
#
#     accuracy                           0.38        40
#    macro avg       0.32      0.38      0.32        40
# weighted avg       0.32      0.38      0.32        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #1
# Mean negativities for all classes: [0.2014259852043346]
# Mean entropies for all classes: [1.9152380170396317e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.43      0.15      0.22        20
#          1.0       0.48      0.80      0.60        20
#
#     accuracy                           0.48        40
#    macro avg       0.46      0.48      0.41        40
# weighted avg       0.46      0.47      0.41        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #2
# Mean negativities for all classes: [0.24079803026705368]
# Mean entropies for all classes: [1.9820351849230973e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.46      0.80      0.58        20
#          1.0       0.20      0.05      0.08        20
#
#     accuracy                           0.42        40
#    macro avg       0.33      0.43      0.33        40
# weighted avg       0.33      0.42      0.33        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #3
# Mean negativities for all classes: [0.2621738278528417]
# Mean entropies for all classes: [1.6844437914729651e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.49      0.90      0.63        20
#          1.0       0.33      0.05      0.09        20
#
#     accuracy                           0.48        40
#    macro avg       0.41      0.48      0.36        40
# weighted avg       0.41      0.47      0.36        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #4
# Mean negativities for all classes: [0.1779123054735726]
# Mean entropies for all classes: [2.333386345308454e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.33      0.05      0.09        20
#          1.0       0.49      0.90      0.63        20
#
#     accuracy                           0.48        40
#    macro avg       0.41      0.48      0.36        40
# weighted avg       0.41      0.47      0.36        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #5
# Mean negativities for all classes: [0.06938564169821804]
# Mean entropies for all classes: [3.333409726964597e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.52      0.55      0.54        20
#          1.0       0.53      0.50      0.51        20
#
#     accuracy                           0.53        40
#    macro avg       0.53      0.53      0.52        40
# weighted avg       0.53      0.53      0.52        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #6
# Mean negativities for all classes: [0.24810011643420427]
# Mean entropies for all classes: [1.830545418158899e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.36      0.40      0.38        20
#          1.0       0.33      0.30      0.32        20
#
#     accuracy                           0.35        40
#    macro avg       0.35      0.35      0.35        40
# weighted avg       0.35      0.35      0.35        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #7
# Mean negativities for all classes: [0.2758014200091715]
# Mean entropies for all classes: [1.2906489736247511e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.52      0.65      0.58        20
#          1.0       0.53      0.40      0.46        20
#
#     accuracy                           0.53        40
#    macro avg       0.53      0.53      0.52        40
# weighted avg       0.53      0.53      0.52        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #8
# Mean negativities for all classes: [0.28166952207502727]
# Mean entropies for all classes: [1.8563623782376662e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.44      0.75      0.56        20
#          1.0       0.17      0.05      0.08        20
#
#     accuracy                           0.40        40
#    macro avg       0.30      0.40      0.32        40
# weighted avg       0.30      0.40      0.32        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #9
# Mean negativities for all classes: [0.2898350640404444]
# Mean entropies for all classes: [3.2835862399935732e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.46      0.80      0.58        20
#          1.0       0.20      0.05      0.08        20
#
#     accuracy                           0.42        40
#    macro avg       0.33      0.43      0.33        40
# weighted avg       0.33      0.42      0.33        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.445 F1-Scores = 0.3823992532870383 Negativity = [0.0034689775474811696, 0.2014259852043346] Entropy = [2.949710076632501e-15, 1.9152380170396317e-15]
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #0
# Mean negativities for all classes: [0.0013316118437428858]
# Mean entropies for all classes: [2.76900622592171e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.36      0.25      0.29        20
#          1.0       0.42      0.55      0.48        20
#
#     accuracy                           0.40        40
#    macro avg       0.39      0.40      0.39        40
# weighted avg       0.39      0.40      0.39        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #1
# Mean negativities for all classes: [0.26409717962968915]
# Mean entropies for all classes: [2.1818319920257023e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.46      0.55      0.50        20
#          1.0       0.44      0.35      0.39        20
#
#     accuracy                           0.45        40
#    macro avg       0.45      0.45      0.44        40
# weighted avg       0.45      0.45      0.44        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #2
# Mean negativities for all classes: [0.18890415381839065]
# Mean entropies for all classes: [2.7392485650038236e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.05      0.09        20
#          1.0       0.50      0.95      0.66        20
#
#     accuracy                           0.50        40
#    macro avg       0.50      0.50      0.37        40
# weighted avg       0.50      0.50      0.37        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #3
# Mean negativities for all classes: [0.2814140618633725]
# Mean entropies for all classes: [2.2412613074124568e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.70      0.58        20
#          1.0       0.50      0.30      0.37        20
#
#     accuracy                           0.50        40
#    macro avg       0.50      0.50      0.48        40
# weighted avg       0.50      0.50      0.48        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #4
# Mean negativities for all classes: [0.24444280604754548]
# Mean entropies for all classes: [1.7236676567848324e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.49      0.85      0.62        20
#          1.0       0.40      0.10      0.16        20
#
#     accuracy                           0.48        40
#    macro avg       0.44      0.47      0.39        40
# weighted avg       0.44      0.47      0.39        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #5
# Mean negativities for all classes: [0.2591838672451086]
# Mean entropies for all classes: [2.1240149951858807e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.54      0.65      0.59        20
#          1.0       0.56      0.45      0.50        20
#
#     accuracy                           0.55        40
#    macro avg       0.55      0.55      0.55        40
# weighted avg       0.55      0.55      0.55        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #6
# Mean negativities for all classes: [0.13362470063708304]
# Mean entropies for all classes: [2.8040041890569218e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.40      0.20      0.27        20
#          1.0       0.47      0.70      0.56        20
#
#     accuracy                           0.45        40
#    macro avg       0.43      0.45      0.41        40
# weighted avg       0.43      0.45      0.41        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #7
# Mean negativities for all classes: [0.002876810457432738]
# Mean entropies for all classes: [2.275949404353328e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.47      0.90      0.62        20
#          1.0       0.00      0.00      0.00        20
#
#     accuracy                           0.45        40
#    macro avg       0.24      0.45      0.31        40
# weighted avg       0.24      0.45      0.31        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #8
# Mean negativities for all classes: [0.2645811254064246]
# Mean entropies for all classes: [2.650891528063354e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.44      0.55      0.49        20
#          1.0       0.40      0.30      0.34        20
#
#     accuracy                           0.42        40
#    macro avg       0.42      0.43      0.42        40
# weighted avg       0.42      0.42      0.42        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #9
# Mean negativities for all classes: [0.2663322431258769]
# Mean entropies for all classes: [1.771097553570857e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.43      0.60      0.50        20
#          1.0       0.33      0.20      0.25        20
#
#     accuracy                           0.40        40
#    macro avg       0.38      0.40      0.38        40
# weighted avg       0.38      0.40      0.38        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.4600000000000001 F1-Scores = 0.413193775311224 Negativity = [0.0013316118437428858, 0.26409717962968915] Entropy = [2.76900622592171e-15, 2.1818319920257023e-15]
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #0
# Mean negativities for all classes: [0.004170629679815066]
# Mean entropies for all classes: [2.4875095864956993e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.40      0.20      0.27        20
#          1.0       0.47      0.70      0.56        20
#
#     accuracy                           0.45        40
#    macro avg       0.43      0.45      0.41        40
# weighted avg       0.43      0.45      0.41        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #1
# Mean negativities for all classes: [0.2777246469428771]
# Mean entropies for all classes: [2.1453073722592458e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.52      0.70      0.60        20
#          1.0       0.54      0.35      0.42        20
#
#     accuracy                           0.53        40
#    macro avg       0.53      0.52      0.51        40
# weighted avg       0.53      0.53      0.51        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #2
# Mean negativities for all classes: [0.2826435151446703]
# Mean entropies for all classes: [2.1843488884608774e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.46      0.60      0.52        20
#          1.0       0.43      0.30      0.35        20
#
#     accuracy                           0.45        40
#    macro avg       0.45      0.45      0.44        40
# weighted avg       0.45      0.45      0.44        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #3
# Mean negativities for all classes: [0.13306732475701327]
# Mean entropies for all classes: [3.0539367934871678e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.33      0.05      0.09        20
#          1.0       0.49      0.90      0.63        20
#
#     accuracy                           0.48        40
#    macro avg       0.41      0.48      0.36        40
# weighted avg       0.41      0.47      0.36        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #4
# Mean negativities for all classes: [0.003723571668523551]
# Mean entropies for all classes: [3.3737760421254643e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.45      0.25      0.32        20
#          1.0       0.48      0.70      0.57        20
#
#     accuracy                           0.48        40
#    macro avg       0.47      0.47      0.45        40
# weighted avg       0.47      0.47      0.45        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #5
# Mean negativities for all classes: [0.06630792919597364]
# Mean entropies for all classes: [3.745446260570766e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00        20
#          1.0       0.49      0.95      0.64        20
#
#     accuracy                           0.48        40
#    macro avg       0.24      0.47      0.32        40
# weighted avg       0.24      0.47      0.32        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #6
# Mean negativities for all classes: [0.2841149042626264]
# Mean entropies for all classes: [2.2393752743892617e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.48      0.50      0.49        20
#          1.0       0.47      0.45      0.46        20
#
#     accuracy                           0.48        40
#    macro avg       0.47      0.47      0.47        40
# weighted avg       0.47      0.47      0.47        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #7
# Mean negativities for all classes: [0.00013700886331149964]
# Mean entropies for all classes: [2.1135822845525095e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.38      0.50      0.43        20
#          1.0       0.29      0.20      0.24        20
#
#     accuracy                           0.35        40
#    macro avg       0.34      0.35      0.34        40
# weighted avg       0.34      0.35      0.34        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #8
# Mean negativities for all classes: [0.0016139433573860273]
# Mean entropies for all classes: [2.6871828618917077e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.29      0.20      0.24        20
#          1.0       0.38      0.50      0.43        20
#
#     accuracy                           0.35        40
#    macro avg       0.34      0.35      0.34        40
# weighted avg       0.34      0.35      0.34        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #9
# Mean negativities for all classes: [0.21603911805399822]
# Mean entropies for all classes: [1.4942716094427938e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.48      0.75      0.59        20
#          1.0       0.44      0.20      0.28        20
#
#     accuracy                           0.48        40
#    macro avg       0.46      0.47      0.43        40
# weighted avg       0.46      0.47      0.43        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.4499999999999999 F1-Scores = 0.40657703581644683 Negativity = [0.004170629679815066, 0.2777246469428771] Entropy = [2.4875095864956993e-15, 2.1453073722592458e-15]
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #0
# Mean negativities for all classes: [0.268765317129692]
# Mean entropies for all classes: [2.0132068822461394e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.38      0.45      0.41        20
#          1.0       0.31      0.25      0.28        20
#
#     accuracy                           0.35        40
#    macro avg       0.34      0.35      0.34        40
# weighted avg       0.34      0.35      0.34        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #1
# Mean negativities for all classes: [0.27739179767752675]
# Mean entropies for all classes: [2.5159005479898716e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.48      0.60      0.53        20
#          1.0       0.47      0.35      0.40        20
#
#     accuracy                           0.48        40
#    macro avg       0.47      0.47      0.47        40
# weighted avg       0.47      0.47      0.47        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #2
# Mean negativities for all classes: [0.10770485035635677]
# Mean entropies for all classes: [2.4790033303242424e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.33      0.10      0.15        20
#          1.0       0.47      0.80      0.59        20
#
#     accuracy                           0.45        40
#    macro avg       0.40      0.45      0.37        40
# weighted avg       0.40      0.45      0.37        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #3
# Mean negativities for all classes: [0.034483852755011465]
# Mean entropies for all classes: [2.2257351129882334e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.39      0.35      0.37        20
#          1.0       0.41      0.45      0.43        20
#
#     accuracy                           0.40        40
#    macro avg       0.40      0.40      0.40        40
# weighted avg       0.40      0.40      0.40        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #4
# Mean negativities for all classes: [0.2640448878585385]
# Mean entropies for all classes: [2.323356290235747e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.48      0.50      0.49        20
#          1.0       0.47      0.45      0.46        20
#
#     accuracy                           0.48        40
#    macro avg       0.47      0.47      0.47        40
# weighted avg       0.47      0.47      0.47        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #5
# Mean negativities for all classes: [0.23483666449172086]
# Mean entropies for all classes: [2.3554618653226026e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.47      0.80      0.59        20
#          1.0       0.33      0.10      0.15        20
#
#     accuracy                           0.45        40
#    macro avg       0.40      0.45      0.37        40
# weighted avg       0.40      0.45      0.37        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #6
# Mean negativities for all classes: [0.0016836150697821545]
# Mean entropies for all classes: [2.4860623154641133e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.40      0.20      0.27        20
#          1.0       0.47      0.70      0.56        20
#
#     accuracy                           0.45        40
#    macro avg       0.43      0.45      0.41        40
# weighted avg       0.43      0.45      0.41        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #7
# Mean negativities for all classes: [0.24993392550233867]
# Mean entropies for all classes: [2.609328703722552e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.43      0.50      0.47        20
#          1.0       0.41      0.35      0.38        20
#
#     accuracy                           0.42        40
#    macro avg       0.42      0.42      0.42        40
# weighted avg       0.42      0.42      0.42        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.4min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #8
# Mean negativities for all classes: [0.2698399607132512]
# Mean entropies for all classes: [2.447847392992282e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.48      0.55      0.51        20
#          1.0       0.47      0.40      0.43        20
#
#     accuracy                           0.48        40
#    macro avg       0.47      0.48      0.47        40
# weighted avg       0.47      0.47      0.47        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  3.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #9
# Mean negativities for all classes: [0.2730285048054587]
# Mean entropies for all classes: [2.81761429974579e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.60      0.55        20
#          1.0       0.50      0.40      0.44        20
#
#     accuracy                           0.50        40
#    macro avg       0.50      0.50      0.49        40
# weighted avg       0.50      0.50      0.49        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.445 F1-Scores = 0.4231767993646371 Negativity = [0.268765317129692, 0.27739179767752675] Entropy = [2.0132068822461394e-15, 2.5159005479898716e-15]
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  3.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #0
# Mean negativities for all classes: [0.285159686944836]
# Mean entropies for all classes: [2.255557970887109e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.54      0.65      0.59        20
#          1.0       0.56      0.45      0.50        20
#
#     accuracy                           0.55        40
#    macro avg       0.55      0.55      0.55        40
# weighted avg       0.55      0.55      0.55        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  3.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #1
# Mean negativities for all classes: [0.0013550245922595433]
# Mean entropies for all classes: [2.8800203598879764e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.43      0.30      0.35        20
#          1.0       0.46      0.60      0.52        20
#
#     accuracy                           0.45        40
#    macro avg       0.45      0.45      0.44        40
# weighted avg       0.45      0.45      0.44        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  3.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #2
# Mean negativities for all classes: [0.2611800491450079]
# Mean entropies for all classes: [2.5612443873162666e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.39      0.35      0.37        20
#          1.0       0.41      0.45      0.43        20
#
#     accuracy                           0.40        40
#    macro avg       0.40      0.40      0.40        40
# weighted avg       0.40      0.40      0.40        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  3.0min finished
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #3
# Mean negativities for all classes: [0.2273857726127922]
# Mean entropies for all classes: [2.1722189598727325e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.50      1.00      0.67        20
#          1.0       0.00      0.00      0.00        20
#
#     accuracy                           0.50        40
#    macro avg       0.25      0.50      0.33        40
# weighted avg       0.25      0.50      0.33        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  3.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #4
# Mean negativities for all classes: [0.2679814964238954]
# Mean entropies for all classes: [1.975559557207358e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.40      0.50      0.44        20
#          1.0       0.33      0.25      0.29        20
#
#     accuracy                           0.38        40
#    macro avg       0.37      0.38      0.37        40
# weighted avg       0.37      0.38      0.37        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.9min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #5
# Mean negativities for all classes: [0.2732151557801644]
# Mean entropies for all classes: [2.1735921607623077e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.55      0.60      0.57        20
#          1.0       0.56      0.50      0.53        20
#
#     accuracy                           0.55        40
#    macro avg       0.55      0.55      0.55        40
# weighted avg       0.55      0.55      0.55        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  3.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #6
# Mean negativities for all classes: [0.24144496075120908]
# Mean entropies for all classes: [8.247972758911812e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.25      0.15      0.19        20
#          1.0       0.39      0.55      0.46        20
#
#     accuracy                           0.35        40
#    macro avg       0.32      0.35      0.32        40
# weighted avg       0.32      0.35      0.32        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.9min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #7
# Mean negativities for all classes: [0.22648383903252628]
# Mean entropies for all classes: [2.3421031578924466e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.43      0.65      0.52        20
#          1.0       0.30      0.15      0.20        20
#
#     accuracy                           0.40        40
#    macro avg       0.37      0.40      0.36        40
# weighted avg       0.37      0.40      0.36        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  3.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #8
# Mean negativities for all classes: [0.2697775498512575]
# Mean entropies for all classes: [1.8611655721839143e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.48      0.65      0.55        20
#          1.0       0.46      0.30      0.36        20
#
#     accuracy                           0.48        40
#    macro avg       0.47      0.47      0.46        40
# weighted avg       0.47      0.47      0.46        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  3.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #9
# Mean negativities for all classes: [0.0017447091844384587]
# Mean entropies for all classes: [2.8598834580232542e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.20      0.29        20
#          1.0       0.50      0.80      0.62        20
#
#     accuracy                           0.50        40
#    macro avg       0.50      0.50      0.45        40
# weighted avg       0.50      0.50      0.45        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.45499999999999996 F1-Scores = 0.4220455862087711 Negativity = [0.285159686944836, 0.0013550245922595433] Entropy = [2.255557970887109e-15, 2.8800203598879764e-15]
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  3.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #0
# Mean negativities for all classes: [0.21673181511701686]
# Mean entropies for all classes: [2.911348684989795e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.59      0.65      0.62        20
#          1.0       0.61      0.55      0.58        20
#
#     accuracy                           0.60        40
#    macro avg       0.60      0.60      0.60        40
# weighted avg       0.60      0.60      0.60        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  3.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #1
# Mean negativities for all classes: [0.0016181490465872277]
# Mean entropies for all classes: [2.4746772015740768e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.51      0.90      0.65        20
#          1.0       0.60      0.15      0.24        20
#
#     accuracy                           0.53        40
#    macro avg       0.56      0.53      0.45        40
# weighted avg       0.56      0.53      0.45        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  3.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #2
# Mean negativities for all classes: [0.2573556498567774]
# Mean entropies for all classes: [1.695129837803521e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.48      0.60      0.53        20
#          1.0       0.47      0.35      0.40        20
#
#     accuracy                           0.48        40
#    macro avg       0.47      0.47      0.47        40
# weighted avg       0.47      0.47      0.47        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  3.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #3
# Mean negativities for all classes: [0.2791358127264064]
# Mean entropies for all classes: [1.9189659564679183e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.47      0.45      0.46        20
#          1.0       0.48      0.50      0.49        20
#
#     accuracy                           0.48        40
#    macro avg       0.47      0.47      0.47        40
# weighted avg       0.47      0.47      0.47        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.8min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #4
# Mean negativities for all classes: [0.27098888611490046]
# Mean entropies for all classes: [2.910788269860568e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.52      0.60      0.56        20
#          1.0       0.53      0.45      0.49        20
#
#     accuracy                           0.53        40
#    macro avg       0.53      0.53      0.52        40
# weighted avg       0.53      0.53      0.52        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.7min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #5
# Mean negativities for all classes: [0.2587908735805368]
# Mean entropies for all classes: [2.0141373624283143e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.47      0.70      0.56        20
#          1.0       0.40      0.20      0.27        20
#
#     accuracy                           0.45        40
#    macro avg       0.43      0.45      0.41        40
# weighted avg       0.43      0.45      0.41        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.5min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #6
# Mean negativities for all classes: [0.2312622682874778]
# Mean entropies for all classes: [2.2131084821712513e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.47      0.75      0.58        20
#          1.0       0.38      0.15      0.21        20
#
#     accuracy                           0.45        40
#    macro avg       0.42      0.45      0.40        40
# weighted avg       0.42      0.45      0.40        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #7
# Mean negativities for all classes: [0.26789833984084876]
# Mean entropies for all classes: [1.5693014548236293e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.46      0.60      0.52        20
#          1.0       0.43      0.30      0.35        20
#
#     accuracy                           0.45        40
#    macro avg       0.45      0.45      0.44        40
# weighted avg       0.45      0.45      0.44        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #8
# Mean negativities for all classes: [0.27733774319414384]
# Mean entropies for all classes: [2.0456556995149292e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.48      0.55      0.51        20
#          1.0       0.47      0.40      0.43        20
#
#     accuracy                           0.48        40
#    macro avg       0.47      0.48      0.47        40
# weighted avg       0.47      0.47      0.47        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #9
# Mean negativities for all classes: [0.27641727476390043]
# Mean entropies for all classes: [1.9045121928572663e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.56      0.70      0.62        20
#          1.0       0.60      0.45      0.51        20
#
#     accuracy                           0.57        40
#    macro avg       0.58      0.57      0.57        40
# weighted avg       0.58      0.57      0.57        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.5 F1-Scores = 0.47964835885014256 Negativity = [0.21673181511701686, 0.0016181490465872277] Entropy = [2.911348684989795e-15, 2.4746772015740768e-15]
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #0
# Mean negativities for all classes: [0.23933915501567143]
# Mean entropies for all classes: [2.7705531920622298e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.33      0.15      0.21        20
#          1.0       0.45      0.70      0.55        20
#
#     accuracy                           0.42        40
#    macro avg       0.39      0.42      0.38        40
# weighted avg       0.39      0.42      0.38        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #1
# Mean negativities for all classes: [0.0011001821610726076]
# Mean entropies for all classes: [2.28476620194614e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.42      0.25      0.31        20
#          1.0       0.46      0.65      0.54        20
#
#     accuracy                           0.45        40
#    macro avg       0.44      0.45      0.43        40
# weighted avg       0.44      0.45      0.43        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #2
# Mean negativities for all classes: [0.06371341411155718]
# Mean entropies for all classes: [1.5939576929668222e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00        20
#          1.0       0.50      1.00      0.67        20
#
#     accuracy                           0.50        40
#    macro avg       0.25      0.50      0.33        40
# weighted avg       0.25      0.50      0.33        40
#
# ...
#
#     accuracy                           0.48        40
#    macro avg       0.41      0.48      0.36        40
# weighted avg       0.41      0.47      0.36        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #3
# Mean negativities for all classes: [0.0011930371955977653]
# Mean entropies for all classes: [3.19876583719536e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.27      0.15      0.19        20
#          1.0       0.41      0.60      0.49        20
#
#     accuracy                           0.38        40
#    macro avg       0.34      0.38      0.34        40
# weighted avg       0.34      0.38      0.34        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #4
# Mean negativities for all classes: [0.2549536066632364]
# Mean entropies for all classes: [1.877811999490458e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.41      0.55      0.47        20
#          1.0       0.31      0.20      0.24        20
#
#     accuracy                           0.38        40
#    macro avg       0.36      0.38      0.36        40
# weighted avg       0.36      0.38      0.36        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #5
# Mean negativities for all classes: [0.22923756136864437]
# Mean entropies for all classes: [1.6388269884414956e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.85      0.63        20
#          1.0       0.50      0.15      0.23        20
#
#     accuracy                           0.50        40
#    macro avg       0.50      0.50      0.43        40
# weighted avg       0.50      0.50      0.43        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #6
# Mean negativities for all classes: [0.05598369188027299]
# Mean entropies for all classes: [2.6417878596612516e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00        20
#          1.0       0.50      1.00      0.67        20
#
#     accuracy                           0.50        40
#    macro avg       0.25      0.50      0.33        40
# weighted avg       0.25      0.50      0.33        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #7
# Mean negativities for all classes: [0.2702951168837109]
# Mean entropies for all classes: [2.2216135249285335e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.48      0.55      0.51        20
#          1.0       0.47      0.40      0.43        20
#
#     accuracy                           0.48        40
#    macro avg       0.47      0.48      0.47        40
# weighted avg       0.47      0.47      0.47        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #8
# Mean negativities for all classes: [0.2642572726855296]
# Mean entropies for all classes: [2.458052944716054e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.45      0.50      0.48        20
#          1.0       0.44      0.40      0.42        20
#
#     accuracy                           0.45        40
#    macro avg       0.45      0.45      0.45        40
# weighted avg       0.45      0.45      0.45        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# K-Fold #9
# Mean negativities for all classes: [0.11468632954695908]
# Mean entropies for all classes: [2.3786251212216003e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00        20
#          1.0       0.47      0.90      0.62        20
#
#     accuracy                           0.45        40
#    macro avg       0.24      0.45      0.31        40
# weighted avg       0.24      0.45      0.31        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.45 F1-Scores = 0.3923640543064384 Negativity = [0.2799891794545863, 0.2179101099648389] Entropy = [1.8662429629303694e-15, 2.334740569030728e-15]
# CPU times: total: 13.1 s
# Wall time: 7h 18min 12s
# Media Score dos N K-Fold 0.45599999999999996
# Maior Score dos K-Fold 0.5
# Menor Score dos K-Fold 0.4425
#
#
# [[0.375, 0.475, 0.425, 0.475, 0.475, 0.525, 0.35, 0.525, 0.4, 0.425], [0.4, 0.45, 0.5, 0.5, 0.475, 0.55, 0.45, 0.45, 0.425, 0.4], [0.45, 0.525, 0.45, 0.475, 0.475, 0.475, 0.475, 0.35, 0.35, 0.475], [0.35, 0.475, 0.45, 0.4, 0.475, 0.45, 0.45, 0.425, 0.475, 0.5], [0.55, 0.45, 0.4, 0.5, 0.375, 0.55, 0.35, 0.4, 0.475, 0.5], [0.6, 0.525, 0.475, 0.475, 0.525, 0.45, 0.45, 0.45, 0.475, 0.575], [0.425, 0.45, 0.5, 0.475, 0.475, 0.425, 0.45, 0.5, 0.475, 0.375], [0.35, 0.5, 0.4, 0.5, 0.35, 0.45, 0.45, 0.525, 0.475, 0.425], [0.4, 0.425, 0.5, 0.4, 0.525, 0.45, 0.475, 0.5, 0.425, 0.525], [0.5, 0.35, 0.425, 0.5, 0.5, 0.425, 0.475, 0.45, 0.5, 0.475], [0.375, 0.5, 0.45, 0.475, 0.425, 0.475, 0.475, 0.425, 0.425, 0.475], [0.525, 0.475, 0.475, 0.45, 0.475, 0.475, 0.4, 0.425, 0.425, 0.45], [0.5, 0.5, 0.425, 0.5, 0.4, 0.5, 0.425, 0.45, 0.4, 0.45], [0.45, 0.4, 0.425, 0.45, 0.525, 0.4, 0.45, 0.5, 0.425, 0.45], [0.5, 0.5, 0.475, 0.5, 0.475, 0.45, 0.325, 0.5, 0.525, 0.35], [0.45, 0.425, 0.35, 0.575, 0.375, 0.475, 0.425, 0.475, 0.45, 0.45], [0.475, 0.5, 0.45, 0.325, 0.475, 0.5, 0.475, 0.425, 0.55, 0.45], [0.45, 0.525, 0.4, 0.425, 0.45, 0.5, 0.425, 0.45, 0.4, 0.45], [0.5, 0.475, 0.425, 0.475, 0.5, 0.425, 0.525, 0.5, 0.4, 0.475], [0.35, 0.55, 0.475, 0.375, 0.375, 0.5, 0.5, 0.475, 0.45, 0.45]]
-15]
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.40      0.44        20
#          1.0       0.50      0.60      0.55        20
#
#     accuracy                           0.50        40
#    macro avg       0.50      0.50      0.49        40
# weighted avg       0.50      0.50      0.49        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #9
# Mean negativities for all classes: [0.0465520346997888]
# Mean entropies for all classes: [2.0018476082207093e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00        20
#          1.0       0.49      0.95      0.64        20
#
#     accuracy                           0.48        40
#    macro avg       0.24      0.47      0.32        40
# weighted avg       0.24      0.47      0.32        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.4574999999999999 F1-Scores = 0.41135021984206227 Negativity = [0.1976368789704848, 0.22153466317834686] Entropy = [3.2312940536583394e-15, 1.5651871044494376e-15]
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #0
# Mean negativities for all classes: [0.06708425281029388]
# Mean entropies for all classes: [1.590637221216904e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00        20
#          1.0       0.50      1.00      0.67        20
#
#     accuracy                           0.50        40
#    macro avg       0.25      0.50      0.33        40
# weighted avg       0.25      0.50      0.33        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #1
# Mean negativities for all classes: [0.215377598834059]
# Mean entropies for all classes: [1.3714238787087548e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.48      0.50      0.49        20
#          1.0       0.47      0.45      0.46        20
#
#     accuracy                           0.48        40
#    macro avg       0.47      0.47      0.47        40
# weighted avg       0.47      0.47      0.47        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #2
# Mean negativities for all classes: [0.001903183013217674]
# Mean entropies for all classes: [2.1136518630322137e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.47      0.45      0.46        20
#          1.0       0.48      0.50      0.49        20
#
#     accuracy                           0.48        40
#    macro avg       0.47      0.47      0.47        40
# weighted avg       0.47      0.47      0.47        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #3
# Mean negativities for all classes: [0.22791249149934734]
# Mean entropies for all classes: [1.804549835311179e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.52      0.55      0.54        20
#          1.0       0.53      0.50      0.51        20
#
#     accuracy                           0.53        40
#    macro avg       0.53      0.53      0.52        40
# weighted avg       0.53      0.53      0.52        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #4
# Mean negativities for all classes: [0.2223844451257968]
# Mean entropies for all classes: [1.4794283284691519e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.38      0.40      0.39        20
#          1.0       0.37      0.35      0.36        20
#
#     accuracy                           0.38        40
#    macro avg       0.37      0.38      0.37        40
# weighted avg       0.37      0.38      0.37        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #5
# Mean negativities for all classes: [0.07602875274964854]
# Mean entropies for all classes: [1.8808581418353475e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.62      0.25      0.36        20
#          1.0       0.53      0.85      0.65        20
#
#     accuracy                           0.55        40
#    macro avg       0.58      0.55      0.51        40
# weighted avg       0.58      0.55      0.51        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #6
# Mean negativities for all classes: [0.21996077366713465]
# Mean entropies for all classes: [1.8600324452749984e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.47      0.40      0.43        20
#          1.0       0.48      0.55      0.51        20
#
#     accuracy                           0.48        40
#    macro avg       0.47      0.48      0.47        40
# weighted avg       0.47      0.47      0.47        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #7
# Mean negativities for all classes: [0.025073399930622946]
# Mean entropies for all classes: [2.571404710933688e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00        20
#          1.0       0.49      0.95      0.64        20
#
#     accuracy                           0.48        40
#    macro avg       0.24      0.47      0.32        40
# weighted avg       0.24      0.47      0.32        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #8
# Mean negativities for all classes: [0.10206784073504094]
# Mean entropies for all classes: [2.2533229227925506e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.44      0.40      0.42        20
#          1.0       0.45      0.50      0.48        20
#
#     accuracy                           0.45        40
#    macro avg       0.45      0.45      0.45        40
# weighted avg       0.45      0.45      0.45        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #9
# Mean negativities for all classes: [0.2207036154093233]
# Mean entropies for all classes: [1.470373492005861e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.38      0.45      0.41        20
#          1.0       0.31      0.25      0.28        20
#
#     accuracy                           0.35        40
#    macro avg       0.34      0.35      0.34        40
# weighted avg       0.34      0.35      0.34        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.46499999999999997 F1-Scores = 0.4273603213787586 Negativity = [0.06708425281029388, 0.215377598834059] Entropy = [1.590637221216904e-15, 1.3714238787087548e-15]
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #0
# Mean negativities for all classes: [0.22192460066631953]
# Mean entropies for all classes: [1.3952728871899317e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.55      0.52        20
#          1.0       0.50      0.45      0.47        20
#
#     accuracy                           0.50        40
#    macro avg       0.50      0.50      0.50        40
# weighted avg       0.50      0.50      0.50        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #1
# Mean negativities for all classes: [0.21676092557736992]
# Mean entropies for all classes: [1.593554702704148e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.48      0.50      0.49        20
#          1.0       0.47      0.45      0.46        20
#
#     accuracy                           0.48        40
#    macro avg       0.47      0.47      0.47        40
# weighted avg       0.47      0.47      0.47        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #2
# Mean negativities for all classes: [0.21562502065542982]
# Mean entropies for all classes: [1.939831307045213e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.45      0.45      0.45        20
#          1.0       0.45      0.45      0.45        20
#
#     accuracy                           0.45        40
#    macro avg       0.45      0.45      0.45        40
# weighted avg       0.45      0.45      0.45        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #3
# Mean negativities for all classes: [0.17625911965591085]
# Mean entropies for all classes: [2.058104998562173e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.20      0.05      0.08        20
#          1.0       0.46      0.80      0.58        20
#
#     accuracy                           0.42        40
#    macro avg       0.33      0.43      0.33        40
# weighted avg       0.33      0.42      0.33        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #4
# Mean negativities for all classes: [0.004873190910456271]
# Mean entropies for all classes: [2.776297728597002e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.47      0.45      0.46        20
#          1.0       0.48      0.50      0.49        20
#
#     accuracy                           0.48        40
#    macro avg       0.47      0.47      0.47        40
# weighted avg       0.47      0.47      0.47        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #5
# Mean negativities for all classes: [0.22465921029105362]
# Mean entropies for all classes: [1.8960426216036432e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.46      0.55      0.50        20
#          1.0       0.44      0.35      0.39        20
#
#     accuracy                           0.45        40
#    macro avg       0.45      0.45      0.44        40
# weighted avg       0.45      0.45      0.44        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #6
# Mean negativities for all classes: [0.21546380366803292]
# Mean entropies for all classes: [1.8082635814612927e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.53      0.45      0.49        20
#          1.0       0.52      0.60      0.56        20
#
#     accuracy                           0.53        40
#    macro avg       0.53      0.53      0.52        40
# weighted avg       0.53      0.53      0.52        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #7
# Mean negativities for all classes: [0.23565532354413704]
# Mean entropies for all classes: [1.6696656716708888e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.54      0.65      0.59        20
#          1.0       0.56      0.45      0.50        20
#
#     accuracy                           0.55        40
#    macro avg       0.55      0.55      0.55        40
# weighted avg       0.55      0.55      0.55        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #8
# Mean negativities for all classes: [0.23017714317456486]
# Mean entropies for all classes: [1.866815375982879e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.39      0.35      0.37        20
#          1.0       0.41      0.45      0.43        20
#
#     accuracy                           0.40        40
#    macro avg       0.40      0.40      0.40        40
# weighted avg       0.40      0.40      0.40        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #9
# Mean negativities for all classes: [0.22119120398898984]
# Mean entropies for all classes: [1.8936601248018997e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.45      0.45      0.45        20
#          1.0       0.45      0.45      0.45        20
#
#     accuracy                           0.45        40
#    macro avg       0.45      0.45      0.45        40
# weighted avg       0.45      0.45      0.45        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.47000000000000003 F1-Scores = 0.4589707538849851 Negativity = [0.22192460066631953, 0.21676092557736992] Entropy = [1.3952728871899317e-15, 1.593554702704148e-15]
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #0
# Mean negativities for all classes: [0.22165014049120918]
# Mean entropies for all classes: [1.5029608514065395e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.35      0.35      0.35        20
#          1.0       0.35      0.35      0.35        20
#
#     accuracy                           0.35        40
#    macro avg       0.35      0.35      0.35        40
# weighted avg       0.35      0.35      0.35        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #1
# Mean negativities for all classes: [0.1370028627935314]
# Mean entropies for all classes: [2.8669399556981194e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.33      0.25      0.29        20
#          1.0       0.40      0.50      0.44        20
#
#     accuracy                           0.38        40
#    macro avg       0.37      0.38      0.37        40
# weighted avg       0.37      0.38      0.37        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #2
# Mean negativities for all classes: [0.22293393622652885]
# Mean entropies for all classes: [1.6362061734301488e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.48      0.50      0.49        20
#          1.0       0.47      0.45      0.46        20
#
#     accuracy                           0.48        40
#    macro avg       0.47      0.47      0.47        40
# weighted avg       0.47      0.47      0.47        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #3
# Mean negativities for all classes: [0.16876553017626192]
# Mean entropies for all classes: [2.1570485089194322e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.40      0.20      0.27        20
#          1.0       0.47      0.70      0.56        20
#
#     accuracy                           0.45        40
#    macro avg       0.43      0.45      0.41        40
# weighted avg       0.43      0.45      0.41        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #4
# Mean negativities for all classes: [0.0016887997165115159]
# Mean entropies for all classes: [2.0849943957426238e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.48      0.50      0.49        20
#          1.0       0.47      0.45      0.46        20
#
#     accuracy                           0.48        40
#    macro avg       0.47      0.47      0.47        40
# weighted avg       0.47      0.47      0.47        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #5
# Mean negativities for all classes: [0.22997310519082856]
# Mean entropies for all classes: [1.904238830165815e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.45      0.45      0.45        20
#          1.0       0.45      0.45      0.45        20
#
#     accuracy                           0.45        40
#    macro avg       0.45      0.45      0.45        40
# weighted avg       0.45      0.45      0.45        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #6
# Mean negativities for all classes: [0.06705099423173887]
# Mean entropies for all classes: [1.5445317022547421e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00        20
#          1.0       0.50      1.00      0.67        20
#
#     accuracy                           0.50        40
#    macro avg       0.25      0.50      0.33        40
# weighted avg       0.25      0.50      0.33        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #7
# Mean negativities for all classes: [0.1804353858399585]
# Mean entropies for all classes: [2.6844876272606004e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.33      0.15      0.21        20
#          1.0       0.45      0.70      0.55        20
#
#     accuracy                           0.42        40
#    macro avg       0.39      0.42      0.38        40
# weighted avg       0.39      0.42      0.38        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #8
# Mean negativities for all classes: [0.23481351630063924]
# Mean entropies for all classes: [1.9726154786302177e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.50      0.50        20
#          1.0       0.50      0.50      0.50        20
#
#     accuracy                           0.50        40
#    macro avg       0.50      0.50      0.50        40
# weighted avg       0.50      0.50      0.50        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #9
# Mean negativities for all classes: [0.18174828114377223]
# Mean entropies for all classes: [1.3974670879451547e-15]
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.05      0.10        20
#          1.0       0.51      1.00      0.68        20
#
#     accuracy                           0.53        40
#    macro avg       0.76      0.53      0.39        40
# weighted avg       0.76      0.53      0.39        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.4525 F1-Scores = 0.4125649549583417 Negativity = [0.22165014049120918, 0.1370028627935314] Entropy = [1.5029608514065395e-15, 2.8669399556981194e-15]
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #0
# Mean negativities for all classes: [0.03621296133219639]
# Mean entropies for all classes: [2.041324548763313e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.40      0.10      0.16        20
#          1.0       0.49      0.85      0.62        20
#
#     accuracy                           0.48        40
#    macro avg       0.44      0.47      0.39        40
# weighted avg       0.44      0.47      0.39        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #1
# Mean negativities for all classes: [0.0005338189674990751]
# Mean entropies for all classes: [2.229233841270604e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.45      0.50      0.48        20
#          1.0       0.44      0.40      0.42        20
#
#     accuracy                           0.45        40
#    macro avg       0.45      0.45      0.45        40
# weighted avg       0.45      0.45      0.45        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #2
# Mean negativities for all classes: [0.17887370398317234]
# Mean entropies for all classes: [2.7732523369453533e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.20      0.29        20
#          1.0       0.50      0.80      0.62        20
#
#     accuracy                           0.50        40
#    macro avg       0.50      0.50      0.45        40
# weighted avg       0.50      0.50      0.45        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #3
# Mean negativities for all classes: [0.06615839089027618]
# Mean entropies for all classes: [2.241700302334933e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00        20
#          1.0       0.50      1.00      0.67        20
#
#     accuracy                           0.50        40
#    macro avg       0.25      0.50      0.33        40
# weighted avg       0.25      0.50      0.33        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #4
# Mean negativities for all classes: [0.2191741805881482]
# Mean entropies for all classes: [1.5170972885259343e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.40      0.40      0.40        20
#          1.0       0.40      0.40      0.40        20
#
#     accuracy                           0.40        40
#    macro avg       0.40      0.40      0.40        40
# weighted avg       0.40      0.40      0.40        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #5
# Mean negativities for all classes: [0.07899754756204637]
# Mean entropies for all classes: [2.08871863440089e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.40      0.44        20
#          1.0       0.50      0.60      0.55        20
#
#     accuracy                           0.50        40
#    macro avg       0.50      0.50      0.49        40
# weighted avg       0.50      0.50      0.49        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #6
# Mean negativities for all classes: [0.000958569952665389]
# Mean entropies for all classes: [2.176013164396957e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.22      0.10      0.14        20
#          1.0       0.42      0.65      0.51        20
#
#     accuracy                           0.38        40
#    macro avg       0.32      0.38      0.32        40
# weighted avg       0.32      0.38      0.32        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #7
# Mean negativities for all classes: [0.02754338589280463]
# Mean entropies for all classes: [2.236630462961037e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00        20
#          1.0       0.50      1.00      0.67        20
#
#     accuracy                           0.50        40
#    macro avg       0.25      0.50      0.33        40
# weighted avg       0.25      0.50      0.33        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #8
# Mean negativities for all classes: [0.22667996647792316]
# Mean entropies for all classes: [1.6389404247565195e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.45      0.50      0.48        20
#          1.0       0.44      0.40      0.42        20
#
#     accuracy                           0.45        40
#    macro avg       0.45      0.45      0.45        40
# weighted avg       0.45      0.45      0.45        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #9
# Mean negativities for all classes: [0.2261041114608701]
# Mean entropies for all classes: [1.7675065967393022e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.55      0.52        20
#          1.0       0.50      0.45      0.47        20
#
#     accuracy                           0.50        40
#    macro avg       0.50      0.50      0.50        40
# weighted avg       0.50      0.50      0.50        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.465 F1-Scores = 0.4121113974219558 Negativity = [0.03621296133219639, 0.0005338189674990751] Entropy = [2.041324548763313e-15, 2.229233841270604e-15]
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #0
# Mean negativities for all classes: [0.18667794103831786]
# Mean entropies for all classes: [2.0451920352692296e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.30      0.15      0.20        20
#          1.0       0.43      0.65      0.52        20
#
#     accuracy                           0.40        40
#    macro avg       0.37      0.40      0.36        40
# weighted avg       0.37      0.40      0.36        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #1
# Mean negativities for all classes: [0.2244555571540241]
# Mean entropies for all classes: [2.1138205987275835e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.40      0.30      0.34        20
#          1.0       0.44      0.55      0.49        20
#
#     accuracy                           0.42        40
#    macro avg       0.42      0.43      0.42        40
# weighted avg       0.42      0.42      0.42        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #2
# Mean negativities for all classes: [0.10739241894520087]
# Mean entropies for all classes: [2.0341220226741292e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.45      0.47        20
#          1.0       0.50      0.55      0.52        20
#
#     accuracy                           0.50        40
#    macro avg       0.50      0.50      0.50        40
# weighted avg       0.50      0.50      0.50        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #3
# Mean negativities for all classes: [0.22068481302195025]
# Mean entropies for all classes: [1.6287668771363805e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.53      0.45      0.49        20
#          1.0       0.52      0.60      0.56        20
#
#     accuracy                           0.53        40
#    macro avg       0.53      0.53      0.52        40
# weighted avg       0.53      0.53      0.52        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #4
# Mean negativities for all classes: [0.04242221566766702]
# Mean entropies for all classes: [1.8888670170519724e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00        20
#          1.0       0.50      1.00      0.67        20
#
#     accuracy                           0.50        40
#    macro avg       0.25      0.50      0.33        40
# weighted avg       0.25      0.50      0.33        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #5
# Mean negativities for all classes: [0.22072522612446838]
# Mean entropies for all classes: [1.833406342198493e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.43      0.50      0.47        20
#          1.0       0.41      0.35      0.38        20
#
#     accuracy                           0.42        40
#    macro avg       0.42      0.42      0.42        40
# weighted avg       0.42      0.42      0.42        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #6
# Mean negativities for all classes: [0.22103436001535534]
# Mean entropies for all classes: [9.589905601249372e-16]
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.50      0.50        20
#          1.0       0.50      0.50      0.50        20
#
#     accuracy                           0.50        40
#    macro avg       0.50      0.50      0.50        40
# weighted avg       0.50      0.50      0.50        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #7
# Mean negativities for all classes: [0.21530712653081965]
# Mean entropies for all classes: [1.6441707178532144e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.48      0.60      0.53        20
#          1.0       0.47      0.35      0.40        20
#
#     accuracy                           0.48        40
#    macro avg       0.47      0.47      0.47        40
# weighted avg       0.47      0.47      0.47        40
#
# ...
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #1
# Mean negativities for all classes: [0.174843036149247]
# Mean entropies for all classes: [1.986851736136498e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.60      0.15      0.24        20
#          1.0       0.51      0.90      0.65        20
#
#     accuracy                           0.53        40
#    macro avg       0.56      0.53      0.45        40
# weighted avg       0.56      0.53      0.45        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #2
# Mean negativities for all classes: [0.0005713367900165578]
# Mean entropies for all classes: [2.2492995707545866e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.46      0.55      0.50        20
#          1.0       0.44      0.35      0.39        20
#
#     accuracy                           0.45        40
#    macro avg       0.45      0.45      0.44        40
# weighted avg       0.45      0.45      0.44        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #3
# Mean negativities for all classes: [0.07762515417023955]
# Mean entropies for all classes: [2.1222148000572833e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.46      0.30      0.36        20
#          1.0       0.48      0.65      0.55        20
#
#     accuracy                           0.48        40
#    macro avg       0.47      0.47      0.46        40
# weighted avg       0.47      0.47      0.46        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #4
# Mean negativities for all classes: [0.22414616283266403]
# Mean entropies for all classes: [1.5760503715676636e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.42      0.50      0.45        20
#          1.0       0.38      0.30      0.33        20
#
#     accuracy                           0.40        40
#    macro avg       0.40      0.40      0.39        40
# weighted avg       0.40      0.40      0.39        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #5
# Mean negativities for all classes: [0.18579617620491037]
# Mean entropies for all classes: [2.1129617287804656e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.33      0.10      0.15        20
#          1.0       0.47      0.80      0.59        20
#
#     accuracy                           0.45        40
#    macro avg       0.40      0.45      0.37        40
# weighted avg       0.40      0.45      0.37        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #6
# Mean negativities for all classes: [0.07799757083559837]
# Mean entropies for all classes: [2.5537867562383852e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.40      0.20      0.27        20
#          1.0       0.47      0.70      0.56        20
#
#     accuracy                           0.45        40
#    macro avg       0.43      0.45      0.41        40
# weighted avg       0.43      0.45      0.41        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #7
# Mean negativities for all classes: [0.22077786463907173]
# Mean entropies for all classes: [1.5084655397174255e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.47      0.45      0.46        20
#          1.0       0.48      0.50      0.49        20
#
#     accuracy                           0.48        40
#    macro avg       0.47      0.47      0.47        40
# weighted avg       0.47      0.47      0.47        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #8
# Mean negativities for all classes: [0.16219640153470363]
# Mean entropies for all classes: [2.1941202094150204e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00        20
#          1.0       0.49      0.95      0.64        20
#
#     accuracy                           0.48        40
#    macro avg       0.24      0.47      0.32        40
# weighted avg       0.24      0.47      0.32        40
#
# -------------------------------------------------------------------------------------------------------------------
# K-Fold #9
# Mean negativities for all classes: [0.22653879460886986]
# Mean entropies for all classes: [1.584358944266185e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.45      0.45      0.45        20
#          1.0       0.45      0.45      0.45        20
#
#     accuracy                           0.45        40
#    macro avg       0.45      0.45      0.45        40
# weighted avg       0.45      0.45      0.45        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.4575 F1-Scores = 0.4199076095531084 Negativity = [0.22599829886685416, 0.174843036149247] Entropy = [2.320420325664134e-15, 1.986851736136498e-15]
# CPU times: total: 13.4 s
# Wall time: 7h 4min 15s
# Media Score dos N K-Fold 0.4583749999999999
# Maior Score dos K-Fold 0.485
# Menor Score dos K-Fold 0.425
#
#
# [[0.3, 0.45, 0.425, 0.525, 0.475, 0.5, 0.45, 0.475, 0.5, 0.475], [0.5, 0.475, 0.475, 0.525, 0.375, 0.55, 0.475, 0.475, 0.45, 0.35], [0.5, 0.475, 0.45, 0.425, 0.475, 0.45, 0.525, 0.55, 0.4, 0.45], [0.35, 0.375, 0.475, 0.45, 0.475, 0.45, 0.5, 0.425, 0.5, 0.525], [0.475, 0.45, 0.5, 0.5, 0.4, 0.5, 0.375, 0.5, 0.45, 0.5], [0.4, 0.425, 0.5, 0.525, 0.5, 0.425, 0.5, 0.475, 0.45, 0.425], [0.4, 0.45, 0.5, 0.5, 0.4, 0.45, 0.425, 0.5, 0.45, 0.375], [0.35, 0.5, 0.5, 0.4, 0.5, 0.475, 0.425, 0.45, 0.45, 0.5], [0.45, 0.45, 0.525, 0.375, 0.575, 0.475, 0.425, 0.45, 0.45, 0.5], [0.45, 0.425, 0.5, 0.5, 0.45, 0.425, 0.425, 0.5, 0.425, 0.5], [0.4, 0.55, 0.45, 0.45, 0.525, 0.5, 0.5, 0.5, 0.425, 0.5], [0.425, 0.475, 0.425, 0.45, 0.525, 0.525, 0.35, 0.425, 0.55, 0.45], [0.5, 0.4, 0.425, 0.475, 0.45, 0.425, 0.5, 0.425, 0.475
-15]
#               precision    recall  f1-score   support
#
#          0.0       0.35      0.35      0.35        20
#          1.0       0.35      0.35      0.35        20
#
#     accuracy                           0.35        40
#    macro avg       0.35      0.35      0.35        40
# weighted avg       0.35      0.35      0.35        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #5
# Mean negativities for all classes: [0.3187306130351905]
# Mean entropies for all classes: [-4.777227305281834e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.65      0.57        20
#          1.0       0.50      0.35      0.41        20
#
#     accuracy                           0.50        40
#    macro avg       0.50      0.50      0.49        40
# weighted avg       0.50      0.50      0.49        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #6
# Mean negativities for all classes: [0.17101533885156125]
# Mean entropies for all classes: [-1.9107918855326484e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.46      0.60      0.52        20
#          1.0       0.43      0.30      0.35        20
#
#     accuracy                           0.45        40
#    macro avg       0.45      0.45      0.44        40
# weighted avg       0.45      0.45      0.44        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #7
# Mean negativities for all classes: [0.22388982146419156]
# Mean entropies for all classes: [-1.1190620252170083e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.38      0.30      0.33        20
#          1.0       0.42      0.50      0.45        20
#
#     accuracy                           0.40        40
#    macro avg       0.40      0.40      0.39        40
# weighted avg       0.40      0.40      0.39        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #8
# Mean negativities for all classes: [0.34876125758680915]
# Mean entropies for all classes: [-3.2038866292210424e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.43      0.65      0.52        20
#          1.0       0.30      0.15      0.20        20
#
#     accuracy                           0.40        40
#    macro avg       0.37      0.40      0.36        40
# weighted avg       0.37      0.40      0.36        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #9
# Mean negativities for all classes: [0.3606526813469828]
# Mean entropies for all classes: [-5.147134834085978e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.90      0.64        20
#          1.0       0.50      0.10      0.17        20
#
#     accuracy                           0.50        40
#    macro avg       0.50      0.50      0.40        40
# weighted avg       0.50      0.50      0.40        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.4375 F1-Scores = 0.4075442212861353 Negativity = [0.29168063736542416, 0.169267979722253] Entropy = [-6.681608387085702e-15, 8.296834867585575e-16]
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #0
# Mean negativities for all classes: [0.23034872648581156]
# Mean entropies for all classes: [4.858494734050713e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.33      0.25      0.29        20
#          1.0       0.40      0.50      0.44        20
#
#     accuracy                           0.38        40
#    macro avg       0.37      0.38      0.37        40
# weighted avg       0.37      0.38      0.37        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #1
# Mean negativities for all classes: [0.23092218721444363]
# Mean entropies for all classes: [-2.3477732078236323e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.65      0.57        20
#          1.0       0.50      0.35      0.41        20
#
#     accuracy                           0.50        40
#    macro avg       0.50      0.50      0.49        40
# weighted avg       0.50      0.50      0.49        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #2
# Mean negativities for all classes: [0.22993284164669867]
# Mean entropies for all classes: [6.299349641010076e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.44      0.55      0.49        20
#          1.0       0.40      0.30      0.34        20
#
#     accuracy                           0.42        40
#    macro avg       0.42      0.43      0.42        40
# weighted avg       0.42      0.42      0.42        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #3
# Mean negativities for all classes: [0.11973561811029339]
# Mean entropies for all classes: [2.1393519502145387e-16]
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.65      0.57        20
#          1.0       0.50      0.35      0.41        20
#
#     accuracy                           0.50        40
#    macro avg       0.50      0.50      0.49        40
# weighted avg       0.50      0.50      0.49        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #4
# Mean negativities for all classes: [0.3096888129220181]
# Mean entropies for all classes: [3.520165084007034e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.75      0.60        20
#          1.0       0.50      0.25      0.33        20
#
#     accuracy                           0.50        40
#    macro avg       0.50      0.50      0.47        40
# weighted avg       0.50      0.50      0.47        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #5
# Mean negativities for all classes: [0.20746464065157683]
# Mean entropies for all classes: [4.279734387854346e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.70      0.58        20
#          1.0       0.50      0.30      0.37        20
#
#     accuracy                           0.50        40
#    macro avg       0.50      0.50      0.48        40
# weighted avg       0.50      0.50      0.48        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #6
# Mean negativities for all classes: [0.3200681778604503]
# Mean entropies for all classes: [-1.3818017513190684e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.75      0.60        20
#          1.0       0.50      0.25      0.33        20
#
#     accuracy                           0.50        40
#    macro avg       0.50      0.50      0.47        40
# weighted avg       0.50      0.50      0.47        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #7
# Mean negativities for all classes: [0.32413956129273985]
# Mean entropies for all classes: [-1.1867779604447552e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.39      0.55      0.46        20
#          1.0       0.25      0.15      0.19        20
#
#     accuracy                           0.35        40
#    macro avg       0.32      0.35      0.32        40
# weighted avg       0.32      0.35      0.32        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #8
# Mean negativities for all classes: [0.32071745379427846]
# Mean entropies for all classes: [1.6066023422102842e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.40      0.50      0.44        20
#          1.0       0.33      0.25      0.29        20
#
#     accuracy                           0.38        40
#    macro avg       0.37      0.38      0.37        40
# weighted avg       0.37      0.38      0.37        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #9
# Mean negativities for all classes: [0.3115162072369307]
# Mean entropies for all classes: [1.979065734182697e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.47      0.85      0.61        20
#          1.0       0.25      0.05      0.08        20
#
#     accuracy                           0.45        40
#    macro avg       0.36      0.45      0.35        40
# weighted avg       0.36      0.45      0.35        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.44750000000000006 F1-Scores = 0.42036686051232086 Negativity = [0.23034872648581156, 0.23092218721444363] Entropy = [4.858494734050713e-15, -2.3477732078236323e-15]
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #0
# Mean negativities for all classes: [0.3269096676198718]
# Mean entropies for all classes: [-2.94804572452504e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.70      0.58        20
#          1.0       0.50      0.30      0.37        20
#
#     accuracy                           0.50        40
#    macro avg       0.50      0.50      0.48        40
# weighted avg       0.50      0.50      0.48        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #1
# Mean negativities for all classes: [0.2783726977450563]
# Mean entropies for all classes: [-4.037355512802069e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.42      0.50      0.45        20
#          1.0       0.38      0.30      0.33        20
#
#     accuracy                           0.40        40
#    macro avg       0.40      0.40      0.39        40
# weighted avg       0.40      0.40      0.39        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #2
# Mean negativities for all classes: [0.2799741011132489]
# Mean entropies for all classes: [4.857715227541664e-17]
#               precision    recall  f1-score   support
#
#          0.0       0.30      0.35      0.33        20
#          1.0       0.24      0.20      0.22        20
#
#     accuracy                           0.28        40
#    macro avg       0.27      0.28      0.27        40
# weighted avg       0.27      0.28      0.27        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #3
# Mean negativities for all classes: [0.3338762851051331]
# Mean entropies for all classes: [-1.3753965110217529e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.46      0.55      0.50        20
#          1.0       0.44      0.35      0.39        20
#
#     accuracy                           0.45        40
#    macro avg       0.45      0.45      0.44        40
# weighted avg       0.45      0.45      0.44        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #4
# Mean negativities for all classes: [0.23299301586314275]
# Mean entropies for all classes: [-5.692728198092223e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.70      0.58        20
#          1.0       0.50      0.30      0.37        20
#
#     accuracy                           0.50        40
#    macro avg       0.50      0.50      0.48        40
# weighted avg       0.50      0.50      0.48        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #5
# Mean negativities for all classes: [0.2947196921324858]
# Mean entropies for all classes: [-1.977062756867669e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.47      0.70      0.56        20
#          1.0       0.40      0.20      0.27        20
#
#     accuracy                           0.45        40
#    macro avg       0.43      0.45      0.41        40
# weighted avg       0.43      0.45      0.41        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #6
# Mean negativities for all classes: [0.2594810866450373]
# Mean entropies for all classes: [1.1605816012744085e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.44      0.55      0.49        20
#          1.0       0.40      0.30      0.34        20
#
#     accuracy                           0.42        40
#    macro avg       0.42      0.43      0.42        40
# weighted avg       0.42      0.42      0.42        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #7
# Mean negativities for all classes: [0.2117671003658974]
# Mean entropies for all classes: [-2.089856028922187e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.70      0.58        20
#          1.0       0.50      0.30      0.37        20
#
#     accuracy                           0.50        40
#    macro avg       0.50      0.50      0.48        40
# weighted avg       0.50      0.50      0.48        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #8
# Mean negativities for all classes: [0.3132319386867415]
# Mean entropies for all classes: [2.976589431124578e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.70      0.58        20
#          1.0       0.50      0.30      0.37        20
#
#     accuracy                           0.50        40
#    macro avg       0.50      0.50      0.48        40
# weighted avg       0.50      0.50      0.48        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #9
# Mean negativities for all classes: [0.3238385267163735]
# Mean entropies for all classes: [-2.425091313719413e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.80      0.62        20
#          1.0       0.50      0.20      0.29        20
#
#     accuracy                           0.50        40
#    macro avg       0.50      0.50      0.45        40
# weighted avg       0.50      0.50      0.45        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.45 F1-Scores = 0.4305705110588831 Negativity = [0.3269096676198718, 0.2783726977450563] Entropy = [-2.94804572452504e-14, -4.037355512802069e-15]
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #0
# Mean negativities for all classes: [0.2535442798753437]
# Mean entropies for all classes: [2.87326778233164e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.46      0.60      0.52        20
#          1.0       0.43      0.30      0.35        20
#
#     accuracy                           0.45        40
#    macro avg       0.45      0.45      0.44        40
# weighted avg       0.45      0.45      0.44        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #1
# Mean negativities for all classes: [0.2497884037616552]
# Mean entropies for all classes: [2.775409589929522e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.47      0.85      0.61        20
#          1.0       0.25      0.05      0.08        20
#
#     accuracy                           0.45        40
#    macro avg       0.36      0.45      0.35        40
# weighted avg       0.36      0.45      0.35        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #2
# Mean negativities for all classes: [0.3187530121443821]
# Mean entropies for all classes: [2.9798763715658133e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.43      0.60      0.50        20
#          1.0       0.33      0.20      0.25        20
#
#     accuracy                           0.40        40
#    macro avg       0.38      0.40      0.38        40
# weighted avg       0.38      0.40      0.38        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #3
# Mean negativities for all classes: [0.23536698353164417]
# Mean entropies for all classes: [1.594943833209689e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.52      0.75      0.61        20
#          1.0       0.55      0.30      0.39        20
#
#     accuracy                           0.53        40
#    macro avg       0.53      0.53      0.50        40
# weighted avg       0.53      0.53      0.50        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #4
# Mean negativities for all classes: [0.33099680377199664]
# Mean entropies for all classes: [1.6400991199498628e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.46      0.55      0.50        20
#          1.0       0.44      0.35      0.39        20
#
#     accuracy                           0.45        40
#    macro avg       0.45      0.45      0.44        40
# weighted avg       0.45      0.45      0.44        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #5
# Mean negativities for all classes: [0.22319225775255144]
# Mean entropies for all classes: [-1.2238600201476407e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.44      0.40      0.42        20
#          1.0       0.45      0.50      0.48        20
#
#     accuracy                           0.45        40
#    macro avg       0.45      0.45      0.45        40
# weighted avg       0.45      0.45      0.45        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #6
# Mean negativities for all classes: [0.31378988903157534]
# Mean entropies for all classes: [-1.4237870665282547e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.44      0.40      0.42        20
#          1.0       0.45      0.50      0.48        20
#
#     accuracy                           0.45        40
#    macro avg       0.45      0.45      0.45        40
# weighted avg       0.45      0.45      0.45        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #7
# Mean negativities for all classes: [0.31216593871704934]
# Mean entropies for all classes: [-8.565384531449842e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.52      0.70      0.60        20
#          1.0       0.54      0.35      0.42        20
#
#     accuracy                           0.53        40
#    macro avg       0.53      0.52      0.51        40
# weighted avg       0.53      0.53      0.51        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #8
# Mean negativities for all classes: [0.31026410957313905]
# Mean entropies for all classes: [2.889345446775758e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.52      0.85      0.64        20
#          1.0       0.57      0.20      0.30        20
#
#     accuracy                           0.53        40
#    macro avg       0.54      0.53      0.47        40
# weighted avg       0.54      0.53      0.47        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #9
# Mean negativities for all classes: [0.3208759935410369]
# Mean entropies for all classes: [1.5051004171438763e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.42      0.55      0.48        20
#          1.0       0.36      0.25      0.29        20
#
#     accuracy                           0.40        40
#    macro avg       0.39      0.40      0.39        40
# weighted avg       0.39      0.40      0.39        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.4625000000000001 F1-Scores = 0.436402231296906 Negativity = [0.2535442798753437, 0.2497884037616552] Entropy = [2.87326778233164e-14, 2.775409589929522e-15]
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #0
# Mean negativities for all classes: [0.3009881737784131]
# Mean entropies for all classes: [7.018683419558154e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.47      0.85      0.61        20
#          1.0       0.25      0.05      0.08        20
#
#     accuracy                           0.45        40
#    macro avg       0.36      0.45      0.35        40
# weighted avg       0.36      0.45      0.35        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #1
# Mean negativities for all classes: [0.10521207337053984]
# Mean entropies for all classes: [5.575751255640936e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.22      0.10      0.14        20
#          1.0       0.42      0.65      0.51        20
#
#     accuracy                           0.38        40
#    macro avg       0.32      0.38      0.32        40
# weighted avg       0.32      0.38      0.32        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #2
# Mean negativities for all classes: [0.2669800440557685]
# Mean entropies for all classes: [-3.1486501569031908e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.44      0.60      0.51        20
#          1.0       0.38      0.25      0.30        20
#
#     accuracy                           0.42        40
#    macro avg       0.41      0.42      0.41        40
# weighted avg       0.41      0.42      0.41        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #3
# Mean negativities for all classes: [0.18413157105907146]
# Mean entropies for all classes: [-1.1256090702066335e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.48      0.60      0.53        20
#          1.0       0.47      0.35      0.40        20
#
#     accuracy                           0.48        40
#    macro avg       0.47      0.47      0.47        40
# weighted avg       0.47      0.47      0.47        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #4
# Mean negativities for all classes: [0.25734011835829607]
# Mean entropies for all classes: [-1.109711955512078e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.60      0.55        20
#          1.0       0.50      0.40      0.44        20
#
#     accuracy                           0.50        40
#    macro avg       0.50      0.50      0.49        40
# weighted avg       0.50      0.50      0.49        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #5
# Mean negativities for all classes: [0.16219152800479097]
# Mean entropies for all classes: [2.2233537694968494e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.33      0.30      0.32        20
#          1.0       0.36      0.40      0.38        20
#
#     accuracy                           0.35        40
#    macro avg       0.35      0.35      0.35        40
# weighted avg       0.35      0.35      0.35        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #6
# Mean negativities for all classes: [0.2478892691515658]
# Mean entropies for all classes: [-1.0991416941615896e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.48      0.55      0.51        20
#          1.0       0.47      0.40      0.43        20
#
#     accuracy                           0.48        40
#    macro avg       0.47      0.48      0.47        40
# weighted avg       0.47      0.47      0.47        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #7
# Mean negativities for all classes: [0.3605509886572339]
# Mean entropies for all classes: [-3.719689325107361e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.48      0.80      0.60        20
#          1.0       0.43      0.15      0.22        20
#
#     accuracy                           0.48        40
#    macro avg       0.46      0.48      0.41        40
# weighted avg       0.46      0.47      0.41        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #8
# Mean negativities for all classes: [0.2906344655723297]
# Mean entropies for all classes: [-4.038078456735061e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.41      0.55      0.47        20
#          1.0       0.31      0.20      0.24        20
#
#     accuracy                           0.38        40
#    macro avg       0.36      0.38      0.36        40
# weighted avg       0.36      0.38      0.36        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #9
# Mean negativities for all classes: [0.23626451939906978]
# Mean entropies for all classes: [-4.864062309611367e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.48      0.70      0.57        20
#          1.0       0.45      0.25      0.32        20
#
#     accuracy                           0.48        40
#    macro avg       0.47      0.47      0.45        40
# weighted avg       0.47      0.47      0.45        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.4374999999999999 F1-Scores = 0.4073214318616638 Negativity = [0.3009881737784131, 0.10521207337053984] Entropy = [7.018683419558154e-15, 5.575751255640936e-15]
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #0
# Mean negativities for all classes: [0.30928425906614]
# Mean entropies for all classes: [-4.7938748314772516e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.44      0.55      0.49        20
#          1.0       0.40      0.30      0.34        20
#
#     accuracy                           0.42        40
#    macro avg       0.42      0.43      0.42        40
# weighted avg       0.42      0.42      0.42        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #1
# Mean negativities for all classes: [0.13320673943479716]
# Mean entropies for all classes: [-9.110926330972707e-16]
#               precision    recall  f1-score   support
#
#          0.0       0.45      0.75      0.57        20
#          1.0       0.29      0.10      0.15        20
#
#     accuracy                           0.42        40
#    macro avg       0.37      0.42      0.36        40
# weighted avg       0.37      0.42      0.36        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #2
# Mean negativities for all classes: [0.2947968921054672]
# Mean entropies for all classes: [1.13787096575377e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.70      0.58        20
#          1.0       0.50      0.30      0.37        20
#
#     accuracy                           0.50        40
#    macro avg       0.50      0.50      0.48        40
# weighted avg       0.50      0.50      0.48        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #3
# Mean negativities for all classes: [0.28094928787237655]
# Mean entropies for all classes: [2.5026476992560858e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.38      0.25      0.30        20
#          1.0       0.44      0.60      0.51        20
#
#     accuracy                           0.42        40
#    macro avg       0.41      0.42      0.41        40
# weighted avg       0.41      0.42      0.41        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #4
# Mean negativities for all classes: [0.21883444546984823]
# Mean entropies for all classes: [-1.5852380905618356e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.40      0.50      0.44        20
#          1.0       0.33      0.25      0.29        20
#
#     accuracy                           0.38        40
#    macro avg       0.37      0.38      0.37        40
# weighted avg       0.37      0.38      0.37        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #5
# Mean negativities for all classes: [0.3271529566176123]
# Mean entropies for all classes: [2.1162293769938327e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.80      0.62        20
#          1.0       0.50      0.20      0.29        20
#
#     accuracy                           0.50        40
#    macro avg       0.50      0.50      0.45        40
# weighted avg       0.50      0.50      0.45        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #6
# Mean negativities for all classes: [0.3266518252199221]
# Mean entropies for all classes: [1.2054361094378398e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.53      0.80      0.64        20
#          1.0       0.60      0.30      0.40        20
#
#     accuracy                           0.55        40
#    macro avg       0.57      0.55      0.52        40
# weighted avg       0.57      0.55      0.52        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #7
# Mean negativities for all classes: [0.35722448383295136]
# Mean entropies for all classes: [-5.954704797106e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.44      0.75      0.56        20
#          1.0       0.17      0.05      0.08        20
#
#     accuracy                           0.40        40
#    macro avg       0.30      0.40      0.32        40
# weighted avg       0.30      0.40      0.32        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #8
# Mean negativities for all classes: [0.2380861816266428]
# Mean entropies for all classes: [2.0912104637551807e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.43      0.60      0.50        20
#          1.0       0.33      0.20      0.25        20
#
#     accuracy                           0.40        40
#    macro avg       0.38      0.40      0.38        40
# weighted avg       0.38      0.40      0.38        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #9
# Mean negativities for all classes: [0.22450367987579628]
# Mean entropies for all classes: [3.5805744440143784e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.48      0.75      0.59        20
#          1.0       0.44      0.20      0.28        20
#
#     accuracy                           0.48        40
#    macro avg       0.46      0.47      0.43        40
# weighted avg       0.46      0.47      0.43        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.44749999999999995 F1-Scores = 0.41178837383993205 Negativity = [0.30928425906614, 0.13320673943479716] Entropy = [-4.7938748314772516e-15, -9.110926330972707e-16]
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #0
# Mean negativities for all classes: [0.14001699642315563]
# Mean entropies for all classes: [-1.825844594782702e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.46      0.65      0.54        20
#          1.0       0.42      0.25      0.31        20
#
#     accuracy                           0.45        40
#    macro avg       0.44      0.45      0.43        40
# weighted avg       0.44      0.45      0.43        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #1
# Mean negativities for all classes: [0.3362163737319291]
# Mean entropies for all classes: [2.202853919028378e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.48      0.70      0.57        20
#          1.0       0.45      0.25      0.32        20
#
#     accuracy                           0.48        40
#    macro avg       0.47      0.47      0.45        40
# weighted avg       0.47      0.47      0.45        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #2
# Mean negativities for all classes: [0.22038392897051579]
# Mean entropies for all classes: [-4.435790628585188e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.43      0.30      0.35        20
#          1.0       0.46      0.60      0.52        20
#
#     accuracy                           0.45        40
#    macro avg       0.45      0.45      0.44        40
# weighted avg       0.45      0.45      0.44        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #3
# Mean negativities for all classes: [0.17726692438968292]
# Mean entropies for all classes: [2.2273744713100276e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.46      0.65      0.54        20
#          1.0       0.42      0.25      0.31        20
#
#     accuracy                           0.45        40
#    macro avg       0.44      0.45      0.43        40
# weighted avg       0.44      0.45      0.43        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #4
# Mean negativities for all classes: [0.12075750641752492]
# Mean entropies for all classes: [-1.3564212737671617e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.48      0.65      0.55        20
#          1.0       0.46      0.30      0.36        20
#
#     accuracy                           0.48        40
#    macro avg       0.47      0.47      0.46        40
# weighted avg       0.47      0.47      0.46        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #5
# Mean negativities for all classes: [0.19316203733790369]
# Mean entropies for all classes: [2.3956360390221e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.46      0.65      0.54        20
#          1.0       0.42      0.25      0.31        20
#
# ...
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #1
# Mean negativities for all classes: [0.13177991131002376]
# Mean entropies for all classes: [1.2924939577372309e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.47      0.70      0.56        20
#          1.0       0.40      0.20      0.27        20
#
#     accuracy                           0.45        40
#    macro avg       0.43      0.45      0.41        40
# weighted avg       0.43      0.45      0.41        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #2
# Mean negativities for all classes: [0.15680683423969857]
# Mean entropies for all classes: [-1.968098138126658e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.60      0.55        20
#          1.0       0.50      0.40      0.44        20
#
#     accuracy                           0.50        40
#    macro avg       0.50      0.50      0.49        40
# weighted avg       0.50      0.50      0.49        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #3
# Mean negativities for all classes: [0.26488401461353606]
# Mean entropies for all classes: [-1.9058031911813092e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.52      0.75      0.61        20
#          1.0       0.55      0.30      0.39        20
#
#     accuracy                           0.53        40
#    macro avg       0.53      0.53      0.50        40
# weighted avg       0.53      0.53      0.50        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #4
# Mean negativities for all classes: [0.1850920961551253]
# Mean entropies for all classes: [2.4585411531452088e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.45      0.65      0.53        20
#          1.0       0.36      0.20      0.26        20
#
#     accuracy                           0.42        40
#    macro avg       0.41      0.43      0.39        40
# weighted avg       0.41      0.42      0.39        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #5
# Mean negativities for all classes: [0.1247678268758293]
# Mean entropies for all classes: [4.028282500023557e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.39      0.35      0.37        20
#          1.0       0.41      0.45      0.43        20
#
#     accuracy                           0.40        40
#    macro avg       0.40      0.40      0.40        40
# weighted avg       0.40      0.40      0.40        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #6
# Mean negativities for all classes: [0.31775303090250595]
# Mean entropies for all classes: [1.5411372613367847e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.48      0.65      0.55        20
#          1.0       0.46      0.30      0.36        20
#
#     accuracy                           0.48        40
#    macro avg       0.47      0.47      0.46        40
# weighted avg       0.47      0.47      0.46        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #7
# Mean negativities for all classes: [0.3059873421448217]
# Mean entropies for all classes: [2.0120976634742406e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.90      0.64        20
#          1.0       0.50      0.10      0.17        20
#
#     accuracy                           0.50        40
#    macro avg       0.50      0.50      0.40        40
# weighted avg       0.50      0.50      0.40        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #8
# Mean negativities for all classes: [0.29041691495501476]
# Mean entropies for all classes: [7.244310225581694e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.48      0.65      0.55        20
#          1.0       0.46      0.30      0.36        20
#
#     accuracy                           0.48        40
#    macro avg       0.47      0.47      0.46        40
# weighted avg       0.47      0.47      0.46        40
#
# -------------------------------------------------------------------------------------------------------------------
# K-Fold #9
# Mean negativities for all classes: [0.31496713475843]
# Mean entropies for all classes: [-4.8004260090039896e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.43      0.60      0.50        20
#          1.0       0.33      0.20      0.25        20
#
#     accuracy                           0.40        40
#    macro avg       0.38      0.40      0.38        40
# weighted avg       0.38      0.40      0.38        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.45999999999999996 F1-Scores = 0.43244613765674983 Negativity = [0.26475053490228956, 0.13177991131002376] Entropy = [2.8290703366508987e-14, 1.2924939577372309e-15]
# CPU times: total: 14.3 s
# Wall time: 7h 49min 6s
# Media Score dos N K-Fold 0.45
# Maior Score dos K-Fold 0.48
# Menor Score dos K-Fold 0.41500000000000004
#
#
# [[0.525, 0.525, 0.325, 0.4, 0.35, 0.5, 0.45, 0.4, 0.4, 0.5], [0.375, 0.5, 0.425, 0.5, 0.5, 0.5, 0.5, 0.35, 0.375, 0.45], [0.5, 0.4, 0.275, 0.45, 0.5, 0.45, 0.425, 0.5, 0.5, 0.5], [0.45, 0.45, 0.4, 0.525, 0.45, 0.45, 0.45, 0.525, 0.525, 0.4], [0.45, 0.375, 0.425, 0.475, 0.5, 0.35, 0.475, 0.475, 0.375, 0.475], [0.425, 0.425, 0.5, 0.425, 0.375, 0.5, 0.55, 0.4, 0.4, 0.475], [0.45, 0.475, 0.45, 0.45, 0.475, 0.45, 0.55, 0.5, 0.375, 0.475], [0.4, 0.5, 0.45, 0.375, 0.425, 0.375, 0.45, 0.45, 0.525, 0.475], [0.425, 0.325, 0.45, 0.45, 0.425, 0.5, 0.475, 0.375, 0.325, 0.4], [0.4, 0.4, 0.425, 0.4, 0.45, 0.45, 0.45, 0.475, 0.45, 0.4], [0.475, 0.35, 0.4, 0.5, 0.45, 0.5, 0.475, 0.425, 0.4, 0.475], [0.45, 0.425, 0.425, 0.5, 0.5, 0.5, 0.45, 0.4, 0.475, 0.4], [0.425, 0.475, 0.525, 0.475, 0.35, 0
-15]
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.85      0.92        20
#          1.0       0.87      1.00      0.93        20
#
#     accuracy                           0.93        40
#    macro avg       0.93      0.93      0.92        40
# weighted avg       0.93      0.93      0.92        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #7
# Mean negativities for all classes: [0.0012679569741120334]
# Mean entropies for all classes: [2.926766787649207e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.83      0.95      0.88        20
#          1.0       0.94      0.80      0.86        20
#
#     accuracy                           0.88        40
#    macro avg       0.88      0.88      0.87        40
# weighted avg       0.88      0.88      0.87        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #8
# Mean negativities for all classes: [0.002338197885590798]
# Mean entropies for all classes: [1.3388859118224765e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.83      0.95      0.88        20
#          1.0       0.94      0.80      0.86        20
#
#     accuracy                           0.88        40
#    macro avg       0.88      0.88      0.87        40
# weighted avg       0.88      0.88      0.87        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #9
# Mean negativities for all classes: [0.0024017650032423067]
# Mean entropies for all classes: [2.282096227403027e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.77      1.00      0.87        20
#          1.0       1.00      0.70      0.82        20
#
#     accuracy                           0.85        40
#    macro avg       0.88      0.85      0.85        40
# weighted avg       0.88      0.85      0.85        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.8699999999999999 F1-Scores = 0.8690879761159908 Negativity = [0.0013423284094055965, 0.0024435421008677572] Entropy = [2.181003333833691e-15, 3.40853212182998e-15]
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #0
# Mean negativities for all classes: [0.0025378702327970904]
# Mean entropies for all classes: [1.8842945271380064e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.78      0.90      0.84        20
#          1.0       0.88      0.75      0.81        20
#
#     accuracy                           0.82        40
#    macro avg       0.83      0.82      0.82        40
# weighted avg       0.83      0.82      0.82        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #1
# Mean negativities for all classes: [0.0014654081509550693]
# Mean entropies for all classes: [2.3353029246926544e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.86      0.90      0.88        20
#          1.0       0.89      0.85      0.87        20
#
#     accuracy                           0.88        40
#    macro avg       0.88      0.88      0.87        40
# weighted avg       0.88      0.88      0.87        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #2
# Mean negativities for all classes: [0.0018274181964140434]
# Mean entropies for all classes: [2.475730876718395e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.83      0.95      0.88        20
#          1.0       0.94      0.80      0.86        20
#
#     accuracy                           0.88        40
#    macro avg       0.88      0.88      0.87        40
# weighted avg       0.88      0.88      0.87        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #3
# Mean negativities for all classes: [0.0018676635301305728]
# Mean entropies for all classes: [2.8024989551849337e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.90      0.95      0.93        20
#          1.0       0.95      0.90      0.92        20
#
#     accuracy                           0.93        40
#    macro avg       0.93      0.93      0.92        40
# weighted avg       0.93      0.93      0.92        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #4
# Mean negativities for all classes: [0.002351422443333545]
# Mean entropies for all classes: [2.6176942576657667e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.82      0.90      0.86        20
#          1.0       0.89      0.80      0.84        20
#
#     accuracy                           0.85        40
#    macro avg       0.85      0.85      0.85        40
# weighted avg       0.85      0.85      0.85        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #5
# Mean negativities for all classes: [0.002453691710919603]
# Mean entropies for all classes: [2.6804657295078324e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.90      0.95      0.93        20
#          1.0       0.95      0.90      0.92        20
#
#     accuracy                           0.93        40
#    macro avg       0.93      0.93      0.92        40
# weighted avg       0.93      0.93      0.92        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #6
# Mean negativities for all classes: [0.0011905802289234075]
# Mean entropies for all classes: [1.7919243586272993e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.86      0.95      0.90        20
#          1.0       0.94      0.85      0.89        20
#
#     accuracy                           0.90        40
#    macro avg       0.90      0.90      0.90        40
# weighted avg       0.90      0.90      0.90        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #7
# Mean negativities for all classes: [0.0013237652342378975]
# Mean entropies for all classes: [2.582503023423213e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.76      0.95      0.84        20
#          1.0       0.93      0.70      0.80        20
#
#     accuracy                           0.82        40
#    macro avg       0.85      0.82      0.82        40
# weighted avg       0.85      0.82      0.82        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #8
# Mean negativities for all classes: [0.002447339838621532]
# Mean entropies for all classes: [2.492882221969198e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.80      0.80      0.80        20
#          1.0       0.80      0.80      0.80        20
#
#     accuracy                           0.80        40
#    macro avg       0.80      0.80      0.80        40
# weighted avg       0.80      0.80      0.80        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #9
# Mean negativities for all classes: [0.0022661010417832695]
# Mean entropies for all classes: [2.0951375225538003e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.86      0.90      0.88        20
#          1.0       0.89      0.85      0.87        20
#
#     accuracy                           0.88        40
#    macro avg       0.88      0.88      0.87        40
# weighted avg       0.88      0.88      0.87        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.8675 F1-Scores = 0.8669648453575372 Negativity = [0.0025378702327970904, 0.0014654081509550693] Entropy = [1.8842945271380064e-15, 2.3353029246926544e-15]
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #0
# Mean negativities for all classes: [0.000898128576336757]
# Mean entropies for all classes: [2.4971138092781013e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.79      0.95      0.86        20
#          1.0       0.94      0.75      0.83        20
#
#     accuracy                           0.85        40
#    macro avg       0.86      0.85      0.85        40
# weighted avg       0.86      0.85      0.85        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #1
# Mean negativities for all classes: [0.002167492410553451]
# Mean entropies for all classes: [1.8897981983044228e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.90      0.95      0.93        20
#          1.0       0.95      0.90      0.92        20
#
#     accuracy                           0.93        40
#    macro avg       0.93      0.93      0.92        40
# weighted avg       0.93      0.93      0.92        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #2
# Mean negativities for all classes: [0.22698165711124524]
# Mean entropies for all classes: [1.698636637275998e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.89      0.85      0.87        20
#          1.0       0.86      0.90      0.88        20
#
#     accuracy                           0.88        40
#    macro avg       0.88      0.88      0.87        40
# weighted avg       0.88      0.88      0.87        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #3
# Mean negativities for all classes: [0.0017124158408300394]
# Mean entropies for all classes: [2.9211607404738906e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.80      0.86        20
#          1.0       0.83      0.95      0.88        20
#
#     accuracy                           0.88        40
#    macro avg       0.88      0.88      0.87        40
# weighted avg       0.88      0.88      0.87        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #4
# Mean negativities for all classes: [0.001860394764607473]
# Mean entropies for all classes: [2.299866585072942e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.80      1.00      0.89        20
#          1.0       1.00      0.75      0.86        20
#
#     accuracy                           0.88        40
#    macro avg       0.90      0.88      0.87        40
# weighted avg       0.90      0.88      0.87        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #5
# Mean negativities for all classes: [0.0017254959681692245]
# Mean entropies for all classes: [3.0358235373207876e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.90      0.92        20
#          1.0       0.90      0.95      0.93        20
#
#     accuracy                           0.93        40
#    macro avg       0.93      0.93      0.92        40
# weighted avg       0.93      0.93      0.92        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #6
# Mean negativities for all classes: [0.0018360198441719987]
# Mean entropies for all classes: [2.6544963329767326e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.78      0.90      0.84        20
#          1.0       0.88      0.75      0.81        20
#
#     accuracy                           0.82        40
#    macro avg       0.83      0.82      0.82        40
# weighted avg       0.83      0.82      0.82        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #7
# Mean negativities for all classes: [0.01744154526982118]
# Mean entropies for all classes: [2.2250881813200273e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.83      0.95      0.88        20
#          1.0       0.94      0.80      0.86        20
#
#     accuracy                           0.88        40
#    macro avg       0.88      0.88      0.87        40
# weighted avg       0.88      0.88      0.87        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #8
# Mean negativities for all classes: [0.0020858456737351703]
# Mean entropies for all classes: [2.2892927945231585e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.89      0.80      0.84        20
#          1.0       0.82      0.90      0.86        20
#
#     accuracy                           0.85        40
#    macro avg       0.85      0.85      0.85        40
# weighted avg       0.85      0.85      0.85        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #9
# Mean negativities for all classes: [0.001829445878871397]
# Mean entropies for all classes: [2.5255838933703786e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.79      0.95      0.86        20
#          1.0       0.94      0.75      0.83        20
#
#     accuracy                           0.85        40
#    macro avg       0.86      0.85      0.85        40
# weighted avg       0.86      0.85      0.85        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.8724999999999999 F1-Scores = 0.8717033499312509 Negativity = [0.000898128576336757, 0.002167492410553451] Entropy = [2.4971138092781013e-15, 1.8897981983044228e-15]
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #0
# Mean negativities for all classes: [0.0020765448374640396]
# Mean entropies for all classes: [2.4748712617809727e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.86      0.95      0.90        20
#          1.0       0.94      0.85      0.89        20
#
#     accuracy                           0.90        40
#    macro avg       0.90      0.90      0.90        40
# weighted avg       0.90      0.90      0.90        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #1
# Mean negativities for all classes: [0.0019123733611823845]
# Mean entropies for all classes: [2.1851879083108775e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.86      0.95      0.90        20
#          1.0       0.94      0.85      0.89        20
#
#     accuracy                           0.90        40
#    macro avg       0.90      0.90      0.90        40
# weighted avg       0.90      0.90      0.90        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #2
# Mean negativities for all classes: [0.0017026491714278002]
# Mean entropies for all classes: [2.0400118432866374e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.85      0.89        20
#          1.0       0.86      0.95      0.90        20
#
#     accuracy                           0.90        40
#    macro avg       0.90      0.90      0.90        40
# weighted avg       0.90      0.90      0.90        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #3
# Mean negativities for all classes: [0.002335469594122569]
# Mean entropies for all classes: [2.1470110093481236e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.83      0.95      0.88        20
#          1.0       0.94      0.80      0.86        20
#
#     accuracy                           0.88        40
#    macro avg       0.88      0.88      0.87        40
# weighted avg       0.88      0.88      0.87        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #4
# Mean negativities for all classes: [0.002434088351193428]
# Mean entropies for all classes: [2.1228052860993403e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.85      0.89        20
#          1.0       0.86      0.95      0.90        20
#
#     accuracy                           0.90        40
#    macro avg       0.90      0.90      0.90        40
# weighted avg       0.90      0.90      0.90        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #5
# Mean negativities for all classes: [0.0016560051246336527]
# Mean entropies for all classes: [2.217607483918859e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.85      0.85      0.85        20
#          1.0       0.85      0.85      0.85        20
#
#     accuracy                           0.85        40
#    macro avg       0.85      0.85      0.85        40
# weighted avg       0.85      0.85      0.85        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #6
# Mean negativities for all classes: [0.0022745650876517115]
# Mean entropies for all classes: [3.00381446351347e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.86      0.95      0.90        20
#          1.0       0.94      0.85      0.89        20
#
#     accuracy                           0.90        40
#    macro avg       0.90      0.90      0.90        40
# weighted avg       0.90      0.90      0.90        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #7
# Mean negativities for all classes: [0.0011208944015828532]
# Mean entropies for all classes: [2.8150716392359917e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.78      0.90      0.84        20
#          1.0       0.88      0.75      0.81        20
#
#     accuracy                           0.82        40
#    macro avg       0.83      0.82      0.82        40
# weighted avg       0.83      0.82      0.82        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #8
# Mean negativities for all classes: [0.0017441031742153946]
# Mean entropies for all classes: [2.622226986735167e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.77      0.85      0.81        20
#          1.0       0.83      0.75      0.79        20
#
#     accuracy                           0.80        40
#    macro avg       0.80      0.80      0.80        40
# weighted avg       0.80      0.80      0.80        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #9
# Mean negativities for all classes: [0.001608510729436885]
# Mean entropies for all classes: [2.2855619715791757e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.83      1.00      0.91        20
#          1.0       1.00      0.80      0.89        20
#
#     accuracy                           0.90        40
#    macro avg       0.92      0.90      0.90        40
# weighted avg       0.92      0.90      0.90        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.875 F1-Scores = 0.8745538467141895 Negativity = [0.0020765448374640396, 0.0019123733611823845] Entropy = [2.4748712617809727e-15, 2.1851879083108775e-15]
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #0
# Mean negativities for all classes: [0.0024567965286998476]
# Mean entropies for all classes: [1.7525941388836322e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.87      1.00      0.93        20
#          1.0       1.00      0.85      0.92        20
#
#     accuracy                           0.93        40
#    macro avg       0.93      0.93      0.92        40
# weighted avg       0.93      0.93      0.92        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #1
# Mean negativities for all classes: [0.0026119628707336195]
# Mean entropies for all classes: [2.198083155489031e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.70      0.95      0.81        20
#          1.0       0.92      0.60      0.73        20
#
#     accuracy                           0.78        40
#    macro avg       0.81      0.77      0.77        40
# weighted avg       0.81      0.78      0.77        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #2
# Mean negativities for all classes: [0.04312272455477473]
# Mean entropies for all classes: [2.6484583570717274e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.77      1.00      0.87        20
#          1.0       1.00      0.70      0.82        20
#
#     accuracy                           0.85        40
#    macro avg       0.88      0.85      0.85        40
# weighted avg       0.88      0.85      0.85        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #3
# Mean negativities for all classes: [0.006633125756086938]
# Mean entropies for all classes: [2.6462299668682025e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.86      0.90      0.88        20
#          1.0       0.89      0.85      0.87        20
#
#     accuracy                           0.88        40
#    macro avg       0.88      0.88      0.87        40
# weighted avg       0.88      0.88      0.87        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #4
# Mean negativities for all classes: [0.0025184657331223602]
# Mean entropies for all classes: [2.8646653298581314e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.89      0.85      0.87        20
#          1.0       0.86      0.90      0.88        20
#
#     accuracy                           0.88        40
#    macro avg       0.88      0.88      0.87        40
# weighted avg       0.88      0.88      0.87        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #5
# Mean negativities for all classes: [0.008444215191027699]
# Mean entropies for all classes: [2.4388779938642634e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.86      0.90      0.88        20
#          1.0       0.89      0.85      0.87        20
#
#     accuracy                           0.88        40
#    macro avg       0.88      0.88      0.87        40
# weighted avg       0.88      0.88      0.87        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #6
# Mean negativities for all classes: [0.20241029199497068]
# Mean entropies for all classes: [1.7352382095505505e-15]
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.75      0.86        20
#          1.0       0.80      1.00      0.89        20
#
#     accuracy                           0.88        40
#    macro avg       0.90      0.88      0.87        40
# weighted avg       0.90      0.88      0.87        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #7
# Mean negativities for all classes: [0.0020657061509577997]
# Mean entropies for all classes: [2.394855449774745e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.86      0.95      0.90        20
#          1.0       0.94      0.85      0.89        20
#
#     accuracy                           0.90        40
#    macro avg       0.90      0.90      0.90        40
# weighted avg       0.90      0.90      0.90        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #8
# Mean negativities for all classes: [0.0021417264789828304]
# Mean entropies for all classes: [2.462084115667743e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.85      0.89        20
#          1.0       0.86      0.95      0.90        20
#
#     accuracy                           0.90        40
#    macro avg       0.90      0.90      0.90        40
# weighted avg       0.90      0.90      0.90        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #9
# Mean negativities for all classes: [0.0022501434501611267]
# Mean entropies for all classes: [2.6200611524911943e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.90      0.92        20
#          1.0       0.90      0.95      0.93        20
#
#     accuracy                           0.93        40
#    macro avg       0.93      0.93      0.92        40
# weighted avg       0.93      0.93      0.92        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.8775000000000001 F1-Scores = 0.876124792988439 Negativity = [0.0024567965286998476, 0.0026119628707336195] Entropy = [1.7525941388836322e-15, 2.198083155489031e-15]
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #0
# Mean negativities for all classes: [0.062127712816683424]
# Mean entropies for all classes: [2.7903076504763432e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.70      0.80      0.74        20
#          1.0       0.76      0.65      0.70        20
#
#     accuracy                           0.73        40
#    macro avg       0.73      0.73      0.72        40
# weighted avg       0.73      0.72      0.72        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #1
# Mean negativities for all classes: [0.0013100284946725381]
# Mean entropies for all classes: [2.74232747908526e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.89      0.80      0.84        20
#          1.0       0.82      0.90      0.86        20
#
#     accuracy                           0.85        40
#    macro avg       0.85      0.85      0.85        40
# weighted avg       0.85      0.85      0.85        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #2
# Mean negativities for all classes: [0.001587715820198124]
# Mean entropies for all classes: [2.4161204071318357e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.90      0.95      0.93        20
#          1.0       0.95      0.90      0.92        20
#
#     accuracy                           0.93        40
#    macro avg       0.93      0.93      0.92        40
# weighted avg       0.93      0.93      0.92        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #3
# Mean negativities for all classes: [0.0023496503877884515]
# Mean entropies for all classes: [2.8434111093345335e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.86      0.95      0.90        20
#          1.0       0.94      0.85      0.89        20
#
#     accuracy                           0.90        40
#    macro avg       0.90      0.90      0.90        40
# weighted avg       0.90      0.90      0.90        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #4
# Mean negativities for all classes: [0.0016765465077993424]
# Mean entropies for all classes: [2.884718370002535e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.76      0.95      0.84        20
#          1.0       0.93      0.70      0.80        20
#
#     accuracy                           0.82        40
#    macro avg       0.85      0.82      0.82        40
# weighted avg       0.85      0.82      0.82        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #5
# Mean negativities for all classes: [0.0019873326090223352]
# Mean entropies for all classes: [2.472224249394412e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.95      0.95        20
#          1.0       0.95      0.95      0.95        20
#
#     accuracy                           0.95        40
#    macro avg       0.95      0.95      0.95        40
# weighted avg       0.95      0.95      0.95        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #6
# Mean negativities for all classes: [0.0018304778137888862]
# Mean entropies for all classes: [2.7109272144051833e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.86      0.95      0.90        20
#          1.0       0.94      0.85      0.89        20
#
#     accuracy                           0.90        40
#    macro avg       0.90      0.90      0.90        40
# weighted avg       0.90      0.90      0.90        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #7
# Mean negativities for all classes: [0.0027237036156578963]
# Mean entropies for all classes: [2.6328366427136533e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.98        20
#          1.0       1.00      0.95      0.97        20
#
#     accuracy                           0.97        40
#    macro avg       0.98      0.97      0.97        40
# weighted avg       0.98      0.97      0.97        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #8
# Mean negativities for all classes: [0.0022720222225397603]
# Mean entropies for all classes: [3.0141746117211566e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.80      0.80      0.80        20
#          1.0       0.80      0.80      0.80        20
#
#     accuracy                           0.80        40
#    macro avg       0.80      0.80      0.80        40
# weighted avg       0.80      0.80      0.80        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #9
# Mean negativities for all classes: [0.0017889042289655293]
# Mean entropies for all classes: [2.7531860645449645e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.90      0.90      0.90        20
#          1.0       0.90      0.90      0.90        20
#
#     accuracy                           0.90        40
#    macro avg       0.90      0.90      0.90        40
# weighted avg       0.90      0.90      0.90        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.875 F1-Scores = 0.8744726864760002 Negativity = [0.062127712816683424, 0.0013100284946725381] Entropy = [2.7903076504763432e-15, 2.74232747908526e-15]
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #0
# Mean negativities for all classes: [0.0016788063508153678]
# Mean entropies for all classes: [3.313438680247599e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.86      0.95      0.90        20
#          1.0       0.94      0.85      0.89        20
#
#     accuracy                           0.90        40
#    macro avg       0.90      0.90      0.90        40
# weighted avg       0.90      0.90      0.90        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #1
# Mean negativities for all classes: [0.0017445389211352968]
# Mean entropies for all classes: [2.601967495125082e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.83      0.95      0.88        20
#          1.0       0.94      0.80      0.86        20
#
#     accuracy                           0.88        40
#    macro avg       0.88      0.88      0.87        40
# weighted avg       0.88      0.88      0.87        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #2
# Mean negativities for all classes: [0.037585082450161636]
# Mean entropies for all classes: [2.4960512918508627e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.78      0.90      0.84        20
#          1.0       0.88      0.75      0.81        20
#
#     accuracy                           0.82        40
#    macro avg       0.83      0.82      0.82        40
# weighted avg       0.83      0.82      0.82        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #3
# Mean negativities for all classes: [0.0014687196020700371]
# Mean entropies for all classes: [1.9656798427230682e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.95      0.95        20
#          1.0       0.95      0.95      0.95        20
#
#     accuracy                           0.95        40
#    macro avg       0.95      0.95      0.95        40
# weighted avg       0.95      0.95      0.95        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #4
# Mean negativities for all classes: [0.002276377883445757]
# Mean entropies for all classes: [2.4792759757686644e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.85      0.89        20
#          1.0       0.86      0.95      0.90        20
#
#     accuracy                           0.90        40
#    macro avg       0.90      0.90      0.90        40
# weighted avg       0.90      0.90      0.90        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #5
# Mean negativities for all classes: [0.0017575880550933954]
# Mean entropies for all classes: [2.343284226172983e-15]
# ...
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #1
# Mean negativities for all classes: [0.001337714498173942]
# Mean entropies for all classes: [2.535894356684251e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.86      0.90      0.88        20
#          1.0       0.89      0.85      0.87        20
#
#     accuracy                           0.88        40
#    macro avg       0.88      0.88      0.87        40
# weighted avg       0.88      0.88      0.87        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #2
# Mean negativities for all classes: [0.002738080544737892]
# Mean entropies for all classes: [2.134853443013256e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.71      0.85      0.77        20
#          1.0       0.81      0.65      0.72        20
#
#     accuracy                           0.75        40
#    macro avg       0.76      0.75      0.75        40
# weighted avg       0.76      0.75      0.75        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #3
# Mean negativities for all classes: [0.001603837983861378]
# Mean entropies for all classes: [2.525357892108113e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.90      0.90      0.90        20
#          1.0       0.90      0.90      0.90        20
#
#     accuracy                           0.90        40
#    macro avg       0.90      0.90      0.90        40
# weighted avg       0.90      0.90      0.90        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #4
# Mean negativities for all classes: [0.0018596661056077296]
# Mean entropies for all classes: [1.938426265269919e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.90      0.92        20
#          1.0       0.90      0.95      0.93        20
#
#     accuracy                           0.93        40
#    macro avg       0.93      0.93      0.92        40
# weighted avg       0.93      0.93      0.92        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #5
# Mean negativities for all classes: [0.21535351983578072]
# Mean entropies for all classes: [1.8068158553700124e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.95      0.95        20
#          1.0       0.95      0.95      0.95        20
#
#     accuracy                           0.95        40
#    macro avg       0.95      0.95      0.95        40
# weighted avg       0.95      0.95      0.95        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #6
# Mean negativities for all classes: [0.0023724431555269708]
# Mean entropies for all classes: [3.0765860341007022e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.85      0.85      0.85        20
#          1.0       0.85      0.85      0.85        20
#
#     accuracy                           0.85        40
#    macro avg       0.85      0.85      0.85        40
# weighted avg       0.85      0.85      0.85        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #7
# Mean negativities for all classes: [0.0017001611899407937]
# Mean entropies for all classes: [2.5772465647015815e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.82      0.90      0.86        20
#          1.0       0.89      0.80      0.84        20
#
#     accuracy                           0.85        40
#    macro avg       0.85      0.85      0.85        40
# weighted avg       0.85      0.85      0.85        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #8
# Mean negativities for all classes: [0.035066033098875335]
# Mean entropies for all classes: [2.3961709534724764e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.83      1.00      0.91        20
#          1.0       1.00      0.80      0.89        20
#
#     accuracy                           0.90        40
#    macro avg       0.92      0.90      0.90        40
# weighted avg       0.92      0.90      0.90        40
#
# -------------------------------------------------------------------------------------------------------------------
# K-Fold #9
# Mean negativities for all classes: [0.0020983496897940936]
# Mean entropies for all classes: [2.1947650090694144e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.82      0.90      0.86        20
#          1.0       0.89      0.80      0.84        20
#
#     accuracy                           0.85        40
#    macro avg       0.85      0.85      0.85        40
# weighted avg       0.85      0.85      0.85        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.
019918002917980347, 0.0030042082534216504, 0.002250249144942171]], [[0.0018804979247217025, 0.0018684328853486893, 0.0025667688050430293, 0.0017401100694950044, 0.010540539402935922, 0.002234792843679112, 0.2283177892841875, 0.24392404861918876, 0.0015094179309792677, 0.0018418586098712304]], [[0.0017307670304241018, 0.002224909505667541, 0.001872816923602641, 0.0020852300992122374, 0.0013719842968993256, 0.002014853515969875, 0.0026183425442159484, 0.003948385870376247, 0.002617277764160744, 0.002620319703029894]], [[0.0021704910714484328, 0.0020727844663861795, 0.0022125292217385294, 0.002001102088895604, 0.003717562103940672, ...
# CPU times: total: 14.1 s
# Wall time: 6h 48min 59s
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished

# %% [markdown]
# # Stripes

# %%
# %%time
# %run Experimento-Artificial-Stripes-20-10-Fold.ipynb
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #0
# Mean negativities for all classes: [0.00195685574280218]
# Mean entropies for all classes: [2.793143958874083e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.90      0.92        20
#          1.0       0.90      0.95      0.93        20
#
#     accuracy                           0.93        40
#    macro avg       0.93      0.93      0.92        40
# weighted avg       0.93      0.93      0.92        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #1
# Mean negativities for all classes: [0.0012645940822682473]
# Mean entropies for all classes: [2.790596475446961e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.90      0.92        20
#          1.0       0.90      0.95      0.93        20
#
#     accuracy                           0.93        40
#    macro avg       0.93      0.93      0.92        40
# weighted avg       0.93      0.93      0.92        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #2
# Mean negativities for all classes: [0.0034097715141601175]
# Mean entropies for all classes: [1.9373112555992886e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.80      0.86        20
#          1.0       0.83      0.95      0.88        20
#
#     accuracy                           0.88        40
#    macro avg       0.88      0.88      0.87        40
# weighted avg       0.88      0.88      0.87        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #3
# Mean negativities for all classes: [0.001044865803809858]
# Mean entropies for all classes: [2.6628806417841544e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.90      0.90      0.90        20
#          1.0       0.90      0.90      0.90        20
#
#     accuracy                           0.90        40
#    macro avg       0.90      0.90      0.90        40
# weighted avg       0.90      0.90      0.90        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #4
# Mean negativities for all classes: [0.00216696132734166]
# Mean entropies for all classes: [2.4376317913453114e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.88      0.75      0.81        20
#          1.0       0.78      0.90      0.84        20
#
#     accuracy                           0.82        40
#    macro avg       0.83      0.82      0.82        40
# weighted avg       0.83      0.82      0.82        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #5
# Mean negativities for all classes: [0.0011050938364620955]
# Mean entropies for all classes: [2.2314523856072753e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.90      0.92        20
#          1.0       0.90      0.95      0.93        20
#
#     accuracy                           0.93        40
#    macro avg       0.93      0.93      0.92        40
# weighted avg       0.93      0.93      0.92        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #6
# Mean negativities for all classes: [0.00046832290725594693]
# Mean entropies for all classes: [2.6702203085913005e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.75      0.83        20
#          1.0       0.79      0.95      0.86        20
#
#     accuracy                           0.85        40
#    macro avg       0.86      0.85      0.85        40
# weighted avg       0.86      0.85      0.85        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #7
# Mean negativities for all classes: [0.0003949070559858686]
# Mean entropies for all classes: [2.511400578989958e-15]
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.95      0.97        20
#          1.0       0.95      1.00      0.98        20
#
#     accuracy                           0.97        40
#    macro avg       0.98      0.97      0.97        40
# weighted avg       0.98      0.97      0.97        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #8
# Mean negativities for all classes: [0.001179236333783032]
# Mean entropies for all classes: [2.045039981616409e-15]
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.90      0.95        20
#          1.0       0.91      1.00      0.95        20
#
#     accuracy                           0.95        40
#    macro avg       0.95      0.95      0.95        40
# weighted avg       0.95      0.95      0.95        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #9
# Mean negativities for all classes: [0.001592040193864122]
# Mean entropies for all classes: [2.2258911719608634e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.90      0.90      0.90        20
#          1.0       0.90      0.90      0.90        20
#
#     accuracy                           0.90        40
#    macro avg       0.90      0.90      0.90        40
# weighted avg       0.90      0.90      0.90        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.905 F1-Scores = 0.9046506141601224 Negativity = [0.00195685574280218, 0.0012645940822682473] Entropy = [2.793143958874083e-15, 2.790596475446961e-15]
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #0
# Mean negativities for all classes: [0.0014303462826702918]
# Mean entropies for all classes: [2.143458048692984e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.95      0.95        20
#          1.0       0.95      0.95      0.95        20
#
#     accuracy                           0.95        40
#    macro avg       0.95      0.95      0.95        40
# weighted avg       0.95      0.95      0.95        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #1
# Mean negativities for all classes: [9.269869528125419e-05]
# Mean entropies for all classes: [2.516428962399773e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.80      0.86        20
#          1.0       0.83      0.95      0.88        20
#
#     accuracy                           0.88        40
#    macro avg       0.88      0.88      0.87        40
# weighted avg       0.88      0.88      0.87        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #2
# Mean negativities for all classes: [0.0014099796906197949]
# Mean entropies for all classes: [2.2684354921325366e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.82      0.90      0.86        20
#          1.0       0.89      0.80      0.84        20
#
#     accuracy                           0.85        40
#    macro avg       0.85      0.85      0.85        40
# weighted avg       0.85      0.85      0.85        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #3
# Mean negativities for all classes: [0.001020984106449424]
# Mean entropies for all classes: [1.613158467929623e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.88      0.75      0.81        20
#          1.0       0.78      0.90      0.84        20
#
#     accuracy                           0.82        40
#    macro avg       0.83      0.82      0.82        40
# weighted avg       0.83      0.82      0.82        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #4
# Mean negativities for all classes: [0.0005718330852010594]
# Mean entropies for all classes: [2.5670204828979464e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.98        20
#          1.0       1.00      0.95      0.97        20
#
#     accuracy                           0.97        40
#    macro avg       0.98      0.97      0.97        40
# weighted avg       0.98      0.97      0.97        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #5
# Mean negativities for all classes: [0.0014923178005111144]
# Mean entropies for all classes: [1.4819184831710667e-15]
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.90      0.95        20
#          1.0       0.91      1.00      0.95        20
#
#     accuracy                           0.95        40
#    macro avg       0.95      0.95      0.95        40
# weighted avg       0.95      0.95      0.95        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #6
# Mean negativities for all classes: [0.0021274460817057193]
# Mean entropies for all classes: [2.1995211368234114e-15]
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.95      0.97        20
#          1.0       0.95      1.00      0.98        20
#
#     accuracy                           0.97        40
#    macro avg       0.98      0.97      0.97        40
# weighted avg       0.98      0.97      0.97        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #7
# Mean negativities for all classes: [0.0020457063783712063]
# Mean entropies for all classes: [2.1802843870345693e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.90      0.92        20
#          1.0       0.90      0.95      0.93        20
#
#     accuracy                           0.93        40
#    macro avg       0.93      0.93      0.92        40
# weighted avg       0.93      0.93      0.92        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #8
# Mean negativities for all classes: [0.0016915402578921656]
# Mean entropies for all classes: [2.774726394858873e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.80      0.86        20
#          1.0       0.83      0.95      0.88        20
#
#     accuracy                           0.88        40
#    macro avg       0.88      0.88      0.87        40
# weighted avg       0.88      0.88      0.87        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #9
# Mean negativities for all classes: [0.0012078468371314183]
# Mean entropies for all classes: [1.8376279117431304e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.70      0.80        20
#          1.0       0.76      0.95      0.84        20
#
#     accuracy                           0.82        40
#    macro avg       0.85      0.82      0.82        40
# weighted avg       0.85      0.82      0.82        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.9024999999999999 F1-Scores = 0.9019238646896348 Negativity = [0.0014303462826702918, 9.269869528125419e-05] Entropy = [2.143458048692984e-15, 2.516428962399773e-15]
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #0
# Mean negativities for all classes: [0.002348159119012838]
# Mean entropies for all classes: [1.4455101939790218e-15]
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.85      0.92        20
#          1.0       0.87      1.00      0.93        20
#
#     accuracy                           0.93        40
#    macro avg       0.93      0.93      0.92        40
# weighted avg       0.93      0.93      0.92        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #1
# Mean negativities for all classes: [0.0016095040938713418]
# Mean entropies for all classes: [2.15079461741825e-15]
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.95      0.97        20
#          1.0       0.95      1.00      0.98        20
#
#     accuracy                           0.97        40
#    macro avg       0.98      0.97      0.97        40
# weighted avg       0.98      0.97      0.97        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #2
# Mean negativities for all classes: [0.0015116999526717302]
# Mean entropies for all classes: [2.0405278754780363e-15]
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00        20
#          1.0       1.00      1.00      1.00        20
#
#     accuracy                           1.00        40
#    macro avg       1.00      1.00      1.00        40
# weighted avg       1.00      1.00      1.00        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #3
# Mean negativities for all classes: [0.0013975933075030533]
# Mean entropies for all classes: [1.58316786383896e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.85      0.89        20
#          1.0       0.86      0.95      0.90        20
#
#     accuracy                           0.90        40
#    macro avg       0.90      0.90      0.90        40
# weighted avg       0.90      0.90      0.90        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #4
# Mean negativities for all classes: [0.0008513887519546959]
# Mean entropies for all classes: [1.7873273533051086e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.84      0.80      0.82        20
#          1.0       0.81      0.85      0.83        20
#
#     accuracy                           0.82        40
#    macro avg       0.83      0.82      0.82        40
# weighted avg       0.83      0.82      0.82        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #5
# Mean negativities for all classes: [0.0009095827589428118]
# Mean entropies for all classes: [2.2498030352902525e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.90      0.92        20
#          1.0       0.90      0.95      0.93        20
#
#     accuracy                           0.93        40
#    macro avg       0.93      0.93      0.92        40
# weighted avg       0.93      0.93      0.92        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #6
# Mean negativities for all classes: [0.0020531613736278235]
# Mean entropies for all classes: [2.150282702872559e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.85      0.89        20
#          1.0       0.86      0.95      0.90        20
#
#     accuracy                           0.90        40
#    macro avg       0.90      0.90      0.90        40
# weighted avg       0.90      0.90      0.90        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #7
# Mean negativities for all classes: [0.002258279420897613]
# Mean entropies for all classes: [1.6152749827070926e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.79      0.75      0.77        20
#          1.0       0.76      0.80      0.78        20
#
#     accuracy                           0.78        40
#    macro avg       0.78      0.78      0.77        40
# weighted avg       0.78      0.78      0.77        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #8
# Mean negativities for all classes: [0.0004246682345465186]
# Mean entropies for all classes: [1.3596216440510403e-15]
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.85      0.92        20
#          1.0       0.87      1.00      0.93        20
#
#     accuracy                           0.93        40
#    macro avg       0.93      0.93      0.92        40
# weighted avg       0.93      0.93      0.92        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #9
# Mean negativities for all classes: [0.0022996823806187587]
# Mean entropies for all classes: [2.0224734190531264e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.89      0.85      0.87        20
#          1.0       0.86      0.90      0.88        20
#
#     accuracy                           0.88        40
#    macro avg       0.88      0.88      0.87        40
# weighted avg       0.88      0.88      0.87        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.9025000000000001 F1-Scores = 0.9023259354632314 Negativity = [0.002348159119012838, 0.0016095040938713418] Entropy = [1.4455101939790218e-15, 2.15079461741825e-15]
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #0
# Mean negativities for all classes: [0.0021097613860569407]
# Mean entropies for all classes: [2.465713558688901e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.90      0.90      0.90        20
#          1.0       0.90      0.90      0.90        20
#
#     accuracy                           0.90        40
#    macro avg       0.90      0.90      0.90        40
# weighted avg       0.90      0.90      0.90        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #1
# Mean negativities for all classes: [0.001736940467494791]
# Mean entropies for all classes: [2.1045992450465507e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.80      0.86        20
#          1.0       0.83      0.95      0.88        20
#
#     accuracy                           0.88        40
#    macro avg       0.88      0.88      0.87        40
# weighted avg       0.88      0.88      0.87        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #2
# Mean negativities for all classes: [0.0012703864210969501]
# Mean entropies for all classes: [1.9061716811951504e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.90      0.92        20
#          1.0       0.90      0.95      0.93        20
#
#     accuracy                           0.93        40
#    macro avg       0.93      0.93      0.92        40
# weighted avg       0.93      0.93      0.92        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #3
# Mean negativities for all classes: [0.0004636009023083809]
# Mean entropies for all classes: [1.7315065763618424e-15]
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.80      0.89        20
#          1.0       0.83      1.00      0.91        20
#
#     accuracy                           0.90        40
#    macro avg       0.92      0.90      0.90        40
# weighted avg       0.92      0.90      0.90        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #4
# Mean negativities for all classes: [0.0019996980540239045]
# Mean entropies for all classes: [2.574831876806287e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.86      0.90      0.88        20
#          1.0       0.89      0.85      0.87        20
#
#     accuracy                           0.88        40
#    macro avg       0.88      0.88      0.87        40
# weighted avg       0.88      0.88      0.87        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #5
# Mean negativities for all classes: [0.0015017545436778635]
# Mean entropies for all classes: [2.0587587152151368e-15]
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.95      0.97        20
#          1.0       0.95      1.00      0.98        20
#
#     accuracy                           0.97        40
#    macro avg       0.98      0.97      0.97        40
# weighted avg       0.98      0.97      0.97        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #6
# Mean negativities for all classes: [0.0004371648086685831]
# Mean entropies for all classes: [2.1216047728582757e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.83      0.75      0.79        20
#          1.0       0.77      0.85      0.81        20
#
#     accuracy                           0.80        40
#    macro avg       0.80      0.80      0.80        40
# weighted avg       0.80      0.80      0.80        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #7
# Mean negativities for all classes: [0.00044977609102098137]
# Mean entropies for all classes: [2.1265344327717502e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.85      0.89        20
#          1.0       0.86      0.95      0.90        20
#
#     accuracy                           0.90        40
#    macro avg       0.90      0.90      0.90        40
# weighted avg       0.90      0.90      0.90        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #8
# Mean negativities for all classes: [0.0012346220717912887]
# Mean entropies for all classes: [2.0773242624925264e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.95      0.95        20
#          1.0       0.95      0.95      0.95        20
#
#     accuracy                           0.95        40
#    macro avg       0.95      0.95      0.95        40
# weighted avg       0.95      0.95      0.95        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #9
# Mean negativities for all classes: [0.0015585406020061394]
# Mean entropies for all classes: [1.6547908008779348e-15]
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.80      0.89        20
#          1.0       0.83      1.00      0.91        20
#
#     accuracy                           0.90        40
#    macro avg       0.92      0.90      0.90        40
# weighted avg       0.92      0.90      0.90        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.9 F1-Scores = 0.899638010288367 Negativity = [0.0021097613860569407, 0.001736940467494791] Entropy = [2.465713558688901e-15, 2.1045992450465507e-15]
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #0
# Mean negativities for all classes: [0.0012847237142144196]
# Mean entropies for all classes: [1.8731294670969996e-15]
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.85      0.92        20
#          1.0       0.87      1.00      0.93        20
#
#     accuracy                           0.93        40
#    macro avg       0.93      0.93      0.92        40
# weighted avg       0.93      0.93      0.92        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #1
# Mean negativities for all classes: [0.0025916327883529766]
# Mean entropies for all classes: [2.5713968691510966e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.90      0.90      0.90        20
#          1.0       0.90      0.90      0.90        20
#
#     accuracy                           0.90        40
#    macro avg       0.90      0.90      0.90        40
# weighted avg       0.90      0.90      0.90        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #2
# Mean negativities for all classes: [0.0019090262748305247]
# Mean entropies for all classes: [2.1936250205598323e-15]
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.85      0.92        20
#          1.0       0.87      1.00      0.93        20
#
#     accuracy                           0.93        40
#    macro avg       0.93      0.93      0.92        40
# weighted avg       0.93      0.93      0.92        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #3
# Mean negativities for all classes: [0.0012289236861800334]
# Mean entropies for all classes: [2.2954128482667766e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.86      0.90      0.88        20
#          1.0       0.89      0.85      0.87        20
#
#     accuracy                           0.88        40
#    macro avg       0.88      0.88      0.87        40
# weighted avg       0.88      0.88      0.87        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #4
# Mean negativities for all classes: [0.0012131256332434531]
# Mean entropies for all classes: [2.5214395995273996e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.89      0.85      0.87        20
#          1.0       0.86      0.90      0.88        20
#
#     accuracy                           0.88        40
#    macro avg       0.88      0.88      0.87        40
# weighted avg       0.88      0.88      0.87        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #5
# Mean negativities for all classes: [0.0009550479792075128]
# Mean entropies for all classes: [2.604383776710428e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.86      0.90      0.88        20
#          1.0       0.89      0.85      0.87        20
#
#     accuracy                           0.88        40
#    macro avg       0.88      0.88      0.87        40
# weighted avg       0.88      0.88      0.87        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #6
# Mean negativities for all classes: [0.0010168642660030314]
# Mean entropies for all classes: [2.516165444396507e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.85      0.89        20
#          1.0       0.86      0.95      0.90        20
#
#     accuracy                           0.90        40
#    macro avg       0.90      0.90      0.90        40
# weighted avg       0.90      0.90      0.90        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #7
# Mean negativities for all classes: [0.0020119388253616866]
# Mean entropies for all classes: [2.057644981826843e-15]
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.90      0.95        20
#          1.0       0.91      1.00      0.95        20
#
#     accuracy                           0.95        40
#    macro avg       0.95      0.95      0.95        40
# weighted avg       0.95      0.95      0.95        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #8
# Mean negativities for all classes: [0.0014541397288339003]
# Mean entropies for all classes: [2.166759725324481e-15]
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.90      0.95        20
#          1.0       0.91      1.00      0.95        20
#
#     accuracy                           0.95        40
#    macro avg       0.95      0.95      0.95        40
# weighted avg       0.95      0.95      0.95        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #9
# Mean negativities for all classes: [0.0040278550967718565]
# Mean entropies for all classes: [2.3721388507831868e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.80      0.86        20
#          1.0       0.83      0.95      0.88        20
#
#     accuracy                           0.88        40
#    macro avg       0.88      0.88      0.87        40
# weighted avg       0.88      0.88      0.87        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.9049999999999999 F1-Scores = 0.9047708599898348 Negativity = [0.0012847237142144196, 0.0025916327883529766] Entropy = [1.8731294670969996e-15, 2.5713968691510966e-15]
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #0
# Mean negativities for all classes: [0.0021640041227975167]
# Mean entropies for all classes: [2.012824563080809e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.80      0.86        20
#          1.0       0.83      0.95      0.88        20
#
#     accuracy                           0.88        40
#    macro avg       0.88      0.88      0.87        40
# weighted avg       0.88      0.88      0.87        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #1
# Mean negativities for all classes: [0.002075044965966555]
# Mean entropies for all classes: [2.0309519191565283e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.85      0.89        20
#          1.0       0.86      0.95      0.90        20
#
#     accuracy                           0.90        40
#    macro avg       0.90      0.90      0.90        40
# weighted avg       0.90      0.90      0.90        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #2
# Mean negativities for all classes: [0.0012603199378075276]
# Mean entropies for all classes: [1.6861296290360097e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.90      0.92        20
#          1.0       0.90      0.95      0.93        20
#
#     accuracy                           0.93        40
#    macro avg       0.93      0.93      0.92        40
# weighted avg       0.93      0.93      0.92        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #3
# Mean negativities for all classes: [0.0014721868046420783]
# Mean entropies for all classes: [1.821851154841185e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.90      0.92        20
#          1.0       0.90      0.95      0.93        20
#
#     accuracy                           0.93        40
#    macro avg       0.93      0.93      0.92        40
# weighted avg       0.93      0.93      0.92        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #4
# Mean negativities for all classes: [0.0017272153287832936]
# Mean entropies for all classes: [2.4519960461519278e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.98        20
#          1.0       1.00      0.95      0.97        20
#
#     accuracy                           0.97        40
#    macro avg       0.98      0.97      0.97        40
# weighted avg       0.98      0.97      0.97        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #5
# Mean negativities for all classes: [0.0018263744502528157]
# Mean entropies for all classes: [1.8787110915885974e-15]
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.90      0.95        20
#          1.0       0.91      1.00      0.95        20
#
#     accuracy                           0.95        40
#    macro avg       0.95      0.95      0.95        40
# weighted avg       0.95      0.95      0.95        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #6
# Mean negativities for all classes: [0.0012423613106830155]
# Mean entropies for all classes: [2.161608432659129e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.90      0.90      0.90        20
#          1.0       0.90      0.90      0.90        20
#
#     accuracy                           0.90        40
#    macro avg       0.90      0.90      0.90        40
# weighted avg       0.90      0.90      0.90        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #7
# Mean negativities for all classes: [0.0009114457004062937]
# Mean entropies for all classes: [2.2030308321182967e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.87      0.65      0.74        20
#          1.0       0.72      0.90      0.80        20
#
#     accuracy                           0.78        40
#    macro avg       0.79      0.78      0.77        40
# weighted avg       0.79      0.78      0.77        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #8
# Mean negativities for all classes: [0.001981753499862582]
# Mean entropies for all classes: [1.8884996616671174e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.89      0.80      0.84        20
#          1.0       0.82      0.90      0.86        20
#
#     accuracy                           0.85        40
#    macro avg       0.85      0.85      0.85        40
# weighted avg       0.85      0.85      0.85        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #9
# Mean negativities for all classes: [0.001489847170705777]
# Mean entropies for all classes: [3.4864812018396067e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.98        20
#          1.0       1.00      0.95      0.97        20
#
#     accuracy                           0.97        40
#    macro avg       0.98      0.97      0.97        40
# weighted avg       0.98      0.97      0.97        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.9049999999999999 F1-Scores = 0.9044844511104178 Negativity = [0.0021640041227975167, 0.002075044965966555] Entropy = [2.012824563080809e-15, 2.0309519191565283e-15]
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #0
# Mean negativities for all classes: [0.000594370319197296]
# Mean entropies for all classes: [1.5847717328137505e-15]
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00        20
#          1.0       1.00      1.00      1.00        20
#
#     accuracy                           1.00        40
#    macro avg       1.00      1.00      1.00        40
# weighted avg       1.00      1.00      1.00        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #1
# Mean negativities for all classes: [0.0007049259010163872]
# Mean entropies for all classes: [2.1141950157849628e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.83      0.95      0.88        20
#          1.0       0.94      0.80      0.86        20
#
#     accuracy                           0.88        40
#    macro avg       0.88      0.88      0.87        40
# weighted avg       0.88      0.88      0.87        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #2
# Mean negativities for all classes: [0.0005478920756201711]
# Mean entropies for all classes: [2.0148455891526403e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.90      0.92        20
#          1.0       0.90      0.95      0.93        20
#
#     accuracy                           0.93        40
#    macro avg       0.93      0.93      0.92        40
# weighted avg       0.93      0.93      0.92        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #3
# Mean negativities for all classes: [0.0018636860450842007]
# Mean entropies for all classes: [2.6673935541550336e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.83      0.75      0.79        20
#          1.0       0.77      0.85      0.81        20
#
#     accuracy                           0.80        40
#    macro avg       0.80      0.80      0.80        40
# weighted avg       0.80      0.80      0.80        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #4
# Mean negativities for all classes: [0.0020176820940473405]
# Mean entropies for all classes: [2.204435735307071e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.75      0.83        20
#          1.0       0.79      0.95      0.86        20
#
#     accuracy                           0.85        40
#    macro avg       0.86      0.85      0.85        40
# weighted avg       0.86      0.85      0.85        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #5
# Mean negativities for all classes: [0.0020282528260303855]
# Mean entropies for all classes: [1.9113299449171797e-15]
# ...
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #1
# Mean negativities for all classes: [0.001502016709886575]
# Mean entropies for all classes: [2.0618868808283925e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.90      0.90      0.90        20
#          1.0       0.90      0.90      0.90        20
#
#     accuracy                           0.90        40
#    macro avg       0.90      0.90      0.90        40
# weighted avg       0.90      0.90      0.90        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #2
# Mean negativities for all classes: [0.0014908792082336641]
# Mean entropies for all classes: [1.584072849828954e-15]
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.80      0.89        20
#          1.0       0.83      1.00      0.91        20
#
#     accuracy                           0.90        40
#    macro avg       0.92      0.90      0.90        40
# weighted avg       0.92      0.90      0.90        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #3
# Mean negativities for all classes: [0.0014229765827846268]
# Mean entropies for all classes: [1.6943770247106915e-15]
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.95      0.97        20
#          1.0       0.95      1.00      0.98        20
#
#     accuracy                           0.97        40
#    macro avg       0.98      0.97      0.97        40
# weighted avg       0.98      0.97      0.97        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #4
# Mean negativities for all classes: [0.0003436152484879634]
# Mean entropies for all classes: [2.767484962397752e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.80      1.00      0.89        20
#          1.0       1.00      0.75      0.86        20
#
#     accuracy                           0.88        40
#    macro avg       0.90      0.88      0.87        40
# weighted avg       0.90      0.88      0.87        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #5
# Mean negativities for all classes: [0.0011736402677562485]
# Mean entropies for all classes: [1.909793005154782e-15]
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.80      0.89        20
#          1.0       0.83      1.00      0.91        20
#
#     accuracy                           0.90        40
#    macro avg       0.92      0.90      0.90        40
# weighted avg       0.92      0.90      0.90        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #6
# Mean negativities for all classes: [0.0011328963318372853]
# Mean entropies for all classes: [1.9028492603771318e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.90      0.90      0.90        20
#          1.0       0.90      0.90      0.90        20
#
#     accuracy                           0.90        40
#    macro avg       0.90      0.90      0.90        40
# weighted avg       0.90      0.90      0.90        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #7
# Mean negativities for all classes: [0.0009390373903536891]
# Mean entropies for all classes: [3.31926092090397e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.89      0.80      0.84        20
#          1.0       0.82      0.90      0.86        20
#
#     accuracy                           0.85        40
#    macro avg       0.85      0.85      0.85        40
# weighted avg       0.85      0.85      0.85        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #8
# Mean negativities for all classes: [0.001285577853932282]
# Mean entropies for all classes: [2.4251012940484216e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.90      0.95      0.93        20
#          1.0       0.95      0.90      0.92        20
#
#     accuracy                           0.93        40
#    macro avg       0.93      0.93      0.92        40
# weighted avg       0.93      0.93      0.92        40
#
# -------------------------------------------------------------------------------------------------------------------
# K-Fold #9
# Mean negativities for all classes: [0.0013545083429739395]
# Mean entropies for all classes: [2.1947317596763455e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.70      0.80        20
#          1.0       0.76      0.95      0.84        20
#
#     accuracy                           0.82        40
#    macro avg       0.85      0.82      0.82        40
# weighted avg       0.85      0.82      0.82        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.9 F1-Scores = 0.8992654100998132 Negativity = [0.001125115618701239, 0.001502016709886575] Entropy = [1.928142900199104e-15, 2.0618868808283925e-15]
# CPU times: total: 14.3 s
# Wall time: 6h 49min 23s
# Media Score dos N K-Fold 0.9038749999999999
# Maior Score dos K-Fold 0.9075
# Menor Score dos K-Fold 0.9
#
#
# [[0.925, 0.925, 0.875, 0.9, 0.825, 0.925, 0.85, 0.975, 0.95, 0.9], [0.95, 0.875, 0.85, 0.825, 0.975, 0.95, 0.975, 0.925, 0.875, 0.825], [0.925, 0.975, 1.0, 0.9, 0.825, 0.925, 0.9, 0.775, 0.925, 0.875], [0.9, 0.875, 0.925, 0.9, 0.875, 0.975, 0.8, 0.9, 0.95, 0.9], [0.925, 0.9, 0.925, 0.875, 0.875, 0.875, 0.9, 0.95, 0.95, 0.875], [0.875, 0.9, 0.925, 0.925, 0.975, 0.95, 0.9, 0.775, 0.85, 0.975], [1.0, 0.875, 0.925, 0.8, 0.85, 0.875, 0.925, 0.925, 0.95, 0.925], [0.9, 0.9, 0.85, 0.85, 0.95, 0.875, 0.975, 0.975, 0.95, 0.825], [0.95, 0.875, 0.875, 0.9, 0.875, 0.85, 0.925, 0.85, 0.95, 0.975], [0.875, 0.95, 0.925, 0.975, 0.9, 0.95, 0.85, 0.85, 0.875, 0.9], [0.825, 0.85, 0.95, 0.925, 0.975, 0.975, 0.9, 0.85, 0.95, 0.85], [0.875, 0.925, 0.875, 0.875, 0.875, 0.975, 0.875, 0.925, 0.95, 0.875], [0.85, 0.875, 0.925, 0.9, 0.975, 0.825, 0.825, 0.95, 0.975, 0.925], [0.925, 0.925, 0.875, 0.875, 0.95, 0.875, 0.925, 0.875, 0.95, 0.875], [0.95, 0.95, 0.925, 0.925, 0.825, 0.825, 0.95, 0.95, 0.9, 0.875], [0.875, 0.85, 0.9, 0.875, 0.925, 0.95, 0.95, 0.875, 0.9, 0.95], [0.85, 0.9, 1.0, 0.85, 0.875, 0.875, 0.925, 0.975, 0.85, 0.95], [0.9, 0.95, 0.9, 0.975, 0.875, 0.9, 0.875, 0.9, 0.825, 0.95], [0.875, 0.875, 0.975, 0.875, 0.875, 0.85, 0.925, 0.95, 0.825, 1.0], [0.95, 0.9, 0.9, 0.975, 0.875, 0.9, 0.9, 0.85, 0.925, 0.825]]
05, 0.0014216017069759168, 0.002395778233957682, 0.002227186537831288, 0.0005805197719240512, 0.002013406669751844, 0.0018764390034124085, 0.0013292782631694477, 0.0009285006506989712, 0.0014425695424191115]], [[0.0015604254954544484, 0.001275622904992163, 0.0011684170720950681, 0.0018117320583291574, 0.0011894299920968882, 0.0016554604405969952, 0.0009358805667761455, 0.0017125302812980386, 0.0012947974515087808, 0.001723423562109669]], [[0.002062761649933803, 0.0010897343402448717, 0.0009907179210776496, 0.0015448681231521127, 0.001536705475965336, 0.0017634082854320527, 0.002183316394481666, 0.0010402141440350066, 0.002224828172845536, 0.0017217451737678914]], [[0.0012176880360695308, 0.0013251437088754898, 0.0003156373213676483, 0.0006316358298798869, 0.0007626546889594465, 0.0016436330885257395, 0.0012850947160144206, 0.001596254695542132, 0.0007251396584034148, 0.0010980778575510747]], [[0.0016056414749682142, 0.0014873916361673955, 0.002043199254424613, 0.001043175416803066, 0.0023857322428978782, 0.0007912502293894369, 0.002255996707842073, 0.002333580662817142, 0.0017478544070569813, 0.0021788667432816517]], [[0.0012207994615465651, 0.0015336939067255278, 0.0015753484083482234, 0.0015730881797706374, 0.002034087909628934, 0.0011276194508496235, 0.001265277505977469, 0.0018883367934500322, 0.0015842355398460405, 0.0014103323111366388]], [[0.001966477321529969, 0.0014326425879901046, 0.0013391296067762875, 0.0015045126629967265, 0.0013877195105550994, 0.0010645892579561084, 0.002008463247272532, 0.0023849097463358227, 0.0006254730619459331, 0.0013530219055474441]], [[0.0010152152785154384, 0.0021840429174746546, 0.001203556 ...
# CPU times: total: 14.4 s
# Wall time: 6h 49min 23s
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished

# %% [markdown]
# # Xor

# %%
# %%time
# %run Experimento-Artificial-Xor-20-10-Fold.ipynb
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #0
# Mean negativities for all classes: [0.2898709712521677]
# Mean entropies for all classes: [2.8380475456142174e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.69      1.00      0.82        20
#          1.0       1.00      0.55      0.71        20
#
#     accuracy                           0.78        40
#    macro avg       0.84      0.78      0.76        40
# weighted avg       0.84      0.78      0.76        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #1
# Mean negativities for all classes: [0.2926719251892153]
# Mean entropies for all classes: [3.071609413429378e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.69      1.00      0.82        20
#          1.0       1.00      0.55      0.71        20
#
#     accuracy                           0.78        40
#    macro avg       0.84      0.78      0.76        40
# weighted avg       0.84      0.78      0.76        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #2
# Mean negativities for all classes: [0.2908171491537745]
# Mean entropies for all classes: [2.491750758574951e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.62      1.00      0.77        20
#          1.0       1.00      0.40      0.57        20
#
#     accuracy                           0.70        40
#    macro avg       0.81      0.70      0.67        40
# weighted avg       0.81      0.70      0.67        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #3
# Mean negativities for all classes: [0.2924180814122622]
# Mean entropies for all classes: [2.6007425782990136e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.65      1.00      0.78        20
#          1.0       1.00      0.45      0.62        20
#
#     accuracy                           0.73        40
#    macro avg       0.82      0.72      0.70        40
# weighted avg       0.82      0.72      0.70        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #4
# Mean negativities for all classes: [0.28827409581447705]
# Mean entropies for all classes: [2.3561301389451942e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.67      1.00      0.80        20
#          1.0       1.00      0.50      0.67        20
#
#     accuracy                           0.75        40
#    macro avg       0.83      0.75      0.73        40
# weighted avg       0.83      0.75      0.73        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #5
# Mean negativities for all classes: [0.2880305711639485]
# Mean entropies for all classes: [2.989623639544817e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.69      1.00      0.82        20
#          1.0       1.00      0.55      0.71        20
#
#     accuracy                           0.78        40
#    macro avg       0.84      0.78      0.76        40
# weighted avg       0.84      0.78      0.76        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #6
# Mean negativities for all classes: [0.25195415009855165]
# Mean entropies for all classes: [2.1275149285231317e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.61      1.00      0.75        20
#          1.0       1.00      0.35      0.52        20
#
#     accuracy                           0.68        40
#    macro avg       0.80      0.68      0.64        40
# weighted avg       0.80      0.68      0.64        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #7
# Mean negativities for all classes: [0.2935372637977749]
# Mean entropies for all classes: [2.064225461879529e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.69      1.00      0.82        20
#          1.0       1.00      0.55      0.71        20
#
#     accuracy                           0.78        40
#    macro avg       0.84      0.78      0.76        40
# weighted avg       0.84      0.78      0.76        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #8
# Mean negativities for all classes: [0.26682182725040227]
# Mean entropies for all classes: [3.8208550787295825e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.62      1.00      0.77        20
#          1.0       1.00      0.40      0.57        20
#
#     accuracy                           0.70        40
#    macro avg       0.81      0.70      0.67        40
# weighted avg       0.81      0.70      0.67        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #9
# Mean negativities for all classes: [0.28746832643816045]
# Mean entropies for all classes: [2.4739167698071886e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.71      1.00      0.83        20
#          1.0       1.00      0.60      0.75        20
#
#     accuracy                           0.80        40
#    macro avg       0.86      0.80      0.79        40
# weighted avg       0.86      0.80      0.79        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.7449999999999999 F1-Scores = 0.725678668075011 Negativity = [0.2898709712521677, 0.2926719251892153] Entropy = [2.8380475456142174e-15, 3.071609413429378e-15]
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #0
# Mean negativities for all classes: [0.2930932619642782]
# Mean entropies for all classes: [2.2545074031914887e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.68      0.95      0.79        20
#          1.0       0.92      0.55      0.69        20
#
#     accuracy                           0.75        40
#    macro avg       0.80      0.75      0.74        40
# weighted avg       0.80      0.75      0.74        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #1
# Mean negativities for all classes: [0.28626643031529736]
# Mean entropies for all classes: [2.216606410057828e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.55      0.90      0.68        20
#          1.0       0.71      0.25      0.37        20
#
#     accuracy                           0.57        40
#    macro avg       0.63      0.57      0.52        40
# weighted avg       0.63      0.57      0.52        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #2
# Mean negativities for all classes: [0.28448667615041334]
# Mean entropies for all classes: [3.3391142665307964e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.71      1.00      0.83        20
#          1.0       1.00      0.60      0.75        20
#
#     accuracy                           0.80        40
#    macro avg       0.86      0.80      0.79        40
# weighted avg       0.86      0.80      0.79        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #3
# Mean negativities for all classes: [0.2901454762379406]
# Mean entropies for all classes: [2.3449590299075364e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.69      1.00      0.82        20
#          1.0       1.00      0.55      0.71        20
#
#     accuracy                           0.78        40
#    macro avg       0.84      0.78      0.76        40
# weighted avg       0.84      0.78      0.76        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #4
# Mean negativities for all classes: [0.2945890046724321]
# Mean entropies for all classes: [2.6713962587905392e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.71      1.00      0.83        20
#          1.0       1.00      0.60      0.75        20
#
#     accuracy                           0.80        40
#    macro avg       0.86      0.80      0.79        40
# weighted avg       0.86      0.80      0.79        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #5
# Mean negativities for all classes: [0.2884739618787223]
# Mean entropies for all classes: [2.4681994351223885e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.71      1.00      0.83        20
#          1.0       1.00      0.60      0.75        20
#
#     accuracy                           0.80        40
#    macro avg       0.86      0.80      0.79        40
# weighted avg       0.86      0.80      0.79        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #6
# Mean negativities for all classes: [0.29018888810681487]
# Mean entropies for all classes: [2.2761109645038073e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.67      1.00      0.80        20
#          1.0       1.00      0.50      0.67        20
#
#     accuracy                           0.75        40
#    macro avg       0.83      0.75      0.73        40
# weighted avg       0.83      0.75      0.73        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #7
# Mean negativities for all classes: [0.26171373184616253]
# Mean entropies for all classes: [1.3965113638364286e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.67      1.00      0.80        20
#          1.0       1.00      0.50      0.67        20
#
#     accuracy                           0.75        40
#    macro avg       0.83      0.75      0.73        40
# weighted avg       0.83      0.75      0.73        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #8
# Mean negativities for all classes: [0.28876783285886154]
# Mean entropies for all classes: [2.8705872284365886e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.65      1.00      0.78        20
#          1.0       1.00      0.45      0.62        20
#
#     accuracy                           0.73        40
#    macro avg       0.82      0.72      0.70        40
# weighted avg       0.82      0.72      0.70        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #9
# Mean negativities for all classes: [0.2546369972079582]
# Mean entropies for all classes: [2.6235436705157803e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.62      1.00      0.77        20
#          1.0       1.00      0.40      0.57        20
#
#     accuracy                           0.70        40
#    macro avg       0.81      0.70      0.67        40
# weighted avg       0.81      0.70      0.67        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.7424999999999999 F1-Scores = 0.7241891162339136 Negativity = [0.2930932619642782, 0.28626643031529736] Entropy = [2.2545074031914887e-15, 2.216606410057828e-15]
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #0
# Mean negativities for all classes: [0.28501572704885414]
# Mean entropies for all classes: [1.5529174495244635e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.69      1.00      0.82        20
#          1.0       1.00      0.55      0.71        20
#
#     accuracy                           0.78        40
#    macro avg       0.84      0.78      0.76        40
# weighted avg       0.84      0.78      0.76        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #1
# Mean negativities for all classes: [0.2580813093510057]
# Mean entropies for all classes: [2.2513733186794164e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.69      1.00      0.82        20
#          1.0       1.00      0.55      0.71        20
#
#     accuracy                           0.78        40
#    macro avg       0.84      0.78      0.76        40
# weighted avg       0.84      0.78      0.76        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #2
# Mean negativities for all classes: [0.2710535277024183]
# Mean entropies for all classes: [3.073553216678965e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.67      1.00      0.80        20
#          1.0       1.00      0.50      0.67        20
#
#     accuracy                           0.75        40
#    macro avg       0.83      0.75      0.73        40
# weighted avg       0.83      0.75      0.73        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #3
# Mean negativities for all classes: [0.2937248771237707]
# Mean entropies for all classes: [2.6416703986299278e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.69      1.00      0.82        20
#          1.0       1.00      0.55      0.71        20
#
#     accuracy                           0.78        40
#    macro avg       0.84      0.78      0.76        40
# weighted avg       0.84      0.78      0.76        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #4
# Mean negativities for all classes: [0.2915214937632188]
# Mean entropies for all classes: [2.069994410540205e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.67      1.00      0.80        20
#          1.0       1.00      0.50      0.67        20
#
#     accuracy                           0.75        40
#    macro avg       0.83      0.75      0.73        40
# weighted avg       0.83      0.75      0.73        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #5
# Mean negativities for all classes: [0.2948029373197401]
# Mean entropies for all classes: [1.9864465468823243e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.67      1.00      0.80        20
#          1.0       1.00      0.50      0.67        20
#
#     accuracy                           0.75        40
#    macro avg       0.83      0.75      0.73        40
# weighted avg       0.83      0.75      0.73        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #6
# Mean negativities for all classes: [0.2873180514276431]
# Mean entropies for all classes: [2.2024623104140316e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.65      1.00      0.78        20
#          1.0       1.00      0.45      0.62        20
#
#     accuracy                           0.73        40
#    macro avg       0.82      0.72      0.70        40
# weighted avg       0.82      0.72      0.70        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #7
# Mean negativities for all classes: [0.29468237424596755]
# Mean entropies for all classes: [2.21852615491745e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.69      1.00      0.82        20
#          1.0       1.00      0.55      0.71        20
#
#     accuracy                           0.78        40
#    macro avg       0.84      0.78      0.76        40
# weighted avg       0.84      0.78      0.76        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #8
# Mean negativities for all classes: [0.2884865835868909]
# Mean entropies for all classes: [2.838642316957459e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.69      1.00      0.82        20
#          1.0       1.00      0.55      0.71        20
#
#     accuracy                           0.78        40
#    macro avg       0.84      0.78      0.76        40
# weighted avg       0.84      0.78      0.76        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #9
# Mean negativities for all classes: [0.2863945241482526]
# Mean entropies for all classes: [2.600942966929138e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.71      1.00      0.83        20
#          1.0       1.00      0.60      0.75        20
#
#     accuracy                           0.80        40
#    macro avg       0.86      0.80      0.79        40
# weighted avg       0.86      0.80      0.79        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.765 F1-Scores = 0.7509178231915682 Negativity = [0.28501572704885414, 0.2580813093510057] Entropy = [1.5529174495244635e-15, 2.2513733186794164e-15]
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #0
# Mean negativities for all classes: [0.29157778884729924]
# Mean entropies for all classes: [1.291540616254033e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.67      1.00      0.80        20
#          1.0       1.00      0.50      0.67        20
#
#     accuracy                           0.75        40
#    macro avg       0.83      0.75      0.73        40
# weighted avg       0.83      0.75      0.73        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #1
# Mean negativities for all classes: [0.284468546036842]
# Mean entropies for all classes: [2.3346913085939918e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.69      1.00      0.82        20
#          1.0       1.00      0.55      0.71        20
#
#     accuracy                           0.78        40
#    macro avg       0.84      0.78      0.76        40
# weighted avg       0.84      0.78      0.76        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #2
# Mean negativities for all classes: [0.29027323541189454]
# Mean entropies for all classes: [2.0632143314212547e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.68      0.95      0.79        20
#          1.0       0.92      0.55      0.69        20
#
#     accuracy                           0.75        40
#    macro avg       0.80      0.75      0.74        40
# weighted avg       0.80      0.75      0.74        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #3
# Mean negativities for all classes: [0.2943603900209409]
# Mean entropies for all classes: [-9.667045204044483e-16]
#               precision    recall  f1-score   support
#
#          0.0       0.69      1.00      0.82        20
#          1.0       1.00      0.55      0.71        20
#
#     accuracy                           0.78        40
#    macro avg       0.84      0.78      0.76        40
# weighted avg       0.84      0.78      0.76        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #4
# Mean negativities for all classes: [0.2536822198108141]
# Mean entropies for all classes: [2.9802759241714558e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.61      0.95      0.75        20
#          1.0       0.89      0.40      0.55        20
#
#     accuracy                           0.68        40
#    macro avg       0.75      0.68      0.65        40
# weighted avg       0.75      0.68      0.65        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #5
# Mean negativities for all classes: [0.001531591640903665]
# Mean entropies for all classes: [4.258179356831168e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.65      1.00      0.78        20
#          1.0       1.00      0.45      0.62        20
#
#     accuracy                           0.73        40
#    macro avg       0.82      0.72      0.70        40
# weighted avg       0.82      0.72      0.70        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #6
# Mean negativities for all classes: [0.2864901758402869]
# Mean entropies for all classes: [2.397996586698907e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.56      0.90      0.69        20
#          1.0       0.75      0.30      0.43        20
#
#     accuracy                           0.60        40
#    macro avg       0.66      0.60      0.56        40
# weighted avg       0.66      0.60      0.56        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #7
# Mean negativities for all classes: [0.2950479350677321]
# Mean entropies for all classes: [3.3450672796073005e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.67      1.00      0.80        20
#          1.0       1.00      0.50      0.67        20
#
#     accuracy                           0.75        40
#    macro avg       0.83      0.75      0.73        40
# weighted avg       0.83      0.75      0.73        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #8
# Mean negativities for all classes: [0.2927162246181504]
# Mean entropies for all classes: [2.3763741730314414e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.77      1.00      0.87        20
#          1.0       1.00      0.70      0.82        20
#
#     accuracy                           0.85        40
#    macro avg       0.88      0.85      0.85        40
# weighted avg       0.88      0.85      0.85        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #9
# Mean negativities for all classes: [0.2918126006432032]
# Mean entropies for all classes: [1.7978055130133113e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.62      1.00      0.77        20
#          1.0       1.00      0.40      0.57        20
#
#     accuracy                           0.70        40
#    macro avg       0.81      0.70      0.67        40
# weighted avg       0.81      0.70      0.67        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.735 F1-Scores = 0.7160483274218985 Negativity = [0.29157778884729924, 0.284468546036842] Entropy = [1.291540616254033e-15, 2.3346913085939918e-15]
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #0
# Mean negativities for all classes: [0.2928771183637891]
# Mean entropies for all classes: [2.184051861592085e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.69      1.00      0.82        20
#          1.0       1.00      0.55      0.71        20
#
#     accuracy                           0.78        40
#    macro avg       0.84      0.78      0.76        40
# weighted avg       0.84      0.78      0.76        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #1
# Mean negativities for all classes: [0.29149025365167064]
# Mean entropies for all classes: [2.2467128490336435e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.71      1.00      0.83        20
#          1.0       1.00      0.60      0.75        20
#
#     accuracy                           0.80        40
#    macro avg       0.86      0.80      0.79        40
# weighted avg       0.86      0.80      0.79        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #2
# Mean negativities for all classes: [0.2907505849263967]
# Mean entropies for all classes: [3.512193466082233e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.69      1.00      0.82        20
#          1.0       1.00      0.55      0.71        20
#
#     accuracy                           0.78        40
#    macro avg       0.84      0.78      0.76        40
# weighted avg       0.84      0.78      0.76        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #3
# Mean negativities for all classes: [0.28933112740662087]
# Mean entropies for all classes: [-3.641918113984341e-16]
#               precision    recall  f1-score   support
#
#          0.0       0.69      1.00      0.82        20
#          1.0       1.00      0.55      0.71        20
#
#     accuracy                           0.78        40
#    macro avg       0.84      0.78      0.76        40
# weighted avg       0.84      0.78      0.76        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #4
# Mean negativities for all classes: [0.25497710719736444]
# Mean entropies for all classes: [2.6635668205259188e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.65      1.00      0.78        20
#          1.0       1.00      0.45      0.62        20
#
#     accuracy                           0.73        40
#    macro avg       0.82      0.72      0.70        40
# weighted avg       0.82      0.72      0.70        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #5
# Mean negativities for all classes: [0.27868621725948145]
# Mean entropies for all classes: [2.8843947577884563e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.62      1.00      0.77        20
#          1.0       1.00      0.40      0.57        20
#
#     accuracy                           0.70        40
#    macro avg       0.81      0.70      0.67        40
# weighted avg       0.81      0.70      0.67        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #6
# Mean negativities for all classes: [0.2542038820561546]
# Mean entropies for all classes: [2.3249227476437393e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.61      1.00      0.75        20
#          1.0       1.00      0.35      0.52        20
#
#     accuracy                           0.68        40
#    macro avg       0.80      0.68      0.64        40
# weighted avg       0.80      0.68      0.64        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #7
# Mean negativities for all classes: [0.28720784308867026]
# Mean entropies for all classes: [2.9079906597245156e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.69      1.00      0.82        20
#          1.0       1.00      0.55      0.71        20
#
#     accuracy                           0.78        40
#    macro avg       0.84      0.78      0.76        40
# weighted avg       0.84      0.78      0.76        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #8
# Mean negativities for all classes: [0.294185985679784]
# Mean entropies for all classes: [3.72515427658978e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.67      1.00      0.80        20
#          1.0       1.00      0.50      0.67        20
#
#     accuracy                           0.75        40
#    macro avg       0.83      0.75      0.73        40
# weighted avg       0.83      0.75      0.73        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #9
# Mean negativities for all classes: [0.2853653795835734]
# Mean entropies for all classes: [2.8539368058567765e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.71      1.00      0.83        20
#          1.0       1.00      0.60      0.75        20
#
#     accuracy                           0.80        40
#    macro avg       0.86      0.80      0.79        40
# weighted avg       0.86      0.80      0.79        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.755 F1-Scores = 0.7378123677087107 Negativity = [0.2928771183637891, 0.29149025365167064] Entropy = [2.184051861592085e-15, 2.2467128490336435e-15]
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #0
# Mean negativities for all classes: [0.2874354502119062]
# Mean entropies for all classes: [2.2764990527416498e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.60      0.90      0.72        20
#          1.0       0.80      0.40      0.53        20
#
#     accuracy                           0.65        40
#    macro avg       0.70      0.65      0.63        40
# weighted avg       0.70      0.65      0.63        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #1
# Mean negativities for all classes: [0.2909619706128024]
# Mean entropies for all classes: [1.7305167015839189e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.71      1.00      0.83        20
#          1.0       1.00      0.60      0.75        20
#
#     accuracy                           0.80        40
#    macro avg       0.86      0.80      0.79        40
# weighted avg       0.86      0.80      0.79        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #2
# Mean negativities for all classes: [0.2891030419072388]
# Mean entropies for all classes: [2.047689198250701e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.67      1.00      0.80        20
#          1.0       1.00      0.50      0.67        20
#
#     accuracy                           0.75        40
#    macro avg       0.83      0.75      0.73        40
# weighted avg       0.83      0.75      0.73        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #3
# Mean negativities for all classes: [0.29102366014251413]
# Mean entropies for all classes: [2.2815664676952087e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.69      1.00      0.82        20
#          1.0       1.00      0.55      0.71        20
#
#     accuracy                           0.78        40
#    macro avg       0.84      0.78      0.76        40
# weighted avg       0.84      0.78      0.76        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #4
# Mean negativities for all classes: [0.2961644324523987]
# Mean entropies for all classes: [3.1274047269353123e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.69      1.00      0.82        20
#          1.0       1.00      0.55      0.71        20
#
#     accuracy                           0.78        40
#    macro avg       0.84      0.78      0.76        40
# weighted avg       0.84      0.78      0.76        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #5
# Mean negativities for all classes: [0.28878639169398]
# Mean entropies for all classes: [2.8602917667806404e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.66      0.95      0.78        20
#          1.0       0.91      0.50      0.65        20
#
#     accuracy                           0.73        40
#    macro avg       0.78      0.72      0.71        40
# weighted avg       0.78      0.72      0.71        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #6
# Mean negativities for all classes: [0.25213532402219785]
# Mean entropies for all classes: [2.8036552126085236e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.57      1.00      0.73        20
#          1.0       1.00      0.25      0.40        20
#
#     accuracy                           0.62        40
#    macro avg       0.79      0.62      0.56        40
# weighted avg       0.79      0.62      0.56        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #7
# Mean negativities for all classes: [0.29125422054181993]
# Mean entropies for all classes: [1.797265271949184e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.59      1.00      0.74        20
#          1.0       1.00      0.30      0.46        20
#
#     accuracy                           0.65        40
#    macro avg       0.79      0.65      0.60        40
# weighted avg       0.79      0.65      0.60        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #8
# Mean negativities for all classes: [0.28762870008617947]
# Mean entropies for all classes: [2.590051180779331e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.71      1.00      0.83        20
#          1.0       1.00      0.60      0.75        20
#
#     accuracy                           0.80        40
#    macro avg       0.86      0.80      0.79        40
# weighted avg       0.86      0.80      0.79        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #9
# Mean negativities for all classes: [0.2892135811905726]
# Mean entropies for all classes: [2.8529956371481637e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.65      1.00      0.78        20
#          1.0       1.00      0.45      0.62        20
#
#     accuracy                           0.73        40
#    macro avg       0.82      0.72      0.70        40
# weighted avg       0.82      0.72      0.70        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.7274999999999999 F1-Scores = 0.7046950685609794 Negativity = [0.2874354502119062, 0.2909619706128024] Entropy = [2.2764990527416498e-15, 1.7305167015839189e-15]
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #0
# Mean negativities for all classes: [0.279451832196643]
# Mean entropies for all classes: [3.2389976536209753e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.71      1.00      0.83        20
#          1.0       1.00      0.60      0.75        20
#
#     accuracy                           0.80        40
#    macro avg       0.86      0.80      0.79        40
# weighted avg       0.86      0.80      0.79        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #1
# Mean negativities for all classes: [0.2901109955776783]
# Mean entropies for all classes: [3.9607699487454255e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.71      1.00      0.83        20
#          1.0       1.00      0.60      0.75        20
#
#     accuracy                           0.80        40
#    macro avg       0.86      0.80      0.79        40
# weighted avg       0.86      0.80      0.79        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #2
# Mean negativities for all classes: [0.2844534123229091]
# Mean entropies for all classes: [1.5307998333123875e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.68      0.95      0.79        20
#          1.0       0.92      0.55      0.69        20
#
#     accuracy                           0.75        40
#    macro avg       0.80      0.75      0.74        40
# weighted avg       0.80      0.75      0.74        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #3
# Mean negativities for all classes: [0.29511432770532087]
# Mean entropies for all classes: [4.855889830272797e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.67      1.00      0.80        20
#          1.0       1.00      0.50      0.67        20
#
#     accuracy                           0.75        40
#    macro avg       0.83      0.75      0.73        40
# weighted avg       0.83      0.75      0.73        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #4
# Mean negativities for all classes: [0.2892308308673783]
# Mean entropies for all classes: [2.6661813375500146e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.69      1.00      0.82        20
#          1.0       1.00      0.55      0.71        20
#
#     accuracy                           0.78        40
#    macro avg       0.84      0.78      0.76        40
# weighted avg       0.84      0.78      0.76        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #5
# Mean negativities for all classes: [0.2943402211963904]
# Mean entropies for all classes: [2.404059761214344e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.69      1.00      0.82        20
#          1.0       1.00      0.55      0.71        20
#
#     accuracy                           0.78        40
# ...
# Mean entropies for all classes: [2.6459077238380257e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.69      1.00      0.82        20
#          1.0       1.00      0.55      0.71        20
#
#     accuracy                           0.78        40
#    macro avg       0.84      0.78      0.76        40
# weighted avg       0.84      0.78      0.76        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #2
# Mean negativities for all classes: [0.25330327432830296]
# Mean entropies for all classes: [2.941796615559422e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.57      1.00      0.73        20
#          1.0       1.00      0.25      0.40        20
#
#     accuracy                           0.62        40
#    macro avg       0.79      0.62      0.56        40
# weighted avg       0.79      0.62      0.56        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #3
# Mean negativities for all classes: [0.29136204306140157]
# Mean entropies for all classes: [1.8579853858098644e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.61      1.00      0.75        20
#          1.0       1.00      0.35      0.52        20
#
#     accuracy                           0.68        40
#    macro avg       0.80      0.68      0.64        40
# weighted avg       0.80      0.68      0.64        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #4
# Mean negativities for all classes: [0.2919188060048435]
# Mean entropies for all classes: [3.1951560968396796e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.68      0.95      0.79        20
#          1.0       0.92      0.55      0.69        20
#
#     accuracy                           0.75        40
#    macro avg       0.80      0.75      0.74        40
# weighted avg       0.80      0.75      0.74        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #5
# Mean negativities for all classes: [0.0008261440289350774]
# Mean entropies for all classes: [2.6804279122060338e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.65      1.00      0.78        20
#          1.0       1.00      0.45      0.62        20
#
#     accuracy                           0.73        40
#    macro avg       0.82      0.72      0.70        40
# weighted avg       0.82      0.72      0.70        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #6
# Mean negativities for all classes: [0.2918205002399056]
# Mean entropies for all classes: [2.7375603408084513e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.69      0.90      0.78        20
#          1.0       0.86      0.60      0.71        20
#
#     accuracy                           0.75        40
#    macro avg       0.77      0.75      0.74        40
# weighted avg       0.77      0.75      0.74        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #7
# Mean negativities for all classes: [0.2881220741332779]
# Mean entropies for all classes: [2.8886380460888796e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.69      1.00      0.82        20
#          1.0       1.00      0.55      0.71        20
#
#     accuracy                           0.78        40
#    macro avg       0.84      0.78      0.76        40
# weighted avg       0.84      0.78      0.76        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #8
# Mean negativities for all classes: [0.2890778053100321]
# Mean entropies for all classes: [1.8618964388678643e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.63      0.95      0.76        20
#          1.0       0.90      0.45      0.60        20
#
#     accuracy                           0.70        40
#    macro avg       0.77      0.70      0.68        40
# weighted avg       0.77      0.70      0.68        40
#
# -------------------------------------------------------------------------------------------------------------------
# K-Fold #9
# Mean negativities for all classes: [0.2880803543147744]
# Mean entropies for all classes: [2.033485771873532e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.71      1.00      0.83        20
#          1.0       1.00      0.60      0.75        20
#
#     accuracy                           0.80        40
#    macro avg       0.86      0.80      0.79        40
# weighted avg       0.86      0.80      0.79        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.735 F1-Scores = 0.7147257253040266 Negativity = [0.29178502882073115, 0.290053327205863] Entropy = [2.4105719069344973e-15, 2.6459077238380257e-15]
# CPU times: total: 14.7 s
# Wall time: 7h 14min 57s
# Media Score dos N K-Fold 0.7408749999999998
# Maior Score dos K-Fold 0.765
# Menor Score dos K-Fold 0.7025
#
#
# [[0.775, 0.775, 0.7, 0.725, 0.75, 0.775, 0.675, 0.775, 0.7, 0.8], [0.75, 0.575, 0.8, 0.775, 0.8, 0.8, 0.75, 0.75, 0.725, 0.7], [0.775, 0.775, 0.75, 0.775, 0.75, 0.75, 0.725, 0.775, 0.775, 0.8], [0.75, 0.775, 0.75, 0.775, 0.675, 0.725, 0.6, 0.75, 0.85, 0.7], [0.775, 0.8, 0.775, 0.775, 0.725, 0.7, 0.675, 0.775, 0.75, 0.8], [0.65, 0.8, 0.75, 0.775, 0.775, 0.725, 0.625, 0.65, 0.8, 0.725], [0.8, 0.8, 0.75, 0.75, 0.775, 0.775, 0.75, 0.775, 0.7, 0.625], [0.675, 0.825, 0.8, 0.7, 0.75, 0.675, 0.825, 0.8, 0.725, 0.725], [0.85, 0.7, 0.6, 0.75, 0.725, 