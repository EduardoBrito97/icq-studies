# %%
normalize_axis = 1
load_inputvector_env_state = True

# %% [markdown]
# # Blobs

# %%
# %%time
# %run Experimento-Artificial-Blobs-20-10-Fold.ipynb
# Out:
# Intel(R) Extension for Scikit-learn* enabled (https://github.com/intel/scikit-learn-intelex)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #0
# Mean negativities for all classes: [0.0971663628008322]
# Mean entropies for all classes: [3.968192431502715e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.58      0.95      0.72        20
#          1.0       0.86      0.30      0.44        20
#
#     accuracy                           0.62        40
#    macro avg       0.72      0.62      0.58        40
# weighted avg       0.72      0.62      0.58        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #1
# Mean negativities for all classes: [0.1710757654908119]
# Mean entropies for all classes: [3.1756335194148424e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.57      0.80      0.67        20
#          1.0       0.67      0.40      0.50        20
#
#     accuracy                           0.60        40
#    macro avg       0.62      0.60      0.58        40
# weighted avg       0.62      0.60      0.58        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #2
# Mean negativities for all classes: [0.26865423984228365]
# Mean entropies for all classes: [7.088947370562273e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.66      0.95      0.78        20
#          1.0       0.91      0.50      0.65        20
#
#     accuracy                           0.73        40
#    macro avg       0.78      0.72      0.71        40
# weighted avg       0.78      0.72      0.71        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #3
# Mean negativities for all classes: [0.14857298263346522]
# Mean entropies for all classes: [2.9898942021054747e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.62      0.65      0.63        20
#          1.0       0.63      0.60      0.62        20
#
#     accuracy                           0.62        40
#    macro avg       0.63      0.62      0.62        40
# weighted avg       0.63      0.62      0.62        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #4
# Mean negativities for all classes: [0.15026249318083518]
# Mean entropies for all classes: [3.289934974531448e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.63      0.95      0.76        20
#          1.0       0.90      0.45      0.60        20
#
#     accuracy                           0.70        40
#    macro avg       0.77      0.70      0.68        40
# weighted avg       0.77      0.70      0.68        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #5
# Mean negativities for all classes: [0.20627318114839652]
# Mean entropies for all classes: [2.1805638163676444e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.55      0.90      0.68        20
#          1.0       0.71      0.25      0.37        20
#
#     accuracy                           0.57        40
#    macro avg       0.63      0.57      0.52        40
# weighted avg       0.63      0.57      0.52        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #6
# Mean negativities for all classes: [0.34351532747483005]
# Mean entropies for all classes: [2.7384127487830197e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.52      0.85      0.64        20
#          1.0       0.57      0.20      0.30        20
#
#     accuracy                           0.53        40
#    macro avg       0.54      0.53      0.47        40
# weighted avg       0.54      0.53      0.47        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #7
# Mean negativities for all classes: [0.16445695950936773]
# Mean entropies for all classes: [3.143961399806939e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.70      0.70      0.70        20
#          1.0       0.70      0.70      0.70        20
#
#     accuracy                           0.70        40
#    macro avg       0.70      0.70      0.70        40
# weighted avg       0.70      0.70      0.70        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #8
# Mean negativities for all classes: [0.15526527103399576]
# Mean entropies for all classes: [2.3961651176282776e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.58      0.90      0.71        20
#          1.0       0.78      0.35      0.48        20
#
#     accuracy                           0.62        40
#    macro avg       0.68      0.62      0.59        40
# weighted avg       0.68      0.62      0.59        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #9
# Mean negativities for all classes: [0.31035773664824184]
# Mean entropies for all classes: [3.129605460615844e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.49      0.85      0.62        20
#          1.0       0.40      0.10      0.16        20
#
#     accuracy                           0.48        40
#    macro avg       0.44      0.47      0.39        40
# weighted avg       0.44      0.47      0.39        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.6174999999999999 F1-Scores = 0.5856269434949637 Negativity = [0.0971663628008322, 0.1710757654908119] Entropy = [3.968192431502715e-15, 3.1756335194148424e-15]
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #0
# Mean negativities for all classes: [0.17393299329340012]
# Mean entropies for all classes: [2.3446087517432058e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.59      0.85      0.69        20
#          1.0       0.73      0.40      0.52        20
#
#     accuracy                           0.62        40
#    macro avg       0.66      0.62      0.61        40
# weighted avg       0.66      0.62      0.61        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #1
# Mean negativities for all classes: [0.13729955491902626]
# Mean entropies for all classes: [3.957075371001338e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.61      0.95      0.75        20
#          1.0       0.89      0.40      0.55        20
#
#     accuracy                           0.68        40
#    macro avg       0.75      0.68      0.65        40
# weighted avg       0.75      0.68      0.65        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #2
# Mean negativities for all classes: [0.15350454656634532]
# Mean entropies for all classes: [2.3378516123209073e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.62      0.65      0.63        20
#          1.0       0.63      0.60      0.62        20
#
#     accuracy                           0.62        40
#    macro avg       0.63      0.62      0.62        40
# weighted avg       0.63      0.62      0.62        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #3
# Mean negativities for all classes: [0.16144797519654733]
# Mean entropies for all classes: [2.9632521734641286e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.61      0.95      0.75        20
#          1.0       0.89      0.40      0.55        20
#
#     accuracy                           0.68        40
#    macro avg       0.75      0.68      0.65        40
# weighted avg       0.75      0.68      0.65        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #4
# Mean negativities for all classes: [0.1742561370377961]
# Mean entropies for all classes: [2.4965886638312793e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.57      1.00      0.73        20
#          1.0       1.00      0.25      0.40        20
#
#     accuracy                           0.62        40
#    macro avg       0.79      0.62      0.56        40
# weighted avg       0.79      0.62      0.56        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #5
# Mean negativities for all classes: [0.14263094779851535]
# Mean entropies for all classes: [-1.9170299357653295e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.58      0.90      0.71        20
#          1.0       0.78      0.35      0.48        20
#
#     accuracy                           0.62        40
#    macro avg       0.68      0.62      0.59        40
# weighted avg       0.68      0.62      0.59        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #6
# Mean negativities for all classes: [0.15418054031094414]
# Mean entropies for all classes: [2.543104632397644e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.63      0.85      0.72        20
#          1.0       0.77      0.50      0.61        20
#
#     accuracy                           0.68        40
#    macro avg       0.70      0.68      0.66        40
# weighted avg       0.70      0.68      0.66        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #7
# Mean negativities for all classes: [0.15149857740894926]
# Mean entropies for all classes: [2.886303537348572e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.54      0.65      0.59        20
#          1.0       0.56      0.45      0.50        20
#
#     accuracy                           0.55        40
#    macro avg       0.55      0.55      0.55        40
# weighted avg       0.55      0.55      0.55        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #8
# Mean negativities for all classes: [0.3149903174464065]
# Mean entropies for all classes: [3.0804733177117862e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.58      0.90      0.71        20
#          1.0       0.78      0.35      0.48        20
#
#     accuracy                           0.62        40
#    macro avg       0.68      0.62      0.59        40
# weighted avg       0.68      0.62      0.59        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #9
# Mean negativities for all classes: [0.15541720523979433]
# Mean entropies for all classes: [2.497249045405499e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.63      0.85      0.72        20
#          1.0       0.77      0.50      0.61        20
#
#     accuracy                           0.68        40
#    macro avg       0.70      0.68      0.66        40
# weighted avg       0.70      0.68      0.66        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.6375 F1-Scores = 0.6153787691311468 Negativity = [0.17393299329340012, 0.13729955491902626] Entropy = [2.3446087517432058e-15, 3.957075371001338e-15]
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #0
# Mean negativities for all classes: [0.003452656756212194]
# Mean entropies for all classes: [2.0065877885582736e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.63      0.95      0.76        20
#          1.0       0.90      0.45      0.60        20
#
#     accuracy                           0.70        40
#    macro avg       0.77      0.70      0.68        40
# weighted avg       0.77      0.70      0.68        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #1
# Mean negativities for all classes: [0.17238081274236064]
# Mean entropies for all classes: [2.6868096275918436e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.56      0.90      0.69        20
#          1.0       0.75      0.30      0.43        20
#
#     accuracy                           0.60        40
#    macro avg       0.66      0.60      0.56        40
# weighted avg       0.66      0.60      0.56        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #2
# Mean negativities for all classes: [0.16632326979422438]
# Mean entropies for all classes: [3.812289944532149e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.59      0.80      0.68        20
#          1.0       0.69      0.45      0.55        20
#
#     accuracy                           0.62        40
#    macro avg       0.64      0.62      0.61        40
# weighted avg       0.64      0.62      0.61        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #3
# Mean negativities for all classes: [0.19015818252724062]
# Mean entropies for all classes: [1.8120624713592883e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.52      0.85      0.64        20
#          1.0       0.57      0.20      0.30        20
#
#     accuracy                           0.53        40
#    macro avg       0.54      0.53      0.47        40
# weighted avg       0.54      0.53      0.47        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #4
# Mean negativities for all classes: [0.14205029726748375]
# Mean entropies for all classes: [2.6244326342482146e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.62      0.90      0.73        20
#          1.0       0.82      0.45      0.58        20
#
#     accuracy                           0.68        40
#    macro avg       0.72      0.68      0.66        40
# weighted avg       0.72      0.68      0.66        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #5
# Mean negativities for all classes: [0.16161190204597706]
# Mean entropies for all classes: [3.0612368061739558e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.58      0.70      0.64        20
#          1.0       0.62      0.50      0.56        20
#
#     accuracy                           0.60        40
#    macro avg       0.60      0.60      0.60        40
# weighted avg       0.60      0.60      0.60        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #6
# Mean negativities for all classes: [0.2274986979917653]
# Mean entropies for all classes: [2.8793404214332166e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.62      1.00      0.77        20
#          1.0       1.00      0.40      0.57        20
#
#     accuracy                           0.70        40
#    macro avg       0.81      0.70      0.67        40
# weighted avg       0.81      0.70      0.67        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #7
# Mean negativities for all classes: [0.12286468508909845]
# Mean entropies for all classes: [3.132171340719464e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.66      0.95      0.78        20
#          1.0       0.91      0.50      0.65        20
#
#     accuracy                           0.73        40
#    macro avg       0.78      0.72      0.71        40
# weighted avg       0.78      0.72      0.71        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #8
# Mean negativities for all classes: [0.2926775554438909]
# Mean entropies for all classes: [2.153140484376198e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.67      1.00      0.80        20
#          1.0       1.00      0.50      0.67        20
#
#     accuracy                           0.75        40
#    macro avg       0.83      0.75      0.73        40
# weighted avg       0.83      0.75      0.73        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #9
# Mean negativities for all classes: [0.32615320360857475]
# Mean entropies for all classes: [3.3859949173616874e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.57      0.85      0.68        20
#          1.0       0.70      0.35      0.47        20
#
#     accuracy                           0.60        40
#    macro avg       0.63      0.60      0.57        40
# weighted avg       0.63      0.60      0.57        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.6499999999999999 F1-Scores = 0.6263456429789718 Negativity = [0.003452656756212194, 0.17238081274236064] Entropy = [2.0065877885582736e-15, 2.6868096275918436e-15]
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #0
# Mean negativities for all classes: [0.1698851264291618]
# Mean entropies for all classes: [2.8667584894796038e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.52      0.85      0.64        20
#          1.0       0.57      0.20      0.30        20
#
#     accuracy                           0.53        40
#    macro avg       0.54      0.53      0.47        40
# weighted avg       0.54      0.53      0.47        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #1
# Mean negativities for all classes: [0.1562143637213189]
# Mean entropies for all classes: [2.331240827395332e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.58      0.90      0.71        20
#          1.0       0.78      0.35      0.48        20
#
#     accuracy                           0.62        40
#    macro avg       0.68      0.62      0.59        40
# weighted avg       0.68      0.62      0.59        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #2
# Mean negativities for all classes: [0.16423175752458238]
# Mean entropies for all classes: [2.711335294153118e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.64      0.80      0.71        20
#          1.0       0.73      0.55      0.63        20
#
#     accuracy                           0.68        40
#    macro avg       0.69      0.68      0.67        40
# weighted avg       0.69      0.68      0.67        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #3
# Mean negativities for all classes: [0.1635612541170132]
# Mean entropies for all classes: [2.9224191677114853e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.60      0.90      0.72        20
#          1.0       0.80      0.40      0.53        20
#
#     accuracy                           0.65        40
#    macro avg       0.70      0.65      0.63        40
# weighted avg       0.70      0.65      0.63        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #4
# Mean negativities for all classes: [0.24183686609723934]
# Mean entropies for all classes: [2.5645350262310452e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.61      0.95      0.75        20
#          1.0       0.89      0.40      0.55        20
#
#     accuracy                           0.68        40
#    macro avg       0.75      0.68      0.65        40
# weighted avg       0.75      0.68      0.65        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #5
# Mean negativities for all classes: [0.2672703569580329]
# Mean entropies for all classes: [2.271030861717398e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.57      0.85      0.68        20
#          1.0       0.70      0.35      0.47        20
#
#     accuracy                           0.60        40
#    macro avg       0.63      0.60      0.57        40
# weighted avg       0.63      0.60      0.57        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #6
# Mean negativities for all classes: [0.2879637946458228]
# Mean entropies for all classes: [-2.3851641230107006e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.57      0.85      0.68        20
#          1.0       0.70      0.35      0.47        20
#
#     accuracy                           0.60        40
#    macro avg       0.63      0.60      0.57        40
# weighted avg       0.63      0.60      0.57        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #7
# Mean negativities for all classes: [0.003973375274224205]
# Mean entropies for all classes: [3.2816040799142362e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.63      0.95      0.76        20
#          1.0       0.90      0.45      0.60        20
#
#     accuracy                           0.70        40
#    macro avg       0.77      0.70      0.68        40
# weighted avg       0.77      0.70      0.68        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #8
# Mean negativities for all classes: [0.1648314150808786]
# Mean entropies for all classes: [2.780001958277297e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.63      0.85      0.72        20
#          1.0       0.77      0.50      0.61        20
#
#     accuracy                           0.68        40
#    macro avg       0.70      0.68      0.66        40
# weighted avg       0.70      0.68      0.66        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #9
# Mean negativities for all classes: [0.30378242148475537]
# Mean entropies for all classes: [4.326326994662149e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.58      0.70      0.64        20
#          1.0       0.62      0.50      0.56        20
#
#     accuracy                           0.60        40
#    macro avg       0.60      0.60      0.60        40
# weighted avg       0.60      0.60      0.60        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.6325 F1-Scores = 0.6095501070342133 Negativity = [0.1698851264291618, 0.1562143637213189] Entropy = [2.8667584894796038e-15, 2.331240827395332e-15]
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #0
# Mean negativities for all classes: [0.16018938785080375]
# Mean entropies for all classes: [2.692708301975496e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.58      0.90      0.71        20
#          1.0       0.78      0.35      0.48        20
#
#     accuracy                           0.62        40
#    macro avg       0.68      0.62      0.59        40
# weighted avg       0.68      0.62      0.59        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #1
# Mean negativities for all classes: [0.17918271244201595]
# Mean entropies for all classes: [2.7006264896918415e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.63      0.85      0.72        20
#          1.0       0.77      0.50      0.61        20
#
#     accuracy                           0.68        40
#    macro avg       0.70      0.68      0.66        40
# weighted avg       0.70      0.68      0.66        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #2
# Mean negativities for all classes: [0.000527329407329491]
# Mean entropies for all classes: [3.276088333079634e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.53      0.85      0.65        20
#          1.0       0.62      0.25      0.36        20
#
#     accuracy                           0.55        40
#    macro avg       0.58      0.55      0.51        40
# weighted avg       0.58      0.55      0.51        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #3
# Mean negativities for all classes: [0.1604761696801946]
# Mean entropies for all classes: [3.000937211923655e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.63      0.95      0.76        20
#          1.0       0.90      0.45      0.60        20
#
#     accuracy                           0.70        40
#    macro avg       0.77      0.70      0.68        40
# weighted avg       0.77      0.70      0.68        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #4
# Mean negativities for all classes: [0.14596231402585827]
# Mean entropies for all classes: [2.300186860181653e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.70      0.80      0.74        20
#          1.0       0.76      0.65      0.70        20
#
#     accuracy                           0.73        40
#    macro avg       0.73      0.73      0.72        40
# weighted avg       0.73      0.72      0.72        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #5
# Mean negativities for all classes: [0.1627228870972924]
# Mean entropies for all classes: [2.2137319814869857e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.63      0.85      0.72        20
#          1.0       0.77      0.50      0.61        20
#
#     accuracy                           0.68        40
#    macro avg       0.70      0.68      0.66        40
# weighted avg       0.70      0.68      0.66        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #6
# Mean negativities for all classes: [0.05011734730425825]
# Mean entropies for all classes: [2.5856617933965364e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.62      0.90      0.73        20
#          1.0       0.82      0.45      0.58        20
#
#     accuracy                           0.68        40
#    macro avg       0.72      0.68      0.66        40
# weighted avg       0.72      0.68      0.66        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #7
# Mean negativities for all classes: [0.3178412354031187]
# Mean entropies for all classes: [2.8710665042100755e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.57      1.00      0.73        20
#          1.0       1.00      0.25      0.40        20
#
#     accuracy                           0.62        40
#    macro avg       0.79      0.62      0.56        40
# weighted avg       0.79      0.62      0.56        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #8
# Mean negativities for all classes: [0.3235468517928187]
# Mean entropies for all classes: [2.8104383263256664e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.59      0.95      0.73        20
#          1.0       0.88      0.35      0.50        20
#
#     accuracy                           0.65        40
#    macro avg       0.73      0.65      0.62        40
# weighted avg       0.73      0.65      0.62        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #9
# Mean negativities for all classes: [0.06723994040724342]
# Mean entropies for all classes: [3.169250515450111e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.53      0.85      0.65        20
#          1.0       0.62      0.25      0.36        20
#
#     accuracy                           0.55        40
#    macro avg       0.58      0.55      0.51        40
# weighted avg       0.58      0.55      0.51        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.645 F1-Scores = 0.6174909232232997 Negativity = [0.16018938785080375, 0.17918271244201595] Entropy = [2.692708301975496e-15, 2.7006264896918415e-15]
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #0
# Mean negativities for all classes: [0.18644698407390364]
# Mean entropies for all classes: [2.5955377535297553e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.59      0.80      0.68        20
#          1.0       0.69      0.45      0.55        20
#
#     accuracy                           0.62        40
#    macro avg       0.64      0.62      0.61        40
# weighted avg       0.64      0.62      0.61        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #1
# Mean negativities for all classes: [0.16758805118834683]
# Mean entropies for all classes: [2.5710616388551535e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.62      0.90      0.73        20
#          1.0       0.82      0.45      0.58        20
#
#     accuracy                           0.68        40
#    macro avg       0.72      0.68      0.66        40
# weighted avg       0.72      0.68      0.66        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #2
# Mean negativities for all classes: [0.15795607276170023]
# Mean entropies for all classes: [3.052310977080005e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.63      0.85      0.72        20
#          1.0       0.77      0.50      0.61        20
#
#     accuracy                           0.68        40
#    macro avg       0.70      0.68      0.66        40
# weighted avg       0.70      0.68      0.66        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #3
# Mean negativities for all classes: [0.14918234366184277]
# Mean entropies for all classes: [4.234026242555742e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.61      1.00      0.75        20
#          1.0       1.00      0.35      0.52        20
#
#     accuracy                           0.68        40
#    macro avg       0.80      0.68      0.64        40
# weighted avg       0.80      0.68      0.64        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #4
# Mean negativities for all classes: [0.31380823420021187]
# Mean entropies for all classes: [3.306397265923762e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.60      0.90      0.72        20
#          1.0       0.80      0.40      0.53        20
#
#     accuracy                           0.65        40
#    macro avg       0.70      0.65      0.63        40
# weighted avg       0.70      0.65      0.63        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #5
# Mean negativities for all classes: [0.16795328610938323]
# Mean entropies for all classes: [2.8674520705874834e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.57      0.85      0.68        20
#          1.0       0.70      0.35      0.47        20
#
#     accuracy                           0.60        40
#    macro avg       0.63      0.60      0.57        40
# weighted avg       0.63      0.60      0.57        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #6
# Mean negativities for all classes: [0.16041653695585462]
# Mean entropies for all classes: [2.7041883853245525e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.53      0.80      0.64        20
#          1.0       0.60      0.30      0.40        20
#
#     accuracy                           0.55        40
#    macro avg       0.57      0.55      0.52        40
# weighted avg       0.57      0.55      0.52        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #7
# Mean negativities for all classes: [0.15902437561790778]
# Mean entropies for all classes: [2.6049754877267273e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.60      0.90      0.72        20
#          1.0       0.80      0.40      0.53        20
#
#     accuracy                           0.65        40
#    macro avg       0.70      0.65      0.63        40
# weighted avg       0.70      0.65      0.63        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #8
# Mean negativities for all classes: [0.15802017729376183]
# Mean entropies for all classes: [2.5789307983454034e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.55      0.80      0.65        20
#          1.0       0.64      0.35      0.45        20
#
#     accuracy                           0.57        40
#    macro avg       0.59      0.57      0.55        40
# weighted avg       0.59      0.57      0.55        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #9
# Mean negativities for all classes: [0.17068298786256095]
# Mean entropies for all classes: [2.935928198984493e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.64      0.70      0.67        20
#          1.0       0.67      0.60      0.63        20
#
#     accuracy                           0.65        40
#    macro avg       0.65      0.65      0.65        40
# weighted avg       0.65      0.65      0.65        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.6325000000000001 F1-Scores = 0.6120299042120024 Negativity = [0.18644698407390364, 0.16758805118834683] Entropy = [2.5955377535297553e-15, 2.5710616388551535e-15]
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #0
# Mean negativities for all classes: [0.1762660032146064]
# Mean entropies for all classes: [2.25916316742113e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.53      0.90      0.67        20
#          1.0       0.67      0.20      0.31        20
#
#     accuracy                           0.55        40
#    macro avg       0.60      0.55      0.49        40
# weighted avg       0.60      0.55      0.49        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #1
# Mean negativities for all classes: [0.2112074402004594]
# Mean entropies for all classes: [3.3733816673707906e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.53      0.95      0.68        20
#          1.0       0.75      0.15      0.25        20
#
#     accuracy                           0.55        40
#    macro avg       0.64      0.55      0.46        40
# weighted avg       0.64      0.55      0.46        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #2
# Mean negativities for all classes: [0.3233517341268349]
# Mean entropies for all classes: [1.1244842427476204e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.54      0.95      0.69        20
#          1.0       0.80      0.20      0.32        20
#
#     accuracy                           0.57        40
#    macro avg       0.67      0.57      0.51        40
# weighted avg       0.67      0.57      0.51        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #3
# Mean negativities for all classes: [0.14813519450920626]
# Mean entropies for all classes: [2.731146157763137e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.58      0.75      0.65        20
#          1.0       0.64      0.45      0.53        20
#
#     accuracy                           0.60        40
#    macro avg       0.61      0.60      0.59        40
# weighted avg       0.61      0.60      0.59        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #4
# Mean negativities for all classes: [0.14712944638506653]
# Mean entropies for all classes: [2.822307906816595e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.58      0.75      0.65        20
#          1.0       0.64      0.45      0.53        20
#
#     accuracy                           0.60        40
#    macro avg       0.61      0.60      0.59        40
# weighted avg       0.61      0.60      0.59        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #5
# Mean negativities for all classes: [0.18932888795935954]
# Mean entropies for all classes: [2.547500841903773e-15]
#               precision    recall  f1-score   support
#
# ...
# K-Fold #1
# Mean negativities for all classes: [0.3076771669567039]
# Mean entropies for all classes: [3.200380540727126e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.56      0.90      0.69        20
#          1.0       0.75      0.30      0.43        20
#
#     accuracy                           0.60        40
#    macro avg       0.66      0.60      0.56        40
# weighted avg       0.66      0.60      0.56        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #2
# Mean negativities for all classes: [0.3031324828799703]
# Mean entropies for all classes: [2.605869296015469e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.52      0.85      0.64        20
#          1.0       0.57      0.20      0.30        20
#
#     accuracy                           0.53        40
#    macro avg       0.54      0.53      0.47        40
# weighted avg       0.54      0.53      0.47        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #3
# Mean negativities for all classes: [0.0038388858043274603]
# Mean entropies for all classes: [2.600751490182415e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.55      0.90      0.68        20
#          1.0       0.71      0.25      0.37        20
#
#     accuracy                           0.57        40
#    macro avg       0.63      0.57      0.52        40
# weighted avg       0.63      0.57      0.52        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #4
# Mean negativities for all classes: [0.30776011112061086]
# Mean entropies for all classes: [2.9161383799936615e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.60      0.75      0.67        20
#          1.0       0.67      0.50      0.57        20
#
#     accuracy                           0.62        40
#    macro avg       0.63      0.62      0.62        40
# weighted avg       0.63      0.62      0.62        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #5
# Mean negativities for all classes: [0.0018617875668886785]
# Mean entropies for all classes: [3.638568129793368e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.52      0.80      0.63        20
#          1.0       0.56      0.25      0.34        20
#
#     accuracy                           0.53        40
#    macro avg       0.54      0.53      0.49        40
# weighted avg       0.54      0.53      0.49        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #6
# Mean negativities for all classes: [0.15853900849202146]
# Mean entropies for all classes: [2.8851029780348612e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.53      0.80      0.64        20
#          1.0       0.60      0.30      0.40        20
#
#     accuracy                           0.55        40
#    macro avg       0.57      0.55      0.52        40
# weighted avg       0.57      0.55      0.52        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #7
# Mean negativities for all classes: [0.16327341501088505]
# Mean entropies for all classes: [2.6417323897380398e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.58      0.95      0.72        20
#          1.0       0.86      0.30      0.44        20
#
#     accuracy                           0.62        40
#    macro avg       0.72      0.62      0.58        40
# weighted avg       0.72      0.62      0.58        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #8
# Mean negativities for all classes: [0.31174339507009574]
# Mean entropies for all classes: [2.177327921210171e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.61      1.00      0.75        20
#          1.0       1.00      0.35      0.52        20
#
#     accuracy                           0.68        40
#    macro avg       0.80      0.68      0.64        40
# weighted avg       0.80      0.68      0.64        40
#
# -------------------------------------------------------------------------------------------------------------------
# K-Fold #9
# Mean negativities for all classes: [0.17075401832192721]
# Mean entropies for all classes: [2.7934564355238234e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.59      0.85      0.69        20
#          1.0       0.73      0.40      0.52        20
#
#     accuracy                           0.62        40
#    macro avg       0.66      0.62      0.61        40
# weighted avg       0.66      0.62      0.61        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.5925 F1-Scores = 0.5525480508144621 Negativity = [0.22588188326462627, 0.3076771669567039] Entropy = [2.938919153219445e-15, 3.200380540727126e-15]
# CPU times: total: 14 s
# Wall time: 7h 6min 35s
# Media Score dos N K-Fold 0.6289999999999999
# Maior Score dos K-Fold 0.6499999999999999
# Menor Score dos K-Fold 0.5925
#
#
# [[0.625, 0.6, 0.725, 0.625, 0.7, 0.575, 0.525, 0.7, 0.625, 0.475], [0.625, 0.675, 0.625, 0.675, 0.625, 0.625, 0.675, 0.55, 0.625, 0.675], [0.7, 0.6, 0.625, 0.525, 0.675, 0.6, 0.7, 0.725, 0.75, 0.6], [0.525, 0.625, 0.675, 0.65, 0.675, 0.6, 0.6, 0.7, 0.675, 0.6], [0.625, 0.675, 0.55, 0.7, 0.725, 0.675, 0.675, 0.625, 0.65, 0.55], [0.625, 0.675, 0.675, 0.675, 0.65, 0.6, 0.55, 0.65, 0.575, 0.65], [0.55, 0.55, 0.575, 0.6, 0.6, 0.75, 0.6, 0.6, 0.575, 0.525], [0.7, 0.625, 0.5, 0.525, 0.65, 0.6, 0.75, 0.675, 0.425, 0.6], [0.7, 0.55, 0.575, 0.7, 0.6, 0.725, 0.625, 0.625, 0.725, 0.6], [0.6, 0.625, 0.65, 0.575, 0.7, 0.575, 0.65, 0.6, 0.6, 0.7], [0.65, 0.575, 0.575, 0.7, 0.625, 0.55, 0.7, 0.65, 0.625, 0.575], [0.475, 0.725, 0.725, 0.625, 0.65, 0.65, 0.7, 0.525, 0.65, 0.6], [0.7, 0.65, 0.65, 0.475, 0.675, 0.55, 0.75, 0.
20
#
#     accuracy                           0.38        40
#    macro avg       0.37      0.38      0.37        40
# weighted avg       0.37      0.38      0.37        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #3
# Mean negativities for all classes: [0.033500429755123254]
# Mean entropies for all classes: [2.122712206931849e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.46      0.60      0.52        20
#          1.0       0.43      0.30      0.35        20
#
#     accuracy                           0.45        40
#    macro avg       0.45      0.45      0.44        40
# weighted avg       0.45      0.45      0.44        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #4
# Mean negativities for all classes: [0.2851715138309302]
# Mean entropies for all classes: [2.311182838275688e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.52      0.85      0.64        20
#          1.0       0.57      0.20      0.30        20
#
#     accuracy                           0.53        40
#    macro avg       0.54      0.53      0.47        40
# weighted avg       0.54      0.53      0.47        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #5
# Mean negativities for all classes: [0.014732752389561959]
# Mean entropies for all classes: [2.475160266981533e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.56      0.50      0.53        20
#          1.0       0.55      0.60      0.57        20
#
#     accuracy                           0.55        40
#    macro avg       0.55      0.55      0.55        40
# weighted avg       0.55      0.55      0.55        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #6
# Mean negativities for all classes: [0.23488067072434732]
# Mean entropies for all classes: [2.0230455633772737e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.36      0.45      0.40        20
#          1.0       0.27      0.20      0.23        20
#
#     accuracy                           0.33        40
#    macro avg       0.31      0.33      0.31        40
# weighted avg       0.31      0.33      0.31        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #7
# Mean negativities for all classes: [0.2329564711917856]
# Mean entropies for all classes: [2.240741368931125e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.60      0.55        20
#          1.0       0.50      0.40      0.44        20
#
#     accuracy                           0.50        40
#    macro avg       0.50      0.50      0.49        40
# weighted avg       0.50      0.50      0.49        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #8
# Mean negativities for all classes: [0.12440675502225551]
# Mean entropies for all classes: [2.19790421189692e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.48      0.60      0.53        20
#          1.0       0.47      0.35      0.40        20
#
#     accuracy                           0.48        40
#    macro avg       0.47      0.47      0.47        40
# weighted avg       0.47      0.47      0.47        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #9
# Mean negativities for all classes: [0.23056636898396404]
# Mean entropies for all classes: [2.537383036415145e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.54      0.75      0.63        20
#          1.0       0.58      0.35      0.44        20
#
#     accuracy                           0.55        40
#    macro avg       0.56      0.55      0.53        40
# weighted avg       0.56      0.55      0.53        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.475 F1-Scores = 0.46157552849298594 Negativity = [0.2144988485201607, 0.05845394339662495] Entropy = [2.8983583368511196e-15, 2.389639138277229e-15]
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #0
# Mean negativities for all classes: [0.25303079612943724]
# Mean entropies for all classes: [2.8947607699542654e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.43      0.45      0.44        20
#          1.0       0.42      0.40      0.41        20
#
#     accuracy                           0.42        40
#    macro avg       0.42      0.43      0.42        40
# weighted avg       0.42      0.42      0.42        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #1
# Mean negativities for all classes: [0.15300611878319895]
# Mean entropies for all classes: [2.698841472661282e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.55      0.52        20
#          1.0       0.50      0.45      0.47        20
#
#     accuracy                           0.50        40
#    macro avg       0.50      0.50      0.50        40
# weighted avg       0.50      0.50      0.50        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #2
# Mean negativities for all classes: [0.1274927745515077]
# Mean entropies for all classes: [2.1158957831777273e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.44      0.55      0.49        20
#          1.0       0.40      0.30      0.34        20
#
#     accuracy                           0.42        40
#    macro avg       0.42      0.43      0.42        40
# weighted avg       0.42      0.42      0.42        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #3
# Mean negativities for all classes: [0.007662270280796768]
# Mean entropies for all classes: [2.1880577677541393e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.50      0.50        20
#          1.0       0.50      0.50      0.50        20
#
#     accuracy                           0.50        40
#    macro avg       0.50      0.50      0.50        40
# weighted avg       0.50      0.50      0.50        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #4
# Mean negativities for all classes: [0.054840294030603476]
# Mean entropies for all classes: [2.2904031054251902e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.54      0.75      0.63        20
#          1.0       0.58      0.35      0.44        20
#
#     accuracy                           0.55        40
#    macro avg       0.56      0.55      0.53        40
# weighted avg       0.56      0.55      0.53        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #5
# Mean negativities for all classes: [0.2548553084420053]
# Mean entropies for all classes: [1.9412440082304596e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.48      0.80      0.60        20
#          1.0       0.43      0.15      0.22        20
#
#     accuracy                           0.48        40
#    macro avg       0.46      0.48      0.41        40
# weighted avg       0.46      0.47      0.41        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #6
# Mean negativities for all classes: [0.040429543310153845]
# Mean entropies for all classes: [2.5354803273442527e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.33      0.20      0.25        20
#          1.0       0.43      0.60      0.50        20
#
#     accuracy                           0.40        40
#    macro avg       0.38      0.40      0.38        40
# weighted avg       0.38      0.40      0.38        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #7
# Mean negativities for all classes: [0.24727402353206812]
# Mean entropies for all classes: [2.33867569240929e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.53      0.80      0.64        20
#          1.0       0.60      0.30      0.40        20
#
#     accuracy                           0.55        40
#    macro avg       0.57      0.55      0.52        40
# weighted avg       0.57      0.55      0.52        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #8
# Mean negativities for all classes: [0.03485044155795913]
# Mean entropies for all classes: [2.306804027052305e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.54      0.65      0.59        20
#          1.0       0.56      0.45      0.50        20
#
#     accuracy                           0.55        40
#    macro avg       0.55      0.55      0.55        40
# weighted avg       0.55      0.55      0.55        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #9
# Mean negativities for all classes: [0.026012015913819596]
# Mean entropies for all classes: [2.2109426885678746e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.53      0.90      0.67        20
#          1.0       0.67      0.20      0.31        20
#
#     accuracy                           0.55        40
#    macro avg       0.60      0.55      0.49        40
# weighted avg       0.60      0.55      0.49        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.4925 F1-Scores = 0.47111422194890656 Negativity = [0.25303079612943724, 0.15300611878319895] Entropy = [2.8947607699542654e-15, 2.698841472661282e-15]
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #0
# Mean negativities for all classes: [0.2522066212034967]
# Mean entropies for all classes: [2.9460740568112556e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.47      0.90      0.62        20
#          1.0       0.00      0.00      0.00        20
#
#     accuracy                           0.45        40
#    macro avg       0.24      0.45      0.31        40
# weighted avg       0.24      0.45      0.31        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #1
# Mean negativities for all classes: [0.005485118188527713]
# Mean entropies for all classes: [3.303272520157612e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.40      0.20      0.27        20
#          1.0       0.47      0.70      0.56        20
#
#     accuracy                           0.45        40
#    macro avg       0.43      0.45      0.41        40
# weighted avg       0.43      0.45      0.41        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #2
# Mean negativities for all classes: [0.22716708471660257]
# Mean entropies for all classes: [2.8302014642064145e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.41      0.55      0.47        20
#          1.0       0.31      0.20      0.24        20
#
#     accuracy                           0.38        40
#    macro avg       0.36      0.38      0.36        40
# weighted avg       0.36      0.38      0.36        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #3
# Mean negativities for all classes: [0.12388116684158659]
# Mean entropies for all classes: [2.3362730335111164e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.42      0.50      0.45        20
#          1.0       0.38      0.30      0.33        20
#
#     accuracy                           0.40        40
#    macro avg       0.40      0.40      0.39        40
# weighted avg       0.40      0.40      0.39        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #4
# Mean negativities for all classes: [0.2303344305493648]
# Mean entropies for all classes: [2.7278411562603484e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.52      0.60      0.56        20
#          1.0       0.53      0.45      0.49        20
#
#     accuracy                           0.53        40
#    macro avg       0.53      0.53      0.52        40
# weighted avg       0.53      0.53      0.52        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #5
# Mean negativities for all classes: [0.08029503901130908]
# Mean entropies for all classes: [2.5707169405053418e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.41      0.35      0.38        20
#          1.0       0.43      0.50      0.47        20
#
#     accuracy                           0.42        40
#    macro avg       0.42      0.42      0.42        40
# weighted avg       0.42      0.42      0.42        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #6
# Mean negativities for all classes: [0.032072877006700445]
# Mean entropies for all classes: [2.721605692694469e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.49      0.85      0.62        20
#          1.0       0.40      0.10      0.16        20
#
#     accuracy                           0.48        40
#    macro avg       0.44      0.47      0.39        40
# weighted avg       0.44      0.47      0.39        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #7
# Mean negativities for all classes: [0.2053169855944091]
# Mean entropies for all classes: [2.359463942889904e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.45      0.47        20
#          1.0       0.50      0.55      0.52        20
#
#     accuracy                           0.50        40
#    macro avg       0.50      0.50      0.50        40
# weighted avg       0.50      0.50      0.50        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #8
# Mean negativities for all classes: [0.05366895217614205]
# Mean entropies for all classes: [2.2792295264214523e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.44      0.55      0.49        20
#          1.0       0.40      0.30      0.34        20
#
#     accuracy                           0.42        40
#    macro avg       0.42      0.43      0.42        40
# weighted avg       0.42      0.42      0.42        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #9
# Mean negativities for all classes: [0.0657760491277106]
# Mean entropies for all classes: [3.12446989534954e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.38      0.30      0.33        20
#          1.0       0.42      0.50      0.45        20
#
#     accuracy                           0.40        40
#    macro avg       0.40      0.40      0.39        40
# weighted avg       0.40      0.40      0.39        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.4425 F1-Scores = 0.41145827547429603 Negativity = [0.2522066212034967, 0.005485118188527713] Entropy = [2.9460740568112556e-15, 3.303272520157612e-15]
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #0
# Mean negativities for all classes: [0.05603353975047502]
# Mean entropies for all classes: [2.7280331550687292e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.42      0.25      0.31        20
#          1.0       0.46      0.65      0.54        20
#
#     accuracy                           0.45        40
#    macro avg       0.44      0.45      0.43        40
# weighted avg       0.44      0.45      0.43        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #1
# Mean negativities for all classes: [0.011978875657011232]
# Mean entropies for all classes: [2.65184591736151e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.43      0.60      0.50        20
#          1.0       0.33      0.20      0.25        20
#
#     accuracy                           0.40        40
#    macro avg       0.38      0.40      0.38        40
# weighted avg       0.38      0.40      0.38        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #2
# Mean negativities for all classes: [0.008023729046682531]
# Mean entropies for all classes: [2.710584897850912e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.43      0.50      0.47        20
#          1.0       0.41      0.35      0.38        20
#
#     accuracy                           0.42        40
#    macro avg       0.42      0.42      0.42        40
# weighted avg       0.42      0.42      0.42        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #3
# Mean negativities for all classes: [0.19009268187562617]
# Mean entropies for all classes: [2.826076931281668e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.48      0.55      0.51        20
#          1.0       0.47      0.40      0.43        20
#
#     accuracy                           0.48        40
#    macro avg       0.47      0.48      0.47        40
# weighted avg       0.47      0.47      0.47        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #4
# Mean negativities for all classes: [0.07941896938666629]
# Mean entropies for all classes: [2.4063167534124626e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.48      0.65      0.55        20
#          1.0       0.46      0.30      0.36        20
#
#     accuracy                           0.48        40
#    macro avg       0.47      0.47      0.46        40
# weighted avg       0.47      0.47      0.46        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #5
# Mean negativities for all classes: [0.09729729155825495]
# Mean entropies for all classes: [2.148951430726444e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.58      0.75      0.65        20
#          1.0       0.64      0.45      0.53        20
#
#     accuracy                           0.60        40
#    macro avg       0.61      0.60      0.59        40
# weighted avg       0.61      0.60      0.59        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #6
# Mean negativities for all classes: [0.2228159081088606]
# Mean entropies for all classes: [2.270795180374091e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.40      0.30      0.34        20
#          1.0       0.44      0.55      0.49        20
#
#     accuracy                           0.42        40
#    macro avg       0.42      0.43      0.42        40
# weighted avg       0.42      0.42      0.42        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #7
# Mean negativities for all classes: [0.12555142128117205]
# Mean entropies for all classes: [2.5831702997703567e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.44      0.55      0.49        20
#          1.0       0.40      0.30      0.34        20
#
#     accuracy                           0.42        40
#    macro avg       0.42      0.43      0.42        40
# weighted avg       0.42      0.42      0.42        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #8
# Mean negativities for all classes: [0.048216481258144886]
# Mean entropies for all classes: [2.3785049118667733e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.47      0.40      0.43        20
#          1.0       0.48      0.55      0.51        20
#
#     accuracy                           0.48        40
#    macro avg       0.47      0.48      0.47        40
# weighted avg       0.47      0.47      0.47        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #9
# Mean negativities for all classes: [0.2510759740281604]
# Mean entropies for all classes: [3.351318990600564e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.52      0.70      0.60        20
#          1.0       0.54      0.35      0.42        20
#
#     accuracy                           0.53        40
#    macro avg       0.53      0.52      0.51        40
# weighted avg       0.53      0.53      0.51        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.46749999999999997 F1-Scores = 0.45588373511330715 Negativity = [0.05603353975047502, 0.011978875657011232] Entropy = [2.7280331550687292e-15, 2.65184591736151e-15]
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #0
# Mean negativities for all classes: [0.07265150746838928]
# Mean entropies for all classes: [2.137502261413047e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.57      0.80      0.67        20
#          1.0       0.67      0.40      0.50        20
#
#     accuracy                           0.60        40
#    macro avg       0.62      0.60      0.58        40
# weighted avg       0.62      0.60      0.58        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #1
# Mean negativities for all classes: [0.23753165442718177]
# Mean entropies for all classes: [2.120567164810699e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.48      0.80      0.60        20
#          1.0       0.43      0.15      0.22        20
#
#     accuracy                           0.48        40
#    macro avg       0.46      0.48      0.41        40
# weighted avg       0.46      0.47      0.41        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #2
# Mean negativities for all classes: [0.1630323996790463]
# Mean entropies for all classes: [2.71474622373103e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.60      0.55        20
#          1.0       0.50      0.40      0.44        20
#
#     accuracy                           0.50        40
#    macro avg       0.50      0.50      0.49        40
# weighted avg       0.50      0.50      0.49        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #3
# Mean negativities for all classes: [0.04544266771018758]
# Mean entropies for all classes: [8.611465629468292e-16]
#               precision    recall  f1-score   support
#
#          0.0       0.49      0.90      0.63        20
#          1.0       0.33      0.05      0.09        20
#
#     accuracy                           0.48        40
#    macro avg       0.41      0.48      0.36        40
# weighted avg       0.41      0.47      0.36        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #4
# Mean negativities for all classes: [0.10902352104461796]
# Mean entropies for all classes: [3.113095782587893e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.70      0.58        20
#          1.0       0.50      0.30      0.37        20
#
#     accuracy                           0.50        40
#    macro avg       0.50      0.50      0.48        40
# weighted avg       0.50      0.50      0.48        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #5
# Mean negativities for all classes: [0.01942065605809702]
# Mean entropies for all classes: [2.240688356427538e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.52      0.65      0.58        20
#          1.0       0.53      0.40      0.46        20
#
#     accuracy                           0.53        40
#    macro avg       0.53      0.53      0.52        40
# weighted avg       0.53      0.53      0.52        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #6
# Mean negativities for all classes: [0.20866606384803119]
# Mean entropies for all classes: [2.8093847206819366e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.45      0.50      0.48        20
#          1.0       0.44      0.40      0.42        20
#
#     accuracy                           0.45        40
#    macro avg       0.45      0.45      0.45        40
# weighted avg       0.45      0.45      0.45        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #7
# Mean negativities for all classes: [0.2140459177309176]
# Mean entropies for all classes: [3.124890354307003e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.47      0.45      0.46        20
#          1.0       0.48      0.50      0.49        20
#
#     accuracy                           0.48        40
#    macro avg       0.47      0.47      0.47        40
# weighted avg       0.47      0.47      0.47        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #8
# Mean negativities for all classes: [0.02690182633584055]
# Mean entropies for all classes: [2.5241932722853536e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.70      0.58        20
#          1.0       0.50      0.30      0.37        20
#
#     accuracy                           0.50        40
#    macro avg       0.50      0.50      0.48        40
# weighted avg       0.50      0.50      0.48        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #9
# Mean negativities for all classes: [0.22390136083206733]
# Mean entropies for all classes: [3.3421181832110673e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.65      0.57        20
#          1.0       0.50      0.35      0.41        20
#
#     accuracy                           0.50        40
#    macro avg       0.50      0.50      0.49        40
# weighted avg       0.50      0.50      0.49        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.5 F1-Scores = 0.4738126389465879 Negativity = [0.07265150746838928, 0.23753165442718177] Entropy = [2.137502261413047e-15, 2.120567164810699e-15]
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #0
# Mean negativities for all classes: [0.11582301719059278]
# Mean entropies for all classes: [2.0609545546129798e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.46      0.55      0.50        20
#          1.0       0.44      0.35      0.39        20
#
#     accuracy                           0.45        40
#    macro avg       0.45      0.45      0.44        40
# weighted avg       0.45      0.45      0.44        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #1
# Mean negativities for all classes: [0.005480482653516616]
# Mean entropies for all classes: [2.9291984987787623e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.42      0.40      0.41        20
#          1.0       0.43      0.45      0.44        20
#
#     accuracy                           0.42        40
#    macro avg       0.42      0.43      0.42        40
# weighted avg       0.42      0.42      0.42        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #2
# Mean negativities for all classes: [0.21890382755375365]
# Mean entropies for all classes: [2.5491201926342525e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.45      0.47        20
#          1.0       0.50      0.55      0.52        20
#
#     accuracy                           0.50        40
#    macro avg       0.50      0.50      0.50        40
# weighted avg       0.50      0.50      0.50        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #3
# Mean negativities for all classes: [0.18022393558906352]
# Mean entropies for all classes: [2.397632514449517e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.52      0.60      0.56        20
#          1.0       0.53      0.45      0.49        20
#
#     accuracy                           0.53        40
#    macro avg       0.53      0.53      0.52        40
# weighted avg       0.53      0.53      0.52        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #4
# Mean negativities for all classes: [0.08529630516828737]
# Mean entropies for all classes: [2.827968991867369e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.58      0.70      0.64        20
#          1.0       0.62      0.50      0.56        20
#
#     accuracy                           0.60        40
#    macro avg       0.60      0.60      0.60        40
# weighted avg       0.60      0.60      0.60        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #5
# Mean negativities for all classes: [0.0682620608263064]
# Mean entropies for all classes: [2.881400128132061e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.39      0.35      0.37        20
#          1.0       0.41      0.45      0.43        20
#
#     accuracy                           0.40        40
#    macro avg       0.40      0.40      0.40        40
# weighted avg       0.40      0.40      0.40        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #6
# Mean negativities for all classes: [0.035490756888229266]
# Mean entropies for all classes: [2.3649650902675705e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.27      0.15      0.19        20
#          1.0       0.41      0.60      0.49        20
#
#     accuracy                           0.38        40
#    macro avg       0.34      0.38      0.34        40
# weighted avg       0.34      0.38      0.34        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #7
# Mean negativities for all classes: [0.13114496406883655]
# Mean entropies for all classes: [2.6854560169798373e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.53      0.80      0.64        20
#          1.0       0.60      0.30      0.40        20
#
#     accuracy                           0.55        40
#    macro avg       0.57      0.55      0.52        40
# weighted avg       0.57      0.55      0.52        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #8
# Mean negativities for all classes: [0.17611443517934305]
# Mean entropies for all classes: [2.0279912741728306e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.48      0.80      0.60        20
#          1.0       0.43      0.15      0.22        20
#
#     accuracy                           0.48        40
#    macro avg       0.46      0.48      0.41        40
# weighted avg       0.46      0.47      0.41        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #9
# Mean negativities for all classes: [0.2239921847858209]
# Mean entropies for all classes: [2.9779826232121243e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.58      0.55      0.56        20
#          1.0       0.57      0.60      0.59        20
#
#     accuracy                           0.57        40
#    macro avg       0.58      0.57      0.57        40
# weighted avg       0.58      0.57      0.57        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.4875 F1-Scores = 0.4734004824285277 Negativity = [0.11582301719059278, 0.005480482653516616] Entropy = [2.0609545546129798e-15, 2.9291984987787623e-15]
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #0
# Mean negativities for all classes: [0.24637449460781286]
# Mean entropies for all classes: [2.447308823525696e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.48      0.70      0.57        20
#          1.0       0.45      0.25      0.32        20
#
#     accuracy                           0.48        40
#    macro avg       0.47      0.47      0.45        40
# weighted avg       0.47      0.47      0.45        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #1
# Mean negativities for all classes: [0.27295178277493365]
# Mean entropies for all classes: [2.4576475157722862e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.48      0.65      0.55        20
#          1.0       0.46      0.30      0.36        20
#
#     accuracy                           0.48        40
#    macro avg       0.47      0.47      0.46        40
# weighted avg       0.47      0.47      0.46        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #2
# Mean negativities for all classes: [0.053499282539290025]
# Mean entropies for all classes: [2.6075425707754764e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.55      0.30      0.39        20
#          1.0       0.52      0.75      0.61        20
#
#     accuracy                           0.53        40
#    macro avg       0.53      0.53      0.50        40
# weighted avg       0.53      0.53      0.50        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #3
# Mean negativities for all classes: [0.25457875267659524]
# Mean entropies for all classes: [3.0331375408030958e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.45      0.65      0.53        20
#          1.0       0.36      0.20      0.26        20
#
#     accuracy                           0.42        40
#    macro avg       0.41      0.43      0.39        40
# weighted avg       0.41      0.42      0.39        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #4
# Mean negativities for all classes: [0.07551890160087413]
# Mean entropies for all classes: [4.086201658135909e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.49      0.95      0.64        20
#          1.0       0.00      0.00      0.00        20
#
#     accuracy                           0.48        40
#    macro avg       0.24      0.47      0.32        40
# weighted avg       0.24      0.47      0.32        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #5
# Mean negativities for all classes: [0.12985678446599355]
# Mean entropies for all classes: [2.4121237843079548e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.43      0.65      0.52        20
#          1.0       0.30      0.15      0.20        20
#
# ...
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #1
# Mean negativities for all classes: [0.016510243951721945]
# Mean entropies for all classes: [2.5611751485394714e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.59      0.65      0.62        20
#          1.0       0.61      0.55      0.58        20
#
#     accuracy                           0.60        40
#    macro avg       0.60      0.60      0.60        40
# weighted avg       0.60      0.60      0.60        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #2
# Mean negativities for all classes: [0.20846763531388784]
# Mean entropies for all classes: [2.5297553142909446e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.36      0.20      0.26        20
#          1.0       0.45      0.65      0.53        20
#
#     accuracy                           0.42        40
#    macro avg       0.41      0.43      0.39        40
# weighted avg       0.41      0.42      0.39        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #3
# Mean negativities for all classes: [0.04097567727383602]
# Mean entropies for all classes: [2.2427400898336275e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.43      0.65      0.52        20
#          1.0       0.30      0.15      0.20        20
#
#     accuracy                           0.40        40
#    macro avg       0.37      0.40      0.36        40
# weighted avg       0.37      0.40      0.36        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #4
# Mean negativities for all classes: [0.1634044129030227]
# Mean entropies for all classes: [2.3816794062982542e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.43      0.30      0.35        20
#          1.0       0.46      0.60      0.52        20
#
#     accuracy                           0.45        40
#    macro avg       0.45      0.45      0.44        40
# weighted avg       0.45      0.45      0.44        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #5
# Mean negativities for all classes: [0.14744886806755847]
# Mean entropies for all classes: [1.974909976910234e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.38      0.30      0.33        20
#          1.0       0.42      0.50      0.45        20
#
#     accuracy                           0.40        40
#    macro avg       0.40      0.40      0.39        40
# weighted avg       0.40      0.40      0.39        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #6
# Mean negativities for all classes: [0.2261953045784722]
# Mean entropies for all classes: [2.4030432065252325e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.48      0.55      0.51        20
#          1.0       0.47      0.40      0.43        20
#
#     accuracy                           0.48        40
#    macro avg       0.47      0.48      0.47        40
# weighted avg       0.47      0.47      0.47        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #7
# Mean negativities for all classes: [0.01925850015724536]
# Mean entropies for all classes: [2.985667958514175e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.48      0.50      0.49        20
#          1.0       0.47      0.45      0.46        20
#
#     accuracy                           0.48        40
#    macro avg       0.47      0.47      0.47        40
# weighted avg       0.47      0.47      0.47        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #8
# Mean negativities for all classes: [0.24513469925287928]
# Mean entropies for all classes: [1.989516037582019e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.55      0.52        20
#          1.0       0.50      0.45      0.47        20
#
#     accuracy                           0.50        40
#    macro avg       0.50      0.50      0.50        40
# weighted avg       0.50      0.50      0.50        40
#
# -------------------------------------------------------------------------------------------------------------------
# K-Fold #9
# Mean negativities for all classes: [0.10711342073782237]
# Mean entropies for all classes: [2.119812170887281e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.60      0.55        20
#          1.0       0.50      0.40      0.44        20
#
#     accuracy                           0.50        40
#    macro avg       0.50      0.50      0.49        40
# weighted avg       0.50      0.50      0.49        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.
780641911052683, 0.1822423760923125]], [[0.10524236798433131, 0.2070478629797797, 0.13963828826313002, 0.14129388034718376, 0.21159694921696764, 0.10139625499115837, 0.1189173094590944, 0.07700546793145094, 0.22945235429291752, 0.219355831669718]], [[0.007083438541640693, 0.09686336116213286, 0.006988635630007639, 0.17297635628027624, 0.11582402654479355, 0.21357104766296375, 0.1315519129608, 0.04839798581104521, 0.012315717768404854, 0.2558270447323374]], [[0.21631899177767727, 0.14807638652078575, 0.24500448807689984, 0.2147326557817233, 0.10157944414933913, 0.027867245217231457, 0.03487103491408926, 0.11549825941161924, 0.20428581621608966, 0.01775850560212321]], [[0.198434899562553, 0.012056953846186037, 0.2685228369782724, 0.20939640765971373, 0.20182065823346065, 0.2096405228789112, 0.23791925944317333, 0.05 ...
# CPU times: total: 13.9 s
# Wall time: 7h 42s
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished

# %% [markdown]
# # Ellipses

# %%
# %%time
# %run Experimento-Artificial-Elipses-20-10-Fold.ipynb
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #0
# Mean negativities for all classes: [0.237911931654114]
# Mean entropies for all classes: [2.3532006563637854e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.56      0.50      0.53        20
#          1.0       0.55      0.60      0.57        20
#
#     accuracy                           0.55        40
#    macro avg       0.55      0.55      0.55        40
# weighted avg       0.55      0.55      0.55        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #1
# Mean negativities for all classes: [0.013047328438690766]
# Mean entropies for all classes: [1.1726692597189848e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00        20
#          1.0       0.49      0.95      0.64        20
#
#     accuracy                           0.48        40
#    macro avg       0.24      0.47      0.32        40
# weighted avg       0.24      0.47      0.32        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #2
# Mean negativities for all classes: [0.2179837461701685]
# Mean entropies for all classes: [1.7164839606614466e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.20      0.29        20
#          1.0       0.50      0.80      0.62        20
#
#     accuracy                           0.50        40
#    macro avg       0.50      0.50      0.45        40
# weighted avg       0.50      0.50      0.45        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #3
# Mean negativities for all classes: [0.24249675953913935]
# Mean entropies for all classes: [1.8908487459865697e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.43      0.15      0.22        20
#          1.0       0.48      0.80      0.60        20
#
#     accuracy                           0.48        40
#    macro avg       0.46      0.48      0.41        40
# weighted avg       0.46      0.47      0.41        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #4
# Mean negativities for all classes: [0.2572451798031309]
# Mean entropies for all classes: [1.6007481591309237e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.85      0.63        20
#          1.0       0.50      0.15      0.23        20
#
#     accuracy                           0.50        40
#    macro avg       0.50      0.50      0.43        40
# weighted avg       0.50      0.50      0.43        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #5
# Mean negativities for all classes: [0.1995890134380943]
# Mean entropies for all classes: [1.5947171087717003e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.10      0.17        20
#          1.0       0.50      0.90      0.64        20
#
#     accuracy                           0.50        40
#    macro avg       0.50      0.50      0.40        40
# weighted avg       0.50      0.50      0.40        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #6
# Mean negativities for all classes: [0.020090273887264355]
# Mean entropies for all classes: [1.2924862766777033e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00        20
#          1.0       0.43      0.75      0.55        20
#
#     accuracy                           0.38        40
#    macro avg       0.21      0.38      0.27        40
# weighted avg       0.21      0.38      0.27        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #7
# Mean negativities for all classes: [0.23579648124780395]
# Mean entropies for all classes: [3.166619634255084e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.10      0.17        20
#          1.0       0.50      0.90      0.64        20
#
#     accuracy                           0.50        40
#    macro avg       0.50      0.50      0.40        40
# weighted avg       0.50      0.50      0.40        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #8
# Mean negativities for all classes: [0.20647270286810784]
# Mean entropies for all classes: [2.329568690976022e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.50      1.00      0.67        20
#          1.0       0.00      0.00      0.00        20
#
#     accuracy                           0.50        40
#    macro avg       0.25      0.50      0.33        40
# weighted avg       0.25      0.50      0.33        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #9
# Mean negativities for all classes: [0.2582424973617524]
# Mean entropies for all classes: [1.94048351960571e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.47      0.70      0.56        20
#          1.0       0.40      0.20      0.27        20
#
#     accuracy                           0.45        40
#    macro avg       0.43      0.45      0.41        40
# weighted avg       0.43      0.45      0.41        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.48250000000000004 F1-Scores = 0.3993570611986784 Negativity = [0.237911931654114, 0.013047328438690766] Entropy = [2.3532006563637854e-15, 1.1726692597189848e-15]
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #0
# Mean negativities for all classes: [0.21762051201794047]
# Mean entropies for all classes: [2.393119444555985e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.55      0.60      0.57        20
#          1.0       0.56      0.50      0.53        20
#
#     accuracy                           0.55        40
#    macro avg       0.55      0.55      0.55        40
# weighted avg       0.55      0.55      0.55        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #1
# Mean negativities for all classes: [0.2280020687872061]
# Mean entropies for all classes: [1.8910780867378195e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.33      0.10      0.15        20
#          1.0       0.47      0.80      0.59        20
#
#     accuracy                           0.45        40
#    macro avg       0.40      0.45      0.37        40
# weighted avg       0.40      0.45      0.37        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #2
# Mean negativities for all classes: [0.06591828086600812]
# Mean entropies for all classes: [1.9843684820949552e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.36      0.25      0.29        20
#          1.0       0.42      0.55      0.48        20
#
#     accuracy                           0.40        40
#    macro avg       0.39      0.40      0.39        40
# weighted avg       0.39      0.40      0.39        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #3
# Mean negativities for all classes: [0.02554547182639011]
# Mean entropies for all classes: [1.6613582886123163e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.55      0.30      0.39        20
#          1.0       0.52      0.75      0.61        20
#
#     accuracy                           0.53        40
#    macro avg       0.53      0.53      0.50        40
# weighted avg       0.53      0.53      0.50        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #4
# Mean negativities for all classes: [0.16200856077974507]
# Mean entropies for all classes: [8.916270494607073e-16]
#               precision    recall  f1-score   support
#
#          0.0       0.71      0.60      0.65        20
#          1.0       0.65      0.75      0.70        20
#
#     accuracy                           0.68        40
#    macro avg       0.68      0.68      0.67        40
# weighted avg       0.68      0.68      0.67        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #5
# Mean negativities for all classes: [0.20219807638194923]
# Mean entropies for all classes: [2.1602578528618936e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.80      0.62        20
#          1.0       0.50      0.20      0.29        20
#
#     accuracy                           0.50        40
#    macro avg       0.50      0.50      0.45        40
# weighted avg       0.50      0.50      0.45        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #6
# Mean negativities for all classes: [0.1374580498471305]
# Mean entropies for all classes: [2.2536297072790156e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.67      0.10      0.17        20
#          1.0       0.51      0.95      0.67        20
#
#     accuracy                           0.53        40
#    macro avg       0.59      0.53      0.42        40
# weighted avg       0.59      0.53      0.42        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #7
# Mean negativities for all classes: [0.13922194990363274]
# Mean entropies for all classes: [1.6251120103025646e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.49      0.90      0.63        20
#          1.0       0.33      0.05      0.09        20
#
#     accuracy                           0.48        40
#    macro avg       0.41      0.48      0.36        40
# weighted avg       0.41      0.47      0.36        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #8
# Mean negativities for all classes: [0.20973043436419517]
# Mean entropies for all classes: [1.694502344201683e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.52      0.60      0.56        20
#          1.0       0.53      0.45      0.49        20
#
#     accuracy                           0.53        40
#    macro avg       0.53      0.53      0.52        40
# weighted avg       0.53      0.53      0.52        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #9
# Mean negativities for all classes: [0.034470024338270545]
# Mean entropies for all classes: [1.6292042068940355e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00        20
#          1.0       0.50      1.00      0.67        20
#
#     accuracy                           0.50        40
#    macro avg       0.25      0.50      0.33        40
# weighted avg       0.25      0.50      0.33        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.5125 F1-Scores = 0.4566866565879664 Negativity = [0.21762051201794047, 0.2280020687872061] Entropy = [2.393119444555985e-15, 1.8910780867378195e-15]
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #0
# Mean negativities for all classes: [0.19577457796184022]
# Mean entropies for all classes: [1.8090912229437533e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.36      0.20      0.26        20
#          1.0       0.45      0.65      0.53        20
#
#     accuracy                           0.42        40
#    macro avg       0.41      0.43      0.39        40
# weighted avg       0.41      0.42      0.39        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #1
# Mean negativities for all classes: [0.021671954311817624]
# Mean entropies for all classes: [1.7169621838953843e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.57      0.65      0.60        20
#          1.0       0.59      0.50      0.54        20
#
#     accuracy                           0.57        40
#    macro avg       0.58      0.57      0.57        40
# weighted avg       0.58      0.57      0.57        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #2
# Mean negativities for all classes: [0.23630794456674487]
# Mean entropies for all classes: [1.7139320069087415e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.55      0.52        20
#          1.0       0.50      0.45      0.47        20
#
#     accuracy                           0.50        40
#    macro avg       0.50      0.50      0.50        40
# weighted avg       0.50      0.50      0.50        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #3
# Mean negativities for all classes: [0.2552432546691671]
# Mean entropies for all classes: [3.138538538703796e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.44      0.60      0.51        20
#          1.0       0.38      0.25      0.30        20
#
#     accuracy                           0.42        40
#    macro avg       0.41      0.42      0.41        40
# weighted avg       0.41      0.42      0.41        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #4
# Mean negativities for all classes: [0.05906214287765944]
# Mean entropies for all classes: [1.896318421942658e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.30      0.35      0.33        20
#          1.0       0.24      0.20      0.22        20
#
#     accuracy                           0.28        40
#    macro avg       0.27      0.28      0.27        40
# weighted avg       0.27      0.28      0.27        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #5
# Mean negativities for all classes: [0.21535619047032695]
# Mean entropies for all classes: [1.540565995051459e-15]
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.10      0.18        20
#          1.0       0.53      1.00      0.69        20
#
#     accuracy                           0.55        40
#    macro avg       0.76      0.55      0.44        40
# weighted avg       0.76      0.55      0.44        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #6
# Mean negativities for all classes: [0.015894263627514192]
# Mean entropies for all classes: [1.9808599077223992e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.43      0.15      0.22        20
#          1.0       0.48      0.80      0.60        20
#
#     accuracy                           0.48        40
#    macro avg       0.46      0.48      0.41        40
# weighted avg       0.46      0.47      0.41        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #7
# Mean negativities for all classes: [0.0025012000442680817]
# Mean entropies for all classes: [1.941552880817061e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.46      0.30      0.36        20
#          1.0       0.48      0.65      0.55        20
#
#     accuracy                           0.48        40
#    macro avg       0.47      0.47      0.46        40
# weighted avg       0.47      0.47      0.46        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #8
# Mean negativities for all classes: [0.008444718821851443]
# Mean entropies for all classes: [4.099845151663145e-16]
#               precision    recall  f1-score   support
#
#          0.0       0.50      1.00      0.67        20
#          1.0       0.00      0.00      0.00        20
#
#     accuracy                           0.50        40
#    macro avg       0.25      0.50      0.33        40
# weighted avg       0.25      0.50      0.33        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #9
# Mean negativities for all classes: [0.02205070999218606]
# Mean entropies for all classes: [1.6377184465830162e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.31      0.25      0.28        20
#          1.0       0.38      0.45      0.41        20
#
#     accuracy                           0.35        40
#    macro avg       0.34      0.35      0.34        40
# weighted avg       0.34      0.35      0.34        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.45499999999999996 F1-Scores = 0.4127330389527522 Negativity = [0.19577457796184022, 0.021671954311817624] Entropy = [1.8090912229437533e-15, 1.7169621838953843e-15]
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #0
# Mean negativities for all classes: [0.09334287840280187]
# Mean entropies for all classes: [1.8011082096527834e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00        20
#          1.0       0.50      1.00      0.67        20
#
#     accuracy                           0.50        40
#    macro avg       0.25      0.50      0.33        40
# weighted avg       0.25      0.50      0.33        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #1
# Mean negativities for all classes: [0.26248681455542106]
# Mean entropies for all classes: [2.7247772370051817e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.42      0.50      0.45        20
#          1.0       0.38      0.30      0.33        20
#
#     accuracy                           0.40        40
#    macro avg       0.40      0.40      0.39        40
# weighted avg       0.40      0.40      0.39        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #2
# Mean negativities for all classes: [0.21784436062882798]
# Mean entropies for all classes: [1.8996035033186358e-15]
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.10      0.18        20
#          1.0       0.53      1.00      0.69        20
#
#     accuracy                           0.55        40
#    macro avg       0.76      0.55      0.44        40
# weighted avg       0.76      0.55      0.44        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #3
# Mean negativities for all classes: [0.013644459964832104]
# Mean entropies for all classes: [1.6614719613458886e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.50      1.00      0.67        20
#          1.0       0.00      0.00      0.00        20
#
#     accuracy                           0.50        40
#    macro avg       0.25      0.50      0.33        40
# weighted avg       0.25      0.50      0.33        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #4
# Mean negativities for all classes: [0.24953139267436075]
# Mean entropies for all classes: [2.34954469181116e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.49      0.90      0.63        20
#          1.0       0.33      0.05      0.09        20
#
#     accuracy                           0.48        40
#    macro avg       0.41      0.48      0.36        40
# weighted avg       0.41      0.47      0.36        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #5
# Mean negativities for all classes: [0.2242121030900046]
# Mean entropies for all classes: [1.723785909297062e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.52      0.55      0.54        20
#          1.0       0.53      0.50      0.51        20
#
#     accuracy                           0.53        40
#    macro avg       0.53      0.53      0.52        40
# weighted avg       0.53      0.53      0.52        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #6
# Mean negativities for all classes: [0.21026615115764855]
# Mean entropies for all classes: [1.6544535011766516e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.64      0.35      0.45        20
#          1.0       0.55      0.80      0.65        20
#
#     accuracy                           0.57        40
#    macro avg       0.59      0.57      0.55        40
# weighted avg       0.59      0.57      0.55        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #7
# Mean negativities for all classes: [0.21324872583091475]
# Mean entropies for all classes: [2.785123413295408e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.67      0.10      0.17        20
#          1.0       0.51      0.95      0.67        20
#
#     accuracy                           0.53        40
#    macro avg       0.59      0.53      0.42        40
# weighted avg       0.59      0.53      0.42        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #8
# Mean negativities for all classes: [0.010871947398823686]
# Mean entropies for all classes: [1.5896815866517875e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.38      0.15      0.21        20
#          1.0       0.47      0.75      0.58        20
#
#     accuracy                           0.45        40
#    macro avg       0.42      0.45      0.40        40
# weighted avg       0.42      0.45      0.40        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #9
# Mean negativities for all classes: [0.20913090455898847]
# Mean entropies for all classes: [1.6158057245684589e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.49      0.85      0.62        20
#          1.0       0.40      0.10      0.16        20
#
#     accuracy                           0.48        40
#    macro avg       0.44      0.47      0.39        40
# weighted avg       0.44      0.47      0.39        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.49750000000000005 F1-Scores = 0.4137635635238479 Negativity = [0.09334287840280187, 0.26248681455542106] Entropy = [1.8011082096527834e-15, 2.7247772370051817e-15]
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #0
# Mean negativities for all classes: [0.22919960134642525]
# Mean entropies for all classes: [2.5113067980572714e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00        20
#          1.0       0.50      1.00      0.67        20
#
#     accuracy                           0.50        40
#    macro avg       0.25      0.50      0.33        40
# weighted avg       0.25      0.50      0.33        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #1
# Mean negativities for all classes: [0.20253456536753262]
# Mean entropies for all classes: [1.0377226631956717e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.95      0.66        20
#          1.0       0.50      0.05      0.09        20
#
#     accuracy                           0.50        40
#    macro avg       0.50      0.50      0.37        40
# weighted avg       0.50      0.50      0.37        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #2
# Mean negativities for all classes: [0.22587341989440998]
# Mean entropies for all classes: [1.897898457824607e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.33      0.20      0.25        20
#          1.0       0.43      0.60      0.50        20
#
#     accuracy                           0.40        40
#    macro avg       0.38      0.40      0.38        40
# weighted avg       0.38      0.40      0.38        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #3
# Mean negativities for all classes: [0.01462998339241747]
# Mean entropies for all classes: [1.5127613586460006e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.50      1.00      0.67        20
#          1.0       0.00      0.00      0.00        20
#
#     accuracy                           0.50        40
#    macro avg       0.25      0.50      0.33        40
# weighted avg       0.25      0.50      0.33        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #4
# Mean negativities for all classes: [0.058007529443803905]
# Mean entropies for all classes: [2.269667440897708e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.29      0.10      0.15        20
#          1.0       0.45      0.75      0.57        20
#
#     accuracy                           0.42        40
#    macro avg       0.37      0.42      0.36        40
# weighted avg       0.37      0.42      0.36        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #5
# Mean negativities for all classes: [0.2094267013558599]
# Mean entropies for all classes: [1.6623650429427258e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.50      1.00      0.67        20
#          1.0       0.00      0.00      0.00        20
#
#     accuracy                           0.50        40
#    macro avg       0.25      0.50      0.33        40
# weighted avg       0.25      0.50      0.33        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #6
# Mean negativities for all classes: [0.01892340122054998]
# Mean entropies for all classes: [1.110456470194769e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.45      0.45      0.45        20
#          1.0       0.45      0.45      0.45        20
#
#     accuracy                           0.45        40
#    macro avg       0.45      0.45      0.45        40
# weighted avg       0.45      0.45      0.45        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #7
# Mean negativities for all classes: [0.0025944512644281493]
# Mean entropies for all classes: [1.9322407652837894e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.38      0.25      0.30        20
#          1.0       0.44      0.60      0.51        20
#
#     accuracy                           0.42        40
#    macro avg       0.41      0.42      0.41        40
# weighted avg       0.41      0.42      0.41        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #8
# Mean negativities for all classes: [0.05194040829329798]
# Mean entropies for all classes: [2.180126019117694e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.60      0.55        20
#          1.0       0.50      0.40      0.44        20
#
#     accuracy                           0.50        40
#    macro avg       0.50      0.50      0.49        40
# weighted avg       0.50      0.50      0.49        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #9
# Mean negativities for all classes: [0.21960014715303738]
# Mean entropies for all classes: [1.884735189332056e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.75      0.15      0.25        20
#          1.0       0.53      0.95      0.68        20
#
#     accuracy                           0.55        40
#    macro avg       0.64      0.55      0.46        40
# weighted avg       0.64      0.55      0.46        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.475 F1-Scores = 0.39212032040362305 Negativity = [0.22919960134642525, 0.20253456536753262] Entropy = [2.5113067980572714e-15, 1.0377226631956717e-15]
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #0
# Mean negativities for all classes: [0.2143381947396176]
# Mean entropies for all classes: [3.1067996501919377e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.33      0.05      0.09        20
#          1.0       0.49      0.90      0.63        20
#
#     accuracy                           0.48        40
#    macro avg       0.41      0.48      0.36        40
# weighted avg       0.41      0.47      0.36        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #1
# Mean negativities for all classes: [0.12100164723629954]
# Mean entropies for all classes: [1.9261139731173343e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.43      0.50      0.47        20
#          1.0       0.41      0.35      0.38        20
#
#     accuracy                           0.42        40
#    macro avg       0.42      0.42      0.42        40
# weighted avg       0.42      0.42      0.42        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #2
# Mean negativities for all classes: [0.004664948950572884]
# Mean entropies for all classes: [1.4988319627433058e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.57      0.20      0.30        20
#          1.0       0.52      0.85      0.64        20
#
#     accuracy                           0.53        40
#    macro avg       0.54      0.53      0.47        40
# weighted avg       0.54      0.53      0.47        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #3
# Mean negativities for all classes: [0.08111072304167838]
# Mean entropies for all classes: [1.6755778373940515e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.50      1.00      0.67        20
#          1.0       0.00      0.00      0.00        20
#
#     accuracy                           0.50        40
#    macro avg       0.25      0.50      0.33        40
# weighted avg       0.25      0.50      0.33        40
#
# ...
# Mean entropies for all classes: [2.256034295083332e-15]
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.10      0.18        20
#          1.0       0.53      1.00      0.69        20
#
#     accuracy                           0.55        40
#    macro avg       0.76      0.55      0.44        40
# weighted avg       0.76      0.55      0.44        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #2
# Mean negativities for all classes: [0.21022717676504135]
# Mean entropies for all classes: [1.7480131784753086e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.33      0.05      0.09        20
#          1.0       0.49      0.90      0.63        20
#
#     accuracy                           0.48        40
#    macro avg       0.41      0.48      0.36        40
# weighted avg       0.41      0.47      0.36        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #3
# Mean negativities for all classes: [0.13479430201060785]
# Mean entropies for all classes: [1.7766290124728766e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.49      0.95      0.64        20
#          1.0       0.00      0.00      0.00        20
#
#     accuracy                           0.48        40
#    macro avg       0.24      0.47      0.32        40
# weighted avg       0.24      0.47      0.32        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #4
# Mean negativities for all classes: [0.2254732584059517]
# Mean entropies for all classes: [1.4862468141641619e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.60      0.15      0.24        20
#          1.0       0.51      0.90      0.65        20
#
#     accuracy                           0.53        40
#    macro avg       0.56      0.53      0.45        40
# weighted avg       0.56      0.53      0.45        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #5
# Mean negativities for all classes: [0.20399112493339772]
# Mean entropies for all classes: [1.810622294120445e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.57      0.40      0.47        20
#          1.0       0.54      0.70      0.61        20
#
#     accuracy                           0.55        40
#    macro avg       0.55      0.55      0.54        40
# weighted avg       0.55      0.55      0.54        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #6
# Mean negativities for all classes: [0.08200927221463358]
# Mean entropies for all classes: [1.9036972723869285e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.47      0.85      0.61        20
#          1.0       0.25      0.05      0.08        20
#
#     accuracy                           0.45        40
#    macro avg       0.36      0.45      0.35        40
# weighted avg       0.36      0.45      0.35        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #7
# Mean negativities for all classes: [0.21076148208254092]
# Mean entropies for all classes: [2.1249506585441184e-15]
#               precision    recall  f1-score   support
#
#          0.0       0
]], [[0.21654537594657608, 0.2017903121935427, 0.22172933074843434, 0.23437910402579826, 0.23891392082272933, 0.18738125587425405, 0.04220130586925521, 0.2178407884478805, 0.12945384566187004, 0.224002993327735]], [[0.21286619857576486, 0.22297054999550858, 0.2218128242162388, 0.004291207263700863, 0.04557329446301097, 0.0017222816338802987, 0.2281763324571548, 0.2354064996432756, 0.2094502751475132, 0.06965400609184542]], [[0.26509134927275874, 0.20907585126672404, 0.21098292683175082, 0.15403947992386283, 0.052809945883765086, 0.2250233865802845, 0.23896006903983508, 0.20801314044874517, 0.03722443533245377, 0.2471717323130068]], [[0.20792800453887325, 0.15345667439539037, 0.031301533912920135, 0.2400536508789366, 0.0870638151354807, 0.017078423099638383, 0.2130166598715287, 0.05548601297968632, 0.20842905031690853, 0.005612593703214564]], [[0.2518170086113601, 0.20080887189140184, 0.19927046687456415, 0.21775594612777435, 0.2161411169223383, 0.24846936119419566, 0.23325947309785683, 0.2020572013014327, 0.20447848010263772, 0.20206857895437205]], [[0.005842164035519589, 0.21894149673110333, 0.02138068533227788, 0.20194062904140048, 0.22039772994391865, 0.18916983724193792, 0.23037231580101797, 0.23720671280939945, 0.24165019703994525, 0.03692491904095176]], [[0.11982455315779608, 0.22874173727475489, 0.1992063083317975, 0.20725482816404578, 0.07932300835254602, 0.20759061299273998, 0.23600294431488 ...
# CPU times: total: 14.2 s
# Wall time: 7h 3min 16s
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished

# %% [markdown]
# # Linear Sep

# %%
# %%time
# %run Experimento-Artificial-Linear-Sep-20-10-Fold.ipynb
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #0
# Mean negativities for all classes: [0.19221673417469365]
# Mean entropies for all classes: [1.3778215935962024e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.55      0.52        20
#          1.0       0.50      0.45      0.47        20
#
#     accuracy                           0.50        40
#    macro avg       0.50      0.50      0.50        40
# weighted avg       0.50      0.50      0.50        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #1
# Mean negativities for all classes: [0.25773723205549876]
# Mean entropies for all classes: [2.7192583477082178e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.47      0.85      0.61        20
#          1.0       0.25      0.05      0.08        20
#
#     accuracy                           0.45        40
#    macro avg       0.36      0.45      0.35        40
# weighted avg       0.36      0.45      0.35        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #2
# Mean negativities for all classes: [0.19769808936778055]
# Mean entropies for all classes: [3.4664923820253044e-16]
#               precision    recall  f1-score   support
#
#          0.0       0.44      0.20      0.28        20
#          1.0       0.48      0.75      0.59        20
#
#     accuracy                           0.48        40
#    macro avg       0.46      0.47      0.43        40
# weighted avg       0.46      0.47      0.43        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #3
# Mean negativities for all classes: [0.2328800981794636]
# Mean entropies for all classes: [-1.321901491358753e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.44      0.60      0.51        20
#          1.0       0.38      0.25      0.30        20
#
#     accuracy                           0.42        40
#    macro avg       0.41      0.42      0.41        40
# weighted avg       0.41      0.42      0.41        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #4
# Mean negativities for all classes: [0.27281485105711867]
# Mean entropies for all classes: [9.281878442093618e-17]
#               precision    recall  f1-score   support
#
#          0.0       0.45      0.65      0.53        20
#          1.0       0.36      0.20      0.26        20
#
#     accuracy                           0.42        40
#    macro avg       0.41      0.43      0.39        40
# weighted avg       0.41      0.42      0.39        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #5
# Mean negativities for all classes: [0.17688335401848349]
# Mean entropies for all classes: [2.7420207153649236e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.48      0.60      0.53        20
#          1.0       0.47      0.35      0.40        20
#
#     accuracy                           0.48        40
#    macro avg       0.47      0.47      0.47        40
# weighted avg       0.47      0.47      0.47        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #6
# Mean negativities for all classes: [0.21666518469168886]
# Mean entropies for all classes: [1.1130452244408975e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.50      0.50        20
#          1.0       0.50      0.50      0.50        20
#
#     accuracy                           0.50        40
#    macro avg       0.50      0.50      0.50        40
# weighted avg       0.50      0.50      0.50        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #7
# Mean negativities for all classes: [0.17697024264075673]
# Mean entropies for all classes: [1.7821482645449305e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.47      0.40      0.43        20
#          1.0       0.48      0.55      0.51        20
#
#     accuracy                           0.48        40
#    macro avg       0.47      0.48      0.47        40
# weighted avg       0.47      0.47      0.47        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #8
# Mean negativities for all classes: [0.2818435448209409]
# Mean entropies for all classes: [6.270811137003434e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.44      0.60      0.51        20
#          1.0       0.38      0.25      0.30        20
#
#     accuracy                           0.42        40
#    macro avg       0.41      0.42      0.41        40
# weighted avg       0.41      0.42      0.41        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #9
# Mean negativities for all classes: [0.05906580370490335]
# Mean entropies for all classes: [-3.4629809544036917e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.47      0.45      0.46        20
#          1.0       0.48      0.50      0.49        20
#
#     accuracy                           0.48        40
#    macro avg       0.47      0.47      0.47        40
# weighted avg       0.47      0.47      0.47        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.4624999999999999 F1-Scores = 0.43974091315286123 Negativity = [0.19221673417469365, 0.25773723205549876] Entropy = [1.3778215935962024e-15, 2.7192583477082178e-14]
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #0
# Mean negativities for all classes: [0.20592952331764228]
# Mean entropies for all classes: [3.1910591162512466e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.47      0.45      0.46        20
#          1.0       0.48      0.50      0.49        20
#
#     accuracy                           0.48        40
#    macro avg       0.47      0.47      0.47        40
# weighted avg       0.47      0.47      0.47        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #1
# Mean negativities for all classes: [0.21209046468229467]
# Mean entropies for all classes: [2.0669927460508032e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.55      0.52        20
#          1.0       0.50      0.45      0.47        20
#
#     accuracy                           0.50        40
#    macro avg       0.50      0.50      0.50        40
# weighted avg       0.50      0.50      0.50        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #2
# Mean negativities for all classes: [0.24784329344432598]
# Mean entropies for all classes: [1.4436289735100248e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.53      0.50      0.51        20
#          1.0       0.52      0.55      0.54        20
#
#     accuracy                           0.53        40
#    macro avg       0.53      0.53      0.52        40
# weighted avg       0.53      0.53      0.52        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #3
# Mean negativities for all classes: [0.1632474644211712]
# Mean entropies for all classes: [8.59794317009135e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.48      0.55      0.51        20
#          1.0       0.47      0.40      0.43        20
#
#     accuracy                           0.48        40
#    macro avg       0.47      0.48      0.47        40
# weighted avg       0.47      0.47      0.47        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #4
# Mean negativities for all classes: [0.1955175941814978]
# Mean entropies for all classes: [-4.0822280291047246e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.60      0.55        20
#          1.0       0.50      0.40      0.44        20
#
#     accuracy                           0.50        40
#    macro avg       0.50      0.50      0.49        40
# weighted avg       0.50      0.50      0.49        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #5
# Mean negativities for all classes: [0.15726126144156666]
# Mean entropies for all classes: [3.801281224198193e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.33      0.20      0.25        20
#          1.0       0.43      0.60      0.50        20
#
#     accuracy                           0.40        40
#    macro avg       0.38      0.40      0.38        40
# weighted avg       0.38      0.40      0.38        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #6
# Mean negativities for all classes: [0.24528668712877302]
# Mean entropies for all classes: [-2.4783234799192536e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.45      0.45      0.45        20
#          1.0       0.45      0.45      0.45        20
#
#     accuracy                           0.45        40
#    macro avg       0.45      0.45      0.45        40
# weighted avg       0.45      0.45      0.45        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #7
# Mean negativities for all classes: [0.2565804252460303]
# Mean entropies for all classes: [2.7084070205369464e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.47      0.75      0.58        20
#          1.0       0.38      0.15      0.21        20
#
#     accuracy                           0.45        40
#    macro avg       0.42      0.45      0.40        40
# weighted avg       0.42      0.45      0.40        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #8
# Mean negativities for all classes: [0.20283340293286117]
# Mean entropies for all classes: [2.8513564588254757e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.45      0.50      0.48        20
#          1.0       0.44      0.40      0.42        20
#
#     accuracy                           0.45        40
#    macro avg       0.45      0.45      0.45        40
# weighted avg       0.45      0.45      0.45        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #9
# Mean negativities for all classes: [0.3259590550586762]
# Mean entropies for all classes: [-3.979666313110963e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.48      0.80      0.60        20
#          1.0       0.43      0.15      0.22        20
#
#     accuracy                           0.48        40
#    macro avg       0.46      0.48      0.41        40
# weighted avg       0.46      0.47      0.41        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.47000000000000003 F1-Scores = 0.4547324994005759 Negativity = [0.20592952331764228, 0.21209046468229467] Entropy = [3.1910591162512466e-15, 2.0669927460508032e-14]
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #0
# Mean negativities for all classes: [0.16369850748459444]
# Mean entropies for all classes: [8.78283261458487e-16]
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.55      0.52        20
#          1.0       0.50      0.45      0.47        20
#
#     accuracy                           0.50        40
#    macro avg       0.50      0.50      0.50        40
# weighted avg       0.50      0.50      0.50        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #1
# Mean negativities for all classes: [0.0823472677457592]
# Mean entropies for all classes: [-3.0970947219071204e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.47      0.45      0.46        20
#          1.0       0.48      0.50      0.49        20
#
#     accuracy                           0.48        40
#    macro avg       0.47      0.47      0.47        40
# weighted avg       0.47      0.47      0.47        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #2
# Mean negativities for all classes: [0.30385492447601126]
# Mean entropies for all classes: [-1.1341981835323586e-13]
#               precision    recall  f1-score   support
#
#          0.0       0.43      0.65      0.52        20
#          1.0       0.30      0.15      0.20        20
#
#     accuracy                           0.40        40
#    macro avg       0.37      0.40      0.36        40
# weighted avg       0.37      0.40      0.36        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #3
# Mean negativities for all classes: [0.2705807328890471]
# Mean entropies for all classes: [2.3281507654107717e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.35      0.30      0.32        20
#          1.0       0.39      0.45      0.42        20
#
#     accuracy                           0.38        40
#    macro avg       0.37      0.38      0.37        40
# weighted avg       0.37      0.38      0.37        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #4
# Mean negativities for all classes: [0.13011709096345073]
# Mean entropies for all classes: [-1.139360608330052e-13]
#               precision    recall  f1-score   support
#
#          0.0       0.49      0.85      0.62        20
#          1.0       0.40      0.10      0.16        20
#
#     accuracy                           0.48        40
#    macro avg       0.44      0.47      0.39        40
# weighted avg       0.44      0.47      0.39        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #5
# Mean negativities for all classes: [0.28159056889073775]
# Mean entropies for all classes: [5.772855792321929e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.47      0.80      0.59        20
#          1.0       0.33      0.10      0.15        20
#
#     accuracy                           0.45        40
#    macro avg       0.40      0.45      0.37        40
# weighted avg       0.40      0.45      0.37        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #6
# Mean negativities for all classes: [0.16885642858208277]
# Mean entropies for all classes: [2.351939511592784e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.48      0.50      0.49        20
#          1.0       0.47      0.45      0.46        20
#
#     accuracy                           0.48        40
#    macro avg       0.47      0.47      0.47        40
# weighted avg       0.47      0.47      0.47        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #7
# Mean negativities for all classes: [0.20034629949032653]
# Mean entropies for all classes: [7.543334729652673e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.52      0.55      0.54        20
#          1.0       0.53      0.50      0.51        20
#
#     accuracy                           0.53        40
#    macro avg       0.53      0.53      0.52        40
# weighted avg       0.53      0.53      0.52        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #8
# Mean negativities for all classes: [0.2759696758876432]
# Mean entropies for all classes: [1.6763656776626756e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.43      0.60      0.50        20
#          1.0       0.33      0.20      0.25        20
#
#     accuracy                           0.40        40
#    macro avg       0.38      0.40      0.38        40
# weighted avg       0.38      0.40      0.38        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.4min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #9
# Mean negativities for all classes: [0.2757369342789743]
# Mean entropies for all classes: [-2.53303631636039e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.50      0.50        20
#          1.0       0.50      0.50      0.50        20
#
#     accuracy                           0.50        40
#    macro avg       0.50      0.50      0.50        40
# weighted avg       0.50      0.50      0.50        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.4575 F1-Scores = 0.43415679161460874 Negativity = [0.16369850748459444, 0.0823472677457592] Entropy = [8.78283261458487e-16, -3.0970947219071204e-14]
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #0
# Mean negativities for all classes: [0.1236344470245903]
# Mean entropies for all classes: [-3.370604728717426e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.48      0.60      0.53        20
#          1.0       0.47      0.35      0.40        20
#
#     accuracy                           0.48        40
#    macro avg       0.47      0.47      0.47        40
# weighted avg       0.47      0.47      0.47        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #1
# Mean negativities for all classes: [0.202964153345226]
# Mean entropies for all classes: [6.131232750320837e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.50      0.50        20
#          1.0       0.50      0.50      0.50        20
#
#     accuracy                           0.50        40
#    macro avg       0.50      0.50      0.50        40
# weighted avg       0.50      0.50      0.50        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #2
# Mean negativities for all classes: [0.2693940731591967]
# Mean entropies for all classes: [-8.469247666616355e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.45      0.65      0.53        20
#          1.0       0.36      0.20      0.26        20
#
#     accuracy                           0.42        40
#    macro avg       0.41      0.43      0.39        40
# weighted avg       0.41      0.42      0.39        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #3
# Mean negativities for all classes: [0.23874244035160838]
# Mean entropies for all classes: [4.758862583728294e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.52      0.65      0.58        20
#          1.0       0.53      0.40      0.46        20
#
#     accuracy                           0.53        40
#    macro avg       0.53      0.53      0.52        40
# weighted avg       0.53      0.53      0.52        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #4
# Mean negativities for all classes: [0.250298597980373]
# Mean entropies for all classes: [1.2678804634704888e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.45      0.45      0.45        20
#          1.0       0.45      0.45      0.45        20
#
#     accuracy                           0.45        40
#    macro avg       0.45      0.45      0.45        40
# weighted avg       0.45      0.45      0.45        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #5
# Mean negativities for all classes: [0.07918575406179758]
# Mean entropies for all classes: [-2.4901525874303304e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00        20
#          1.0       0.44      0.80      0.57        20
#
#     accuracy                           0.40        40
#    macro avg       0.22      0.40      0.29        40
# weighted avg       0.22      0.40      0.29        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #6
# Mean negativities for all classes: [0.24779723912507032]
# Mean entropies for all classes: [6.573712105101253e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.48      0.65      0.55        20
#          1.0       0.46      0.30      0.36        20
#
#     accuracy                           0.48        40
#    macro avg       0.47      0.47      0.46        40
# weighted avg       0.47      0.47      0.46        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #7
# Mean negativities for all classes: [0.25411812773651343]
# Mean entropies for all classes: [4.574420673667513e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.45      0.47        20
#          1.0       0.50      0.55      0.52        20
#
#     accuracy                           0.50        40
#    macro avg       0.50      0.50      0.50        40
# weighted avg       0.50      0.50      0.50        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #8
# Mean negativities for all classes: [0.2437886908879851]
# Mean entropies for all classes: [-1.4356374132482135e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.41      0.45      0.43        20
#          1.0       0.39      0.35      0.37        20
#
#     accuracy                           0.40        40
#    macro avg       0.40      0.40      0.40        40
# weighted avg       0.40      0.40      0.40        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #9
# Mean negativities for all classes: [0.25266020810495626]
# Mean entropies for all classes: [7.660064135230512e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.43      0.50      0.47        20
#          1.0       0.41      0.35      0.38        20
#
#     accuracy                           0.42        40
#    macro avg       0.42      0.42      0.42        40
# weighted avg       0.42      0.42      0.42        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.4575 F1-Scores = 0.4391584013347295 Negativity = [0.1236344470245903, 0.202964153345226] Entropy = [-3.370604728717426e-14, 6.131232750320837e-15]
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #0
# Mean negativities for all classes: [0.1937705094519419]
# Mean entropies for all classes: [2.197707923002027e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.42      0.40      0.41        20
#          1.0       0.43      0.45      0.44        20
#
#     accuracy                           0.42        40
#    macro avg       0.42      0.43      0.42        40
# weighted avg       0.42      0.42      0.42        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #1
# Mean negativities for all classes: [0.1485456657002848]
# Mean entropies for all classes: [1.776835200775006e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.67      0.20      0.31        20
#          1.0       0.53      0.90      0.67        20
#
#     accuracy                           0.55        40
#    macro avg       0.60      0.55      0.49        40
# weighted avg       0.60      0.55      0.49        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #2
# Mean negativities for all classes: [0.30694775206615954]
# Mean entropies for all classes: [-1.062758257273093e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.47      0.70      0.56        20
#          1.0       0.40      0.20      0.27        20
#
#     accuracy                           0.45        40
#    macro avg       0.43      0.45      0.41        40
# weighted avg       0.43      0.45      0.41        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #3
# Mean negativities for all classes: [0.2888120090947949]
# Mean entropies for all classes: [1.3352171604217892e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.42      0.55      0.48        20
#          1.0       0.36      0.25      0.29        20
#
#     accuracy                           0.40        40
#    macro avg       0.39      0.40      0.39        40
# weighted avg       0.39      0.40      0.39        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #4
# Mean negativities for all classes: [0.14654899696877216]
# Mean entropies for all classes: [3.1486980786676246e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.43      0.60      0.50        20
#          1.0       0.33      0.20      0.25        20
#
#     accuracy                           0.40        40
#    macro avg       0.38      0.40      0.38        40
# weighted avg       0.38      0.40      0.38        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #5
# Mean negativities for all classes: [0.27960862598031977]
# Mean entropies for all classes: [4.644224339335088e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.47      0.70      0.56        20
#          1.0       0.40      0.20      0.27        20
#
#     accuracy                           0.45        40
#    macro avg       0.43      0.45      0.41        40
# weighted avg       0.43      0.45      0.41        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #6
# Mean negativities for all classes: [0.2543114454465781]
# Mean entropies for all classes: [3.788146572249876e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.39      0.45      0.42        20
#          1.0       0.35      0.30      0.32        20
#
#     accuracy                           0.38        40
#    macro avg       0.37      0.38      0.37        40
# weighted avg       0.37      0.38      0.37        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #7
# Mean negativities for all classes: [0.11395121885534087]
# Mean entropies for all classes: [-1.3145854771221394e-13]
#               precision    recall  f1-score   support
#
#          0.0       0.33      0.10      0.15        20
#          1.0       0.47      0.80      0.59        20
#
#     accuracy                           0.45        40
#    macro avg       0.40      0.45      0.37        40
# weighted avg       0.40      0.45      0.37        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #8
# Mean negativities for all classes: [0.2322023019736827]
# Mean entropies for all classes: [1.8619079543759833e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.43      0.65      0.52        20
#          1.0       0.30      0.15      0.20        20
#
#     accuracy                           0.40        40
#    macro avg       0.37      0.40      0.36        40
# weighted avg       0.37      0.40      0.36        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #9
# Mean negativities for all classes: [0.20288736811339617]
# Mean entropies for all classes: [-2.5668728562109478e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.29      0.10      0.15        20
#          1.0       0.45      0.75      0.57        20
#
#     accuracy                           0.42        40
#    macro avg       0.37      0.42      0.36        40
# weighted avg       0.37      0.42      0.36        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.4325 F1-Scores = 0.39614526153698637 Negativity = [0.1937705094519419, 0.1485456657002848] Entropy = [2.197707923002027e-14, 1.776835200775006e-15]
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #0
# Mean negativities for all classes: [0.104150863554712]
# Mean entropies for all classes: [1.3452682578523522e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.52      0.60      0.56        20
#          1.0       0.53      0.45      0.49        20
#
#     accuracy                           0.53        40
#    macro avg       0.53      0.53      0.52        40
# weighted avg       0.53      0.53      0.52        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #1
# Mean negativities for all classes: [0.2572147691151566]
# Mean entropies for all classes: [5.138853622644951e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.42      0.65      0.51        20
#          1.0       0.22      0.10      0.14        20
#
#     accuracy                           0.38        40
#    macro avg       0.32      0.38      0.32        40
# weighted avg       0.32      0.38      0.32        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #2
# Mean negativities for all classes: [0.07615880218535326]
# Mean entropies for all classes: [-2.8420655210021205e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.43      0.45      0.44        20
#          1.0       0.42      0.40      0.41        20
#
#     accuracy                           0.42        40
#    macro avg       0.42      0.43      0.42        40
# weighted avg       0.42      0.42      0.42        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #3
# Mean negativities for all classes: [0.1609388679520922]
# Mean entropies for all classes: [6.766823252392101e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.44      0.35      0.39        20
#          1.0       0.46      0.55      0.50        20
#
#     accuracy                           0.45        40
#    macro avg       0.45      0.45      0.44        40
# weighted avg       0.45      0.45      0.44        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #4
# Mean negativities for all classes: [0.18067129884015207]
# Mean entropies for all classes: [-2.3361682991155226e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.45      0.50      0.48        20
#          1.0       0.44      0.40      0.42        20
#
#     accuracy                           0.45        40
#    macro avg       0.45      0.45      0.45        40
# weighted avg       0.45      0.45      0.45        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #5
# Mean negativities for all classes: [0.2552198897443335]
# Mean entropies for all classes: [-2.866605309446748e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.75      0.60        20
#          1.0       0.50      0.25      0.33        20
#
#     accuracy                           0.50        40
#    macro avg       0.50      0.50      0.47        40
# weighted avg       0.50      0.50      0.47        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #6
# Mean negativities for all classes: [0.058986649111640845]
# Mean entropies for all classes: [5.9007820844002425e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.10      0.17        20
#          1.0       0.50      0.90      0.64        20
#
#     accuracy                           0.50        40
#    macro avg       0.50      0.50      0.40        40
# weighted avg       0.50      0.50      0.40        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #7
# Mean negativities for all classes: [0.24688102134349937]
# Mean entropies for all classes: [-5.96967104216054e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.45      0.65      0.53        20
#          1.0       0.36      0.20      0.26        20
#
#     accuracy                           0.42        40
#    macro avg       0.41      0.43      0.39        40
# weighted avg       0.41      0.42      0.39        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #8
# Mean negativities for all classes: [0.281364133850537]
# Mean entropies for all classes: [-4.420459725254208e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.47      0.70      0.56        20
#          1.0       0.40      0.20      0.27        20
#
#     accuracy                           0.45        40
#    macro avg       0.43      0.45      0.41        40
# weighted avg       0.43      0.45      0.41        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #9
# Mean negativities for all classes: [0.2313683146506329]
# Mean entropies for all classes: [1.660347617510004e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.48      0.60      0.53        20
#          1.0       0.47      0.35      0.40        20
#
#     accuracy                           0.48        40
#    macro avg       0.47      0.47      0.47        40
# weighted avg       0.47      0.47      0.47        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.4574999999999999 F1-Scores = 0.4309653839232177 Negativity = [0.104150863554712, 0.2572147691151566] Entropy = [1.3452682578523522e-15, 5.138853622644951e-15]
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #0
# Mean negativities for all classes: [0.32131339431045314]
# Mean entropies for all classes: [1.7898267552891323e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.48      0.75      0.59        20
#          1.0       0.44      0.20      0.28        20
#
#     accuracy                           0.48        40
#    macro avg       0.46      0.47      0.43        40
# weighted avg       0.46      0.47      0.43        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #1
# Mean negativities for all classes: [0.28980395594270314]
# Mean entropies for all classes: [-8.70540476973128e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.47      0.70      0.56        20
#          1.0       0.40      0.20      0.27        20
#
#     accuracy                           0.45        40
#    macro avg       0.43      0.45      0.41        40
# weighted avg       0.43      0.45      0.41        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #2
# Mean negativities for all classes: [0.22461812602039313]
# Mean entropies for all classes: [2.1265629342298787e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.48      0.50      0.49        20
#          1.0       0.47      0.45      0.46        20
#
#     accuracy                           0.48        40
#    macro avg       0.47      0.47      0.47        40
# weighted avg       0.47      0.47      0.47        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #3
# Mean negativities for all classes: [0.2986581360838291]
# Mean entropies for all classes: [5.7890711718920874e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.45      0.75      0.57        20
#          1.0       0.29      0.10      0.15        20
#
#     accuracy                           0.42        40
#    macro avg       0.37      0.42      0.36        40
# weighted avg       0.37      0.42      0.36        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #4
# Mean negativities for all classes: [0.07478785908304605]
# Mean entropies for all classes: [-2.104766943844752e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.55      0.80      0.65        20
#          1.0       0.64      0.35      0.45        20
#
#     accuracy                           0.57        40
#    macro avg       0.59      0.57      0.55        40
# weighted avg       0.59      0.57      0.55        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #5
# Mean negativities for all classes: [0.151170274105737]
# Mean entropies for all classes: [-1.2034183987646502e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.43      0.45      0.44        20
#          1.0       0.42      0.40      0.41        20
#
# ...
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #1
# Mean negativities for all classes: [0.2092957672068371]
# Mean entropies for all classes: [-1.6610776876136295e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.43      0.45      0.44        20
#          1.0       0.42      0.40      0.41        20
#
#     accuracy                           0.42        40
#    macro avg       0.42      0.43      0.42        40
# weighted avg       0.42      0.42      0.42        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #2
# Mean negativities for all classes: [0.1219728819892341]
# Mean entropies for all classes: [2.1363179813226827e-16]
#               precision    recall  f1-score   support
#
#          0.0       0.47      0.45      0.46        20
#          1.0       0.48      0.50      0.49        20
#
#     accuracy                           0.48        40
#    macro avg       0.47      0.47      0.47        40
# weighted avg       0.47      0.47      0.47        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #3
# Mean negativities for all classes: [0.19556781252349692]
# Mean entropies for all classes: [-4.17596320018505e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.48      0.50      0.49        20
#          1.0       0.47      0.45      0.46        20
#
#     accuracy                           0.48        40
#    macro avg       0.47      0.47      0.47        40
# weighted avg       0.47      0.47      0.47        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #4
# Mean negativities for all classes: [0.25795049497547823]
# Mean entropies for all classes: [-1.4119251952719475e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.41      0.55      0.47        20
#          1.0       0.31      0.20      0.24        20
#
#     accuracy                           0.38        40
#    macro avg       0.36      0.38      0.36        40
# weighted avg       0.36      0.38      0.36        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #5
# Mean negativities for all classes: [0.06286821844226713]
# Mean entropies for all classes: [4.7997310092719734e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.29      0.10      0.15        20
#          1.0       0.45      0.75      0.57        20
#
#     accuracy                           0.42        40
#    macro avg       0.37      0.42      0.36        40
# weighted avg       0.37      0.42      0.36        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #6
# Mean negativities for all classes: [0.2576710465732651]
# Mean entropies for all classes: [8.2921469006731e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.48      0.70      0.57        20
#          1.0       0.45      0.25      0.32        20
#
#     accuracy                           0.48        40
#    macro avg       0.47      0.47      0.45        40
# weighted avg       0.47      0.47      0.45        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #7
# Mean negativities for all classes: [0.2601983043833621]
# Mean entropies for all classes: [8.76441254726124e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.44      0.55      0.49        20
#          1.0       0.40      0.30      0.34        20
#
#     accuracy                           0.42        40
#    macro avg       0.42      0.43      0.42        40
# weighted avg       0.42      0.42      0.42        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #8
# Mean negativities for all classes: [0.2550092870439086]
# Mean entropies for all classes: [-1.7994165645568262e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.38      0.15      0.21        20
#          1.0       0.47      0.75      0.58        20
#
#     accuracy                           0.45        40
#    macro avg       0.42      0.45      0.40        40
# weighted avg       0.42      0.45      0.40        40
#
# -------------------------------------------------------------------------------------------------------------------
# K-Fold #9
# Mean negativities for all classes: [0.16329130203120126]
# Mean entropies for all classes: [3.051981091522999e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.44      0.40      0.42        20
#          1.0       0.45      0.50      0.48        20
#
#     accuracy                           0.45        40
#    macro avg       0.45      0.45      0.45        40
# weighted avg       0.45      0.45      0.45        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.4425 F1-Scores = 0.42420564837813773 Negativity = [0.23207879435118556, 0.2092957672068371] Entropy = [-6.302160943474225e-15, -1.6610776876136295e-14]
# CPU times: total: 14.4 s
# Wall time: 8h 4min 15s
# Media Score dos N K-Fold 0.4553750000000001
# Maior Score dos K-Fold 0.4725
# Menor Score dos K-Fold 0.43
#
#
880620702357, 0.15052949960043102, 0.19850219435264918, 0.14415922180944085, 0.2862598880092403, 0.27411089912182984, 0.21082868030067808, 0.14506528014352252, 0.197346129811577, 0.21911773814200916]], [[0.21262490002746154, 0.2057200104650731, 0.2391290284975074, 0.2749868788516155, 0.24748652297584312, 0.16277911206412216, 0.10906493833555095, 0.19632095452801943, 0.2260450968643692, 0.25887159514632085]], [[0.12448133561214966, 0.2548390411616678, 0.2236452199705667, 0.2749317472970995, 0.28209781418796076, 0.12324961953829065, 0.14841177211285844, 0.2724440396385718, 0.19033340173704794, 0.08341659530389403]], [[0.2 ...
# CPU times: total: 14.5 s
# Wall time: 8h 4min 15s
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished

# %% [markdown]
# # Moons

# %%
# %%time
# %run Experimento-Artificial-Moons-20-10-Fold.ipynb
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #0
# Mean negativities for all classes: [0.15157361492572058]
# Mean entropies for all classes: [1.9784411068532998e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.86      0.60      0.71        20
#          1.0       0.69      0.90      0.78        20
#
#     accuracy                           0.75        40
#    macro avg       0.77      0.75      0.74        40
# weighted avg       0.77      0.75      0.74        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #1
# Mean negativities for all classes: [0.05698186554365361]
# Mean entropies for all classes: [3.3341622513089673e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.88      0.70      0.78        20
#          1.0       0.75      0.90      0.82        20
#
#     accuracy                           0.80        40
#    macro avg       0.81      0.80      0.80        40
# weighted avg       0.81      0.80      0.80        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #2
# Mean negativities for all classes: [0.22988866355384596]
# Mean entropies for all classes: [2.5734216662426993e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.69      0.55      0.61        20
#          1.0       0.62      0.75      0.68        20
#
#     accuracy                           0.65        40
#    macro avg       0.66      0.65      0.65        40
# weighted avg       0.66      0.65      0.65        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #3
# Mean negativities for all classes: [0.214027979183042]
# Mean entropies for all classes: [-5.275437983515254e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.71      0.50      0.59        20
#          1.0       0.62      0.80      0.70        20
#
#     accuracy                           0.65        40
#    macro avg       0.66      0.65      0.64        40
# weighted avg       0.66      0.65      0.64        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #4
# Mean negativities for all classes: [0.07703694560884597]
# Mean entropies for all classes: [2.6305365902181155e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.57      0.40      0.47        20
#          1.0       0.54      0.70      0.61        20
#
#     accuracy                           0.55        40
#    macro avg       0.55      0.55      0.54        40
# weighted avg       0.55      0.55      0.54        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #5
# Mean negativities for all classes: [0.17961111903619514]
# Mean entropies for all classes: [2.5352548972744803e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.80      0.40      0.53        20
#          1.0       0.60      0.90      0.72        20
#
#     accuracy                           0.65        40
#    macro avg       0.70      0.65      0.63        40
# weighted avg       0.70      0.65      0.63        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #6
# Mean negativities for all classes: [0.17822729763625508]
# Mean entropies for all classes: [3.0283239399631377e-15]
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.40      0.57        20
#          1.0       0.62      1.00      0.77        20
#
#     accuracy                           0.70        40
#    macro avg       0.81      0.70      0.67        40
# weighted avg       0.81      0.70      0.67        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.4min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #7
# Mean negativities for all classes: [0.22296742370182984]
# Mean entropies for all classes: [2.7892979489940222e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.80      0.60      0.69        20
#          1.0       0.68      0.85      0.76        20
#
#     accuracy                           0.73        40
#    macro avg       0.74      0.72      0.72        40
# weighted avg       0.74      0.72      0.72        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.5min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #8
# Mean negativities for all classes: [0.05781259813985255]
# Mean entropies for all classes: [2.9626615712825746e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.67      0.50      0.57        20
#          1.0       0.60      0.75      0.67        20
#
#     accuracy                           0.62        40
#    macro avg       0.63      0.62      0.62        40
# weighted avg       0.63      0.62      0.62        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #9
# Mean negativities for all classes: [0.04313236426967513]
# Mean entropies for all classes: [2.3216199255122564e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.76      0.65      0.70        20
#          1.0       0.70      0.80      0.74        20
#
#     accuracy                           0.73        40
#    macro avg       0.73      0.73      0.72        40
# weighted avg       0.73      0.72      0.72        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.6824999999999999 F1-Scores = 0.6730398897776523 Negativity = [0.15157361492572058, 0.05698186554365361] Entropy = [1.9784411068532998e-15, 3.3341622513089673e-15]
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #0
# Mean negativities for all classes: [0.029302473811004908]
# Mean entropies for all classes: [1.633984954510074e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.77      0.50      0.61        20
#          1.0       0.63      0.85      0.72        20
#
#     accuracy                           0.68        40
#    macro avg       0.70      0.68      0.66        40
# weighted avg       0.70      0.68      0.66        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #1
# Mean negativities for all classes: [0.20838261031717123]
# Mean entropies for all classes: [2.365378106038806e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.73      0.55      0.63        20
#          1.0       0.64      0.80      0.71        20
#
#     accuracy                           0.68        40
#    macro avg       0.69      0.68      0.67        40
# weighted avg       0.69      0.68      0.67        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #2
# Mean negativities for all classes: [0.07852352564305955]
# Mean entropies for all classes: [2.053112304685322e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.65      0.55      0.59        20
#          1.0       0.61      0.70      0.65        20
#
#     accuracy                           0.62        40
#    macro avg       0.63      0.62      0.62        40
# weighted avg       0.63      0.62      0.62        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #3
# Mean negativities for all classes: [0.1960392775367117]
# Mean entropies for all classes: [2.385604743155603e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.86      0.60      0.71        20
#          1.0       0.69      0.90      0.78        20
#
#     accuracy                           0.75        40
#    macro avg       0.77      0.75      0.74        40
# weighted avg       0.77      0.75      0.74        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #4
# Mean negativities for all classes: [0.22407101708422683]
# Mean entropies for all classes: [3.0897994687865e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.82      0.45      0.58        20
#          1.0       0.62      0.90      0.73        20
#
#     accuracy                           0.68        40
#    macro avg       0.72      0.68      0.66        40
# weighted avg       0.72      0.68      0.66        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #5
# Mean negativities for all classes: [0.20875014565392913]
# Mean entropies for all classes: [2.7293282132611617e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.79      0.55      0.65        20
#          1.0       0.65      0.85      0.74        20
#
#     accuracy                           0.70        40
#    macro avg       0.72      0.70      0.69        40
# weighted avg       0.72      0.70      0.69        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #6
# Mean negativities for all classes: [0.024179631960493348]
# Mean entropies for all classes: [2.7531391476909854e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.69      0.45      0.55        20
#          1.0       0.59      0.80      0.68        20
#
#     accuracy                           0.62        40
#    macro avg       0.64      0.62      0.61        40
# weighted avg       0.64      0.62      0.61        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #7
# Mean negativities for all classes: [0.0451833913931393]
# Mean entropies for all classes: [2.9034342234325045e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.87      0.65      0.74        20
#          1.0       0.72      0.90      0.80        20
#
#     accuracy                           0.78        40
#    macro avg       0.79      0.78      0.77        40
# weighted avg       0.79      0.78      0.77        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #8
# Mean negativities for all classes: [0.20141224908383312]
# Mean entropies for all classes: [1.7773185576339704e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.71      0.50      0.59        20
#          1.0       0.62      0.80      0.70        20
#
#     accuracy                           0.65        40
#    macro avg       0.66      0.65      0.64        40
# weighted avg       0.66      0.65      0.64        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #9
# Mean negativities for all classes: [0.23197735108112147]
# Mean entropies for all classes: [2.593645081139004e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.71      0.50      0.59        20
#          1.0       0.62      0.80      0.70        20
#
#     accuracy                           0.65        40
#    macro avg       0.66      0.65      0.64        40
# weighted avg       0.66      0.65      0.64        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.68 F1-Scores = 0.6720930910152066 Negativity = [0.029302473811004908, 0.20838261031717123] Entropy = [1.633984954510074e-15, 2.365378106038806e-15]
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #0
# Mean negativities for all classes: [0.08403284702485303]
# Mean entropies for all classes: [2.772712783955359e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.78      0.70      0.74        20
#          1.0       0.73      0.80      0.76        20
#
#     accuracy                           0.75        40
#    macro avg       0.75      0.75      0.75        40
# weighted avg       0.75      0.75      0.75        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #1
# Mean negativities for all classes: [0.20329064914673087]
# Mean entropies for all classes: [2.6521854523190746e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.92      0.55      0.69        20
#          1.0       0.68      0.95      0.79        20
#
#     accuracy                           0.75        40
#    macro avg       0.80      0.75      0.74        40
# weighted avg       0.80      0.75      0.74        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #2
# Mean negativities for all classes: [0.19036982198455413]
# Mean entropies for all classes: [2.6685278660092122e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.83      0.50      0.62        20
#          1.0       0.64      0.90      0.75        20
#
#     accuracy                           0.70        40
#    macro avg       0.74      0.70      0.69        40
# weighted avg       0.74      0.70      0.69        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #3
# Mean negativities for all classes: [0.20212640067211002]
# Mean entropies for all classes: [3.2994680844131335e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.83      0.50      0.62        20
#          1.0       0.64      0.90      0.75        20
#
#     accuracy                           0.70        40
#    macro avg       0.74      0.70      0.69        40
# weighted avg       0.74      0.70      0.69        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #4
# Mean negativities for all classes: [0.028941253931712124]
# Mean entropies for all classes: [2.8224978801952636e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.69      0.45      0.55        20
#          1.0       0.59      0.80      0.68        20
#
#     accuracy                           0.62        40
#    macro avg       0.64      0.62      0.61        40
# weighted avg       0.64      0.62      0.61        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #5
# Mean negativities for all classes: [0.22257107021012762]
# Mean entropies for all classes: [2.8432687324070158e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.77      0.50      0.61        20
#          1.0       0.63      0.85      0.72        20
#
#     accuracy                           0.68        40
#    macro avg       0.70      0.68      0.66        40
# weighted avg       0.70      0.68      0.66        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #6
# Mean negativities for all classes: [0.053746371438054844]
# Mean entropies for all classes: [2.98578071536086e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.62      0.50      0.56        20
#          1.0       0.58      0.70      0.64        20
#
#     accuracy                           0.60        40
#    macro avg       0.60      0.60      0.60        40
# weighted avg       0.60      0.60      0.60        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #7
# Mean negativities for all classes: [0.045909611032527955]
# Mean entropies for all classes: [2.843873266597761e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.69      0.55      0.61        20
#          1.0       0.62      0.75      0.68        20
#
#     accuracy                           0.65        40
#    macro avg       0.66      0.65      0.65        40
# weighted avg       0.66      0.65      0.65        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #8
# Mean negativities for all classes: [0.036248046572423774]
# Mean entropies for all classes: [2.0224199771686467e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.73      0.40      0.52        20
#          1.0       0.59      0.85      0.69        20
#
#     accuracy                           0.62        40
#    macro avg       0.66      0.62      0.61        40
# weighted avg       0.66      0.62      0.61        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #9
# Mean negativities for all classes: [0.01617814332763441]
# Mean entropies for all classes: [2.9125276639425663e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.81      0.65      0.72        20
#          1.0       0.71      0.85      0.77        20
#
#     accuracy                           0.75        40
#    macro avg       0.76      0.75      0.75        40
# weighted avg       0.76      0.75      0.75        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.6824999999999999 F1-Scores = 0.6736744283787564 Negativity = [0.08403284702485303, 0.20329064914673087] Entropy = [2.772712783955359e-15, 2.6521854523190746e-15]
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #0
# Mean negativities for all classes: [0.052962232087079265]
# Mean entropies for all classes: [2.8901347909873393e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.58      0.35      0.44        20
#          1.0       0.54      0.75      0.63        20
#
#     accuracy                           0.55        40
#    macro avg       0.56      0.55      0.53        40
# weighted avg       0.56      0.55      0.53        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #1
# Mean negativities for all classes: [0.015324861911422674]
# Mean entropies for all classes: [3.1159704757429207e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.87      0.65      0.74        20
#          1.0       0.72      0.90      0.80        20
#
#     accuracy                           0.78        40
#    macro avg       0.79      0.78      0.77        40
# weighted avg       0.79      0.78      0.77        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #2
# Mean negativities for all classes: [0.20180222492737956]
# Mean entropies for all classes: [3.0333172437928956e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.92      0.60      0.73        20
#          1.0       0.70      0.95      0.81        20
#
#     accuracy                           0.78        40
#    macro avg       0.81      0.77      0.77        40
# weighted avg       0.81      0.78      0.77        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #3
# Mean negativities for all classes: [0.1811388417102257]
# Mean entropies for all classes: [2.288952651847326e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.71      0.50      0.59        20
#          1.0       0.62      0.80      0.70        20
#
#     accuracy                           0.65        40
#    macro avg       0.66      0.65      0.64        40
# weighted avg       0.66      0.65      0.64        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #4
# Mean negativities for all classes: [0.19533586597504166]
# Mean entropies for all classes: [2.8413158359626885e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.80      0.40      0.53        20
#          1.0       0.60      0.90      0.72        20
#
#     accuracy                           0.65        40
#    macro avg       0.70      0.65      0.63        40
# weighted avg       0.70      0.65      0.63        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #5
# Mean negativities for all classes: [0.2148119456180547]
# Mean entropies for all classes: [2.7133996645983226e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.69      0.45      0.55        20
#          1.0       0.59      0.80      0.68        20
#
#     accuracy                           0.62        40
#    macro avg       0.64      0.62      0.61        40
# weighted avg       0.64      0.62      0.61        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #6
# Mean negativities for all classes: [0.20004130816382748]
# Mean entropies for all classes: [2.190778104486947e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.82      0.70      0.76        20
#          1.0       0.74      0.85      0.79        20
#
#     accuracy                           0.78        40
#    macro avg       0.78      0.77      0.77        40
# weighted avg       0.78      0.78      0.77        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #7
# Mean negativities for all classes: [0.18382652893793688]
# Mean entropies for all classes: [2.2506255082109503e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.67      0.50      0.57        20
#          1.0       0.60      0.75      0.67        20
#
#     accuracy                           0.62        40
#    macro avg       0.63      0.62      0.62        40
# weighted avg       0.63      0.62      0.62        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #8
# Mean negativities for all classes: [0.07508664327849549]
# Mean entropies for all classes: [2.9367283922850656e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.73      0.55      0.63        20
#          1.0       0.64      0.80      0.71        20
#
#     accuracy                           0.68        40
#    macro avg       0.69      0.68      0.67        40
# weighted avg       0.69      0.68      0.67        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #9
# Mean negativities for all classes: [0.041846724453429206]
# Mean entropies for all classes: [3.0317546605613246e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.75      0.60      0.67        20
#          1.0       0.67      0.80      0.73        20
#
#     accuracy                           0.70        40
#    macro avg       0.71      0.70      0.70        40
# weighted avg       0.71      0.70      0.70        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.6799999999999999 F1-Scores = 0.6711919260984317 Negativity = [0.052962232087079265, 0.015324861911422674] Entropy = [2.8901347909873393e-15, 3.1159704757429207e-15]
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #0
# Mean negativities for all classes: [0.19548469640941663]
# Mean entropies for all classes: [3.211427727479281e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.81      0.65      0.72        20
#          1.0       0.71      0.85      0.77        20
#
#     accuracy                           0.75        40
#    macro avg       0.76      0.75      0.75        40
# weighted avg       0.76      0.75      0.75        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #1
# Mean negativities for all classes: [0.062161307497991446]
# Mean entropies for all classes: [3.212510799572851e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.63      0.60      0.62        20
#          1.0       0.62      0.65      0.63        20
#
#     accuracy                           0.62        40
#    macro avg       0.63      0.62      0.62        40
# weighted avg       0.63      0.62      0.62        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #2
# Mean negativities for all classes: [0.06264071410684631]
# Mean entropies for all classes: [2.547348965827294e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.76      0.80      0.78        20
#          1.0       0.79      0.75      0.77        20
#
#     accuracy                           0.78        40
#    macro avg       0.78      0.78      0.77        40
# weighted avg       0.78      0.78      0.77        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #3
# Mean negativities for all classes: [0.18047033889891484]
# Mean entropies for all classes: [2.6650922876402445e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.78      0.70      0.74        20
#          1.0       0.73      0.80      0.76        20
#
#     accuracy                           0.75        40
#    macro avg       0.75      0.75      0.75        40
# weighted avg       0.75      0.75      0.75        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #4
# Mean negativities for all classes: [0.21955749680761177]
# Mean entropies for all classes: [2.648024013959386e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.60      0.30      0.40        20
#          1.0       0.53      0.80      0.64        20
#
#     accuracy                           0.55        40
#    macro avg       0.57      0.55      0.52        40
# weighted avg       0.57      0.55      0.52        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #5
# Mean negativities for all classes: [0.1779851144533522]
# Mean entropies for all classes: [1.6758586181192067e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.73      0.55      0.63        20
#          1.0       0.64      0.80      0.71        20
#
#     accuracy                           0.68        40
#    macro avg       0.69      0.68      0.67        40
# weighted avg       0.69      0.68      0.67        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #6
# Mean negativities for all classes: [0.20105714105093025]
# Mean entropies for all classes: [2.5697059810331944e-15]
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.20      0.33        20
#          1.0       0.56      1.00      0.71        20
#
#     accuracy                           0.60        40
#    macro avg       0.78      0.60      0.52        40
# weighted avg       0.78      0.60      0.52        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #7
# Mean negativities for all classes: [0.05299329221826593]
# Mean entropies for all classes: [2.765037567675233e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.67      0.40      0.50        20
#          1.0       0.57      0.80      0.67        20
#
#     accuracy                           0.60        40
#    macro avg       0.62      0.60      0.58        40
# weighted avg       0.62      0.60      0.58        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #8
# Mean negativities for all classes: [0.2095946617262911]
# Mean entropies for all classes: [2.7079653748054895e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.71      0.50      0.59        20
#          1.0       0.62      0.80      0.70        20
#
#     accuracy                           0.65        40
#    macro avg       0.66      0.65      0.64        40
# weighted avg       0.66      0.65      0.64        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #9
# Mean negativities for all classes: [0.21162024378934227]
# Mean entropies for all classes: [2.2073631962081845e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.92      0.60      0.73        20
#          1.0       0.70      0.95      0.81        20
#
#     accuracy                           0.78        40
#    macro avg       0.81      0.77      0.77        40
# weighted avg       0.81      0.78      0.77        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.675 F1-Scores = 0.6603292490321904 Negativity = [0.19548469640941663, 0.062161307497991446] Entropy = [3.211427727479281e-15, 3.212510799572851e-15]
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #0
# Mean negativities for all classes: [0.16870838657033294]
# Mean entropies for all classes: [2.6760497931270306e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.68      0.65      0.67        20
#          1.0       0.67      0.70      0.68        20
#
#     accuracy                           0.68        40
#    macro avg       0.68      0.68      0.67        40
# weighted avg       0.68      0.68      0.67        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #1
# Mean negativities for all classes: [0.014517971917711777]
# Mean entropies for all classes: [3.5730336383410955e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.83      0.50      0.62        20
#          1.0       0.64      0.90      0.75        20
#
#     accuracy                           0.70        40
#    macro avg       0.74      0.70      0.69        40
# weighted avg       0.74      0.70      0.69        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #2
# Mean negativities for all classes: [0.19847622394062445]
# Mean entropies for all classes: [2.1038722413909996e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.75      0.45      0.56        20
#          1.0       0.61      0.85      0.71        20
#
#     accuracy                           0.65        40
#    macro avg       0.68      0.65      0.64        40
# weighted avg       0.68      0.65      0.64        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #3
# Mean negativities for all classes: [0.05929752046689538]
# Mean entropies for all classes: [3.220862530844646e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.70      0.35      0.47        20
#          1.0       0.57      0.85      0.68        20
#
#     accuracy                           0.60        40
#    macro avg       0.63      0.60      0.57        40
# weighted avg       0.63      0.60      0.57        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #4
# Mean negativities for all classes: [0.2331567258817266]
# Mean entropies for all classes: [2.132585704749707e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.59      0.50      0.54        20
#          1.0       0.57      0.65      0.60        20
#
#     accuracy                           0.57        40
#    macro avg       0.58      0.57      0.57        40
# weighted avg       0.58      0.57      0.57        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #5
# Mean negativities for all classes: [0.0662618650522875]
# Mean entropies for all classes: [2.9398605925775753e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.65      0.76        20
#          1.0       0.73      0.95      0.83        20
#
#     accuracy                           0.80        40
#    macro avg       0.83      0.80      0.80        40
# weighted avg       0.83      0.80      0.80        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #6
# Mean negativities for all classes: [0.05906053691121012]
# Mean entropies for all classes: [2.5556102136562666e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.77      0.50      0.61        20
#          1.0       0.63      0.85      0.72        20
#
#     accuracy                           0.68        40
#    macro avg       0.70      0.68      0.66        40
# weighted avg       0.70      0.68      0.66        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #7
# Mean negativities for all classes: [0.22422175272627828]
# Mean entropies for all classes: [2.220568919366922e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.83      0.50      0.62        20
#          1.0       0.64      0.90      0.75        20
#
#     accuracy                           0.70        40
#    macro avg       0.74      0.70      0.69        40
# weighted avg       0.74      0.70      0.69        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #8
# Mean negativities for all classes: [0.02115819714569781]
# Mean entropies for all classes: [2.991865153169212e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.75      0.60      0.67        20
#          1.0       0.67      0.80      0.73        20
#
#     accuracy                           0.70        40
#    macro avg       0.71      0.70      0.70        40
# weighted avg       0.71      0.70      0.70        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #9
# Mean negativities for all classes: [0.20477029852085282]
# Mean entropies for all classes: [8.692463151160041e-16]
#               precision    recall  f1-score   support
#
#          0.0       0.80      0.60      0.69        20
#          1.0       0.68      0.85      0.76        20
#
#     accuracy                           0.73        40
#    macro avg       0.74      0.72      0.72        40
# weighted avg       0.74      0.72      0.72        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.6799999999999999 F1-Scores = 0.6708876067364934 Negativity = [0.16870838657033294, 0.014517971917711777] Entropy = [2.6760497931270306e-15, 3.5730336383410955e-15]
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #0
# Mean negativities for all classes: [0.19465358338901273]
# Mean entropies for all classes: [3.5842712144168755e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.79      0.55      0.65        20
#          1.0       0.65      0.85      0.74        20
#
#     accuracy                           0.70        40
#    macro avg       0.72      0.70      0.69        40
# weighted avg       0.72      0.70      0.69        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #1
# Mean negativities for all classes: [0.18862469915352853]
# Mean entropies for all classes: [2.259905492468163e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.80      0.60      0.69        20
#          1.0       0.68      0.85      0.76        20
#
#     accuracy                           0.73        40
#    macro avg       0.74      0.72      0.72        40
# weighted avg       0.74      0.72      0.72        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #2
# Mean negativities for all classes: [0.038279546513637644]
# Mean entropies for all classes: [2.940678416504592e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.56      0.45      0.50        20
#          1.0       0.54      0.65      0.59        20
#
#     accuracy                           0.55        40
#    macro avg       0.55      0.55      0.55        40
# weighted avg       0.55      0.55      0.55        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #3
# Mean negativities for all classes: [0.19510536238038417]
# Mean entropies for all classes: [2.493154221293383e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.80      0.40      0.53        20
#          1.0       0.60      0.90      0.72        20
#
#     accuracy                           0.65        40
#    macro avg       0.70      0.65      0.63        40
# weighted avg       0.70      0.65      0.63        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #4
# Mean negativities for all classes: [0.21403690006364445]
# Mean entropies for all classes: [2.355285960375161e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.85      0.55      0.67        20
#          1.0       0.67      0.90      0.77        20
#
#     accuracy                           0.73        40
#    macro avg       0.76      0.73      0.72        40
# weighted avg       0.76      0.72      0.72        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #5
# Mean negativities for all classes: [0.22908796145078875]
# Mean entropies for all classes: [2.36841284316978e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.82      0.70      0.76        20
# ...
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #1
# Mean negativities for all classes: [0.17285067751929992]
# Mean entropies for all classes: [2.701824820315357e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.81      0.65      0.72        20
#          1.0       0.71      0.85      0.77        20
#
#     accuracy                           0.75        40
#    macro avg       0.76      0.75      0.75        40
# weighted avg       0.76      0.75      0.75        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #2
# Mean negativities for all classes: [0.03694259597707106]
# Mean entropies for all classes: [2.498442512109342e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.46      0.30      0.36        20
#          1.0       0.48      0.65      0.55        20
#
#     accuracy                           0.48        40
#    macro avg       0.47      0.47      0.46        40
# weighted avg       0.47      0.47      0.46        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #3
# Mean negativities for all classes: [0.17509521062640848]
# Mean entropies for all classes: [1.808636501960547e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.87      0.65      0.74        20
#          1.0       0.72      0.90      0.80        20
#
#     accuracy                           0.78        40
#    macro avg       0.79      0.78      0.77        40
# weighted avg       0.79      0.78      0.77        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #4
# Mean negativities for all classes: [0.24013687456247895]
# Mean entropies for all classes: [2.691569839726495e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.73      0.40      0.52        20
#          1.0       0.59      0.85      0.69        20
#
#     accuracy                           0.62        40
#    macro avg       0.66      0.62      0.61        40
# weighted avg       0.66      0.62      0.61        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #5
# Mean negativities for all classes: [0.2030067499408407]
# Mean entropies for all classes: [2.8432132905892906e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.87      0.65      0.74        20
#          1.0       0.72      0.90      0.80        20
#
#     accuracy                           0.78        40
#    macro avg       0.79      0.78      0.77        40
# weighted avg       0.79      0.78      0.77        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #6
# Mean negativities for all classes: [0.04860255324911707]
# Mean entropies for all classes: [3.2953903376106804e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.78      0.35      0.48        20
#          1.0       0.58      0.90      0.71        20
#
#     accuracy                           0.62        40
#    macro avg       0.68      0.62      0.59        40
# weighted avg       0.68      0.62      0.59        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #7
# Mean negativities for all classes: [0.060824386463490455]
# Mean entropies for all classes: [2.5737281253703935e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.80      0.60      0.69        20
#          1.0       0.68      0.85      0.76        20
#
#     accuracy                           0.73        40
#    macro avg       0.74      0.72      0.72        40
# weighted avg       0.74      0.72      0.72        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #8
# Mean negativities for all classes: [0.22765612539871025]
# Mean entropies for all classes: [3.1493010586900865e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.73      0.55      0.63        20
#          1.0       0.64      0.80      0.71        20
#
#     accuracy                           0.68        40
#    macro avg       0.69      0.68      0.67        40
# weighted avg       0.69      0.68      0.67        40
#
# -------------------------------------------------------------------------------------------------------------------
# K-Fold #9
# Mean negativities for all classes: [0.2064438212342897]
# Mean entropies for all classes: [3.1087895903683273e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.76      0
111566125178, 0.21914591929009314, 0.19564283341882177, 0.21702801501824903, 0.1867242633523215, 0.023345374664418023]], [[0.2059066562137418, 0.05077870544326819, 0.21544206009850644, 0.07910810640248589, 0.19625294985680375, 0.03653243357388044, 0.24507910082713485, 0.2050372556539867, 0.03137439335274975, 0.04246582608306386]], [[0.2024034431976965, 0.012602384997437831, 0.11357536800433335, 0.20578068534969254, 0.18479094997309606, 0.19365698290358352, 0.19536942560146028, 0.18616650521742795, 0.20827406194481882, 0.2102726042679058]], [[0.19984831591788602, 0.20824611389037573, 0.08242527344308288, 0.20064396705356766, 0.18748072791247233, 0.20177496323274752, 0.203104467546361, 0.20607928940125966, 0.03357730182024323, 0.08858841607100096]], [[0.014032449280584095, 0.20678056278206597, 0.030051984674871534, 0.07015286166429054, 0.18019060981876328, 0.027313329964052446, 0.20785615654604114, 0.19832415546338006, 0.17430448213842867, 0.22455520165985626]], [[0.18214058354452015, 0.027258657137176606, 0.04440761714728362, 0.055986089058898306, 0.1810525359176836, 0.2126992875127786, 0.0870130487115407,  ...
# CPU times: total: 14.2 s
# Wall time: 7h 56min 10s
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished

# %% [markdown]
# # Stripes

# %%
# %%time
# %run Experimento-Artificial-Stripes-20-10-Fold.ipynb
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #0
# Mean negativities for all classes: [0.1443321884511155]
# Mean entropies for all classes: [-1.3910950033522733e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.89      0.80      0.84        20
#          1.0       0.82      0.90      0.86        20
#
#     accuracy                           0.85        40
#    macro avg       0.85      0.85      0.85        40
# weighted avg       0.85      0.85      0.85        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #1
# Mean negativities for all classes: [0.18754135368547303]
# Mean entropies for all classes: [1.4820412225611374e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.91      0.50      0.65        20
#          1.0       0.66      0.95      0.78        20
#
#     accuracy                           0.73        40
#    macro avg       0.78      0.72      0.71        40
# weighted avg       0.78      0.72      0.71        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #2
# Mean negativities for all classes: [0.0741845488170412]
# Mean entropies for all classes: [1.0537173018436033e-16]
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.60      0.75        20
#          1.0       0.71      1.00      0.83        20
#
#     accuracy                           0.80        40
#    macro avg       0.86      0.80      0.79        40
# weighted avg       0.86      0.80      0.79        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #3
# Mean negativities for all classes: [0.1915661840367176]
# Mean entropies for all classes: [-1.7927249828273723e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.75      0.83        20
#          1.0       0.79      0.95      0.86        20
#
#     accuracy                           0.85        40
#    macro avg       0.86      0.85      0.85        40
# weighted avg       0.86      0.85      0.85        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #4
# Mean negativities for all classes: [0.18961302725247497]
# Mean entropies for all classes: [-2.736701237511444e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.83      0.75      0.79        20
#          1.0       0.77      0.85      0.81        20
#
#     accuracy                           0.80        40
#    macro avg       0.80      0.80      0.80        40
# weighted avg       0.80      0.80      0.80        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #5
# Mean negativities for all classes: [0.17222857329427246]
# Mean entropies for all classes: [4.581073020355794e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.65      0.76        20
#          1.0       0.73      0.95      0.83        20
#
#     accuracy                           0.80        40
#    macro avg       0.83      0.80      0.80        40
# weighted avg       0.83      0.80      0.80        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #6
# Mean negativities for all classes: [0.1862119538616108]
# Mean entropies for all classes: [1.6988502896642734e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.87      0.65      0.74        20
#          1.0       0.72      0.90      0.80        20
#
#     accuracy                           0.78        40
#    macro avg       0.79      0.78      0.77        40
# weighted avg       0.79      0.78      0.77        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #7
# Mean negativities for all classes: [0.18644265436028568]
# Mean entropies for all classes: [9.342162246608297e-15]
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.65      0.79        20
#          1.0       0.74      1.00      0.85        20
#
#     accuracy                           0.82        40
#    macro avg       0.87      0.82      0.82        40
# weighted avg       0.87      0.82      0.82        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #8
# Mean negativities for all classes: [0.12361403619346659]
# Mean entropies for all classes: [-2.915247280250823e-14]
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.75      0.86        20
#          1.0       0.80      1.00      0.89        20
#
#     accuracy                           0.88        40
#    macro avg       0.90      0.88      0.87        40
# weighted avg       0.90      0.88      0.87        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #9
# Mean negativities for all classes: [0.16852149205220632]
# Mean entropies for all classes: [9.78357089356025e-16]
#               precision    recall  f1-score   support
#
#          0.0       0.81      0.65      0.72        20
#          1.0       0.71      0.85      0.77        20
#
#     accuracy                           0.75        40
#    macro avg       0.76      0.75      0.75        40
# weighted avg       0.76      0.75      0.75        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.805 F1-Scores = 0.8006396989560708 Negativity = [0.1443321884511155, 0.18754135368547303] Entropy = [-1.3910950033522733e-14, 1.4820412225611374e-15]
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #0
# Mean negativities for all classes: [0.20000847469506172]
# Mean entropies for all classes: [2.8995124498100013e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.75      0.83        20
#          1.0       0.79      0.95      0.86        20
#
#     accuracy                           0.85        40
#    macro avg       0.86      0.85      0.85        40
# weighted avg       0.86      0.85      0.85        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #1
# Mean negativities for all classes: [0.13181497608356557]
# Mean entropies for all classes: [3.012005839497932e-14]
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.60      0.75        20
#          1.0       0.71      1.00      0.83        20
#
#     accuracy                           0.80        40
#    macro avg       0.86      0.80      0.79        40
# weighted avg       0.86      0.80      0.79        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #2
# Mean negativities for all classes: [0.20153466967395106]
# Mean entropies for all classes: [-2.5454386085959775e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.82      0.70      0.76        20
#          1.0       0.74      0.85      0.79        20
#
#     accuracy                           0.78        40
#    macro avg       0.78      0.77      0.77        40
# weighted avg       0.78      0.78      0.77        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #3
# Mean negativities for all classes: [0.19367722514609156]
# Mean entropies for all classes: [2.870021092343686e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.75      0.83        20
#          1.0       0.79      0.95      0.86        20
#
#     accuracy                           0.85        40
#    macro avg       0.86      0.85      0.85        40
# weighted avg       0.86      0.85      0.85        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #4
# Mean negativities for all classes: [0.047117691891393323]
# Mean entropies for all classes: [7.456765398503092e-16]
#               precision    recall  f1-score   support
#
#          0.0       0.88      0.75      0.81        20
#          1.0       0.78      0.90      0.84        20
#
#     accuracy                           0.82        40
#    macro avg       0.83      0.82      0.82        40
# weighted avg       0.83      0.82      0.82        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #5
# Mean negativities for all classes: [0.18697627193245628]
# Mean entropies for all classes: [1.1059101372677663e-15]
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.70      0.82        20
#          1.0       0.77      1.00      0.87        20
#
#     accuracy                           0.85        40
#    macro avg       0.88      0.85      0.85        40
# weighted avg       0.88      0.85      0.85        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #6
# Mean negativities for all classes: [0.19083328554242254]
# Mean entropies for all classes: [1.1176956882564316e-15]
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.60      0.75        20
#          1.0       0.71      1.00      0.83        20
#
#     accuracy                           0.80        40
#    macro avg       0.86      0.80      0.79        40
# weighted avg       0.86      0.80      0.79        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #7
# Mean negativities for all classes: [0.13775036298592452]
# Mean entropies for all classes: [-5.978144841500879e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.91      0.50      0.65        20
#          1.0       0.66      0.95      0.78        20
#
#     accuracy                           0.73        40
#    macro avg       0.78      0.72      0.71        40
# weighted avg       0.78      0.72      0.71        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #8
# Mean negativities for all classes: [0.1789163329981547]
# Mean entropies for all classes: [4.7472524430538e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.65      0.76        20
#          1.0       0.73      0.95      0.83        20
#
#     accuracy                           0.80        40
#    macro avg       0.83      0.80      0.80        40
# weighted avg       0.83      0.80      0.80        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #9
# Mean negativities for all classes: [0.1492267719635426]
# Mean entropies for all classes: [1.2018097141889285e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.88      0.70      0.78        20
#          1.0       0.75      0.90      0.82        20
#
#     accuracy                           0.80        40
#    macro avg       0.81      0.80      0.80        40
# weighted avg       0.81      0.80      0.80        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.8074999999999999 F1-Scores = 0.8028299581656156 Negativity = [0.20000847469506172, 0.13181497608356557] Entropy = [2.8995124498100013e-15, 3.012005839497932e-14]
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #0
# Mean negativities for all classes: [0.12213742651384732]
# Mean entropies for all classes: [-1.3131225642865446e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.92      0.60      0.73        20
#          1.0       0.70      0.95      0.81        20
#
#     accuracy                           0.78        40
#    macro avg       0.81      0.77      0.77        40
# weighted avg       0.81      0.78      0.77        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #1
# Mean negativities for all classes: [0.0980795456508814]
# Mean entropies for all classes: [3.3453220345481587e-15]
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.70      0.82        20
#          1.0       0.77      1.00      0.87        20
#
#     accuracy                           0.85        40
#    macro avg       0.88      0.85      0.85        40
# weighted avg       0.88      0.85      0.85        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #2
# Mean negativities for all classes: [0.14445048273106303]
# Mean entropies for all classes: [-1.8200120853165626e-14]
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.65      0.79        20
#          1.0       0.74      1.00      0.85        20
#
#     accuracy                           0.82        40
#    macro avg       0.87      0.82      0.82        40
# weighted avg       0.87      0.82      0.82        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #3
# Mean negativities for all classes: [0.20999418362794836]
# Mean entropies for all classes: [-8.499608122282351e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.70      0.80        20
#          1.0       0.76      0.95      0.84        20
#
#     accuracy                           0.82        40
#    macro avg       0.85      0.82      0.82        40
# weighted avg       0.85      0.82      0.82        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #4
# Mean negativities for all classes: [0.1981537387110336]
# Mean entropies for all classes: [-2.7213652937516607e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.82      0.70      0.76        20
#          1.0       0.74      0.85      0.79        20
#
#     accuracy                           0.78        40
#    macro avg       0.78      0.77      0.77        40
# weighted avg       0.78      0.78      0.77        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #5
# Mean negativities for all classes: [0.16469928127024752]
# Mean entropies for all classes: [-7.976579206266119e-16]
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.80      0.89        20
#          1.0       0.83      1.00      0.91        20
#
#     accuracy                           0.90        40
#    macro avg       0.92      0.90      0.90        40
# weighted avg       0.92      0.90      0.90        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #6
# Mean negativities for all classes: [0.17230782875234535]
# Mean entropies for all classes: [1.9916704617138538e-15]
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.60      0.75        20
#          1.0       0.71      1.00      0.83        20
#
#     accuracy                           0.80        40
#    macro avg       0.86      0.80      0.79        40
# weighted avg       0.86      0.80      0.79        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #7
# Mean negativities for all classes: [0.1967501955675624]
# Mean entropies for all classes: [-5.462811489352873e-16]
#               precision    recall  f1-score   support
#
#          0.0       0.75      0.75      0.75        20
#          1.0       0.75      0.75      0.75        20
#
#     accuracy                           0.75        40
#    macro avg       0.75      0.75      0.75        40
# weighted avg       0.75      0.75      0.75        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #8
# Mean negativities for all classes: [0.1736871535213749]
# Mean entropies for all classes: [1.3403978821261381e-15]
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.50      0.67        20
#          1.0       0.67      1.00      0.80        20
#
#     accuracy                           0.75        40
#    macro avg       0.83      0.75      0.73        40
# weighted avg       0.83      0.75      0.73        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #9
# Mean negativities for all classes: [0.17149869800431436]
# Mean entropies for all classes: [1.4872706466360136e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.88      0.75      0.81        20
#          1.0       0.78      0.90      0.84        20
#
#     accuracy                           0.82        40
#    macro avg       0.83      0.82      0.82        40
# weighted avg       0.83      0.82      0.82        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.8074999999999999 F1-Scores = 0.8027859699564314 Negativity = [0.12213742651384732, 0.0980795456508814] Entropy = [-1.3131225642865446e-14, 3.3453220345481587e-15]
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #0
# Mean negativities for all classes: [0.14211221719366973]
# Mean entropies for all classes: [-1.670162490290884e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.88      0.70      0.78        20
#          1.0       0.75      0.90      0.82        20
#
#     accuracy                           0.80        40
#    macro avg       0.81      0.80      0.80        40
# weighted avg       0.81      0.80      0.80        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #1
# Mean negativities for all classes: [0.18825179674252793]
# Mean entropies for all classes: [1.9770695962775926e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.92      0.60      0.73        20
#          1.0       0.70      0.95      0.81        20
#
#     accuracy                           0.78        40
#    macro avg       0.81      0.77      0.77        40
# weighted avg       0.81      0.78      0.77        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #2
# Mean negativities for all classes: [0.20250548542969313]
# Mean entropies for all classes: [5.1384687134619945e-17]
#               precision    recall  f1-score   support
#
#          0.0       0.90      0.90      0.90        20
#          1.0       0.90      0.90      0.90        20
#
#     accuracy                           0.90        40
#    macro avg       0.90      0.90      0.90        40
# weighted avg       0.90      0.90      0.90        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #3
# Mean negativities for all classes: [0.17758685137634111]
# Mean entropies for all classes: [3.6455862560812925e-15]
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.70      0.82        20
#          1.0       0.77      1.00      0.87        20
#
#     accuracy                           0.85        40
#    macro avg       0.88      0.85      0.85        40
# weighted avg       0.88      0.85      0.85        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #4
# Mean negativities for all classes: [0.18220930747854566]
# Mean entropies for all classes: [2.4546962290583574e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.73      0.55      0.63        20
#          1.0       0.64      0.80      0.71        20
#
#     accuracy                           0.68        40
#    macro avg       0.69      0.68      0.67        40
# weighted avg       0.69      0.68      0.67        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #5
# Mean negativities for all classes: [0.20185284629456018]
# Mean entropies for all classes: [3.864443304795503e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.70      0.80        20
#          1.0       0.76      0.95      0.84        20
#
#     accuracy                           0.82        40
#    macro avg       0.85      0.82      0.82        40
# weighted avg       0.85      0.82      0.82        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #6
# Mean negativities for all classes: [0.1583577386119803]
# Mean entropies for all classes: [4.8601395238043955e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.91      0.50      0.65        20
#          1.0       0.66      0.95      0.78        20
#
#     accuracy                           0.73        40
#    macro avg       0.78      0.72      0.71        40
# weighted avg       0.78      0.72      0.71        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #7
# Mean negativities for all classes: [0.1489129205268993]
# Mean entropies for all classes: [7.730368580019728e-15]
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.65      0.79        20
#          1.0       0.74      1.00      0.85        20
#
#     accuracy                           0.82        40
#    macro avg       0.87      0.82      0.82        40
# weighted avg       0.87      0.82      0.82        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #8
# Mean negativities for all classes: [0.1179293567487941]
# Mean entropies for all classes: [1.818996560758095e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.87      0.65      0.74        20
#          1.0       0.72      0.90      0.80        20
#
#     accuracy                           0.78        40
#    macro avg       0.79      0.78      0.77        40
# weighted avg       0.79      0.78      0.77        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #9
# Mean negativities for all classes: [0.16228330601420296]
# Mean entropies for all classes: [-4.0118464409672765e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.75      0.83        20
#          1.0       0.79      0.95      0.86        20
#
#     accuracy                           0.85        40
#    macro avg       0.86      0.85      0.85        40
# weighted avg       0.86      0.85      0.85        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.8 F1-Scores = 0.7954202763355133 Negativity = [0.14211221719366973, 0.18825179674252793] Entropy = [-1.670162490290884e-15, 1.9770695962775926e-15]
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #0
# Mean negativities for all classes: [0.14757297460959543]
# Mean entropies for all classes: [4.0452009635515845e-15]
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.60      0.75        20
#          1.0       0.71      1.00      0.83        20
#
#     accuracy                           0.80        40
#    macro avg       0.86      0.80      0.79        40
# weighted avg       0.86      0.80      0.79        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #1
# Mean negativities for all classes: [0.19132167492711016]
# Mean entropies for all classes: [-5.464251275388192e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.88      0.70      0.78        20
#          1.0       0.75      0.90      0.82        20
#
#     accuracy                           0.80        40
#    macro avg       0.81      0.80      0.80        40
# weighted avg       0.81      0.80      0.80        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #2
# Mean negativities for all classes: [0.13179320052641094]
# Mean entropies for all classes: [6.825088144675527e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.65      0.76        20
#          1.0       0.73      0.95      0.83        20
#
#     accuracy                           0.80        40
#    macro avg       0.83      0.80      0.80        40
# weighted avg       0.83      0.80      0.80        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #3
# Mean negativities for all classes: [0.07623428197475604]
# Mean entropies for all classes: [4.069646620917293e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.89      0.85      0.87        20
#          1.0       0.86      0.90      0.88        20
#
#     accuracy                           0.88        40
#    macro avg       0.88      0.88      0.87        40
# weighted avg       0.88      0.88      0.87        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #4
# Mean negativities for all classes: [0.09016222591883986]
# Mean entropies for all classes: [2.1266967206073758e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.88      0.75      0.81        20
#          1.0       0.78      0.90      0.84        20
#
#     accuracy                           0.82        40
#    macro avg       0.83      0.82      0.82        40
# weighted avg       0.83      0.82      0.82        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #5
# Mean negativities for all classes: [0.19431469734915807]
# Mean entropies for all classes: [5.606714810824367e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.88      0.75      0.81        20
#          1.0       0.78      0.90      0.84        20
#
#     accuracy                           0.82        40
#    macro avg       0.83      0.82      0.82        40
# weighted avg       0.83      0.82      0.82        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #6
# Mean negativities for all classes: [0.17300452958400447]
# Mean entropies for all classes: [4.481286751673642e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.90      0.45      0.60        20
#          1.0       0.63      0.95      0.76        20
#
#     accuracy                           0.70        40
#    macro avg       0.77      0.70      0.68        40
# weighted avg       0.77      0.70      0.68        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #7
# Mean negativities for all classes: [0.15393337548932612]
# Mean entropies for all classes: [5.787155163249995e-16]
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.60      0.75        20
#          1.0       0.71      1.00      0.83        20
#
#     accuracy                           0.80        40
#    macro avg       0.86      0.80      0.79        40
# weighted avg       0.86      0.80      0.79        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #8
# Mean negativities for all classes: [0.1911690667261837]
# Mean entropies for all classes: [9.298486379842108e-15]
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.60      0.75        20
#          1.0       0.71      1.00      0.83        20
#
#     accuracy                           0.80        40
#    macro avg       0.86      0.80      0.79        40
# weighted avg       0.86      0.80      0.79        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #9
# Mean negativities for all classes: [0.1918576364672116]
# Mean entropies for all classes: [2.0586440466965443e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.80      0.86        20
#          1.0       0.83      0.95      0.88        20
#
#     accuracy                           0.88        40
#    macro avg       0.88      0.88      0.87        40
# weighted avg       0.88      0.88      0.87        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.8100000000000002 F1-Scores = 0.804561105424358 Negativity = [0.14757297460959543, 0.19132167492711016] Entropy = [4.0452009635515845e-15, -5.464251275388192e-15]
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #0
# Mean negativities for all classes: [0.1509504116756571]
# Mean entropies for all classes: [1.5588794730633318e-15]
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.60      0.75        20
#          1.0       0.71      1.00      0.83        20
#
#     accuracy                           0.80        40
#    macro avg       0.86      0.80      0.79        40
# weighted avg       0.86      0.80      0.79        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #1
# Mean negativities for all classes: [0.17572699907436065]
# Mean entropies for all classes: [2.311551526334563e-16]
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.70      0.80        20
#          1.0       0.76      0.95      0.84        20
#
#     accuracy                           0.82        40
#    macro avg       0.85      0.82      0.82        40
# weighted avg       0.85      0.82      0.82        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #2
# Mean negativities for all classes: [0.18737966425584993]
# Mean entropies for all classes: [1.1864787623018043e-14]
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.65      0.79        20
#          1.0       0.74      1.00      0.85        20
#
#     accuracy                           0.82        40
#    macro avg       0.87      0.82      0.82        40
# weighted avg       0.87      0.82      0.82        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #3
# Mean negativities for all classes: [0.1333969575621559]
# Mean entropies for all classes: [-5.829805236405253e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.65      0.76        20
#          1.0       0.73      0.95      0.83        20
#
#     accuracy                           0.80        40
#    macro avg       0.83      0.80      0.80        40
# weighted avg       0.83      0.80      0.80        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #4
# Mean negativities for all classes: [0.13662086356108666]
# Mean entropies for all classes: [-1.1688367670825906e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.65      0.76        20
#          1.0       0.73      0.95      0.83        20
#
#     accuracy                           0.80        40
#    macro avg       0.83      0.80      0.80        40
# weighted avg       0.83      0.80      0.80        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #5
# Mean negativities for all classes: [0.17965453905560227]
# Mean entropies for all classes: [2.494722398344175e-15]
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.70      0.82        20
#          1.0       0.77      1.00      0.87        20
#
#     accuracy                           0.85        40
#    macro avg       0.88      0.85      0.85        40
# weighted avg       0.88      0.85      0.85        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #6
# Mean negativities for all classes: [0.1839376713903121]
# Mean entropies for all classes: [4.108446373462648e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.76      0.65      0.70        20
#          1.0       0.70      0.80      0.74        20
#
#     accuracy                           0.73        40
#    macro avg       0.73      0.73      0.72        40
# weighted avg       0.73      0.72      0.72        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #7
# Mean negativities for all classes: [0.1769016316338487]
# Mean entropies for all classes: [5.35514067087313e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.88      0.70      0.78        20
#          1.0       0.75      0.90      0.82        20
#
#     accuracy                           0.80        40
#    macro avg       0.81      0.80      0.80        40
# weighted avg       0.81      0.80      0.80        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #8
# Mean negativities for all classes: [0.1770995209744506]
# Mean entropies for all classes: [3.579555869022875e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.88      0.70      0.78        20
#          1.0       0.75      0.90      0.82        20
#
#     accuracy                           0.80        40
#    macro avg       0.81      0.80      0.80        40
# weighted avg       0.81      0.80      0.80        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #9
# Mean negativities for all classes: [0.19722496583969126]
# Mean entropies for all classes: [2.3931356472191545e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.70      0.80        20
#          1.0       0.76      0.95      0.84        20
#
#     accuracy                           0.82        40
#    macro avg       0.85      0.82      0.82        40
# weighted avg       0.85      0.82      0.82        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.8049999999999999 F1-Scores = 0.8012326543963569 Negativity = [0.1509504116756571, 0.17572699907436065] Entropy = [1.5588794730633318e-15, 2.311551526334563e-16]
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #0
# Mean negativities for all classes: [0.18456974057695438]
# Mean entropies for all classes: [2.176921418951383e-15]
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.80      0.89        20
#          1.0       0.83      1.00      0.91        20
#
#     accuracy                           0.90        40
#    macro avg       0.92      0.90      0.90        40
# weighted avg       0.92      0.90      0.90        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #1
# Mean negativities for all classes: [0.10429962743088513]
# Mean entropies for all classes: [1.7223685051900992e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.75      0.45      0.56        20
#          1.0       0.61      0.85      0.71        20
#
#     accuracy                           0.65        40
#    macro avg       0.68      0.65      0.64        40
# weighted avg       0.68      0.65      0.64        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #2
# Mean negativities for all classes: [0.21575648256827407]
# Mean entropies for all classes: [-6.529490940660656e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.65      0.76        20
#          1.0       0.73      0.95      0.83        20
#
#     accuracy                           0.80        40
#    macro avg       0.83      0.80      0.80        40
# weighted avg       0.83      0.80      0.80        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #3
# Mean negativities for all classes: [0.1314876596894535]
# Mean entropies for all classes: [4.1186597279144764e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.83      0.50      0.62        20
#          1.0       0.64      0.90      0.75        20
#
#     accuracy                           0.70        40
#    macro avg       0.74      0.70      0.69        40
# weighted avg       0.74      0.70      0.69        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #4
# Mean negativities for all classes: [0.18516085078032968]
# Mean entropies for all classes: [1.2487067506902006e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.86      0.60      0.71        20
#          1.0       0.69      0.90      0.78        20
#
#     accuracy                           0.75        40
#    macro avg       0.77      0.75      0.74        40
# weighted avg       0.77      0.75      0.74        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #5
# Mean negativities for all classes: [0.1792408911122096]
# Mean entropies for all classes: [1.4764735298654208e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.89      0.80      0.84        20
#          1.0       0.82      0.90      0.86        20
#
# ...
# K-Fold #1
# Mean negativities for all classes: [0.14948878510115587]
# Mean entropies for all classes: [3.1341686577764043e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.92      0.60      0.73        20
#          1.0       0.70      0.95      0.81        20
#
#     accuracy                           0.78        40
#    macro avg       0.81      0.77      0.77        40
# weighted avg       0.81      0.78      0.77        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #2
# Mean negativities for all classes: [0.1720783854879126]
# Mean entropies for all classes: [2.2973539303189222e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.89      0.85      0.87        20
#          1.0       0.86      0.90      0.88        20
#
#     accuracy                           0.88        40
#    macro avg       0.88      0.88      0.87        40
# weighted avg       0.88      0.88      0.87        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #3
# Mean negativities for all classes: [0.16551256210801218]
# Mean entropies for all classes: [3.1523773389568165e-15]
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.50      0.67        20
#          1.0       0.67      1.00      0.80        20
#
#     accuracy                           0.75        40
#    macro avg       0.83      0.75      0.73        40
# weighted avg       0.83      0.75      0.73        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #4
# Mean negativities for all classes: [0.1972238828020232]
# Mean entropies for all classes: [-9.575522705397078e-16]
#               precision    recall  f1-score   support
#
#          0.0       0.80      0.60      0.69        20
#          1.0       0.68      0.85      0.76        20
#
#     accuracy                           0.73        40
#    macro avg       0.74      0.72      0.72        40
# weighted avg       0.74      0.72      0.72        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #5
# Mean negativities for all classes: [0.1548294018856144]
# Mean entropies for all classes: [-1.4174478960735058e-15]
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.60      0.75        20
#          1.0       0.71      1.00      0.83        20
#
#     accuracy                           0.80        40
#    macro avg       0.86      0.80      0.79        40
# weighted avg       0.86      0.80      0.79        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #6
# Mean negativities for all classes: [0.16637270460766745]
# Mean entropies for all classes: [2.2546750285734124e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.81      0.65      0.72        20
#          1.0       0.71      0.85      0.77        20
#
#     accuracy                           0.75        40
#    macro avg       0.76      0.75      0.75        40
# weighted avg       0.76      0.75      0.75        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #7
# Mean negativities for all classes: [0.16809983799930944]
# Mean entropies for all classes: [3.03082989344521e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.73      0.55      0.63        20
#          1.0       0.64      0.80      0.71        20
#
#     accuracy                           0.68        40
#    macro avg       0.69      0.68      0.67        40
# weighted avg       0.69      0.68      0.67        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #8
# Mean negativities for all classes: [0.05429613838809625]
# Mean entropies for all classes: [1.2993246170197858e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.80      0.86        20
#          1.0       0.83      0.95      0.88        20
#
#     accuracy                           0.88        40
#    macro avg       0.88      0.88      0.87        40
# weighted avg       0.88      0.88      0.87        40
#
# -------------------------------------------------------------------------------------------------------------------
# K-Fold #9
# Mean negativities for all classes: [0.14897946738537846]
# Mean entropies for all classes: [8.632530775070549e-15]
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.75      0.86        20
#          1.0       0.80      1.00      0.89        20
#
#     accuracy                           0.88        40
#    macro avg       0.90      0.88      0.87        40
# weighted avg       0.90      0.88      0.87        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.8 F1-Scores = 0.795206311643206 Negativity = [0.1817157724443657, 0.14948878510115587] Entropy = [6.435927209356125e-15, 3.1341686577764043e-15]
# CPU times: total: 15 s
# Wall time: 7h 43min 46s
# Media Score dos N K-Fold 0.805125
# Maior Score dos K-Fold 0.8100000000000002
# Menor Score dos K-Fold 0.8
#
#
# [[0.85, 0.725, 0.8, 0.85, 0.8, 0.8, 0.775, 0.825, 0.875, 0.75], [0.85, 0.8, 0.775, 0.85, 0.825, 0.85, 0.8, 0.725, 0.8, 0.8], [0.775, 0.85, 0.825, 0.825, 0.775, 0.9, 0.8, 0.75, 0.75, 0.825], [0.8, 0.775, 0.9, 0.85, 0.675, 0.825, 0.725, 0.825, 0.775, 0.85], [0.8, 0.8, 0.8, 0.875, 0.825, 0.825, 0.7, 0.8, 0.8, 0.875], [0.8, 0.825, 0.825, 0.8, 0.8, 0.85, 0.725, 0.8, 0.8, 0.825], [0.9, 0.65, 0.8, 0.7, 0.75, 0.85, 0.825, 0.9, 0.875, 0.775], [0.675, 0.75, 0.825, 0.85, 0.85, 0.85, 0.775, 0.85, 0.825, 0.825], [0.85, 0.875, 0.8, 0.8, 0.75, 0.825, 0.775, 0.85, 0.75, 0.8], [0.85, 0.8, 0.825, 0.875, 0.775, 0.8, 0.75, 0.8, 0.825, 0.8], [0.8, 0.85, 0.925, 0.725, 0.775, 0.875, 0.875, 0.725, 0.65, 0.875], [0.825, 0.
-15]
#               precision    recall  f1-score   support
#
#          0.0       0.44      0.60      0.51        20
#          1.0       0.38      0.25      0.30        20
#
#     accuracy                           0.42        40
#    macro avg       0.41      0.42      0.41        40
# weighted avg       0.41      0.42      0.41        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #2
# Mean negativities for all classes: [0.18891965169571762]
# Mean entropies for all classes: [3.1077025917082683e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00        20
#          1.0       0.50      1.00      0.67        20
#
#     accuracy                           0.50        40
#    macro avg       0.25      0.50      0.33        40
# weighted avg       0.25      0.50      0.33        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #3
# Mean negativities for all classes: [0.007120967520283688]
# Mean entropies for all classes: [3.602983413781364e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.55      0.60      0.57        20
#          1.0       0.56      0.50      0.53        20
#
#     accuracy                           0.55        40
#    macro avg       0.55      0.55      0.55        40
# weighted avg       0.55      0.55      0.55        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #4
# Mean negativities for all classes: [0.008615698673198674]
# Mean entropies for all classes: [3.298888705805254e-15]
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.05      0.10        20
#          1.0       0.51      1.00      0.68        20
#
#     accuracy                           0.53        40
#    macro avg       0.76      0.53      0.39        40
# weighted avg       0.76      0.53      0.39        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #5
# Mean negativities for all classes: [0.010042706776479535]
# Mean entropies for all classes: [3.228002717070405e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.75      0.60        20
#          1.0       0.50      0.25      0.33        20
#
#     accuracy                           0.50        40
#    macro avg       0.50      0.50      0.47        40
# weighted avg       0.50      0.50      0.47        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #6
# Mean negativities for all classes: [0.10965371551065868]
# Mean entropies for all classes: [3.3271703983816995e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.49      0.85      0.62        20
#          1.0       0.40      0.10      0.16        20
#
#     accuracy                           0.48        40
#    macro avg       0.44      0.47      0.39        40
# weighted avg       0.44      0.47      0.39        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #7
# Mean negativities for all classes: [0.23633071887028684]
# Mean entropies for all classes: [3.0652087497471486e-15]
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.05      0.10        20
#          1.0       0.51      1.00      0.68        20
#
#     accuracy                           0.53        40
#    macro avg       0.76      0.53      0.39        40
# weighted avg       0.76      0.53      0.39        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #8
# Mean negativities for all classes: [0.1901183460223322]
# Mean entropies for all classes: [2.5133020073856764e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.90      0.64        20
#          1.0       0.50      0.10      0.17        20
#
#     accuracy                           0.50        40
#    macro avg       0.50      0.50      0.40        40
# weighted avg       0.50      0.50      0.40        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #9
# Mean negativities for all classes: [0.3094508861404605]
# Mean entropies for all classes: [3.212451559710746e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.33      0.05      0.09        20
#          1.0       0.49      0.90      0.63        20
#
#     accuracy                           0.48        40
#    macro avg       0.41      0.48      0.36        40
# weighted avg       0.41      0.47      0.36        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.49749999999999994 F1-Scores = 0.40153645595753823 Negativity = [0.008734306767567715, 0.31819952581649347] Entropy = [2.322038837421644e-15, 3.340241280754375e-15]
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #0
# Mean negativities for all classes: [0.013538400331842402]
# Mean entropies for all classes: [3.5063387119661864e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.48      0.65      0.55        20
#          1.0       0.46      0.30      0.36        20
#
#     accuracy                           0.48        40
#    macro avg       0.47      0.47      0.46        40
# weighted avg       0.47      0.47      0.46        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #1
# Mean negativities for all classes: [0.05469449974364991]
# Mean entropies for all classes: [3.1904022630494518e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.45      0.75      0.57        20
#          1.0       0.29      0.10      0.15        20
#
#     accuracy                           0.42        40
#    macro avg       0.37      0.42      0.36        40
# weighted avg       0.37      0.42      0.36        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #2
# Mean negativities for all classes: [0.2848128203832542]
# Mean entropies for all classes: [4.83958389241607e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.60      0.55        20
#          1.0       0.50      0.40      0.44        20
#
#     accuracy                           0.50        40
#    macro avg       0.50      0.50      0.49        40
# weighted avg       0.50      0.50      0.49        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #3
# Mean negativities for all classes: [0.22335789116120447]
# Mean entropies for all classes: [2.720314749494424e-15]
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.05      0.10        20
#          1.0       0.51      1.00      0.68        20
#
#     accuracy                           0.53        40
#    macro avg       0.76      0.53      0.39        40
# weighted avg       0.76      0.53      0.39        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #4
# Mean negativities for all classes: [0.07446468651844569]
# Mean entropies for all classes: [3.0679389080631364e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.47      0.90      0.62        20
#          1.0       0.00      0.00      0.00        20
#
#     accuracy                           0.45        40
#    macro avg       0.24      0.45      0.31        40
# weighted avg       0.24      0.45      0.31        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #5
# Mean negativities for all classes: [0.040966554298229596]
# Mean entropies for all classes: [2.9143778864555736e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.42      0.50      0.45        20
#          1.0       0.38      0.30      0.33        20
#
#     accuracy                           0.40        40
#    macro avg       0.40      0.40      0.39        40
# weighted avg       0.40      0.40      0.39        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #6
# Mean negativities for all classes: [0.008541267072760164]
# Mean entropies for all classes: [2.9739242984346397e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.70      0.58        20
#          1.0       0.50      0.30      0.37        20
#
#     accuracy                           0.50        40
#    macro avg       0.50      0.50      0.48        40
# weighted avg       0.50      0.50      0.48        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #7
# Mean negativities for all classes: [0.0032790860031691378]
# Mean entropies for all classes: [2.3108247897442808e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.20      0.05      0.08        20
#          1.0       0.46      0.80      0.58        20
#
#     accuracy                           0.42        40
#    macro avg       0.33      0.43      0.33        40
# weighted avg       0.33      0.42      0.33        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #8
# Mean negativities for all classes: [0.009419869014323425]
# Mean entropies for all classes: [2.891509055997059e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.56      0.75      0.64        20
#          1.0       0.62      0.40      0.48        20
#
#     accuracy                           0.57        40
#    macro avg       0.59      0.57      0.56        40
# weighted avg       0.59      0.57      0.56        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #9
# Mean negativities for all classes: [0.11750957257926291]
# Mean entropies for all classes: [2.8973097541859012e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.49      0.95      0.64        20
#          1.0       0.00      0.00      0.00        20
#
#     accuracy                           0.48        40
#    macro avg       0.24      0.47      0.32        40
# weighted avg       0.24      0.47      0.32        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.475 F1-Scores = 0.40950255179145334 Negativity = [0.013538400331842402, 0.05469449974364991] Entropy = [3.5063387119661864e-15, 3.1904022630494518e-15]
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #0
# Mean negativities for all classes: [0.006177296399499996]
# Mean entropies for all classes: [2.3955347123307984e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.65      0.57        20
#          1.0       0.50      0.35      0.41        20
#
#     accuracy                           0.50        40
#    macro avg       0.50      0.50      0.49        40
# weighted avg       0.50      0.50      0.49        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #1
# Mean negativities for all classes: [0.012523645713555742]
# Mean entropies for all classes: [2.484968888677709e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00        20
#          1.0       0.49      0.95      0.64        20
#
#     accuracy                           0.48        40
#    macro avg       0.24      0.47      0.32        40
# weighted avg       0.24      0.47      0.32        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #2
# Mean negativities for all classes: [0.052970580694411275]
# Mean entropies for all classes: [3.1905976670183186e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.05      0.09        20
#          1.0       0.50      0.95      0.66        20
#
#     accuracy                           0.50        40
#    macro avg       0.50      0.50      0.37        40
# weighted avg       0.50      0.50      0.37        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #3
# Mean negativities for all classes: [0.00857323431623587]
# Mean entropies for all classes: [3.3506167812579063e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.70      0.58        20
#          1.0       0.50      0.30      0.37        20
#
#     accuracy                           0.50        40
#    macro avg       0.50      0.50      0.48        40
# weighted avg       0.50      0.50      0.48        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #4
# Mean negativities for all classes: [0.005166710287149443]
# Mean entropies for all classes: [3.3969326759167827e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.47      0.85      0.61        20
#          1.0       0.25      0.05      0.08        20
#
#     accuracy                           0.45        40
#    macro avg       0.36      0.45      0.35        40
# weighted avg       0.36      0.45      0.35        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #5
# Mean negativities for all classes: [0.007463287302923252]
# Mean entropies for all classes: [2.6843309271069613e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.50      1.00      0.67        20
#          1.0       0.00      0.00      0.00        20
#
#     accuracy                           0.50        40
#    macro avg       0.25      0.50      0.33        40
# weighted avg       0.25      0.50      0.33        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #6
# Mean negativities for all classes: [0.13069209412550453]
# Mean entropies for all classes: [3.220216155083625e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.33      0.35      0.34        20
#          1.0       0.32      0.30      0.31        20
#
#     accuracy                           0.33        40
#    macro avg       0.32      0.32      0.32        40
# weighted avg       0.32      0.33      0.32        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #7
# Mean negativities for all classes: [0.3397402171008923]
# Mean entropies for all classes: [3.980301830479836e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.70      0.58        20
#          1.0       0.50      0.30      0.37        20
#
#     accuracy                           0.50        40
#    macro avg       0.50      0.50      0.48        40
# weighted avg       0.50      0.50      0.48        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #8
# Mean negativities for all classes: [0.06551928449432305]
# Mean entropies for all classes: [2.649726778484754e-15]
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.05      0.10        20
#          1.0       0.51      1.00      0.68        20
#
#     accuracy                           0.53        40
#    macro avg       0.76      0.53      0.39        40
# weighted avg       0.76      0.53      0.39        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #9
# Mean negativities for all classes: [0.31336610955495636]
# Mean entropies for all classes: [3.629414401660255e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.70      0.58        20
#          1.0       0.50      0.30      0.37        20
#
#     accuracy                           0.50        40
#    macro avg       0.50      0.50      0.48        40
# weighted avg       0.50      0.50      0.48        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.47750000000000004 F1-Scores = 0.4010817087450693 Negativity = [0.006177296399499996, 0.012523645713555742] Entropy = [2.3955347123307984e-15, 2.484968888677709e-15]
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #0
# Mean negativities for all classes: [0.32697598201901956]
# Mean entropies for all classes: [3.796893461993066e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.46      0.60      0.52        20
#          1.0       0.43      0.30      0.35        20
#
#     accuracy                           0.45        40
#    macro avg       0.45      0.45      0.44        40
# weighted avg       0.45      0.45      0.44        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #1
# Mean negativities for all classes: [0.31371255976916296]
# Mean entropies for all classes: [3.4208960760403726e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00        20
#          1.0       0.50      1.00      0.67        20
#
#     accuracy                           0.50        40
#    macro avg       0.25      0.50      0.33        40
# weighted avg       0.25      0.50      0.33        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #2
# Mean negativities for all classes: [0.006931092171289485]
# Mean entropies for all classes: [3.553293676579305e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.48      0.75      0.59        20
#          1.0       0.44      0.20      0.28        20
#
#     accuracy                           0.48        40
#    macro avg       0.46      0.47      0.43        40
# weighted avg       0.46      0.47      0.43        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #3
# Mean negativities for all classes: [0.004244368641446597]
# Mean entropies for all classes: [1.5584421482653915e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.40      0.10      0.16        20
#          1.0       0.49      0.85      0.62        20
#
#     accuracy                           0.48        40
#    macro avg       0.44      0.47      0.39        40
# weighted avg       0.44      0.47      0.39        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #4
# Mean negativities for all classes: [0.18678175290835233]
# Mean entropies for all classes: [2.9493689944523718e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.90      0.64        20
#          1.0       0.50      0.10      0.17        20
#
#     accuracy                           0.50        40
#    macro avg       0.50      0.50      0.40        40
# weighted avg       0.50      0.50      0.40        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #5
# Mean negativities for all classes: [0.0021361833160002093]
# Mean entropies for all classes: [3.1140943534659315e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00        20
#          1.0       0.50      1.00      0.67        20
#
#     accuracy                           0.50        40
#    macro avg       0.25      0.50      0.33        40
# weighted avg       0.25      0.50      0.33        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #6
# Mean negativities for all classes: [0.006963130536887971]
# Mean entropies for all classes: [2.9089081518073822e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.20      0.29        20
#          1.0       0.50      0.80      0.62        20
#
#     accuracy                           0.50        40
#    macro avg       0.50      0.50      0.45        40
# weighted avg       0.50      0.50      0.45        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #7
# Mean negativities for all classes: [0.004940842700923734]
# Mean entropies for all classes: [3.427441082308251e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00        20
#          1.0       0.50      1.00      0.67        20
#
#     accuracy                           0.50        40
#    macro avg       0.25      0.50      0.33        40
# weighted avg       0.25      0.50      0.33        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #8
# Mean negativities for all classes: [0.3340900667331692]
# Mean entropies for all classes: [3.829218444543267e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.45      0.50      0.48        20
#          1.0       0.44      0.40      0.42        20
#
#     accuracy                           0.45        40
#    macro avg       0.45      0.45      0.45        40
# weighted avg       0.45      0.45      0.45        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #9
# Mean negativities for all classes: [0.009077415255405391]
# Mean entropies for all classes: [2.8932494833321827e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.42      0.65      0.51        20
#          1.0       0.22      0.10      0.14        20
#
#     accuracy                           0.38        40
#    macro avg       0.32      0.38      0.32        40
# weighted avg       0.32      0.38      0.32        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.4725 F1-Scores = 0.3886280131306937 Negativity = [0.32697598201901956, 0.31371255976916296] Entropy = [3.796893461993066e-15, 3.4208960760403726e-15]
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #0
# Mean negativities for all classes: [0.007948877430902338]
# Mean entropies for all classes: [3.3672303773222077e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.05      0.09        20
#          1.0       0.50      0.95      0.66        20
#
#     accuracy                           0.50        40
#    macro avg       0.50      0.50      0.37        40
# weighted avg       0.50      0.50      0.37        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #1
# Mean negativities for all classes: [0.0021043172095169425]
# Mean entropies for all classes: [5.552749471812554e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.33      0.20      0.25        20
#          1.0       0.43      0.60      0.50        20
#
#     accuracy                           0.40        40
#    macro avg       0.38      0.40      0.38        40
# weighted avg       0.38      0.40      0.38        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #2
# Mean negativities for all classes: [0.31570897153093325]
# Mean entropies for all classes: [2.7701964010975317e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.80      0.20      0.32        20
#          1.0       0.54      0.95      0.69        20
#
#     accuracy                           0.57        40
#    macro avg       0.67      0.57      0.51        40
# weighted avg       0.67      0.57      0.51        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #3
# Mean negativities for all classes: [0.22998436002725658]
# Mean entropies for all classes: [1.6520017330220594e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.41      0.60      0.49        20
#          1.0       0.27      0.15      0.19        20
#
#     accuracy                           0.38        40
#    macro avg       0.34      0.38      0.34        40
# weighted avg       0.34      0.38      0.34        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #4
# Mean negativities for all classes: [0.006479040099602993]
# Mean entropies for all classes: [2.5995167122460628e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.25      0.25      0.25        20
#          1.0       0.25      0.25      0.25        20
#
#     accuracy                           0.25        40
#    macro avg       0.25      0.25      0.25        40
# weighted avg       0.25      0.25      0.25        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #5
# Mean negativities for all classes: [0.010608182703772232]
# Mean entropies for all classes: [3.1735678585525747e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.47      0.85      0.61        20
#          1.0       0.25      0.05      0.08        20
#
#     accuracy                           0.45        40
#    macro avg       0.36      0.45      0.35        40
# weighted avg       0.36      0.45      0.35        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #6
# Mean negativities for all classes: [0.18711948877815004]
# Mean entropies for all classes: [2.800374422524687e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.44      0.75      0.56        20
#          1.0       0.17      0.05      0.08        20
#
#     accuracy                           0.40        40
#    macro avg       0.30      0.40      0.32        40
# weighted avg       0.30      0.40      0.32        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #7
# Mean negativities for all classes: [0.005756544720855491]
# Mean entropies for all classes: [2.197793700147824e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00        20
#          1.0       0.47      0.90      0.62        20
#
#     accuracy                           0.45        40
#    macro avg       0.24      0.45      0.31        40
# weighted avg       0.24      0.45      0.31        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #8
# Mean negativities for all classes: [0.04776920014527271]
# Mean entropies for all classes: [3.658048723536502e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00        20
#          1.0       0.49      0.95      0.64        20
#
#     accuracy                           0.48        40
#    macro avg       0.24      0.47      0.32        40
# weighted avg       0.24      0.47      0.32        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #9
# Mean negativities for all classes: [0.18789728661644933]
# Mean entropies for all classes: [2.649966036460805e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.47      0.90      0.62        20
#          1.0       0.00      0.00      0.00        20
#
#     accuracy                           0.45        40
#    macro avg       0.24      0.45      0.31        40
# weighted avg       0.24      0.45      0.31        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.4325 F1-Scores = 0.3449368415492613 Negativity = [0.007948877430902338, 0.0021043172095169425] Entropy = [3.3672303773222077e-15, 5.552749471812554e-15]
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #0
# Mean negativities for all classes: [0.0074410289627098725]
# Mean entropies for all classes: [3.0104900327417994e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.47      0.75      0.58        20
#          1.0       0.38      0.15      0.21        20
#
#     accuracy                           0.45        40
#    macro avg       0.42      0.45      0.40        40
# weighted avg       0.42      0.45      0.40        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #1
# Mean negativities for all classes: [0.18915956951860652]
# Mean entropies for all classes: [3.206590517960844e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.90      0.64        20
#          1.0       0.50      0.10      0.17        20
#
#     accuracy                           0.50        40
#    macro avg       0.50      0.50      0.40        40
# weighted avg       0.50      0.50      0.40        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #2
# Mean negativities for all classes: [0.1163238878458233]
# Mean entropies for all classes: [3.875899805869993e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00        20
#          1.0       0.46      0.85      0.60        20
#
#     accuracy                           0.42        40
#    macro avg       0.23      0.42      0.30        40
# weighted avg       0.23      0.42      0.30        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #3
# Mean negativities for all classes: [0.004844460747129678]
# Mean entropies for all classes: [3.919611671204986e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00        20
#          1.0       0.50      1.00      0.67        20
#
#     accuracy                           0.50        40
#    macro avg       0.25      0.50      0.33        40
# weighted avg       0.25      0.50      0.33        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #4
# Mean negativities for all classes: [0.003571301337253452]
# Mean entropies for all classes: [2.755285469256621e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.33      0.20      0.25        20
#          1.0       0.43      0.60      0.50        20
#
#     accuracy                           0.40        40
#    macro avg       0.38      0.40      0.38        40
# weighted avg       0.38      0.40      0.38        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #5
# ...
# Mean entropies for all classes: [2.976892719212949e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.52      0.75      0.61        20
#          1.0       0.55      0.30      0.39        20
#
#     accuracy                           0.53        40
#    macro avg       0.53      0.53      0.50        40
# weighted avg       0.53      0.53      0.50        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #2
# Mean negativities for all classes: [0.19822416041933683]
# Mean entropies for all classes: [3.2984602685129553e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.46      0.80      0.58        20
#          1.0       0.20      0.05      0.08        20
#
#     accuracy                           0.42        40
#    macro avg       0.33      0.43      0.33        40
# weighted avg       0.33      0.42      0.33        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.4min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #3
# Mean negativities for all classes: [0.28893753149100265]
# Mean entropies for all classes: [2.447214156701732e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.48      0.80      0.60        20
#          1.0       0.43      0.15      0.22        20
#
#     accuracy                           0.48        40
#    macro avg       0.46      0.48      0.41        40
# weighted avg       0.46      0.47      0.41        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #4
# Mean negativities for all classes: [0.004028218497566715]
# Mean entropies for all classes: [3.566539627907531e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.25      0.05      0.08        20
#          1.0       0.47      0.85      0.61        20
#
#     accuracy                           0.45        40
#    macro avg       0.36      0.45      0.35        40
# weighted avg       0.36      0.45      0.35        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.4min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #5
# Mean negativities for all classes: [0.005055281790901689]
# Mean entropies for all classes: [2.9934802238679813e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.53      0.80      0.64        20
#          1.0       0.60      0.30      0.40        20
#
#     accuracy                           0.55        40
#    macro avg       0.57      0.55      0.52        40
# weighted avg       0.57      0.55      0.52        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.4min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #6
# Mean negativities for all classes: [0.05773395541623161]
# Mean entropies for all classes: [2.798903579315948e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.47      0.90      0.62        20
#          1.0       0.00      0.00      0.00        20
#
#     accuracy                           0.45        40
#    macro avg       0.24      0.45      0.31        40
# weighted avg       0.24      0.45      0.31        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.5min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #7
# Mean negativities for all classes: [0.1982963839785421]
# Mean entropies for all classes: [2.6517470937247948e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.52      0.65      0.58        20
#          1.0       0.53      0.40      0.46        20
#
#     accuracy                           0.53        40
#    macro avg       0.53      0.53      0.52        40
# weighted avg       0.53      0.53      0.52        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #8
# Mean negativities for all classes: [0.005493420291791687]
# Mean entropies for all classes: [2.729251269817452e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.49      0.90      0.63        20
#          1.0       0.33      0.05      0.09        20
#
#     accuracy                           0.48        40
#    macro avg       0.41      0.48      0.36        40
# weighted avg       0.41      0.47      0.36        40
#
# -------------------------------------------------------------------------------------------------------------------
# K-Fold #9
# Mean negativities for all classes: [0.007196510457200167]
# Mean entropies for all classes: [3.180595502403196e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.48      0.60      0.53        20
#          1.0       0.47      0.35      0.40        20
#
#     accuracy                           0.48        40
#    macro avg       0.47      0.47      0.47        40
# weighted avg       0.47      0.47      0.47        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.4774999999999999 F1-Scores = 0.41693897725057816 Negativity = [0.005747161583540725, 0.009084171617037517] Entropy = [3.173390406656148e-15, 2.976892719212949e-15]
# CPU times: total: 14.2 s
# Wall time: 6h 58min 40s
# Media Score dos N K-Fold 0.48262499999999997
# Maior Score dos K-Fold 0.515
# Menor Score dos K-Fold 0.4325
#
#
# [[0.5, 0.425, 0.5, 0.55, 0.525, 0.5, 0.475, 0.525, 0.5, 0.475], [0.475, 0.425, 0.5, 0.525, 0.45, 0.4, 0.5, 0.425, 0.575, 0.475], [0.5, 0.475, 0.5, 0.5, 0.45, 0.5, 0.325, 0.5, 0.525, 0.5], [0.45, 0.5, 0.475, 0.475, 0.5, 0.5, 0.5, 0.5, 0.45, 0.375], [0.5, 0.4, 0.575, 0.375, 0.25, 0.45, 0.4, 0.45, 0.475, 0.45], [0.45, 0.5, 0.425, 0.5, 0.4, 0.5, 0.425, 0.425, 0.525, 0.5], [0.475, 0.475, 0.525, 0.5, 0.45, 0.5, 0.45, 0.5, 0.5, 0.525], [0.55, 0.525, 0.55, 0.525, 0.45, 0.425, 0.45, 0.425, 0.5, 0.375], [