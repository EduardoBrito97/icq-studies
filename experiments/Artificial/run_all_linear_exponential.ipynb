# %%
use_exponential_on_input = True

# %%
normalize_axis = 0
load_inputvector_env_state = False

# %%
# %%time
# %run Experimento-Artificial-Linear-Sep-20-10-Fold.ipynb
# Out:
# Intel(R) Extension for Scikit-learn* enabled (https://github.com/intel/scikit-learn-intelex)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# K-Fold #0
# Mean negativities for all classes: [0.24545720518392403]
# Mean entropies for all classes: [3.317984813010364e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.98        20
#          1.0       1.00      0.95      0.97        20
#
#     accuracy                           0.97        40
#    macro avg       0.98      0.97      0.97        40
# weighted avg       0.98      0.97      0.97        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# K-Fold #1
# Mean negativities for all classes: [0.2526319056754091]
# Mean entropies for all classes: [2.763895267667929e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.87      1.00      0.93        20
#          1.0       1.00      0.85      0.92        20
#
#     accuracy                           0.93        40
#    macro avg       0.93      0.93      0.92        40
# weighted avg       0.93      0.93      0.92        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# K-Fold #2
# Mean negativities for all classes: [0.2473832360047905]
# Mean entropies for all classes: [2.7969126814226663e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.87      1.00      0.93        20
#          1.0       1.00      0.85      0.92        20
#
#     accuracy                           0.93        40
#    macro avg       0.93      0.93      0.92        40
# weighted avg       0.93      0.93      0.92        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# K-Fold #3
# Mean negativities for all classes: [0.250320334856962]
# Mean entropies for all classes: [3.0616514909035618e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.83      1.00      0.91        20
#          1.0       1.00      0.80      0.89        20
#
#     accuracy                           0.90        40
#    macro avg       0.92      0.90      0.90        40
# weighted avg       0.92      0.90      0.90        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# K-Fold #4
# Mean negativities for all classes: [0.25141862486469085]
# Mean entropies for all classes: [3.4029921140097635e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.77      1.00      0.87        20
#          1.0       1.00      0.70      0.82        20
#
#     accuracy                           0.85        40
#    macro avg       0.88      0.85      0.85        40
# weighted avg       0.88      0.85      0.85        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# K-Fold #5
# Mean negativities for all classes: [0.24106496410440884]
# Mean entropies for all classes: [4.236215519244215e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.83      1.00      0.91        20
#          1.0       1.00      0.80      0.89        20
#
#     accuracy                           0.90        40
#    macro avg       0.92      0.90      0.90        40
# weighted avg       0.92      0.90      0.90        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# K-Fold #6
# Mean negativities for all classes: [0.2427016954430475]
# Mean entropies for all classes: [3.854536876295698e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.91      1.00      0.95        20
#          1.0       1.00      0.90      0.95        20
#
#     accuracy                           0.95        40
#    macro avg       0.95      0.95      0.95        40
# weighted avg       0.95      0.95      0.95        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# K-Fold #7
# Mean negativities for all classes: [0.24016983129312539]
# Mean entropies for all classes: [3.1290668858312822e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.91      1.00      0.95        20
#          1.0       1.00      0.90      0.95        20
#
#     accuracy                           0.95        40
#    macro avg       0.95      0.95      0.95        40
# weighted avg       0.95      0.95      0.95        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# K-Fold #8
# Mean negativities for all classes: [0.2365375789711206]
# Mean entropies for all classes: [3.4517017862722383e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.87      1.00      0.93        20
#          1.0       1.00      0.85      0.92        20
#
#     accuracy                           0.93        40
#    macro avg       0.93      0.93      0.92        40
# weighted avg       0.93      0.93      0.92        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# K-Fold #9
# Mean negativities for all classes: [0.24552711156587984]
# Mean entropies for all classes: [3.016889892162631e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.83      1.00      0.91        20
#          1.0       1.00      0.80      0.89        20
#
#     accuracy                           0.90        40
#    macro avg       0.92      0.90      0.90        40
# weighted avg       0.92      0.90      0.90        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.9200000000000002 F1-Scores = 0.9191977965797233 Negativity = [0.24545720518392403, 0.2526319056754091] Entropy = [3.317984813010364e-15, 2.763895267667929e-15]
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# K-Fold #0
# Mean negativities for all classes: [0.24307764665593493]
# Mean entropies for all classes: [3.009274078217741e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.80      1.00      0.89        20
#          1.0       1.00      0.75      0.86        20
#
#     accuracy                           0.88        40
#    macro avg       0.90      0.88      0.87        40
# weighted avg       0.90      0.88      0.87        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# K-Fold #1
# Mean negativities for all classes: [0.24057755170667497]
# Mean entropies for all classes: [2.9283873062386267e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.83      1.00      0.91        20
#          1.0       1.00      0.80      0.89        20
#
#     accuracy                           0.90        40
#    macro avg       0.92      0.90      0.90        40
# weighted avg       0.92      0.90      0.90        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# K-Fold #2
# Mean negativities for all classes: [0.24793528737153064]
# Mean entropies for all classes: [3.337269517004674e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.91      1.00      0.95        20
#          1.0       1.00      0.90      0.95        20
#
#     accuracy                           0.95        40
#    macro avg       0.95      0.95      0.95        40
# weighted avg       0.95      0.95      0.95        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# K-Fold #3
# Mean negativities for all classes: [0.25232188980433123]
# Mean entropies for all classes: [3.1089640051156872e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.83      1.00      0.91        20
#          1.0       1.00      0.80      0.89        20
#
#     accuracy                           0.90        40
#    macro avg       0.92      0.90      0.90        40
# weighted avg       0.92      0.90      0.90        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# K-Fold #4
# Mean negativities for all classes: [0.23579631934542036]
# Mean entropies for all classes: [2.9638863563451912e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.83      1.00      0.91        20
#          1.0       1.00      0.80      0.89        20
#
#     accuracy                           0.90        40
#    macro avg       0.92      0.90      0.90        40
# weighted avg       0.92      0.90      0.90        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# K-Fold #5
# Mean negativities for all classes: [0.23918582722869589]
# Mean entropies for all classes: [3.2439433382775173e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.87      1.00      0.93        20
#          1.0       1.00      0.85      0.92        20
#
#     accuracy                           0.93        40
#    macro avg       0.93      0.93      0.92        40
# weighted avg       0.93      0.93      0.92        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# K-Fold #6
# Mean negativities for all classes: [0.23660623926818047]
# Mean entropies for all classes: [2.808446661633746e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.98        20
#          1.0       1.00      0.95      0.97        20
#
#     accuracy                           0.97        40
#    macro avg       0.98      0.97      0.97        40
# weighted avg       0.98      0.97      0.97        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# K-Fold #7
# Mean negativities for all classes: [0.23686404381644593]
# Mean entropies for all classes: [2.4631418802170193e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.87      1.00      0.93        20
#          1.0       1.00      0.85      0.92        20
#
#     accuracy                           0.93        40
#    macro avg       0.93      0.93      0.92        40
# weighted avg       0.93      0.93      0.92        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# K-Fold #8
# Mean negativities for all classes: [0.2573133706769311]
# Mean entropies for all classes: [3.857296274775707e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.87      1.00      0.93        20
#          1.0       1.00      0.85      0.92        20
#
#     accuracy                           0.93        40
#    macro avg       0.93      0.93      0.92        40
# weighted avg       0.93      0.93      0.92        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# K-Fold #9
# Mean negativities for all classes: [0.24668241793053616]
# Mean entropies for all classes: [3.1129483884986436e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.91      1.00      0.95        20
#          1.0       1.00      0.90      0.95        20
#
#     accuracy                           0.95        40
#    macro avg       0.95      0.95      0.95        40
# weighted avg       0.95      0.95      0.95        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.9225 F1-Scores = 0.9218446524235102 Negativity = [0.24307764665593493, 0.24057755170667497] Entropy = [3.009274078217741e-15, 2.9283873062386267e-15]
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# K-Fold #0
# Mean negativities for all classes: [0.24384885998257083]
# Mean entropies for all classes: [2.9882562766696825e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.83      1.00      0.91        20
#          1.0       1.00      0.80      0.89        20
#
#     accuracy                           0.90        40
#    macro avg       0.92      0.90      0.90        40
# weighted avg       0.92      0.90      0.90        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# K-Fold #1
# Mean negativities for all classes: [0.24544278566721073]
# Mean entropies for all classes: [3.988608996233128e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.83      1.00      0.91        20
#          1.0       1.00      0.80      0.89        20
#
#     accuracy                           0.90        40
#    macro avg       0.92      0.90      0.90        40
# weighted avg       0.92      0.90      0.90        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# K-Fold #2
# Mean negativities for all classes: [0.23801406353523874]
# Mean entropies for all classes: [3.2645573703517854e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.91      1.00      0.95        20
#          1.0       1.00      0.90      0.95        20
#
#     accuracy                           0.95        40
#    macro avg       0.95      0.95      0.95        40
# weighted avg       0.95      0.95      0.95        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# K-Fold #3
# Mean negativities for all classes: [0.24886831431696255]
# Mean entropies for all classes: [3.483513318655302e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.91      1.00      0.95        20
#          1.0       1.00      0.90      0.95        20
#
#     accuracy                           0.95        40
#    macro avg       0.95      0.95      0.95        40
# weighted avg       0.95      0.95      0.95        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# K-Fold #4
# Mean negativities for all classes: [0.2433840922504446]
# Mean entropies for all classes: [3.692742146583108e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.87      1.00      0.93        20
#          1.0       1.00      0.85      0.92        20
#
#     accuracy                           0.93        40
#    macro avg       0.93      0.93      0.92        40
# weighted avg       0.93      0.93      0.92        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# K-Fold #5
# Mean negativities for all classes: [0.2426526175821469]
# Mean entropies for all classes: [2.6623667394393787e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.91      1.00      0.95        20
#          1.0       1.00      0.90      0.95        20
#
#     accuracy                           0.95        40
#    macro avg       0.95      0.95      0.95        40
# weighted avg       0.95      0.95      0.95        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# K-Fold #6
# Mean negativities for all classes: [0.24306157209083787]
# Mean entropies for all classes: [2.672757933761211e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.80      1.00      0.89        20
#          1.0       1.00      0.75      0.86        20
#
#     accuracy                           0.88        40
#    macro avg       0.90      0.88      0.87        40
# weighted avg       0.90      0.88      0.87        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# K-Fold #7
# Mean negativities for all classes: [0.24608572049031655]
# Mean entropies for all classes: [2.960681771614317e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.91      1.00      0.95        20
#          1.0       1.00      0.90      0.95        20
#
#     accuracy                           0.95        40
#    macro avg       0.95      0.95      0.95        40
# weighted avg       0.95      0.95      0.95        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# K-Fold #8
# Mean negativities for all classes: [0.242332176687927]
# Mean entropies for all classes: [3.5531833707295244e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.80      1.00      0.89        20
#          1.0       1.00      0.75      0.86        20
#
#     accuracy                           0.88        40
#    macro avg       0.90      0.88      0.87        40
# weighted avg       0.90      0.88      0.87        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# K-Fold #9
# Mean negativities for all classes: [0.2522594672074639]
# Mean entropies for all classes: [3.1862323824222468e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.87      1.00      0.93        20
#          1.0       1.00      0.85      0.92        20
#
#     accuracy                           0.93        40
#    macro avg       0.93      0.93      0.92        40
# weighted avg       0.93      0.93      0.92        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.9200000000000002 F1-Scores = 0.9192661767937166 Negativity = [0.24384885998257083, 0.24544278566721073] Entropy = [2.9882562766696825e-15, 3.988608996233128e-15]
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# K-Fold #0
# Mean negativities for all classes: [0.25365629815044255]
# Mean entropies for all classes: [3.0056608971730987e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.80      1.00      0.89        20
#          1.0       1.00      0.75      0.86        20
#
#     accuracy                           0.88        40
#    macro avg       0.90      0.88      0.87        40
# weighted avg       0.90      0.88      0.87        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# K-Fold #1
# Mean negativities for all classes: [0.23560594726517695]
# Mean entropies for all classes: [2.9556529066957998e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.91      1.00      0.95        20
#          1.0       1.00      0.90      0.95        20
#
#     accuracy                           0.95        40
#    macro avg       0.95      0.95      0.95        40
# weighted avg       0.95      0.95      0.95        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# K-Fold #2
# Mean negativities for all classes: [0.2283418898110085]
# Mean entropies for all classes: [3.0881083103028393e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.91      1.00      0.95        20
#          1.0       1.00      0.90      0.95        20
#
#     accuracy                           0.95        40
#    macro avg       0.95      0.95      0.95        40
# weighted avg       0.95      0.95      0.95        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# K-Fold #3
# Mean negativities for all classes: [0.24173622177448295]
# Mean entropies for all classes: [2.8884345909264637e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.87      1.00      0.93        20
#          1.0       1.00      0.85      0.92        20
#
#     accuracy                           0.93        40
#    macro avg       0.93      0.93      0.92        40
# weighted avg       0.93      0.93      0.92        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# K-Fold #4
# Mean negativities for all classes: [0.24709797477679213]
# Mean entropies for all classes: [3.1868342676811786e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.87      1.00      0.93        20
#          1.0       1.00      0.85      0.92        20
#
#     accuracy                           0.93        40
#    macro avg       0.93      0.93      0.92        40
# weighted avg       0.93      0.93      0.92        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# K-Fold #5
# Mean negativities for all classes: [0.24229098186474904]
# Mean entropies for all classes: [2.797879517080838e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.83      1.00      0.91        20
#          1.0       1.00      0.80      0.89        20
#
#     accuracy                           0.90        40
#    macro avg       0.92      0.90      0.90        40
# weighted avg       0.92      0.90      0.90        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# K-Fold #6
# Mean negativities for all classes: [0.23912355480173897]
# Mean entropies for all classes: [3.733553301347891e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.83      1.00      0.91        20
#          1.0       1.00      0.80      0.89        20
#
#     accuracy                           0.90        40
#    macro avg       0.92      0.90      0.90        40
# weighted avg       0.92      0.90      0.90        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# K-Fold #7
# Mean negativities for all classes: [0.2291379752170092]
# Mean entropies for all classes: [3.109753438640398e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.83      1.00      0.91        20
#          1.0       1.00      0.80      0.89        20
#
#     accuracy                           0.90        40
#    macro avg       0.92      0.90      0.90        40
# weighted avg       0.92      0.90      0.90        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# K-Fold #8
# Mean negativities for all classes: [0.24465189960250852]
# Mean entropies for all classes: [3.1583753297719414e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.98        20
#          1.0       1.00      0.95      0.97        20
#
#     accuracy                           0.97        40
#    macro avg       0.98      0.97      0.97        40
# weighted avg       0.98      0.97      0.97        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# K-Fold #9
# Mean negativities for all classes: [0.25318979955193077]
# Mean entropies for all classes: [3.2133102799046154e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.87      1.00      0.93        20
#          1.0       1.00      0.85      0.92        20
#
#     accuracy                           0.93        40
#    macro avg       0.93      0.93      0.92        40
# weighted avg       0.93      0.93      0.92        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.9225000000000001 F1-Scores = 0.9218446524235102 Negativity = [0.25365629815044255, 0.23560594726517695] Entropy = [3.0056608971730987e-15, 2.9556529066957998e-15]
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# K-Fold #0
# Mean negativities for all classes: [0.23926665440553246]
# Mean entropies for all classes: [2.9919325164067646e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.83      1.00      0.91        20
#          1.0       1.00      0.80      0.89        20
#
#     accuracy                           0.90        40
#    macro avg       0.92      0.90      0.90        40
# weighted avg       0.92      0.90      0.90        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# K-Fold #1
# Mean negativities for all classes: [0.2544626366008208]
# Mean entropies for all classes: [3.1458390505921967e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.98        20
#          1.0       1.00      0.95      0.97        20
#
#     accuracy                           0.97        40
#    macro avg       0.98      0.97      0.97        40
# weighted avg       0.98      0.97      0.97        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# K-Fold #2
# Mean negativities for all classes: [0.24454849687210486]
# Mean entropies for all classes: [3.13667014652769e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.83      1.00      0.91        20
#          1.0       1.00      0.80      0.89        20
#
#     accuracy                           0.90        40
#    macro avg       0.92      0.90      0.90        40
# weighted avg       0.92      0.90      0.90        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# K-Fold #3
# Mean negativities for all classes: [0.2465389055220784]
# Mean entropies for all classes: [2.653849570404133e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.91      1.00      0.95        20
#          1.0       1.00      0.90      0.95        20
#
#     accuracy                           0.95        40
#    macro avg       0.95      0.95      0.95        40
# weighted avg       0.95      0.95      0.95        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# K-Fold #4
# Mean negativities for all classes: [0.23593383169367393]
# Mean entropies for all classes: [3.1806939619546227e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.83      1.00      0.91        20
#          1.0       1.00      0.80      0.89        20
#
#     accuracy                           0.90        40
#    macro avg       0.92      0.90      0.90        40
# weighted avg       0.92      0.90      0.90        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# K-Fold #5
# Mean negativities for all classes: [0.23113194786436136]
# Mean entropies for all classes: [3.607855251376314e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.98        20
#          1.0       1.00      0.95      0.97        20
#
#     accuracy                           0.97        40
#    macro avg       0.98      0.97      0.97        40
# weighted avg       0.98      0.97      0.97        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# K-Fold #6
# Mean negativities for all classes: [0.23839859549658104]
# Mean entropies for all classes: [2.8018147048236032e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.83      1.00      0.91        20
#          1.0       1.00      0.80      0.89        20
#
#     accuracy                           0.90        40
#    macro avg       0.92      0.90      0.90        40
# weighted avg       0.92      0.90      0.90        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# K-Fold #7
# Mean negativities for all classes: [0.2441366613051546]
# Mean entropies for all classes: [3.183770860856817e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.87      1.00      0.93        20
#          1.0       1.00      0.85      0.92        20
#
#     accuracy                           0.93        40
#    macro avg       0.93      0.93      0.92        40
# weighted avg       0.93      0.93      0.92        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# K-Fold #8
# Mean negativities for all classes: [0.24999257096482114]
# Mean entropies for all classes: [3.008795528348528e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.87      1.00      0.93        20
#          1.0       1.00      0.85      0.92        20
#
#     accuracy                           0.93        40
#    macro avg       0.93      0.93      0.92        40
# weighted avg       0.93      0.93      0.92        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# K-Fold #9
# Mean negativities for all classes: [0.24690309041394673]
# Mean entropies for all classes: [3.3840282659179606e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.87      1.00      0.93        20
#          1.0       1.00      0.85      0.92        20
#
#     accuracy                           0.93        40
#    macro avg       0.93      0.93      0.92        40
# weighted avg       0.93      0.93      0.92        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.9275000000000002 F1-Scores = 0.9269530228720603 Negativity = [0.23926665440553246, 0.2544626366008208] Entropy = [2.9919325164067646e-15, 3.1458390505921967e-15]
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# K-Fold #0
# Mean negativities for all classes: [0.24134819911463162]
# Mean entropies for all classes: [2.9130950063602613e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.80      1.00      0.89        20
#          1.0       1.00      0.75      0.86        20
#
#     accuracy                           0.88        40
#    macro avg       0.90      0.88      0.87        40
# weighted avg       0.90      0.88      0.87        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# K-Fold #1
# Mean negativities for all classes: [0.24358061408573822]
# Mean entropies for all classes: [2.8790919243979718e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.91      1.00      0.95        20
#          1.0       1.00      0.90      0.95        20
#
#     accuracy                           0.95        40
#    macro avg       0.95      0.95      0.95        40
# weighted avg       0.95      0.95      0.95        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# K-Fold #2
# Mean negativities for all classes: [0.24495170784810333]
# Mean entropies for all classes: [2.7708266320684283e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.87      1.00      0.93        20
#          1.0       1.00      0.85      0.92        20
#
#     accuracy                           0.93        40
#    macro avg       0.93      0.93      0.92        40
# weighted avg       0.93      0.93      0.92        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# K-Fold #3
# Mean negativities for all classes: [0.24033286889572966]
# Mean entropies for all classes: [2.8743493844299683e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.80      1.00      0.89        20
#          1.0       1.00      0.75      0.86        20
#
#     accuracy                           0.88        40
#    macro avg       0.90      0.88      0.87        40
# weighted avg       0.90      0.88      0.87        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# K-Fold #4
# Mean negativities for all classes: [0.25319206754278506]
# Mean entropies for all classes: [3.577948883382477e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.83      1.00      0.91        20
#          1.0       1.00      0.80      0.89        20
#
#     accuracy                           0.90        40
#    macro avg       0.92      0.90      0.90        40
# weighted avg       0.92      0.90      0.90        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# K-Fold #5
# Mean negativities for all classes: [0.24795648881212232]
# Mean entropies for all classes: [3.622180529370289e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.87      1.00      0.93        20
#          1.0       1.00      0.85      0.92        20
#
#     accuracy                           0.93        40
#    macro avg       0.93      0.93      0.92        40
# weighted avg       0.93      0.93      0.92        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# K-Fold #6
# Mean negativities for all classes: [0.24606248406836945]
# Mean entropies for all classes: [2.677721523336448e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.98        20
#          1.0       1.00      0.95      0.97        20
#
#     accuracy                           0.97        40
#    macro avg       0.98      0.97      0.97        40
# weighted avg       0.98      0.97      0.97        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# K-Fold #7
# Mean negativities for all classes: [0.24278019264183417]
# Mean entropies for all classes: [3.365608410412583e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.87      1.00      0.93        20
#          1.0       1.00      0.85      0.92        20
#
#     accuracy                           0.93        40
#    macro avg       0.93      0.93      0.92        40
# weighted avg       0.93      0.93      0.92        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# K-Fold #8
# Mean negativities for all classes: [0.23216644479759055]
# Mean entropies for all classes: [3.0642493274369177e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.98        20
#          1.0       1.00      0.95      0.97        20
#
#     accuracy                           0.97        40
#    macro avg       0.98      0.97      0.97        40
# weighted avg       0.98      0.97      0.97        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# K-Fold #9
# Mean negativities for all classes: [0.2523320783022418]
# Mean entropies for all classes: [2.7635703239145775e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.91      1.00      0.95        20
#          1.0       1.00      0.90      0.95        20
#
#     accuracy                           0.95        40
#    macro avg       0.95      0.95      0.95        40
# weighted avg       0.95      0.95      0.95        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.9274999999999999 F1-Scores = 0.9268466964499444 Negativity = [0.24134819911463162, 0.24358061408573822] Entropy = [2.9130950063602613e-15, 2.8790919243979718e-15]
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# K-Fold #0
# Mean negativities for all classes: [0.25158839494843865]
# Mean entropies for all classes: [3.1978117584116434e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.87      1.00      0.93        20
#          1.0       1.00      0.85      0.92        20
#
#     accuracy                           0.93        40
#    macro avg       0.93      0.93      0.92        40
# weighted avg       0.93      0.93      0.92        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# K-Fold #1
# Mean negativities for all classes: [0.2520950459002683]
# Mean entropies for all classes: [3.1850361698075496e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.87      1.00      0.93        20
#          1.0       1.00      0.85      0.92        20
#
#     accuracy                           0.93        40
#    macro avg       0.93      0.93      0.92        40
# weighted avg       0.93      0.93      0.92        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# K-Fold #2
# Mean negativities for all classes: [0.23220102728133946]
# Mean entropies for all classes: [3.334365860128784e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.87      1.00      0.93        20
#          1.0       1.00      0.85      0.92        20
#
#     accuracy                           0.93        40
#    macro avg       0.93      0.93      0.92        40
# weighted avg       0.93      0.93      0.92        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# K-Fold #3
# Mean negativities for all classes: [0.24460839953085395]
# Mean entropies for all classes: [3.4506588124198077e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.87      1.00      0.93        20
#          1.0       1.00      0.85      0.92        20
#
#     accuracy                           0.93        40
#    macro avg       0.93      0.93      0.92        40
# weighted avg       0.93      0.93      0.92        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# K-Fold #4
# Mean negativities for all classes: [0.2518820596369524]
# Mean entropies for all classes: [3.2389615135474304e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.83      1.00      0.91        20
#          1.0       1.00      0.80      0.89        20
#
#     accuracy                           0.90        40
#    macro avg       0.92      0.90      0.90        40
# weighted avg       0.92      0.90      0.90        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# K-Fold #5
# Mean negativities for all classes: [0.24934153316497923]
# Mean entropies for all classes: [3.2911674119719383e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.83      1.00      0.91        20
# ...
#               precision    recall  f1-score   support
#
#          0.0       0.87      1.00      0.93        20
#          1.0       1.00      0.85      0.92        20
#
#     accuracy                           0.93        40
#    macro avg       0.93      0.93      0.92        40
# weighted avg       0.93      0.93      0.92        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# K-Fold #2
# Mean negativities for all classes: [0.23456033009463662]
# Mean entropies for all classes: [3.160530836513659e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.83      1.00      0.91        20
#          1.0       1.00      0.80      0.89        20
#
#     accuracy                           0.90        40
#    macro avg       0.92      0.90      0.90        40
# weighted avg       0.92      0.90      0.90        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# K-Fold #3
# Mean negativities for all classes: [0.24756935365111418]
# Mean entropies for all classes: [3.3505460081452625e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.87      1.00      0.93        20
#          1.0       1.00      0.85      0.92        20
#
#     accuracy                           0.93        40
#    macro avg       0.93      0.93      0.92        40
# weighted avg       0.93      0.93      0.92        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# K-Fold #4
# Mean negativities for all classes: [0.25103223375343753]
# Mean entropies for all classes: [2.7221117802763964e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.87      1.00      0.93        20
#          1.0       1.00      0.85      0.92        20
#
#     accuracy                           0.93        40
#    macro avg       0.93      0.93      0.92        40
# weighted avg       0.93      0.93      0.92        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# K-Fold #5
# Mean negativities for all classes: [0.24116061149703533]
# Mean entropies for all classes: [3.230096528983027e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.83      1.00      0.91        20
#          1.0       1.00      0.80      0.89        20
#
#     accuracy                           0.90        40
#    macro avg       0.92      0.90      0.90        40
# weighted avg       0.92      0.90      0.90        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# K-Fold #6
# Mean negativities for all classes: [0.24394810639168146]
# Mean entropies for all classes: [3.567723983044412e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.83      1.00      0.91        20
#          1.0       1.00      0.80      0.89        20
#
#     accuracy                           0.90        40
#    macro avg       0.92      0.90      0.90        40
# weighted avg       0.92      0.90      0.90        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# K-Fold #7
# Mean negativities for all classes: [0.2459439022949988]
# Mean entropies for all classes: [3.1512922251680033e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.91      1.00      0.95        20
#          1.0       1.00      0.90      0.95        20
#
#     accuracy                           0.95        40
#    macro avg       0.95      0.95      0.95        40
# weighted avg       0.95      0.95      0.95        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# K-Fold #8
# Mean negativities for all classes: [0.2552518266471393]
# Mean entropies for all classes: [2.929290145572863e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.77      1.00      0.87        20
#          1.0       1.00      0.70      0.82        20
#
#     accuracy                           0.85        40
#    macro avg       0.88      0.85      0.85        40
# weighted avg       0.88      0.85      0.85        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# K-Fold #9
# Mean negativities for all classes: [0.23750495098689814]
# Mean entropies for all classes: [3.0589167279808007e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.83      1.00      0.91        20
#          1.0       1.00      0.80      0.89        20
#
#     accuracy                           0.90        40
#    macro avg       0.92      0.90      0.90        40
# weighted avg       0.92      0.90      0.90        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.9125 F1-Scores = 0.9115983499558867 Negativity = [0.24695923757122182, 0.2521222276993672] Entropy = [3.4375906746075103e-15, 3.231209901279801e-15]
# CPU times: total: 9min 3s
# Wall time: 6h 52min 25s
# Media Score dos N K-Fold 0.9213750000000003
# Maior Score dos K-Fold 0.9324999999999999
# Menor Score dos K-Fold 0.9075000000000001
#
#
# [[0.975, 0.925, 0.925, 0.9, 0.85, 0.9, 0.95, 0.95, 0.925, 0.9], [0.875, 0.9, 0.95, 0.9, 0.9, 0.925, 0.975, 0.925, 0.925, 0.95], [0.9, 0.9, 0.95, 0.95, 0.925, 0.95, 0.875, 0.95, 0.875, 0.925], [0.875, 0.95, 0.95, 0.925, 0.925, 0.9, 0.9, 0.9, 0.975, 0.925], [0.9, 0.975, 0.9, 0.95, 0.9, 0.975, 0.9, 0.925, 0.925, 0.925], [0.875, 0.95
20-10-Fold.ipynb
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# K-Fold #0
# Mean negativities for all classes: [0.2108697922239749]
# Mean entropies for all classes: [2.5024649798853607e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.62      1.00      0.77        20
#          1.0       1.00      0.40      0.57        20
#
#     accuracy                           0.70        40
#    macro avg       0.81      0.70      0.67        40
# weighted avg       0.81      0.70      0.67        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# K-Fold #1
# Mean negativities for all classes: [0.218693973084327]
# Mean entropies for all classes: [2.1850401487407264e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.61      1.00      0.75        20
#          1.0       1.00      0.35      0.52        20
#
#     accuracy                           0.68        40
#    macro avg       0.80      0.68      0.64        40
# weighted avg       0.80      0.68      0.64        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# K-Fold #2
# Mean negativities for all classes: [0.21384011696251487]
# Mean entropies for all classes: [3.8872276446807396e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.61      1.00      0.75        20
#          1.0       1.00      0.35      0.52        20
#
#     accuracy                           0.68        40
#    macro avg       0.80      0.68      0.64        40
# weighted avg       0.80      0.68      0.64        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# K-Fold #3
# Mean negativities for all classes: [0.23234948275745188]
# Mean entropies for all classes: [2.29231552078767e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.62      1.00      0.77        20
#          1.0       1.00      0.40      0.57        20
#
#     accuracy                           0.70        40
#    macro avg       0.81      0.70      0.67        40
# weighted avg       0.81      0.70      0.67        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# K-Fold #4
# Mean negativities for all classes: [0.2254630834941384]
# Mean entropies for all classes: [3.269077034377797e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.56      1.00      0.71        20
#          1.0       1.00      0.20      0.33        20
#
#     accuracy                           0.60        40
#    macro avg       0.78      0.60      0.52        40
# weighted avg       0.78      0.60      0.52        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# K-Fold #5
# Mean negativities for all classes: [0.17304413676134892]
# Mean entropies for all classes: [2.5391408039821086e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.67      1.00      0.80        20
#          1.0       1.00      0.50      0.67        20
#
#     accuracy                           0.75        40
#    macro avg       0.83      0.75      0.73        40
# weighted avg       0.83      0.75      0.73        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# K-Fold #6
# Mean negativities for all classes: [0.2286796820242257]
# Mean entropies for all classes: [3.145872245202939e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.59      1.00      0.74        20
#          1.0       1.00      0.30      0.46        20
#
#     accuracy                           0.65        40
#    macro avg       0.79      0.65      0.60        40
# weighted avg       0.79      0.65      0.60        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# K-Fold #7
# Mean negativities for all classes: [0.20356661946488314]
# Mean entropies for all classes: [3.4602491477176873e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.57      1.00      0.73        20
#          1.0       1.00      0.25      0.40        20
#
#     accuracy                           0.62        40
#    macro avg       0.79      0.62      0.56        40
# weighted avg       0.79      0.62      0.56        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# K-Fold #8
# Mean negativities for all classes: [0.19703640306339262]
# Mean entropies for all classes: [3.2629093517471906e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.61      1.00      0.75        20
#          1.0       1.00      0.35      0.52        20
#
#     accuracy                           0.68        40
#    macro avg       0.80      0.68      0.64        40
# weighted avg       0.80      0.68      0.64        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# K-Fold #9
# Mean negativities for all classes: [0.19306591104044252]
# Mean entropies for all classes: [2.8353959101923675e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.61      1.00      0.75        20
#          1.0       1.00      0.35      0.52        20
#
#     accuracy                           0.68        40
#    macro avg       0.80      0.68      0.64        40
# weighted avg       0.80      0.68      0.64        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.6725 F1-Scores = 0.6309049161879351 Negativity = [0.2108697922239749, 0.218693973084327] Entropy = [2.5024649798853607e-15, 2.1850401487407264e-15]
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# K-Fold #0
# Mean negativities for all classes: [0.17471443406442752]
# Mean entropies for all classes: [2.8135778656904085e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.67      1.00      0.80        20
#          1.0       1.00      0.50      0.67        20
#
#     accuracy                           0.75        40
#    macro avg       0.83      0.75      0.73        40
# weighted avg       0.83      0.75      0.73        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# K-Fold #1
# Mean negativities for all classes: [0.2129006196762334]
# Mean entropies for all classes: [3.2715790131809593e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.56      1.00      0.71        20
#          1.0       1.00      0.20      0.33        20
#
#     accuracy                           0.60        40
#    macro avg       0.78      0.60      0.52        40
# weighted avg       0.78      0.60      0.52        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# K-Fold #2
# Mean negativities for all classes: [0.21284732497707623]
# Mean entropies for all classes: [2.349768752219196e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.57      1.00      0.73        20
#          1.0       1.00      0.25      0.40        20
#
#     accuracy                           0.62        40
#    macro avg       0.79      0.62      0.56        40
# weighted avg       0.79      0.62      0.56        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# K-Fold #3
# Mean negativities for all classes: [0.2373585789120785]
# Mean entropies for all classes: [3.3710600450520206e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.59      1.00      0.74        20
#          1.0       1.00      0.30      0.46        20
#
#     accuracy                           0.65        40
#    macro avg       0.79      0.65      0.60        40
# weighted avg       0.79      0.65      0.60        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# K-Fold #4
# Mean negativities for all classes: [0.18795948294708964]
# Mean entropies for all classes: [1.9430253556900064e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.67      1.00      0.80        20
#          1.0       1.00      0.50      0.67        20
#
#     accuracy                           0.75        40
#    macro avg       0.83      0.75      0.73        40
# weighted avg       0.83      0.75      0.73        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# K-Fold #5
# Mean negativities for all classes: [0.2022983454859661]
# Mean entropies for all classes: [2.8768284389300673e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.65      1.00      0.78        20
#          1.0       1.00      0.45      0.62        20
#
#     accuracy                           0.73        40
#    macro avg       0.82      0.72      0.70        40
# weighted avg       0.82      0.72      0.70        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# K-Fold #6
# Mean negativities for all classes: [0.20268761177117084]
# Mean entropies for all classes: [2.6290243682277103e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.62      1.00      0.77        20
#          1.0       1.00      0.40      0.57        20
#
#     accuracy                           0.70        40
#    macro avg       0.81      0.70      0.67        40
# weighted avg       0.81      0.70      0.67        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# K-Fold #7
# Mean negativities for all classes: [0.19685499586194802]
# Mean entropies for all classes: [2.664578013378292e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.59      1.00      0.74        20
#          1.0       1.00      0.30      0.46        20
#
#     accuracy                           0.65        40
#    macro avg       0.79      0.65      0.60        40
# weighted avg       0.79      0.65      0.60        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# K-Fold #8
# Mean negativities for all classes: [0.2530822085352186]
# Mean entropies for all classes: [2.4208415094958392e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.57      1.00      0.73        20
#          1.0       1.00      0.25      0.40        20
#
#     accuracy                           0.62        40
#    macro avg       0.79      0.62      0.56        40
# weighted avg       0.79      0.62      0.56        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# K-Fold #9
# Mean negativities for all classes: [0.20837456184747166]
# Mean entropies for all classes: [1.876166520781167e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.61      1.00      0.75        20
#          1.0       1.00      0.35      0.52        20
#
#     accuracy                           0.68        40
#    macro avg       0.80      0.68      0.64        40
# weighted avg       0.80      0.68      0.64        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.675 F1-Scores = 0.6329477230514392 Negativity = [0.17471443406442752, 0.2129006196762334] Entropy = [2.8135778656904085e-15, 3.2715790131809593e-15]
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# K-Fold #0
# Mean negativities for all classes: [0.1929574628616111]
# Mean entropies for all classes: [3.0219421863759954e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.62      1.00      0.77        20
#          1.0       1.00      0.40      0.57        20
#
#     accuracy                           0.70        40
#    macro avg       0.81      0.70      0.67        40
# weighted avg       0.81      0.70      0.67        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# K-Fold #1
# Mean negativities for all classes: [0.20612622191505792]
# Mean entropies for all classes: [3.0840572807149687e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.59      1.00      0.74        20
#          1.0       1.00      0.30      0.46        20
#
#     accuracy                           0.65        40
#    macro avg       0.79      0.65      0.60        40
# weighted avg       0.79      0.65      0.60        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# K-Fold #2
# Mean negativities for all classes: [0.20688717316139602]
# Mean entropies for all classes: [2.2318676106673366e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.53      1.00      0.69        20
#          1.0       1.00      0.10      0.18        20
#
#     accuracy                           0.55        40
#    macro avg       0.76      0.55      0.44        40
# weighted avg       0.76      0.55      0.44        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# K-Fold #3
# Mean negativities for all classes: [0.1884556295248197]
# Mean entropies for all classes: [2.906016382019453e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.65      1.00      0.78        20
#          1.0       1.00      0.45      0.62        20
#
#     accuracy                           0.73        40
#    macro avg       0.82      0.72      0.70        40
# weighted avg       0.82      0.72      0.70        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# K-Fold #4
# Mean negativities for all classes: [0.218065741530729]
# Mean entropies for all classes: [3.0248403709356084e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.62      1.00      0.77        20
#          1.0       1.00      0.40      0.57        20
#
#     accuracy                           0.70        40
#    macro avg       0.81      0.70      0.67        40
# weighted avg       0.81      0.70      0.67        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# K-Fold #5
# Mean negativities for all classes: [0.2357563353658482]
# Mean entropies for all classes: [2.273795224754591e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.62      1.00      0.77        20
#          1.0       1.00      0.40      0.57        20
#
#     accuracy                           0.70        40
#    macro avg       0.81      0.70      0.67        40
# weighted avg       0.81      0.70      0.67        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# K-Fold #6
# Mean negativities for all classes: [0.20950873028917397]
# Mean entropies for all classes: [3.1046647371488884e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.67      1.00      0.80        20
#          1.0       1.00      0.50      0.67        20
#
#     accuracy                           0.75        40
#    macro avg       0.83      0.75      0.73        40
# weighted avg       0.83      0.75      0.73        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# K-Fold #7
# Mean negativities for all classes: [0.20108487064415503]
# Mean entropies for all classes: [2.488831421250365e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.62      1.00      0.77        20
#          1.0       1.00      0.40      0.57        20
#
#     accuracy                           0.70        40
#    macro avg       0.81      0.70      0.67        40
# weighted avg       0.81      0.70      0.67        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# K-Fold #8
# Mean negativities for all classes: [0.23769931897702373]
# Mean entropies for all classes: [3.8664042448567846e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.56      1.00      0.71        20
#          1.0       1.00      0.20      0.33        20
#
#     accuracy                           0.60        40
#    macro avg       0.78      0.60      0.52        40
# weighted avg       0.78      0.60      0.52        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# K-Fold #9
# Mean negativities for all classes: [0.20700974685138585]
# Mean entropies for all classes: [2.6486309846939887e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.65      1.00      0.78        20
#          1.0       1.00      0.45      0.62        20
#
#     accuracy                           0.73        40
#    macro avg       0.82      0.72      0.70        40
# weighted avg       0.82      0.72      0.70        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.6799999999999999 F1-Scores = 0.6380341197379737 Negativity = [0.1929574628616111, 0.20612622191505792] Entropy = [3.0219421863759954e-15, 3.0840572807149687e-15]
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# K-Fold #0
# Mean negativities for all classes: [0.21908571406116914]
# Mean entropies for all classes: [3.402894809341097e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.59      1.00      0.74        20
#          1.0       1.00      0.30      0.46        20
#
#     accuracy                           0.65        40
#    macro avg       0.79      0.65      0.60        40
# weighted avg       0.79      0.65      0.60        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# K-Fold #1
# Mean negativities for all classes: [0.18273347258575207]
# Mean entropies for all classes: [3.186921399477671e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.65      1.00      0.78        20
#          1.0       1.00      0.45      0.62        20
#
#     accuracy                           0.73        40
#    macro avg       0.82      0.72      0.70        40
# weighted avg       0.82      0.72      0.70        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# K-Fold #2
# Mean negativities for all classes: [0.2024888122721921]
# Mean entropies for all classes: [3.0671048412137974e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.61      1.00      0.75        20
#          1.0       1.00      0.35      0.52        20
#
#     accuracy                           0.68        40
#    macro avg       0.80      0.68      0.64        40
# weighted avg       0.80      0.68      0.64        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# K-Fold #3
# Mean negativities for all classes: [0.21404163419152034]
# Mean entropies for all classes: [3.187898397742877e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.65      1.00      0.78        20
#          1.0       1.00      0.45      0.62        20
#
#     accuracy                           0.73        40
#    macro avg       0.82      0.72      0.70        40
# weighted avg       0.82      0.72      0.70        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# K-Fold #4
# Mean negativities for all classes: [0.1900556294720635]
# Mean entropies for all classes: [2.33481445856045e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.62      1.00      0.77        20
#          1.0       1.00      0.40      0.57        20
#
#     accuracy                           0.70        40
#    macro avg       0.81      0.70      0.67        40
# weighted avg       0.81      0.70      0.67        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# K-Fold #5
# Mean negativities for all classes: [0.19827198109440164]
# Mean entropies for all classes: [2.8293325810397077e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.57      1.00      0.73        20
#          1.0       1.00      0.25      0.40        20
#
#     accuracy                           0.62        40
#    macro avg       0.79      0.62      0.56        40
# weighted avg       0.79      0.62      0.56        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# K-Fold #6
# Mean negativities for all classes: [0.20265212927541518]
# Mean entropies for all classes: [2.036465062711173e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.61      1.00      0.75        20
#          1.0       1.00      0.35      0.52        20
#
#     accuracy                           0.68        40
#    macro avg       0.80      0.68      0.64        40
# weighted avg       0.80      0.68      0.64        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# K-Fold #7
# Mean negativities for all classes: [0.22505679909168247]
# Mean entropies for all classes: [3.150398871018866e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.57      1.00      0.73        20
#          1.0       1.00      0.25      0.40        20
#
#     accuracy                           0.62        40
#    macro avg       0.79      0.62      0.56        40
# weighted avg       0.79      0.62      0.56        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# K-Fold #8
# Mean negativities for all classes: [0.26646435737720325]
# Mean entropies for all classes: [2.692871986662647e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.61      1.00      0.75        20
#          1.0       1.00      0.35      0.52        20
#
#     accuracy                           0.68        40
#    macro avg       0.80      0.68      0.64        40
# weighted avg       0.80      0.68      0.64        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# K-Fold #9
# Mean negativities for all classes: [0.23955004803012078]
# Mean entropies for all classes: [2.4375748039477264e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.59      1.00      0.74        20
#          1.0       1.00      0.30      0.46        20
#
#     accuracy                           0.65        40
#    macro avg       0.79      0.65      0.60        40
# weighted avg       0.79      0.65      0.60        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.6725000000000001 F1-Scores = 0.63147382300201 Negativity = [0.21908571406116914, 0.18273347258575207] Entropy = [3.402894809341097e-15, 3.186921399477671e-15]
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# K-Fold #0
# Mean negativities for all classes: [0.17707512725018942]
# Mean entropies for all classes: [2.7712541478537235e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.62      1.00      0.77        20
#          1.0       1.00      0.40      0.57        20
#
#     accuracy                           0.70        40
#    macro avg       0.81      0.70      0.67        40
# weighted avg       0.81      0.70      0.67        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# K-Fold #1
# Mean negativities for all classes: [0.20793219449670888]
# Mean entropies for all classes: [2.9749006286788514e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.62      1.00      0.77        20
#          1.0       1.00      0.40      0.57        20
#
#     accuracy                           0.70        40
#    macro avg       0.81      0.70      0.67        40
# weighted avg       0.81      0.70      0.67        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# K-Fold #2
# Mean negativities for all classes: [0.22520068763538212]
# Mean entropies for all classes: [3.350246360748959e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.59      1.00      0.74        20
#          1.0       1.00      0.30      0.46        20
#
#     accuracy                           0.65        40
#    macro avg       0.79      0.65      0.60        40
# weighted avg       0.79      0.65      0.60        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# K-Fold #3
# Mean negativities for all classes: [0.23448005231125374]
# Mean entropies for all classes: [2.599738634089148e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.59      1.00      0.74        20
#          1.0       1.00      0.30      0.46        20
#
#     accuracy                           0.65        40
#    macro avg       0.79      0.65      0.60        40
# weighted avg       0.79      0.65      0.60        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# K-Fold #4
# Mean negativities for all classes: [0.21455105119138845]
# Mean entropies for all classes: [2.7256958558725035e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.59      1.00      0.74        20
#          1.0       1.00      0.30      0.46        20
#
#     accuracy                           0.65        40
#    macro avg       0.79      0.65      0.60        40
# weighted avg       0.79      0.65      0.60        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# K-Fold #5
# Mean negativities for all classes: [0.20405435897344099]
# Mean entropies for all classes: [2.013522943189705e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.57      1.00      0.73        20
#          1.0       1.00      0.25      0.40        20
#
#     accuracy                           0.62        40
#    macro avg       0.79      0.62      0.56        40
# weighted avg       0.79      0.62      0.56        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# K-Fold #6
# Mean negativities for all classes: [0.1895460204064401]
# Mean entropies for all classes: [3.5701512665748295e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.61      1.00      0.75        20
#          1.0       1.00      0.35      0.52        20
#
#     accuracy                           0.68        40
#    macro avg       0.80      0.68      0.64        40
# weighted avg       0.80      0.68      0.64        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# K-Fold #7
# Mean negativities for all classes: [0.21453425363157036]
# Mean entropies for all classes: [2.714738220263851e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.61      1.00      0.75        20
#          1.0       1.00      0.35      0.52        20
#
#     accuracy                           0.68        40
#    macro avg       0.80      0.68      0.64        40
# weighted avg       0.80      0.68      0.64        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# K-Fold #8
# Mean negativities for all classes: [0.20032357766984274]
# Mean entropies for all classes: [3.054487088176877e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.62      1.00      0.77        20
#          1.0       1.00      0.40      0.57        20
#
#     accuracy                           0.70        40
#    macro avg       0.81      0.70      0.67        40
# weighted avg       0.81      0.70      0.67        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# K-Fold #9
# Mean negativities for all classes: [0.2234196110735887]
# Mean entropies for all classes: [2.9788357263374554e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.57      1.00      0.73        20
#          1.0       1.00      0.25      0.40        20
#
#     accuracy                           0.62        40
#    macro avg       0.79      0.62      0.56        40
# weighted avg       0.79      0.62      0.56        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.665 F1-Scores = 0.6214916041331137 Negativity = [0.17707512725018942, 0.20793219449670888] Entropy = [2.7712541478537235e-15, 2.9749006286788514e-15]
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# K-Fold #0
# Mean negativities for all classes: [0.21004860645161835]
# Mean entropies for all classes: [2.7895636206340565e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.67      1.00      0.80        20
#          1.0       1.00      0.50      0.67        20
#
#     accuracy                           0.75        40
#    macro avg       0.83      0.75      0.73        40
# weighted avg       0.83      0.75      0.73        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# K-Fold #1
# Mean negativities for all classes: [0.21308302993206288]
# Mean entropies for all classes: [3.051473257359265e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.59      1.00      0.74        20
#          1.0       1.00      0.30      0.46        20
#
#     accuracy                           0.65        40
#    macro avg       0.79      0.65      0.60        40
# weighted avg       0.79      0.65      0.60        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# K-Fold #2
# Mean negativities for all classes: [0.17988579218153217]
# Mean entropies for all classes: [3.212881492210849e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.62      1.00      0.77        20
#          1.0       1.00      0.40      0.57        20
#
#     accuracy                           0.70        40
#    macro avg       0.81      0.70      0.67        40
# weighted avg       0.81      0.70      0.67        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# K-Fold #3
# Mean negativities for all classes: [0.1865441213522641]
# Mean entropies for all classes: [2.83375588681909e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.59      1.00      0.74        20
#          1.0       1.00      0.30      0.46        20
#
#     accuracy                           0.65        40
#    macro avg       0.79      0.65      0.60        40
# weighted avg       0.79      0.65      0.60        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# K-Fold #4
# Mean negativities for all classes: [0.3082542684188184]
# Mean entropies for all classes: [1.9818292635383834e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.54      1.00      0.70        20
#          1.0       1.00      0.15      0.26        20
#
#     accuracy                           0.57        40
#    macro avg       0.77      0.57      0.48        40
# weighted avg       0.77      0.57      0.48        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# K-Fold #5
# Mean negativities for all classes: [0.2195095240071697]
# Mean entropies for all classes: [3.2365818190604823e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.57      1.00      0.73        20
#          1.0       1.00      0.25      0.40        20
#
#     accuracy                           0.62        40
#    macro avg       0.79      0.62      0.56        40
# weighted avg       0.79      0.62      0.56        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# K-Fold #6
# Mean negativities for all classes: [0.212091090633915]
# Mean entropies for all classes: [3.036969223868464e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.61      1.00      0.75        20
#          1.0       1.00      0.35      0.52        20
#
#     accuracy                           0.68        40
#    macro avg       0.80      0.68      0.64        40
# weighted avg       0.80      0.68      0.64        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# K-Fold #7
# Mean negativities for all classes: [0.22860237145734047]
# Mean entropies for all classes: [2.601905485092226e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.65      1.00      0.78        20
#          1.0       1.00      0.45      0.62        20
#
#     accuracy                           0.73        40
#    macro avg       0.82      0.72      0.70        40
# weighted avg       0.82      0.72      0.70        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# K-Fold #8
# Mean negativities for all classes: [0.21071183519692954]
# Mean entropies for all classes: [3.043297335034623e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.59      1.00      0.74        20
#          1.0       1.00      0.30      0.46        20
#
#     accuracy                           0.65        40
#    macro avg       0.79      0.65      0.60        40
# weighted avg       0.79      0.65      0.60        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# K-Fold #9
# Mean negativities for all classes: [0.2696698836761503]
# Mean entropies for all classes: [3.188846686323532e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.57      1.00      0.73        20
#          1.0       1.00      0.25      0.40        20
#
#     accuracy                           0.62        40
#    macro avg       0.79      0.62      0.56        40
# weighted avg       0.79      0.62      0.56        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.6625 F1-Scores = 0.6154785950102288 Negativity = [0.21004860645161835, 0.21308302993206288] Entropy = [2.7895636206340565e-15, 3.051473257359265e-15]
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# K-Fold #0
# Mean negativities for all classes: [0.2054860341570573]
# Mean entropies for all classes: [3.2861239923389717e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.61      1.00      0.75        20
#          1.0       1.00      0.35      0.52        20
#
#     accuracy                           0.68        40
#    macro avg       0.80      0.68      0.64        40
# weighted avg       0.80      0.68      0.64        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# K-Fold #1
# Mean negativities for all classes: [0.22281619436397807]
# Mean entropies for all classes: [2.951974210129699e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.59      1.00      0.74        20
#          1.0       1.00      0.30      0.46        20
#
#     accuracy                           0.65        40
#    macro avg       0.79      0.65      0.60        40
# weighted avg       0.79      0.65      0.60        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# K-Fold #2
# Mean negativities for all classes: [0.18405391019441525]
# Mean entropies for all classes: [3.301323680633594e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.65      1.00      0.78        20
#          1.0       1.00      0.45      0.62        20
#
#     accuracy                           0.73        40
#    macro avg       0.82      0.72      0.70        40
# weighted avg       0.82      0.72      0.70        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# K-Fold #3
# Mean negativities for all classes: [0.2393381767300312]
# Mean entropies for all classes: [2.20620366628403e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.59      1.00      0.74        20
#          1.0       1.00      0.30      0.46        20
#
#     accuracy                           0.65        40
#    macro avg       0.79      0.65      0.60        40
# weighted avg       0.79      0.65      0.60        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# K-Fold #4
# Mean negativities for all classes: [0.2259742885432865]
# Mean entropies for all classes: [2.6879671561695284e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.62      1.00      0.77        20
#          1.0       1.00      0.40      0.57        20
#
#     accuracy                           0.70        40
#    macro avg       0.81      0.70      0.67        40
# weighted avg       0.81      0.70      0.67        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# K-Fold #5
# Mean negativities for all classes: [0.22166864570527936]
# Mean entropies for all classes: [2.60479019445903e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.65      1.00      0.78        20
#          1.0       1.00      0.45      0.62        20
#
#     accuracy                           0.73        40
#    macro avg       0.82      0.72      0.70        40
# ...
#
#          0.0       0.61      1.00      0.75        20
#          1.0       1.00      0.35      0.52        20
#
#     accuracy                           0.68        40
#    macro avg       0.80      0.68      0.64        40
# weighted avg       0.80      0.68      0.64        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# K-Fold #2
# Mean negativities for all classes: [0.1968991192835673]
# Mean entropies for all classes: [2.351948154293114e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.61      1.00      0.75        20
#          1.0       1.00      0.35      0.52        20
#
#     accuracy                           0.68        40
#    macro avg       0.80      0.68      0.64        40
# weighted avg       0.80      0.68      0.64        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# K-Fold #3
# Mean negativities for all classes: [0.1858121282548976]
# Mean entropies for all classes: [3.053723643924054e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.67      1.00      0.80        20
#          1.0       1.00      0.50      0.67        20
#
#     accuracy                           0.75        40
#    macro avg       0.83      0.75      0.73        40
# weighted avg       0.83      0.75      0.73        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# K-Fold #4
# Mean negativities for all classes: [0.2362023006988542]
# Mean entropies for all classes: [2.534972700253102e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.56      1.00      0.71        20
#          1.0       1.00      0.20      0.33        20
#
#     accuracy                           0.60        40
#    macro avg       0.78      0.60      0.52        40
# weighted avg       0.78      0.60      0.52        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# K-Fold #5
# Mean negativities for all classes: [0.19594247950775795]
# Mean entropies for all classes: [3.418683135572426e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.59      1.00      0.74        20
#          1.0       1.00      0.30      0.46        20
#
#     accuracy                           0.65        40
#    macro avg       0.79      0.65      0.60        40
# weighted avg       0.79      0.65      0.60        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# K-Fold #6
# Mean negativities for all classes: [0.21349628451195146]
# Mean entropies for all classes: [3.4392907469023947e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.61      1.00      0.75        20
#          1.0       1.00      0.35      0.52        20
#
#     accuracy                           0.68        40
#    macro avg       0.80      0.68      0.64        40
# weighted avg       0.80      0.68      0.64        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# K-Fold #7
# Mean negativities for all classes: [0.23227824680936643]
# Mean entropies for all classes: [3.051060107151007e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.59      1.00      0.74        20
#          1.0       1.00      0.30      0.46        20
#
#     accuracy                           0.65        40
#    macro avg       0.79      0.65      0.60        40
# weighted avg       0.79      0.65      0.60        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# K-Fold #8
# Mean negativities for all classes: [0.19800554308658386]
# Mean entropies for all classes: [3.1270017199685515e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.65      1.00      0.78        20
#          1.0       1.00      0.45      0.62        20
#
#     accuracy                           0.73        40
#    macro avg       0.82      0.72      0.70        40
# weighted avg       0.82      0.72      0.70        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.1min finished
# K-Fold #9
# Mean negativities for all classes: [0.21805977300571824]
# Mean entropies for all classes: [2.557320684992254e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.57      1.00      0.73        20
#          1.0       1.00      0.25      0.40        20
#
#     accuracy                           0.62        40
#    macro avg       0.79      0.62      0.56        40
# weighted avg       0.79      0.62      0.56        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.6775 F1-Scores = 0.6368746696198951 Negativity = [0.20683331678930306, 0.2101289868394153] Entropy = [2.1207749464077576e-15, 2.8112969591576278e-15]
# CPU times: total: 8min 56s
# Wall time: 7h 17min 15s
# Media Score dos N K-Fold 0.670125
# Maior Score dos K-Fold 0.6799999999999999
# Menor Score dos K-Fold 0.6575
#
#
# [[0.7, 0.675, 0.675, 0.7, 0.6, 0.75, 0.65, 0.625, 0.675, 0.675], [0.75, 0.6, 0.625, 0.65, 0.75, 0.725, 0.7, 0.65, 0.625, 0.675], [0.7, 0.65, 0.55, 0.725, 0.7, 0.7, 0.75, 0.7, 0.6, 0.725], [0.65, 0.725, 0.675, 0.725, 0.7, 0.625, 0.675, 0.625, 0.675, 0.65], [0.7, 0.7, 0.65, 0.65, 0.65, 0.625, 0.675, 0.675, 0.7, 0.625], [0.75, 0.65, 0.7, 0.65, 0.575, 0.625, 0.675, 0.725, 0.65, 0.625], [0.675, 0.65, 0.725, 0.65, 0.7, 0.725, 0.675, 0.7, 
20-10-Fold.ipynb
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# K-Fold #0
# Mean negativities for all classes: [0.21131843890030705]
# Mean entropies for all classes: [3.227302489463834e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.40      0.44        20
#          1.0       0.50      0.60      0.55        20
#
#     accuracy                           0.50        40
#    macro avg       0.50      0.50      0.49        40
# weighted avg       0.50      0.50      0.49        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# K-Fold #1
# Mean negativities for all classes: [0.17303659323552995]
# Mean entropies for all classes: [2.440489432381992e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.52      0.75      0.61        20
#          1.0       0.55      0.30      0.39        20
#
#     accuracy                           0.53        40
#    macro avg       0.53      0.53      0.50        40
# weighted avg       0.53      0.53      0.50        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# K-Fold #2
# Mean negativities for all classes: [0.23580901047289063]
# Mean entropies for all classes: [-8.873141834561612e-16]
#               precision    recall  f1-score   support
#
#          0.0       0.52      0.60      0.56        20
#          1.0       0.53      0.45      0.49        20
#
#     accuracy                           0.53        40
#    macro avg       0.53      0.53      0.52        40
# weighted avg       0.53      0.53      0.52        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# K-Fold #3
# Mean negativities for all classes: [0.215745762861815]
# Mean entropies for all classes: [2.505851909374575e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.39      0.45      0.42        20
#          1.0       0.35      0.30      0.32        20
#
#     accuracy                           0.38        40
#    macro avg       0.37      0.38      0.37        40
# weighted avg       0.37      0.38      0.37        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# K-Fold #4
# Mean negativities for all classes: [0.1641930595117389]
# Mean entropies for all classes: [3.462683337141766e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.62      0.40      0.48        20
#          1.0       0.56      0.75      0.64        20
#
#     accuracy                           0.57        40
#    macro avg       0.59      0.57      0.56        40
# weighted avg       0.59      0.57      0.56        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# K-Fold #5
# Mean negativities for all classes: [0.1886934490373145]
# Mean entropies for all classes: [3.584849614145165e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.45      0.45      0.45        20
#          1.0       0.45      0.45      0.45        20
#
#     accuracy                           0.45        40
#    macro avg       0.45      0.45      0.45        40
# weighted avg       0.45      0.45      0.45        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# K-Fold #6
# Mean negativities for all classes: [0.25261219607223395]
# Mean entropies for all classes: [-6.919439092727592e-16]
#               precision    recall  f1-score   support
#
#          0.0       0.54      0.35      0.42        20
#          1.0       0.52      0.70      0.60        20
#
#     accuracy                           0.53        40
#    macro avg       0.53      0.52      0.51        40
# weighted avg       0.53      0.53      0.51        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# K-Fold #7
# Mean negativities for all classes: [0.24444261342062562]
# Mean entropies for all classes: [4.5543744053012525e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.45      0.47        20
#          1.0       0.50      0.55      0.52        20
#
#     accuracy                           0.50        40
#    macro avg       0.50      0.50      0.50        40
# weighted avg       0.50      0.50      0.50        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# K-Fold #8
# Mean negativities for all classes: [0.17676229538248456]
# Mean entropies for all classes: [7.706581183240949e-16]
#               precision    recall  f1-score   support
#
#          0.0       0.44      0.20      0.28        20
#          1.0       0.48      0.75      0.59        20
#
#     accuracy                           0.48        40
#    macro avg       0.46      0.47      0.43        40
# weighted avg       0.46      0.47      0.43        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# K-Fold #9
# Mean negativities for all classes: [0.15278415011287122]
# Mean entropies for all classes: [2.587142548113759e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.55      0.55      0.55        20
#          1.0       0.55      0.55      0.55        20
#
#     accuracy                           0.55        40
#    macro avg       0.55      0.55      0.55        40
# weighted avg       0.55      0.55      0.55        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.4999999999999999 F1-Scores = 0.4890760109305224 Negativity = [0.21131843890030705, 0.17303659323552995] Entropy = [3.227302489463834e-15, 2.440489432381992e-15]
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# K-Fold #0
# Mean negativities for all classes: [0.18377693608602996]
# Mean entropies for all classes: [3.406973704872809e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.47      0.35      0.40        20
#          1.0       0.48      0.60      0.53        20
#
#     accuracy                           0.48        40
#    macro avg       0.47      0.47      0.47        40
# weighted avg       0.47      0.47      0.47        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# K-Fold #1
# Mean negativities for all classes: [0.21774991331074872]
# Mean entropies for all classes: [4.601517613831829e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.53      0.40      0.46        20
#          1.0       0.52      0.65      0.58        20
#
#     accuracy                           0.53        40
#    macro avg       0.53      0.53      0.52        40
# weighted avg       0.53      0.53      0.52        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# K-Fold #2
# Mean negativities for all classes: [0.2266018988695701]
# Mean entropies for all classes: [5.269788641640425e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.56      0.50      0.53        20
#          1.0       0.55      0.60      0.57        20
#
#     accuracy                           0.55        40
#    macro avg       0.55      0.55      0.55        40
# weighted avg       0.55      0.55      0.55        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# K-Fold #3
# Mean negativities for all classes: [0.1966666430272967]
# Mean entropies for all classes: [4.300979561635433e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.50      0.50        20
#          1.0       0.50      0.50      0.50        20
#
#     accuracy                           0.50        40
#    macro avg       0.50      0.50      0.50        40
# weighted avg       0.50      0.50      0.50        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# K-Fold #4
# Mean negativities for all classes: [0.18411397864829424]
# Mean entropies for all classes: [1.8014931894790676e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.30      0.37        20
#          1.0       0.50      0.70      0.58        20
#
#     accuracy                           0.50        40
#    macro avg       0.50      0.50      0.48        40
# weighted avg       0.50      0.50      0.48        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# K-Fold #5
# Mean negativities for all classes: [0.2535580681479287]
# Mean entropies for all classes: [3.1468626405845605e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.48      0.50      0.49        20
#          1.0       0.47      0.45      0.46        20
#
#     accuracy                           0.48        40
#    macro avg       0.47      0.47      0.47        40
# weighted avg       0.47      0.47      0.47        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# K-Fold #6
# Mean negativities for all classes: [0.21292645782448255]
# Mean entropies for all classes: [3.9043268381781966e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.25      0.33        20
#          1.0       0.50      0.75      0.60        20
#
#     accuracy                           0.50        40
#    macro avg       0.50      0.50      0.47        40
# weighted avg       0.50      0.50      0.47        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# K-Fold #7
# Mean negativities for all classes: [0.17147137590040953]
# Mean entropies for all classes: [1.5762007223541956e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.40      0.44        20
#          1.0       0.50      0.60      0.55        20
#
#     accuracy                           0.50        40
#    macro avg       0.50      0.50      0.49        40
# weighted avg       0.50      0.50      0.49        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# K-Fold #8
# Mean negativities for all classes: [0.2528158881428948]
# Mean entropies for all classes: [6.737913632504881e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.42      0.25      0.31        20
#          1.0       0.46      0.65      0.54        20
#
#     accuracy                           0.45        40
#    macro avg       0.44      0.45      0.43        40
# weighted avg       0.44      0.45      0.43        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# K-Fold #9
# Mean negativities for all classes: [0.1625251083796698]
# Mean entropies for all classes: [2.506830061164954e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.46      0.65      0.54        20
#          1.0       0.42      0.25      0.31        20
#
#     accuracy                           0.45        40
#    macro avg       0.44      0.45      0.43        40
# weighted avg       0.44      0.45      0.43        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.49250000000000005 F1-Scores = 0.4802620329321227 Negativity = [0.18377693608602996, 0.21774991331074872] Entropy = [3.406973704872809e-15, 4.601517613831829e-15]
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# K-Fold #0
# Mean negativities for all classes: [0.1598062246750722]
# Mean entropies for all classes: [6.372266272487623e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.56      0.75      0.64        20
#          1.0       0.62      0.40      0.48        20
#
#     accuracy                           0.57        40
#    macro avg       0.59      0.57      0.56        40
# weighted avg       0.59      0.57      0.56        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# K-Fold #1
# Mean negativities for all classes: [0.1414519085887008]
# Mean entropies for all classes: [2.8615477295653626e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.45      0.47        20
#          1.0       0.50      0.55      0.52        20
#
#     accuracy                           0.50        40
#    macro avg       0.50      0.50      0.50        40
# weighted avg       0.50      0.50      0.50        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# K-Fold #2
# Mean negativities for all classes: [0.18078933357585283]
# Mean entropies for all classes: [2.7046564752546477e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.46      0.30      0.36        20
#          1.0       0.48      0.65      0.55        20
#
#     accuracy                           0.48        40
#    macro avg       0.47      0.47      0.46        40
# weighted avg       0.47      0.47      0.46        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# K-Fold #3
# Mean negativities for all classes: [0.22707642558500182]
# Mean entropies for all classes: [2.3575083064770874e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.65      0.57        20
#          1.0       0.50      0.35      0.41        20
#
#     accuracy                           0.50        40
#    macro avg       0.50      0.50      0.49        40
# weighted avg       0.50      0.50      0.49        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# K-Fold #4
# Mean negativities for all classes: [0.1688760714813872]
# Mean entropies for all classes: [4.613725246482426e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.38      0.30      0.33        20
#          1.0       0.42      0.50      0.45        20
#
#     accuracy                           0.40        40
#    macro avg       0.40      0.40      0.39        40
# weighted avg       0.40      0.40      0.39        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# K-Fold #5
# Mean negativities for all classes: [0.21296430016046894]
# Mean entropies for all classes: [2.930518523942975e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.55      0.55      0.55        20
#          1.0       0.55      0.55      0.55        20
#
#     accuracy                           0.55        40
#    macro avg       0.55      0.55      0.55        40
# weighted avg       0.55      0.55      0.55        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# K-Fold #6
# Mean negativities for all classes: [0.19709993615207738]
# Mean entropies for all classes: [-2.5965442350023033e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.40      0.40      0.40        20
#          1.0       0.40      0.40      0.40        20
#
#     accuracy                           0.40        40
#    macro avg       0.40      0.40      0.40        40
# weighted avg       0.40      0.40      0.40        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# K-Fold #7
# Mean negativities for all classes: [0.21594389854217608]
# Mean entropies for all classes: [1.9585867613266825e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.57      0.60      0.59        20
#          1.0       0.58      0.55      0.56        20
#
#     accuracy                           0.57        40
#    macro avg       0.58      0.57      0.57        40
# weighted avg       0.58      0.57      0.57        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# K-Fold #8
# Mean negativities for all classes: [0.18476862336890093]
# Mean entropies for all classes: [2.3613681960011697e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.46      0.30      0.36        20
#          1.0       0.48      0.65      0.55        20
#
#     accuracy                           0.48        40
#    macro avg       0.47      0.47      0.46        40
# weighted avg       0.47      0.47      0.46        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# K-Fold #9
# Mean negativities for all classes: [0.28051223003164777]
# Mean entropies for all classes: [-8.71577272634863e-16]
#               precision    recall  f1-score   support
#
#          0.0       0.47      0.45      0.46        20
#          1.0       0.48      0.50      0.49        20
#
#     accuracy                           0.48        40
#    macro avg       0.47      0.47      0.47        40
# weighted avg       0.47      0.47      0.47        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.4924999999999999 F1-Scores = 0.48589842199673566 Negativity = [0.1598062246750722, 0.1414519085887008] Entropy = [6.372266272487623e-15, 2.8615477295653626e-15]
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# K-Fold #0
# Mean negativities for all classes: [0.17053670665333592]
# Mean entropies for all classes: [1.354970944655552e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.52      0.55      0.54        20
#          1.0       0.53      0.50      0.51        20
#
#     accuracy                           0.53        40
#    macro avg       0.53      0.53      0.52        40
# weighted avg       0.53      0.53      0.52        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# K-Fold #1
# Mean negativities for all classes: [0.1741152073618228]
# Mean entropies for all classes: [2.5861090222031275e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.45      0.47        20
#          1.0       0.50      0.55      0.52        20
#
#     accuracy                           0.50        40
#    macro avg       0.50      0.50      0.50        40
# weighted avg       0.50      0.50      0.50        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# K-Fold #2
# Mean negativities for all classes: [0.1832966843410631]
# Mean entropies for all classes: [3.199815160179346e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.55      0.52        20
#          1.0       0.50      0.45      0.47        20
#
#     accuracy                           0.50        40
#    macro avg       0.50      0.50      0.50        40
# weighted avg       0.50      0.50      0.50        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# K-Fold #3
# Mean negativities for all classes: [0.1883091709491141]
# Mean entropies for all classes: [6.601029287731605e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.38      0.25      0.30        20
#          1.0       0.44      0.60      0.51        20
#
#     accuracy                           0.42        40
#    macro avg       0.41      0.42      0.41        40
# weighted avg       0.41      0.42      0.41        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# K-Fold #4
# Mean negativities for all classes: [0.23271556153594325]
# Mean entropies for all classes: [2.074331865889788e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.52      0.55      0.54        20
#          1.0       0.53      0.50      0.51        20
#
#     accuracy                           0.53        40
#    macro avg       0.53      0.53      0.52        40
# weighted avg       0.53      0.53      0.52        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# K-Fold #5
# Mean negativities for all classes: [0.2027353146873828]
# Mean entropies for all classes: [2.2747180027253424e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.40      0.44        20
#          1.0       0.50      0.60      0.55        20
#
#     accuracy                           0.50        40
#    macro avg       0.50      0.50      0.49        40
# weighted avg       0.50      0.50      0.49        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# K-Fold #6
# Mean negativities for all classes: [0.15808109139435622]
# Mean entropies for all classes: [4.1153875491361165e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.56      0.50      0.53        20
#          1.0       0.55      0.60      0.57        20
#
#     accuracy                           0.55        40
#    macro avg       0.55      0.55      0.55        40
# weighted avg       0.55      0.55      0.55        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# K-Fold #7
# Mean negativities for all classes: [0.12862901035418622]
# Mean entropies for all classes: [6.839340209171127e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.61      0.55      0.58        20
#          1.0       0.59      0.65      0.62        20
#
#     accuracy                           0.60        40
#    macro avg       0.60      0.60      0.60        40
# weighted avg       0.60      0.60      0.60        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# K-Fold #8
# Mean negativities for all classes: [0.31930191545052733]
# Mean entropies for all classes: [3.4155693314199975e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.45      0.50      0.48        20
#          1.0       0.44      0.40      0.42        20
#
#     accuracy                           0.45        40
#    macro avg       0.45      0.45      0.45        40
# weighted avg       0.45      0.45      0.45        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# K-Fold #9
# Mean negativities for all classes: [0.2007456618598235]
# Mean entropies for all classes: [2.9732929366725734e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.52      0.60      0.56        20
#          1.0       0.53      0.45      0.49        20
#
#     accuracy                           0.53        40
#    macro avg       0.53      0.53      0.52        40
# weighted avg       0.53      0.53      0.52        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.51 F1-Scores = 0.5067487647166107 Negativity = [0.17053670665333592, 0.1741152073618228] Entropy = [1.354970944655552e-15, 2.5861090222031275e-15]
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# K-Fold #0
# Mean negativities for all classes: [0.15142096139609043]
# Mean entropies for all classes: [4.9027796530165706e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.54      0.65      0.59        20
#          1.0       0.56      0.45      0.50        20
#
#     accuracy                           0.55        40
#    macro avg       0.55      0.55      0.55        40
# weighted avg       0.55      0.55      0.55        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# K-Fold #1
# Mean negativities for all classes: [0.21977720134177892]
# Mean entropies for all classes: [6.210974004172667e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.44      0.35      0.39        20
#          1.0       0.46      0.55      0.50        20
#
#     accuracy                           0.45        40
#    macro avg       0.45      0.45      0.44        40
# weighted avg       0.45      0.45      0.44        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# K-Fold #2
# Mean negativities for all classes: [0.16272457839311483]
# Mean entropies for all classes: [2.1898052698309767e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.56      0.45      0.50        20
#          1.0       0.54      0.65      0.59        20
#
#     accuracy                           0.55        40
#    macro avg       0.55      0.55      0.55        40
# weighted avg       0.55      0.55      0.55        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# K-Fold #3
# Mean negativities for all classes: [0.20325112325001057]
# Mean entropies for all classes: [2.6913178100167216e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.46      0.65      0.54        20
#          1.0       0.42      0.25      0.31        20
#
#     accuracy                           0.45        40
#    macro avg       0.44      0.45      0.43        40
# weighted avg       0.44      0.45      0.43        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# K-Fold #4
# Mean negativities for all classes: [0.11174309185085893]
# Mean entropies for all classes: [4.064915708491521e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.47      0.70      0.56        20
#          1.0       0.40      0.20      0.27        20
#
#     accuracy                           0.45        40
#    macro avg       0.43      0.45      0.41        40
# weighted avg       0.43      0.45      0.41        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# K-Fold #5
# Mean negativities for all classes: [0.132141676190278]
# Mean entropies for all classes: [1.0178367263549078e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.38      0.30      0.33        20
#          1.0       0.42      0.50      0.45        20
#
#     accuracy                           0.40        40
#    macro avg       0.40      0.40      0.39        40
# weighted avg       0.40      0.40      0.39        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# K-Fold #6
# Mean negativities for all classes: [0.25397880937530193]
# Mean entropies for all classes: [4.290344064971791e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.42      0.50      0.45        20
#          1.0       0.38      0.30      0.33        20
#
#     accuracy                           0.40        40
#    macro avg       0.40      0.40      0.39        40
# weighted avg       0.40      0.40      0.39        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# K-Fold #7
# Mean negativities for all classes: [0.21220581828520002]
# Mean entropies for all classes: [5.750194173085626e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.41      0.35      0.38        20
#          1.0       0.43      0.50      0.47        20
#
#     accuracy                           0.42        40
#    macro avg       0.42      0.42      0.42        40
# weighted avg       0.42      0.42      0.42        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# K-Fold #8
# Mean negativities for all classes: [0.21403301265090705]
# Mean entropies for all classes: [2.706761932437407e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.45      0.47        20
#          1.0       0.50      0.55      0.52        20
#
#     accuracy                           0.50        40
#    macro avg       0.50      0.50      0.50        40
# weighted avg       0.50      0.50      0.50        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# K-Fold #9
# Mean negativities for all classes: [0.27024052299374046]
# Mean entropies for all classes: [2.7386469264536464e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.58      0.35      0.44        20
#          1.0       0.54      0.75      0.63        20
#
#     accuracy                           0.55        40
#    macro avg       0.56      0.55      0.53        40
# weighted avg       0.56      0.55      0.53        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.4725 F1-Scores = 0.4615393185790982 Negativity = [0.15142096139609043, 0.21977720134177892] Entropy = [4.9027796530165706e-15, 6.210974004172667e-15]
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# K-Fold #0
# Mean negativities for all classes: [0.169649989029344]
# Mean entropies for all classes: [2.0022866265145694e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.45      0.47        20
#          1.0       0.50      0.55      0.52        20
#
#     accuracy                           0.50        40
#    macro avg       0.50      0.50      0.50        40
# weighted avg       0.50      0.50      0.50        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# K-Fold #1
# Mean negativities for all classes: [0.1872684154849953]
# Mean entropies for all classes: [3.860586399994412e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.54      0.35      0.42        20
#          1.0       0.52      0.70      0.60        20
#
#     accuracy                           0.53        40
#    macro avg       0.53      0.52      0.51        40
# weighted avg       0.53      0.53      0.51        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# K-Fold #2
# Mean negativities for all classes: [0.22641536413189742]
# Mean entropies for all classes: [3.895758050269846e-16]
#               precision    recall  f1-score   support
#
#          0.0       0.55      0.60      0.57        20
#          1.0       0.56      0.50      0.53        20
#
#     accuracy                           0.55        40
#    macro avg       0.55      0.55      0.55        40
# weighted avg       0.55      0.55      0.55        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# K-Fold #3
# Mean negativities for all classes: [0.20204272674559332]
# Mean entropies for all classes: [3.842802331360714e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.52      0.65      0.58        20
#          1.0       0.53      0.40      0.46        20
#
#     accuracy                           0.53        40
#    macro avg       0.53      0.53      0.52        40
# weighted avg       0.53      0.53      0.52        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# K-Fold #4
# Mean negativities for all classes: [0.2690054511246164]
# Mean entropies for all classes: [1.861793142880066e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.62      0.40      0.48        20
#          1.0       0.56      0.75      0.64        20
#
#     accuracy                           0.57        40
#    macro avg       0.59      0.57      0.56        40
# weighted avg       0.59      0.57      0.56        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# K-Fold #5
# Mean negativities for all classes: [0.21302853407650577]
# Mean entropies for all classes: [2.811555366142111e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.54      0.35      0.42        20
#          1.0       0.52      0.70      0.60        20
#
#     accuracy                           0.53        40
#    macro avg       0.53      0.52      0.51        40
# weighted avg       0.53      0.53      0.51        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# K-Fold #6
# Mean negativities for all classes: [0.1796630099542773]
# Mean entropies for all classes: [3.2869770685281506e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.36      0.20      0.26        20
#          1.0       0.45      0.65      0.53        20
#
#     accuracy                           0.42        40
#    macro avg       0.41      0.43      0.39        40
# weighted avg       0.41      0.42      0.39        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# K-Fold #7
# Mean negativities for all classes: [0.15435821525706928]
# Mean entropies for all classes: [2.5621420193441065e-16]
#               precision    recall  f1-score   support
#
#          0.0       0.56      0.50      0.53        20
#          1.0       0.55      0.60      0.57        20
#
#     accuracy                           0.55        40
#    macro avg       0.55      0.55      0.55        40
# weighted avg       0.55      0.55      0.55        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# K-Fold #8
# Mean negativities for all classes: [0.1512192727742317]
# Mean entropies for all classes: [2.435847566627394e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.43      0.60      0.50        20
#          1.0       0.33      0.20      0.25        20
#
#     accuracy                           0.40        40
#    macro avg       0.38      0.40      0.38        40
# weighted avg       0.38      0.40      0.38        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# K-Fold #9
# Mean negativities for all classes: [0.29802979313614886]
# Mean entropies for all classes: [1.0303954836757928e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.42      0.40      0.41        20
#          1.0       0.43      0.45      0.44        20
#
#     accuracy                           0.42        40
#    macro avg       0.42      0.43      0.42        40
# weighted avg       0.42      0.42      0.42        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.5000000000000001 F1-Scores = 0.48894906099820884 Negativity = [0.169649989029344, 0.1872684154849953] Entropy = [2.0022866265145694e-15, 3.860586399994412e-15]
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# K-Fold #0
# Mean negativities for all classes: [0.2060548040160623]
# Mean entropies for all classes: [3.487252589892611e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.53      0.45      0.49        20
#          1.0       0.52      0.60      0.56        20
#
#     accuracy                           0.53        40
#    macro avg       0.53      0.53      0.52        40
# weighted avg       0.53      0.53      0.52        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# K-Fold #1
# Mean negativities for all classes: [0.17386194730469756]
# Mean entropies for all classes: [1.935016116981963e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.67      0.30      0.41        20
#          1.0       0.55      0.85      0.67        20
#
#     accuracy                           0.57        40
#    macro avg       0.61      0.57      0.54        40
# weighted avg       0.61      0.57      0.54        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# K-Fold #2
# Mean negativities for all classes: [0.16639266390909896]
# Mean entropies for all classes: [5.624526758621639e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.54      0.65      0.59        20
#          1.0       0.56      0.45      0.50        20
#
#     accuracy                           0.55        40
#    macro avg       0.55      0.55      0.55        40
# weighted avg       0.55      0.55      0.55        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# K-Fold #3
# Mean negativities for all classes: [0.16818229964131018]
# Mean entropies for all classes: [1.542139039826664e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.48      0.70      0.57        20
#          1.0       0.45      0.25      0.32        20
#
#     accuracy                           0.48        40
#    macro avg       0.47      0.47      0.45        40
# weighted avg       0.47      0.47      0.45        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# K-Fold #4
# Mean negativities for all classes: [0.07173023531712619]
# Mean entropies for all classes: [5.662684391436025e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.46      0.30      0.36        20
#          1.0       0.48      0.65      0.55        20
#
#     accuracy                           0.48        40
#    macro avg       0.47      0.47      0.46        40
# weighted avg       0.47      0.47      0.46        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# K-Fold #5
# Mean negativities for all classes: [0.24081293317042393]
# Mean entropies for all classes: [4.393217294068604e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.52      0.55      0.54        20
#          1.0       0.53      0.50      0.51        20
#
#     accuracy                           0.53        40
#    macro avg       0.53      0.53      0.52        40
# ...
# Mean negativities for all classes: [0.21737861774103315]
# Mean entropies for all classes: [3.1392603817968764e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.53      0.50      0.51        20
#          1.0       0.52      0.55      0.54        20
#
#     accuracy                           0.53        40
#    macro avg       0.53      0.53      0.52        40
# weighted avg       0.53      0.53      0.52        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# K-Fold #2
# Mean negativities for all classes: [0.1840812944693891]
# Mean entropies for all classes: [2.2822980441048184e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.36      0.20      0.26        20
#          1.0       0.45      0.65      0.53        20
#
#     accuracy                           0.42        40
#    macro avg       0.41      0.43      0.39        40
# weighted avg       0.41      0.42      0.39        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# K-Fold #3
# Mean negativities for all classes: [0.1729488093197638]
# Mean entropies for all classes: [4.683246500725386e-16]
#               precision    recall  f1-score   support
#
#          0.0       0.35      0.30      0.32        20
#          1.0       0.39      0.45      0.42        20
#
#     accuracy                           0.38        40
#    macro avg       0.37      0.38      0.37        40
# weighted avg       0.37      0.38      0.37        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# K-Fold #4
# Mean negativities for all classes: [0.1848857209599615]
# Mean entropies for all classes: [9.610145529690068e-16]
#               precision    recall  f1-score   support
#
#          0.0       0.52      0.55      0.54        20
#          1.0       0.53      0.50      0.51        20
#
#     accuracy                           0.53        40
#    macro avg       0.53      0.53      0.52        40
# weighted avg       0.53      0.53      0.52        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# K-Fold #5
# Mean negativities for all classes: [0.1428319388882441]
# Mean entropies for all classes: [5.223525912967562e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.55      0.60      0.57        20
#          1.0       0.56      0.50      0.53        20
#
#     accuracy                           0.55        40
#    macro avg       0.55      0.55      0.55        40
# weighted avg       0.55      0.55      0.55        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# K-Fold #6
# Mean negativities for all classes: [0.13528922789660708]
# Mean entropies for all classes: [8.122283988591937e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.42      0.40      0.41        20
#          1.0       0.43      0.45      0.44        20
#
#     accuracy                           0.42        40
#    macro avg       0.42      0.43      0.42        40
# weighted avg       0.42      0.42      0.42        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# K-Fold #7
# Mean negativities for all classes: [0.15874352809356748]
# Mean entropies for all classes: [1.090297523316937e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.44      0.40      0.42        20
#          1.0       0.45      0.50      0.48        20
#
#     accuracy                           0.45        40
#    macro avg       0.45      0.45      0.45        40
# weighted avg       0.45      0.45      0.45        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# K-Fold #8
# Mean negativities for all classes: [0.22873933107552222]
# Mean entropies for all classes: [2.5606655795134135e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.35      0.30      0.32        20
#          1.0       0.39      0.45      0.42        20
#
#     accuracy                           0.38        40
#    macro avg       0.37      0.38      0.37        40
# weighted avg       0.37      0.38      0.37        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# K-Fold #9
# Mean negativities for all classes: [0.17881510614201454]
# Mean entropies for all classes: [3.36722529796346e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.40      0.20      0.27        20
#          1.0       0.47      0.70      0.56        20
#
#     accuracy                           0.45        40
#    macro avg       0.43      0.45      0.41        40
# weighted avg       0.43      0.45      0.41        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.4600000000000001 F1-Scores = 0.45106317511874616 Negativity = [0.2124130753954359, 0.21737861774103315] Entropy = [2.951069198376712e-15, 3.1392603817968764e-15]
# CPU times: total: 8min 26s
# Wall time: 7h 32min 26s
# Media Score dos N K-Fold 0.4866250000000001
# Maior Score dos K-Fold 0.51
# Menor Score dos K-Fold 0.4600000000000001
#
#
# CPU times: total: 8min 26s
# Wall time: 7h 32min 27s

# %%
normalize_axis = 1
load_inputvector_env_state = True

# %%
# %%time
# %run Experimento-Artificial-Linear-Sep-20-10-Fold.ipynb
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# K-Fold #0
# Mean negativities for all classes: [0.29168063736542416]
# Mean entropies for all classes: [-6.681608387085702e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.52      0.80      0.63        20
#          1.0       0.56      0.25      0.34        20
#
#     accuracy                           0.53        40
#    macro avg       0.54      0.53      0.49        40
# weighted avg       0.54      0.53      0.49        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# K-Fold #1
# Mean negativities for all classes: [0.169267979722253]
# Mean entropies for all classes: [8.296834867585575e-16]
#               precision    recall  f1-score   support
#
#          0.0       0.52      0.70      0.60        20
#          1.0       0.54      0.35      0.42        20
#
#     accuracy                           0.53        40
#    macro avg       0.53      0.52      0.51        40
# weighted avg       0.53      0.53      0.51        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# K-Fold #2
# Mean negativities for all classes: [0.18576487675050113]
# Mean entropies for all classes: [1.5246020707982548e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.11      0.05      0.07        20
#          1.0       0.39      0.60      0.47        20
#
#     accuracy                           0.33        40
#    macro avg       0.25      0.33      0.27        40
# weighted avg       0.25      0.33      0.27        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# K-Fold #3
# Mean negativities for all classes: [0.23938136780227776]
# Mean entropies for all classes: [3.0833548483387834e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.43      0.60      0.50        20
#          1.0       0.33      0.20      0.25        20
#
#     accuracy                           0.40        40
#    macro avg       0.38      0.40      0.38        40
# weighted avg       0.38      0.40      0.38        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# K-Fold #4
# Mean negativities for all classes: [0.2241677630093703]
# Mean entropies for all classes: [-5.3938028278550995e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.35      0.35      0.35        20
#          1.0       0.35      0.35      0.35        20
#
#     accuracy                           0.35        40
#    macro avg       0.35      0.35      0.35        40
# weighted avg       0.35      0.35      0.35        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# K-Fold #5
# Mean negativities for all classes: [0.3187306130351905]
# Mean entropies for all classes: [-4.777227305281834e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.65      0.57        20
#          1.0       0.50      0.35      0.41        20
#
#     accuracy                           0.50        40
#    macro avg       0.50      0.50      0.49        40
# weighted avg       0.50      0.50      0.49        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# K-Fold #6
# Mean negativities for all classes: [0.17101533885156125]
# Mean entropies for all classes: [-1.9107918855326484e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.46      0.60      0.52        20
#          1.0       0.43      0.30      0.35        20
#
#     accuracy                           0.45        40
#    macro avg       0.45      0.45      0.44        40
# weighted avg       0.45      0.45      0.44        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# K-Fold #7
# Mean negativities for all classes: [0.22388982146419156]
# Mean entropies for all classes: [-1.1190620252170083e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.38      0.30      0.33        20
#          1.0       0.42      0.50      0.45        20
#
#     accuracy                           0.40        40
#    macro avg       0.40      0.40      0.39        40
# weighted avg       0.40      0.40      0.39        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# K-Fold #8
# Mean negativities for all classes: [0.34876125758680915]
# Mean entropies for all classes: [-3.2038866292210424e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.43      0.65      0.52        20
#          1.0       0.30      0.15      0.20        20
#
#     accuracy                           0.40        40
#    macro avg       0.37      0.40      0.36        40
# weighted avg       0.37      0.40      0.36        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# K-Fold #9
# Mean negativities for all classes: [0.3606526813469828]
# Mean entropies for all classes: [-5.147134834085978e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.90      0.64        20
#          1.0       0.50      0.10      0.17        20
#
#     accuracy                           0.50        40
#    macro avg       0.50      0.50      0.40        40
# weighted avg       0.50      0.50      0.40        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.4375 F1-Scores = 0.4075442212861353 Negativity = [0.29168063736542416, 0.169267979722253] Entropy = [-6.681608387085702e-15, 8.296834867585575e-16]
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.2min finished
# K-Fold #0
# Mean negativities for all classes: [0.23034872648581156]
# Mean entropies for all classes: [4.858494734050713e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.33      0.25      0.29        20
#          1.0       0.40      0.50      0.44        20
#
#     accuracy                           0.38        40
#    macro avg       0.37      0.38      0.37        40
# weighted avg       0.37      0.38      0.37        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# K-Fold #1
# Mean negativities for all classes: [0.23092218721444363]
# Mean entropies for all classes: [-2.3477732078236323e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.65      0.57        20
#          1.0       0.50      0.35      0.41        20
#
#     accuracy                           0.50        40
#    macro avg       0.50      0.50      0.49        40
# weighted avg       0.50      0.50      0.49        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# K-Fold #2
# Mean negativities for all classes: [0.22993284164669867]
# Mean entropies for all classes: [6.299349641010076e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.44      0.55      0.49        20
#          1.0       0.40      0.30      0.34        20
#
#     accuracy                           0.42        40
#    macro avg       0.42      0.43      0.42        40
# weighted avg       0.42      0.42      0.42        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# K-Fold #3
# Mean negativities for all classes: [0.11973561811029339]
# Mean entropies for all classes: [2.1393519502145387e-16]
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.65      0.57        20
#          1.0       0.50      0.35      0.41        20
#
#     accuracy                           0.50        40
#    macro avg       0.50      0.50      0.49        40
# weighted avg       0.50      0.50      0.49        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# K-Fold #4
# Mean negativities for all classes: [0.3096888129220181]
# Mean entropies for all classes: [3.520165084007034e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.75      0.60        20
#          1.0       0.50      0.25      0.33        20
#
#     accuracy                           0.50        40
#    macro avg       0.50      0.50      0.47        40
# weighted avg       0.50      0.50      0.47        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# K-Fold #5
# Mean negativities for all classes: [0.20746464065157683]
# Mean entropies for all classes: [4.279734387854346e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.70      0.58        20
#          1.0       0.50      0.30      0.37        20
#
#     accuracy                           0.50        40
#    macro avg       0.50      0.50      0.48        40
# weighted avg       0.50      0.50      0.48        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# K-Fold #6
# Mean negativities for all classes: [0.3200681778604503]
# Mean entropies for all classes: [-1.3818017513190684e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.75      0.60        20
#          1.0       0.50      0.25      0.33        20
#
#     accuracy                           0.50        40
#    macro avg       0.50      0.50      0.47        40
# weighted avg       0.50      0.50      0.47        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# K-Fold #7
# Mean negativities for all classes: [0.32413956129273985]
# Mean entropies for all classes: [-1.1867779604447552e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.39      0.55      0.46        20
#          1.0       0.25      0.15      0.19        20
#
#     accuracy                           0.35        40
#    macro avg       0.32      0.35      0.32        40
# weighted avg       0.32      0.35      0.32        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# K-Fold #8
# Mean negativities for all classes: [0.32071745379427846]
# Mean entropies for all classes: [1.6066023422102842e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.40      0.50      0.44        20
#          1.0       0.33      0.25      0.29        20
#
#     accuracy                           0.38        40
#    macro avg       0.37      0.38      0.37        40
# weighted avg       0.37      0.38      0.37        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# K-Fold #9
# Mean negativities for all classes: [0.3115162072369307]
# Mean entropies for all classes: [1.979065734182697e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.47      0.85      0.61        20
#          1.0       0.25      0.05      0.08        20
#
#     accuracy                           0.45        40
#    macro avg       0.36      0.45      0.35        40
# weighted avg       0.36      0.45      0.35        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.44750000000000006 F1-Scores = 0.42036686051232086 Negativity = [0.23034872648581156, 0.23092218721444363] Entropy = [4.858494734050713e-15, -2.3477732078236323e-15]
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# K-Fold #0
# Mean negativities for all classes: [0.3269096676198718]
# Mean entropies for all classes: [-2.94804572452504e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.70      0.58        20
#          1.0       0.50      0.30      0.37        20
#
#     accuracy                           0.50        40
#    macro avg       0.50      0.50      0.48        40
# weighted avg       0.50      0.50      0.48        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# K-Fold #1
# Mean negativities for all classes: [0.2783726977450563]
# Mean entropies for all classes: [-4.037355512802069e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.42      0.50      0.45        20
#          1.0       0.38      0.30      0.33        20
#
#     accuracy                           0.40        40
#    macro avg       0.40      0.40      0.39        40
# weighted avg       0.40      0.40      0.39        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# K-Fold #2
# Mean negativities for all classes: [0.2799741011132489]
# Mean entropies for all classes: [4.857715227541664e-17]
#               precision    recall  f1-score   support
#
#          0.0       0.30      0.35      0.33        20
#          1.0       0.24      0.20      0.22        20
#
#     accuracy                           0.28        40
#    macro avg       0.27      0.28      0.27        40
# weighted avg       0.27      0.28      0.27        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# K-Fold #3
# Mean negativities for all classes: [0.3338762851051331]
# Mean entropies for all classes: [-1.3753965110217529e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.46      0.55      0.50        20
#          1.0       0.44      0.35      0.39        20
#
#     accuracy                           0.45        40
#    macro avg       0.45      0.45      0.44        40
# weighted avg       0.45      0.45      0.44        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# K-Fold #4
# Mean negativities for all classes: [0.23299301586314275]
# Mean entropies for all classes: [-5.692728198092223e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.70      0.58        20
#          1.0       0.50      0.30      0.37        20
#
#     accuracy                           0.50        40
#    macro avg       0.50      0.50      0.48        40
# weighted avg       0.50      0.50      0.48        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# K-Fold #5
# Mean negativities for all classes: [0.2947196921324858]
# Mean entropies for all classes: [-1.977062756867669e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.47      0.70      0.56        20
#          1.0       0.40      0.20      0.27        20
#
#     accuracy                           0.45        40
#    macro avg       0.43      0.45      0.41        40
# weighted avg       0.43      0.45      0.41        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# K-Fold #6
# Mean negativities for all classes: [0.2594810866450373]
# Mean entropies for all classes: [1.1605816012744085e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.44      0.55      0.49        20
#          1.0       0.40      0.30      0.34        20
#
#     accuracy                           0.42        40
#    macro avg       0.42      0.43      0.42        40
# weighted avg       0.42      0.42      0.42        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# K-Fold #7
# Mean negativities for all classes: [0.2117671003658974]
# Mean entropies for all classes: [-2.089856028922187e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.70      0.58        20
#          1.0       0.50      0.30      0.37        20
#
#     accuracy                           0.50        40
#    macro avg       0.50      0.50      0.48        40
# weighted avg       0.50      0.50      0.48        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# K-Fold #8
# Mean negativities for all classes: [0.3132319386867415]
# Mean entropies for all classes: [2.976589431124578e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.70      0.58        20
#          1.0       0.50      0.30      0.37        20
#
#     accuracy                           0.50        40
#    macro avg       0.50      0.50      0.48        40
# weighted avg       0.50      0.50      0.48        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# K-Fold #9
# Mean negativities for all classes: [0.3238385267163735]
# Mean entropies for all classes: [-2.425091313719413e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.80      0.62        20
#          1.0       0.50      0.20      0.29        20
#
#     accuracy                           0.50        40
#    macro avg       0.50      0.50      0.45        40
# weighted avg       0.50      0.50      0.45        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.45 F1-Scores = 0.4305705110588831 Negativity = [0.3269096676198718, 0.2783726977450563] Entropy = [-2.94804572452504e-14, -4.037355512802069e-15]
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# K-Fold #0
# Mean negativities for all classes: [0.2535442798753437]
# Mean entropies for all classes: [2.87326778233164e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.46      0.60      0.52        20
#          1.0       0.43      0.30      0.35        20
#
#     accuracy                           0.45        40
#    macro avg       0.45      0.45      0.44        40
# weighted avg       0.45      0.45      0.44        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# K-Fold #1
# Mean negativities for all classes: [0.2497884037616552]
# Mean entropies for all classes: [2.775409589929522e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.47      0.85      0.61        20
#          1.0       0.25      0.05      0.08        20
#
#     accuracy                           0.45        40
#    macro avg       0.36      0.45      0.35        40
# weighted avg       0.36      0.45      0.35        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# K-Fold #2
# Mean negativities for all classes: [0.3187530121443821]
# Mean entropies for all classes: [2.9798763715658133e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.43      0.60      0.50        20
#          1.0       0.33      0.20      0.25        20
#
#     accuracy                           0.40        40
#    macro avg       0.38      0.40      0.38        40
# weighted avg       0.38      0.40      0.38        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# K-Fold #3
# Mean negativities for all classes: [0.23536698353164417]
# Mean entropies for all classes: [1.594943833209689e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.52      0.75      0.61        20
#          1.0       0.55      0.30      0.39        20
#
#     accuracy                           0.53        40
#    macro avg       0.53      0.53      0.50        40
# weighted avg       0.53      0.53      0.50        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# K-Fold #4
# Mean negativities for all classes: [0.33099680377199664]
# Mean entropies for all classes: [1.6400991199498628e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.46      0.55      0.50        20
#          1.0       0.44      0.35      0.39        20
#
#     accuracy                           0.45        40
#    macro avg       0.45      0.45      0.44        40
# weighted avg       0.45      0.45      0.44        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# K-Fold #5
# Mean negativities for all classes: [0.22319225775255144]
# Mean entropies for all classes: [-1.2238600201476407e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.44      0.40      0.42        20
#          1.0       0.45      0.50      0.48        20
#
#     accuracy                           0.45        40
#    macro avg       0.45      0.45      0.45        40
# weighted avg       0.45      0.45      0.45        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# K-Fold #6
# Mean negativities for all classes: [0.31378988903157534]
# Mean entropies for all classes: [-1.4237870665282547e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.44      0.40      0.42        20
#          1.0       0.45      0.50      0.48        20
#
#     accuracy                           0.45        40
#    macro avg       0.45      0.45      0.45        40
# weighted avg       0.45      0.45      0.45        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# K-Fold #7
# Mean negativities for all classes: [0.31216593871704934]
# Mean entropies for all classes: [-8.565384531449842e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.52      0.70      0.60        20
#          1.0       0.54      0.35      0.42        20
#
#     accuracy                           0.53        40
#    macro avg       0.53      0.52      0.51        40
# weighted avg       0.53      0.53      0.51        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# K-Fold #8
# Mean negativities for all classes: [0.31026410957313905]
# Mean entropies for all classes: [2.889345446775758e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.52      0.85      0.64        20
#          1.0       0.57      0.20      0.30        20
#
#     accuracy                           0.53        40
#    macro avg       0.54      0.53      0.47        40
# weighted avg       0.54      0.53      0.47        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# K-Fold #9
# Mean negativities for all classes: [0.3208759935410369]
# Mean entropies for all classes: [1.5051004171438763e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.42      0.55      0.48        20
#          1.0       0.36      0.25      0.29        20
#
#     accuracy                           0.40        40
#    macro avg       0.39      0.40      0.39        40
# weighted avg       0.39      0.40      0.39        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.4625000000000001 F1-Scores = 0.436402231296906 Negativity = [0.2535442798753437, 0.2497884037616552] Entropy = [2.87326778233164e-14, 2.775409589929522e-15]
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# K-Fold #0
# Mean negativities for all classes: [0.3009881737784131]
# Mean entropies for all classes: [7.018683419558154e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.47      0.85      0.61        20
#          1.0       0.25      0.05      0.08        20
#
#     accuracy                           0.45        40
#    macro avg       0.36      0.45      0.35        40
# weighted avg       0.36      0.45      0.35        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# K-Fold #1
# Mean negativities for all classes: [0.10521207337053984]
# Mean entropies for all classes: [5.575751255640936e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.22      0.10      0.14        20
#          1.0       0.42      0.65      0.51        20
#
#     accuracy                           0.38        40
#    macro avg       0.32      0.38      0.32        40
# weighted avg       0.32      0.38      0.32        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# K-Fold #2
# Mean negativities for all classes: [0.2669800440557685]
# Mean entropies for all classes: [-3.1486501569031908e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.44      0.60      0.51        20
#          1.0       0.38      0.25      0.30        20
#
#     accuracy                           0.42        40
#    macro avg       0.41      0.42      0.41        40
# weighted avg       0.41      0.42      0.41        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# K-Fold #3
# Mean negativities for all classes: [0.18413157105907146]
# Mean entropies for all classes: [-1.1256090702066335e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.48      0.60      0.53        20
#          1.0       0.47      0.35      0.40        20
#
#     accuracy                           0.48        40
#    macro avg       0.47      0.47      0.47        40
# weighted avg       0.47      0.47      0.47        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# K-Fold #4
# Mean negativities for all classes: [0.25734011835829607]
# Mean entropies for all classes: [-1.109711955512078e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.60      0.55        20
#          1.0       0.50      0.40      0.44        20
#
#     accuracy                           0.50        40
#    macro avg       0.50      0.50      0.49        40
# weighted avg       0.50      0.50      0.49        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# K-Fold #5
# Mean negativities for all classes: [0.16219152800479097]
# Mean entropies for all classes: [2.2233537694968494e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.33      0.30      0.32        20
#          1.0       0.36      0.40      0.38        20
#
#     accuracy                           0.35        40
#    macro avg       0.35      0.35      0.35        40
# weighted avg       0.35      0.35      0.35        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# K-Fold #6
# Mean negativities for all classes: [0.2478892691515658]
# Mean entropies for all classes: [-1.0991416941615896e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.48      0.55      0.51        20
#          1.0       0.47      0.40      0.43        20
#
#     accuracy                           0.48        40
#    macro avg       0.47      0.48      0.47        40
# weighted avg       0.47      0.47      0.47        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# K-Fold #7
# Mean negativities for all classes: [0.3605509886572339]
# Mean entropies for all classes: [-3.719689325107361e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.48      0.80      0.60        20
#          1.0       0.43      0.15      0.22        20
#
#     accuracy                           0.48        40
#    macro avg       0.46      0.48      0.41        40
# weighted avg       0.46      0.47      0.41        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# K-Fold #8
# Mean negativities for all classes: [0.2906344655723297]
# Mean entropies for all classes: [-4.038078456735061e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.41      0.55      0.47        20
#          1.0       0.31      0.20      0.24        20
#
#     accuracy                           0.38        40
#    macro avg       0.36      0.38      0.36        40
# weighted avg       0.36      0.38      0.36        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# K-Fold #9
# Mean negativities for all classes: [0.23626451939906978]
# Mean entropies for all classes: [-4.864062309611367e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.48      0.70      0.57        20
#          1.0       0.45      0.25      0.32        20
#
#     accuracy                           0.48        40
#    macro avg       0.47      0.47      0.45        40
# weighted avg       0.47      0.47      0.45        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.4374999999999999 F1-Scores = 0.4073214318616638 Negativity = [0.3009881737784131, 0.10521207337053984] Entropy = [7.018683419558154e-15, 5.575751255640936e-15]
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# K-Fold #0
# Mean negativities for all classes: [0.30928425906614]
# Mean entropies for all classes: [-4.7938748314772516e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.44      0.55      0.49        20
#          1.0       0.40      0.30      0.34        20
#
#     accuracy                           0.42        40
#    macro avg       0.42      0.43      0.42        40
# weighted avg       0.42      0.42      0.42        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# K-Fold #1
# Mean negativities for all classes: [0.13320673943479716]
# Mean entropies for all classes: [-9.110926330972707e-16]
#               precision    recall  f1-score   support
#
#          0.0       0.45      0.75      0.57        20
#          1.0       0.29      0.10      0.15        20
#
#     accuracy                           0.42        40
#    macro avg       0.37      0.42      0.36        40
# weighted avg       0.37      0.42      0.36        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# K-Fold #2
# Mean negativities for all classes: [0.2947968921054672]
# Mean entropies for all classes: [1.13787096575377e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.70      0.58        20
#          1.0       0.50      0.30      0.37        20
#
#     accuracy                           0.50        40
#    macro avg       0.50      0.50      0.48        40
# weighted avg       0.50      0.50      0.48        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# K-Fold #3
# Mean negativities for all classes: [0.28094928787237655]
# Mean entropies for all classes: [2.5026476992560858e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.38      0.25      0.30        20
#          1.0       0.44      0.60      0.51        20
#
#     accuracy                           0.42        40
#    macro avg       0.41      0.42      0.41        40
# weighted avg       0.41      0.42      0.41        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# K-Fold #4
# Mean negativities for all classes: [0.21883444546984823]
# Mean entropies for all classes: [-1.5852380905618356e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.40      0.50      0.44        20
#          1.0       0.33      0.25      0.29        20
#
#     accuracy                           0.38        40
#    macro avg       0.37      0.38      0.37        40
# weighted avg       0.37      0.38      0.37        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# K-Fold #5
# Mean negativities for all classes: [0.3271529566176123]
# Mean entropies for all classes: [2.1162293769938327e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.80      0.62        20
#          1.0       0.50      0.20      0.29        20
#
#     accuracy                           0.50        40
#    macro avg       0.50      0.50      0.45        40
# weighted avg       0.50      0.50      0.45        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# K-Fold #6
# Mean negativities for all classes: [0.3266518252199221]
# Mean entropies for all classes: [1.2054361094378398e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.53      0.80      0.64        20
#          1.0       0.60      0.30      0.40        20
#
#     accuracy                           0.55        40
#    macro avg       0.57      0.55      0.52        40
# weighted avg       0.57      0.55      0.52        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# K-Fold #7
# Mean negativities for all classes: [0.35722448383295136]
# Mean entropies for all classes: [-5.954704797106e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.44      0.75      0.56        20
#          1.0       0.17      0.05      0.08        20
#
#     accuracy                           0.40        40
#    macro avg       0.30      0.40      0.32        40
# weighted avg       0.30      0.40      0.32        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# K-Fold #8
# Mean negativities for all classes: [0.2380861816266428]
# Mean entropies for all classes: [2.0912104637551807e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.43      0.60      0.50        20
#          1.0       0.33      0.20      0.25        20
#
#     accuracy                           0.40        40
#    macro avg       0.38      0.40      0.38        40
# weighted avg       0.38      0.40      0.38        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# K-Fold #9
# Mean negativities for all classes: [0.22450367987579628]
# Mean entropies for all classes: [3.5805744440143784e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.48      0.75      0.59        20
#          1.0       0.44      0.20      0.28        20
#
#     accuracy                           0.48        40
#    macro avg       0.46      0.47      0.43        40
# weighted avg       0.46      0.47      0.43        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.44749999999999995 F1-Scores = 0.41178837383993205 Negativity = [0.30928425906614, 0.13320673943479716] Entropy = [-4.7938748314772516e-15, -9.110926330972707e-16]
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# K-Fold #0
# Mean negativities for all classes: [0.14001699642315563]
# Mean entropies for all classes: [-1.825844594782702e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.46      0.65      0.54        20
#          1.0       0.42      0.25      0.31        20
#
#     accuracy                           0.45        40
#    macro avg       0.44      0.45      0.43        40
# weighted avg       0.44      0.45      0.43        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# K-Fold #1
# Mean negativities for all classes: [0.3362163737319291]
# Mean entropies for all classes: [2.202853919028378e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.48      0.70      0.57        20
#          1.0       0.45      0.25      0.32        20
#
#     accuracy                           0.48        40
#    macro avg       0.47      0.47      0.45        40
# weighted avg       0.47      0.47      0.45        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# K-Fold #2
# Mean negativities for all classes: [0.22038392897051579]
# Mean entropies for all classes: [-4.435790628585188e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.43      0.30      0.35        20
#          1.0       0.46      0.60      0.52        20
#
#     accuracy                           0.45        40
#    macro avg       0.45      0.45      0.44        40
# weighted avg       0.45      0.45      0.44        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# K-Fold #3
# Mean negativities for all classes: [0.17726692438968292]
# Mean entropies for all classes: [2.2273744713100276e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.46      0.65      0.54        20
#          1.0       0.42      0.25      0.31        20
#
#     accuracy                           0.45        40
#    macro avg       0.44      0.45      0.43        40
# weighted avg       0.44      0.45      0.43        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# K-Fold #4
# Mean negativities for all classes: [0.12075750641752492]
# Mean entropies for all classes: [-1.3564212737671617e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.48      0.65      0.55        20
#          1.0       0.46      0.30      0.36        20
#
#     accuracy                           0.48        40
#    macro avg       0.47      0.47      0.46        40
# weighted avg       0.47      0.47      0.46        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# K-Fold #5
# Mean negativities for all classes: [0.19316203733790369]
# Mean entropies for all classes: [2.3956360390221e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.46      0.65      0.54        20
#          1.0       0.42      0.25      0.31        20
#
#     accuracy                           0.45        40
# ...
# K-Fold #1
# Mean negativities for all classes: [0.13177991131002376]
# Mean entropies for all classes: [1.2924939577372309e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.47      0.70      0.56        20
#          1.0       0.40      0.20      0.27        20
#
#     accuracy                           0.45        40
#    macro avg       0.43      0.45      0.41        40
# weighted avg       0.43      0.45      0.41        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.4min finished
# K-Fold #2
# Mean negativities for all classes: [0.15680683423969857]
# Mean entropies for all classes: [-1.968098138126658e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.60      0.55        20
#          1.0       0.50      0.40      0.44        20
#
#     accuracy                           0.50        40
#    macro avg       0.50      0.50      0.49        40
# weighted avg       0.50      0.50      0.49        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# K-Fold #3
# Mean negativities for all classes: [0.26488401461353606]
# Mean entropies for all classes: [-1.9058031911813092e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.52      0.75      0.61        20
#          1.0       0.55      0.30      0.39        20
#
#     accuracy                           0.53        40
#    macro avg       0.53      0.53      0.50        40
# weighted avg       0.53      0.53      0.50        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# K-Fold #4
# Mean negativities for all classes: [0.1850920961551253]
# Mean entropies for all classes: [2.4585411531452088e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.45      0.65      0.53        20
#          1.0       0.36      0.20      0.26        20
#
#     accuracy                           0.42        40
#    macro avg       0.41      0.43      0.39        40
# weighted avg       0.41      0.42      0.39        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# K-Fold #5
# Mean negativities for all classes: [0.1247678268758293]
# Mean entropies for all classes: [4.028282500023557e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.39      0.35      0.37        20
#          1.0       0.41      0.45      0.43        20
#
#     accuracy                           0.40        40
#    macro avg       0.40      0.40      0.40        40
# weighted avg       0.40      0.40      0.40        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# K-Fold #6
# Mean negativities for all classes: [0.31775303090250595]
# Mean entropies for all classes: [1.5411372613367847e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.48      0.65      0.55        20
#          1.0       0.46      0.30      0.36        20
#
#     accuracy                           0.48        40
#    macro avg       0.47      0.47      0.46        40
# weighted avg       0.47      0.47      0.46        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# K-Fold #7
# Mean negativities for all classes: [0.3059873421448217]
# Mean entropies for all classes: [2.0120976634742406e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.90      0.64        20
#          1.0       0.50      0.10      0.17        20
#
#     accuracy                           0.50        40
#    macro avg       0.50      0.50      0.40        40
# weighted avg       0.50      0.50      0.40        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# K-Fold #8
# Mean negativities for all classes: [0.29041691495501476]
# Mean entropies for all classes: [7.244310225581694e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.48      0.65      0.55        20
#          1.0       0.46      0.30      0.36        20
#
#     accuracy                           0.48        40
#    macro avg       0.47      0.47      0.46        40
# weighted avg       0.47      0.47      0.46        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.3min finished
# K-Fold #9
# Mean negativities for all classes: [0.31496713475843]
# Mean entropies for all classes: [-4.8004260090039896e-14]
#               precision    recall  f1-score   support
#
#          0.0       0.43      0.60      0.50        20
#          1.0       0.33      0.20      0.25        20
#
#     accuracy                           0.40        40
#    macro avg       0.38      0.40      0.38        40
# weighted avg       0.38      0.40      0.38        40
#
# -------------------------------------------------------------------------------------------------------------------
# AVG: Scores = 0.45999999999999996 F1-Scores = 0.43244613765674983 Negativity = [0.26475053490228956, 0.13177991131002376] Entropy = [2.8290703366508987e-14, 1.2924939577372309e-15]
# CPU times: total: 8min 42s
# Wall time: 7h 47min 29s
# Media Score dos N K-Fold 0.45
# Maior Score dos K-Fold 0.48
# Menor Score dos K-Fold 0.41500000000000004
#
#
# [[0.525, 0.525, 0.325, 0.4, 0.35, 0.5, 0.45, 0.4, 0.4, 0.5], [0.375, 0.5, 0.425, 0.5, 0.5, 0.5, 0.5, 0.35, 0.375, 0.45], [0.5, 0.4, 0.275, 0.45, 0.5, 0.45, 0.425, 0.5, 0.5, 0.5], [0.45, 0.45, 0.4, 0.525, 0.45, 0.45, 0.45, 0.525, 0.525, 0.4], [0.45, 0.375, 0.425, 0.475, 0.5, 0.35, 0.475, 0.475, 0.375, 0.475], [0.425, 0.425, 0.5, 0.425, 0.375, 0.5, 0.55, 0.4, 0.4, 0.475], [0.45