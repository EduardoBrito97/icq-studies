# %%
normalize_axis = 0
load_inputvector_env_state = False
use_exponential_on_input = True

# %% [markdown]
# # Blobs

# %%
# %%time
# %run Experimento-Artificial-Blobs-20-10-Fold.ipynb
# Out:
# Intel(R) Extension for Scikit-learn* enabled (https://github.com/intel/scikit-learn-intelex)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
print("Media Negativity dos N K-Fold", np.mean([neg for neg in negativities_list]))

print()
print()
print(negativities_list)
# Out:
# Media Negativity dos N K-Fold 0.20632248320049185
#
#
# ...

# %% [markdown]
# # Circles

# %%
# %%time
# %run Experimento-Artificial-Circles-20-10-Fold.ipynb
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  1.9min finished
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %% [markdown]
# # Ellipses

# %%
# %%time
# %run Experimento-Artificial-Elipses-20-10-Fold.ipynb
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  1.8min finished
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %% [markdown]
# # Linear Sep

# %%
# %%time
# %run Experimento-Artificial-Linear-Sep-20-10-Fold.ipynb
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #0
# Mean negativities for all classes: [0.24545720518392403]
# Mean entropies for all classes: [3.317984813010364e-15]
#               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.98        20
#          1.0       1.00      0.95      0.97        20
#
#     accuracy                           0.97        40
#    macro avg       0.98      0.97      0.97        40
# weighted avg       0.98      0.97      0.97        40
#
# -------------------------------------------------------------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# K-Fold #1
# ...

# %% [markdown]
# # Moons

# %%
# %%time
# %run Experimento-Artificial-Moons-20-10-Fold.ipynb

# %% [markdown]
# # Stripes

# %%
# %%time
# %run Experimento-Artificial-Stripes-20-10-Fold.ipynb

# %% [markdown]
# # Xor

# %%
# %%time
# %run Experimento-Artificial-Xor-20-10-Fold.ipynb
