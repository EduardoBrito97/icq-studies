# %% [markdown]
# # Setting up

# %% [markdown]
# ## General setup

# %%
epoch_range = range(1, 1000, 100)

# %%
definitions_order = ["1-PCA", "2-PCA", "3-PCA", "4-PCA"]

# %% [markdown]
# ## Proposed method

# %%
one_pca_accuracy_proposed = [0.33333333333333337, 0.33333333333333337, 0.33333333333333337, 0.33333333333333337, 0.33333333333333337, 0.33333333333333337, 0.33333333333333337, 0.33333333333333337, 0.33333333333333337, 0.33333333333333337, 0.33333333333333337, 0.33333333333333337, 0.33333333333333337, 0.33333333333333337, 0.33333333333333337, 0.33333333333333337, 0.33333333333333337, 0.33333333333333337, 0.33333333333333337, 0.33333333333333337]
two_pca_accuracy_proposed = [0.4000000000000001, 0.5066666666666666, 0.4866666666666667, 0.4866666666666667, 0.4866666666666667, 0.4866666666666667, 0.4866666666666667, 0.4866666666666667, 0.48, 0.48, 0.48, 0.48, 0.48, 0.48, 0.48, 0.48, 0.48, 0.48, 0.48, 0.48]
three_pca_accuracy_proposed = [0.4000000000000001, 0.47333333333333333, 0.48, 0.48, 0.4866666666666667, 0.4666666666666667, 0.47333333333333333, 0.48, 0.4866666666666667, 0.49333333333333335, 0.5066666666666666, 0.5066666666666666, 0.49333333333333335, 0.5, 0.5066666666666666, 0.5066666666666666, 0.5066666666666666, 0.5066666666666666, 0.5066666666666666, 0.5133333333333333]
four_pca_accuracy_proposed = [0.4000000000000001, 0.47333333333333333, 0.48, 0.48, 0.4666666666666667, 0.4666666666666667, 0.4666666666666667, 0.48, 0.4866666666666667, 0.5, 0.5133333333333334, 0.49333333333333335, 0.49333333333333335, 0.4866666666666667, 0.4866666666666667, 0.5133333333333334, 0.5, 0.5, 0.49333333333333335, 0.49333333333333335]

# %%
one_pca_negativity_proposed_0 = [-1.0547118733938987e-16, -1.0547118733938987e-16, -1.0547118733938987e-16, -1.0547118733938987e-16, -1.0547118733938987e-16, -1.0547118733938987e-16, -1.0547118733938987e-16, -1.0547118733938987e-16, -1.0547118733938987e-16, -1.0547118733938987e-16, -1.0547118733938987e-16, -1.0547118733938987e-16, -1.0547118733938987e-16, -1.0547118733938987e-16, -1.0547118733938987e-16, -1.0547118733938987e-16, -1.0547118733938987e-16, -1.0547118733938987e-16, -1.0547118733938987e-16, -1.0547118733938987e-16]
one_pca_negativity_proposed_1 = [-1.1102230246251565e-16, -1.1102230246251565e-16, -1.1102230246251565e-16, -1.1102230246251565e-16, -1.1102230246251565e-16, -1.1102230246251565e-16, -1.1102230246251565e-16, -1.1102230246251565e-16, -1.1102230246251565e-16, -1.1102230246251565e-16, -1.1102230246251565e-16, -1.1102230246251565e-16, -1.1102230246251565e-16, -1.1102230246251565e-16, -1.1102230246251565e-16, -1.1102230246251565e-16, -1.1102230246251565e-16, -1.1102230246251565e-16, -1.1102230246251565e-16, -1.1102230246251565e-16]
one_pca_negativity_proposed_2 = [-5.551115123125783e-17, -5.551115123125783e-17, -5.551115123125783e-17, -5.551115123125783e-17, -5.551115123125783e-17, -5.551115123125783e-17, -5.551115123125783e-17, -5.551115123125783e-17, -5.551115123125783e-17, -5.551115123125783e-17, -5.551115123125783e-17, -5.551115123125783e-17, -5.551115123125783e-17, -5.551115123125783e-17, -5.551115123125783e-17, -5.551115123125783e-17, -5.551115123125783e-17, -5.551115123125783e-17, -5.551115123125783e-17, -5.551115123125783e-17]

two_pca_negativity_proposed_0 = [0.1150998430078154, 0.15901113561289598, 0.1477888841168003, 0.1477888841168003, 0.14745601395372446, 0.14745601395372446, 0.14745601395372446, 0.14745601395372446, 0.14712094263237402, 0.14712094263237402, 0.14712094263237402, 0.14712094263237402, 0.14712094263237402, 0.14712094263237402, 0.13744418405132103, 0.13744418405132103, 0.13744418405132103, 0.13744418405132103, 0.13744418405132103, 0.13744418405132103]
two_pca_negativity_proposed_1 = [0.01521653816781351, 0.11848980768812292, 0.11848980768812292, 0.11848980768812292, 0.11720488478513238, 0.11229449292527445, 0.1130781996444774, 0.1130781996444774, 0.11179764153396621, 0.11172466130363698, 0.11172466130363698, 0.11172466130363698, 0.11172466130363698, 0.11172466130363698, 0.11047972497804477, 0.11047972497804477, 0.11047972497804477, 0.11047972497804477, 0.10934838306063241, 0.10934838306063241]
two_pca_negativity_proposed_2 = [0.020225845595185803, 0.1603519706086305, 0.15894564336045636, 0.15894564336045636, 0.15894564336045636, 0.15894564336045636, 0.15894564336045636, 0.15894564336045636, 0.15894564336045636, 0.15894564336045636, 0.15894564336045636, 0.15894564336045636, 0.15894564336045636, 0.15894564336045636, 0.15894564336045636, 0.15894564336045636, 0.15894564336045636, 0.15894564336045636, 0.15894564336045636, 0.15894564336045
 0.6066666666666667, 0.6066666666666667, 0.6066666666666667, 0.6066666666666667, 0.6066666666666667, 0.6066666666666667, 0.6066666666666667, 0.6066666666666667, 0.6066666666666667, 0.6066666666666667, 0.6066666666666667, 0.6066666666666667, 0.6066666666666667, 0.6066666666666667, 0.6066666666666667, 0.6066666666666667, 0.6066666666666667, 0.6066666666666667, 0.6066666666666667]
two_pca_accuracy_original = [0.16, 0.7466666666666666, 0.76, 0.76, 0.76, 0.76, 0.76, 0.76, 0.76, 0.76, 0.76, 0.76, 0.76, 0.76, 0.76, 0.76, 0.76, 0.76, 0.76, 0.76]
three_pca_accuracy_original = [0.0, 0.76, 0.7133333333333333, 0.68, 0.6933333333333334, 0.68, 0.72, 0.7133333333333333, 0.7133333333333333, 0.72, 0.72, 0.7133333333333334, 0.7133333333333334, 0.7133333333333334, 0.7133333333333334, 0.7133333333333334, 0.7133333333333334, 0.7133333333333334, 0.7133333333333334, 0.7133333333333334]
four_pca_accuracy_original = [0.0, 0.7266666666666667, 0.6933333333333332, 0.6533333333333333, 0.6533333333333333, 0.6733333333333333, 0.6733333333333333, 0.7, 0.6933333333333334, 0.6933333333333334, 0.7, 0.7, 0.7, 0.7, 0.7, 0.7, 0.7, 0.7, 0.7, 0.7]

# %%
one_pca_negativity_original_0 = [-1.691239740845655e-16, -1.2101430968414207e-16, -1.2101430968414207e-16, -1.2101430968414207e-16, -1.2101430968414207e-16, -1.2101430968414207e-16, -1.2101430968414207e-16, -1.2101430968414207e-16, -1.2101430968414207e-16, -1.2101430968414207e-16, -1.2101430968414207e-16, -1.2101430968414207e-16, -1.2101430968414207e-16, -1.2101430968414207e-16, -1.2101430968414207e-16, -1.2101430968414207e-16, -1.2101430968414207e-16, -1.2101430968414207e-16, -1.2101430968414207e-16, -1.2101430968414207e-16]
one_pca_negativity_original_1 = [-4.107825191113079e-17, -4.107825191113079e-17, -4.107825191113079e-17, -4.107825191113079e-17, -4.107825191113079e-17, -4.107825191113079e-17, -4.107825191113079e-17, -4.107825191113079e-17, -4.107825191113079e-17, -4.107825191113079e-17, -4.107825191113079e-17, -4.107825191113079e-17, -4.107825191113079e-17, -4.107825191113079e-17, -4.107825191113079e-17, -4.107825191113079e-17, -4.107825191113079e-17, -4.107825191113079e-17, -4.107825191113079e-17, -4.107825191113079e-17]
one_pca_negativity_original_2 = [-1.5617137213060536e-16, -1.5617137213060536e-16, -1.5617137213060536e-16, -1.5617137213060536e-16, -1.5617137213060536e-16, -1.5617137213060536e-16, -1.5617137213060536e-16, -1.5617137213060536e-16, -1.5617137213060536e-16, -1.5617137213060536e-16, -1.5617137213060536e-16, -1.5617137213060536e-16, -1.5617137213060536e-16, -1.5617137213060536e-16, -1.5617137213060536e-16, -1.5617137213060536e-16, -1.5617137213060536e-16, -1.5617137213060536e-16, -1.5617137213060536e-16, -1.5617137213060536e-16]

two_pca_negativity_original_0 = [0.28615478512894704, 0.19717836074372355, 0.19717836074372355, 0.19717836074372355, 0.19717836074372355, 0.19717836074372355, 0.19717836074372355, 0.19717836074372355, 0.19717836074372355, 0.19717836074372355, 0.19717836074372355, 0.19717836074372355, 0.19717836074372355, 0.19717836074372355, 0.19717836074372355, 0.19717836074372355, 0.19717836074372355, 0.19717836074372355, 0.19717836074372355, 0.19717836074372355]
two_pca_negativity_original_1 = [0.1104268903409199, 0.2828689574037901, 0.3062264350987704, 0.3062264350987704, 0.3062264350987704, 0.3062264350987704, 0.3062264350987704, 0.3062264350987704, 0.3062264350987704, 0.3062264350987704, 0.3062264350987704, 0.3062264350987704, 0.3062264350987704, 0.3062264350987704, 0.3062264350987704, 0.3062264350987704, 0.3062264350987704, 0.3062264350987704, 0.3062264350987704, 0.3062264350987704]
two_pca_negativity_original_2 = [0.09109001953387914, 0.22605306153450835, 0.22605306153450835, 0.22605306153450835, 0.22605306153450835, 0.22605306153450835, 0.22605306153450835, 0.22605306153450835, 0.22605306153450835, 0.22605306153450835, 0.22605306153450835, 0.22605306153450835, 0.22605306153450835, 0.22605306153450835, 0.22605306153450835, 0.22605306153450835, 0.22605306153450835, 0.22605306153450835, 0.22605306153450835, 0.22605306153450835]

three_pca_negativity_original_0 = [0.26317509024549085, 0.2566534695861732, 0.2566534695861732, 0.2566534695861732, 0.2566534695861732, 0.2566534695861732, 0.2566534695861732, 0.2566534695861732, 0.2566534695861732, 0.2566534695861732, 0.2566534695861732, 0.2566534695861732, 0.2566534695861732, 0.2566534695861732, 0.2566534695861732, 0.2566534695861732, 0.2566534695861732, 0.2566534695861732, 0.2566534695861732, 0.2566534695861732]
three_pca_negativity_original_1 = [0.08879029691345461, 0.14870771928822543, 0.23958012204844112, 0.3302859739434719, 0.3236977084974254, 0.3242853259915365, 0.3105900892912886, 0.3168460159268882, 0.3168460159268882, 0.3148463068339254, 0.3148463068339254, 0.31835626169516107, 0.31835626169516107, 0.31835626169516107, 0.31835626169516107, 0.31835626169516107, 0.31835626169516107, 0.31835626169516107, 0.31835626169516107, 0.31835626169516107]
three_pca_negativity_original_2 = [0.08461253307116391, 0.24802709186526042, 0.24802709186526042, 0.24802709186526042, 0.24802709186526042, 0.24802709186526042, 0.24802709186526042, 0.24802709186526042, 0.24802709186526042, 0.24802709186526042, 0.24802709186526042, 0.24802709186526042, 0.24802709186526042, 0.24802709186526042, 0.24802709186526042, 0.24802709186526042, 0.24802709186526042, 0.24802709186526042, 0.24802709186526042, 0.24802709186526042]

four_pca_negativity_original_0 = [0.24412554124343805, 0.24490957742630362, 0.24490957742630362, 0.24490957742630362, 0.24490957742630362, 0.24490957742630362, 0.24490957742630362, 0.24490957742630362, 0.24490957742630362, 0.24490957742630362, 0.24490957742630362, 0.24490957742630362, 0.24490957742630362, 0.24490957742630362, 0.24490957742630362, 0.24490957742630362, 0.24490957742630362, 0.24490957742630362, 0.24490957742630362, 0.24490957742630362]
four_pca_negativity_original_1 = [0.08651913112755225, 0.09103058303558484, 0.14731506448806353, 0.28137945524863406, 0.33269574677465175, 0.3609224940240009, 0.3609224940240009, 0.3599966450826163, 0.3592053601966302, 0.3592053601966302, 0.3500271739935594, 0.3500271739935594, 0.3500271739935594, 0.3517859812631194, 0.3517859812631194, 0.3517859812631194, 0.3517859812631194, 0.3517859812631194, 0.3517859812631194, 0.3517859812631194]
four_pca_negativity_original_2 = [0.0813979279165633, 0.24630161258459124, 0.24630161258459124, 0.24630161258459124, 0.24630161258459124, 0.24630161258459124, 0.24630161258459124, 0.24630161258459124, 0.24630161258459124, 0.24630161258459124, 0.24630161258459124, 0.24630161258459124, 0.24630161258459124, 0.24630161258459124, 0.24630161258459124, 0.24630161258459124, 0.24630161258459124, 0.24630161258459124, 0.24630161258459124, 0.24630161258459124]

# %%
all_class_0_original = [one_pca_negativity_original_0, two_pca_negativity_original_0, three_pca_negativity_original_0, four_pca_negativity_original_0]

all_class_1_original = [one_pca_negativity_original_1, two_pca_negativity_original_1, three_pca_negativity_original_1, four_pca_negativity_original_1]

all_class_2_original = [one_pca_negativity_original_2, two_pca_negativity_original_2, three_pca_negativity_original_2, four_pca_negativity_original_2]

all_scores_original = [one_pca_accuracy_original, two_pca_accuracy_original, three_pca_accuracy_original, four_pca_accuracy_original]

# %% [markdown]
# # Plotting graphs

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def plot_graph_mult_lines(list_of_xs, list_of_ys, labelX, labelY, list_of_xs_legend, title, step=1, ax=None, plot=True, y_ticks=0.1):
    colors = ["red", "black", "blue", "gray", "yellow", "green"]

    for i in range(len(list_of_xs)):
        if ax == None:
            plt.plot(list_of_xs[i][0::step], list_of_ys[i][0::step], color=colors[i], marker=".",  linestyle="-")
        else:
            ax.plot(list_of_xs[i][0::step], list_of_ys[i][0::step], color=colors[i], marker=".",  linestyle="-")
    if ax == None:
        ax = plt.gca()
    ax.tick_params(axis='y', colors='red')
    ax.tick_params(axis='x', colors='red')

    ax.set_xlabel(labelX)
    ax.xaxis.label.set_color('red')

    ax.set_ylabel(labelY)
    ax.yaxis.label.set_color('red')

    ax.set_title(title)
    ax.set_xticks(np.arange(0, 0.5, 0.05))
    ax.set_yticks(np.arange(0, max(10 * y_ticks, 0.6), y_ticks))

    if list_of_xs_legend != None:
        ax.legend([list_of_xs_legend[i] for i in range(len(list_of_xs))], loc="lower right", bbox_to_anchor=(1, -0.3))
    if plot:
        plt.show()

# %% [markdown]
# ## Proposed

# %%
fig, axs = plt.subplots(1, 3, figsize=(15, 5))
plot_graph_mult_lines(all_class_0_proposed, all_scores_proposed, "Negativity", "Accuracy", None, title="Proposed method - Class 0", step=1, ax=axs[0], plot=False, y_ticks=0.05)
plot_graph_mult_lines(all_class_1_proposed, all_scores_proposed, "Negativity", "Accuracy", None, title="Proposed method - Class 1", step=1, ax=axs[1], plot=False, y_ticks=0.05)
plot_graph_mult_lines(all_class_2_proposed, all_scores_proposed, "Negativity", "Accuracy", definitions_order, title="Proposed method - Class 2", step=1, ax=axs[2], plot=False, y_ticks=0.05)
plt.show()

# %% [markdown]
# ## Original

# %%
fig, axs = plt.subplots(1, 3, figsize=(15, 5))
plot_graph_mult_lines(all_class_0_original, all_scores_original, "Negativity", "Accuracy", None, title="Original method - Class 0", step=1, ax=axs[0], plot=False, y_ticks=0.1)
plot_graph_mult_lines(all_class_1_original, all_scores_original, "Negativity", "Accuracy", None, title="Original method - Class 1", step=1, ax=axs[1], plot=False, y_ticks=0.1)
plot_graph_mult_lines(all_class_2_original, all_scores_original, "Negativity", "Accuracy", definitions_order, title="Original method - Class 2", step=1, ax=axs[2], plot=False, y_ticks=0.1)
plt.show()

# %% [markdown]
# # Comparing

# %%
fig, axs = plt.subplots(2, 3, figsize=(15, 10))
plot_graph_mult_lines(all_class_0_proposed, all_scores_proposed, "Negativity", "Accuracy", None, title="Proposed method - Class 0", step=1, ax=axs[0][0], plot=False, y_ticks=0.03)
plot_graph_mult_lines(all_class_1_proposed, all_scores_proposed, "Negativity", "Accuracy", None, title="Proposed method - Class 1", step=1, ax=axs[0][1], plot=False, y_ticks=0.03)
plot_graph_mult_lines(all_class_2_proposed, all_scores_proposed, "Negativity", "Accuracy", None, title="Proposed method - Class 2", step=1, ax=axs[0][2], plot=False, y_ticks=0.03)

plot_graph_mult_lines(all_class_0_original, all_scores_original, "Negativity", "Accuracy", None, title="Original method - Class 0", step=1, ax=axs[1][0], plot=False, y_ticks=0.1)
plot_graph_mult_lines(all_class_1_original, all_scores_original, "Negativity", "Accuracy", None, title="Original method - Class 1", step=1, ax=axs[1][1], plot=False, y_ticks=0.1)
plot_graph_mult_lines(all_class_2_original, all_scores_original, "Negativity", "Accuracy", definitions_order, title="Original method - Class 2", step=1, ax=axs[1][2], plot=False, y_ticks=0.1)

plt.subplots_adjust(wspace = 0.5, hspace = 0.25)
plt.show()
