# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def plot_graph_mult_lines(list_of_xs, list_of_ys, labelX, labelY, list_of_xs_legend, title, step=1, ax=None, plot=True):
    colors = ["red", "black", "blue", "yellow", "gray", "green"]

    for i in range(len(list_of_xs)):
        if ax == None:
            plt.plot(list_of_xs[i][0::step], list_of_ys[i][0::step], color=colors[i], marker="o",  linestyle="-")
        else:
            ax.plot(list_of_xs[i][0::step], list_of_ys[i][0::step], color=colors[i], marker="o",  linestyle="-")
    if ax == None:
        ax = plt.gca()
    ax.tick_params(axis='y', colors='red')
    ax.tick_params(axis='x', colors='red')

    ax.set_xlabel(labelX)
    ax.xaxis.label.set_color('red')

    ax.set_ylabel(labelY)
    ax.yaxis.label.set_color('red')

    ax.set_title(title)
    ax.set_xticks(np.arange(0, 0.5, 0.05))
    #ax.set_yticks(np.arange(0, 1.1, 0.1))

    ax.legend([list_of_xs_legend[i] for i in range(len(list_of_xs))], loc="lower right", bbox_to_anchor=(1, -0.5))
    if plot:
        plt.show()

# %% [markdown]
# # Scores

# %%
norm_0_original_identity_scores = [0.29333333333333333, 0.33333333333333337, 0.33333333333333337, 0.33333333333333337, 0.33333333333333337, 0.33333333333333337, 0.33333333333333337, 0.33333333333333337, 0.33333333333333337, 0.33333333333333337, 0.33333333333333337, 0.33333333333333337, 0.33333333333333337, 0.33333333333333337, 0.33333333333333337, 0.33333333333333337, 0.33333333333333337, 0.33333333333333337, 0.33333333333333337, 0.32, 0.31333333333333335, 0.29333333333333333, 0.22666666666666666, 0.18666666666666668, 0.18, 0.18, 0.17333333333333334, 0.17333333333333334, 0.17333333333333334, 0.17333333333333334, 0.18, 0.18666666666666668, 0.18, 0.16666666666666669, 0.17333333333333334, 0.17333333333333334, 0.17333333333333334, 0.19333333333333333, 0.2, 0.2, 0.2066666666666667, 0.21333333333333332, 0.21333333333333332, 0.22000000000000003, 0.22000000000000003, 0.24000000000000005, 0.2733333333333334, 0.2733333333333334, 0.2733333333333334, 0.2733333333333334]

norm_0_original_scores = [0.2, 0.33333333333333337, 0.33333333333333337, 0.33333333333333337, 0.33333333333333337, 0.33333333333333337, 0.33333333333333337, 0.33333333333333337, 0.33333333333333337, 0.33333333333333337, 0.31333333333333335, 0.2866666666666667, 0.28, 0.26666666666666666, 0.25999999999999995, 0.25999999999999995, 0.25999999999999995, 0.25999999999999995, 0.24666666666666667, 0.23333333333333334, 0.22000000000000003, 0.24, 0.26, 0.2733333333333333, 0.27999999999999997, 0.29333333333333333, 0.2866666666666667, 0.29333333333333333, 0.33333333333333337, 0.3466666666666666, 0.36, 0.3666666666666667, 0.3666666666666667, 0.3733333333333334, 0.3733333333333334, 0.3733333333333334, 0.3733333333333334, 0.3266666666666667, 0.2733333333333333, 0.23333333333333334, 0.23333333333333334, 0.23333333333333334, 0.26, 0.26666666666666666, 0.26666666666666666, 0.28, 0.29333333333333333, 0.29333333333333333, 0.29333333333333333, 0.30000000000000004]

norm_0_proposed_scores = [0.2066666666666667, 0.2066666666666667, 0.2066666666666667, 0.2066666666666667, 0.2066666666666667, 0.33333333333333337, 0.33333333333333337, 0.6666666666666667, 0.6666666666666667, 0.6666666666666667, 0.6666666666666667, 0.6666666666666667, 0.6666666666666667, 0.6666666666666667, 0.6666666666666667, 0.6666666666666667, 0.6666666666666667, 0.6666666666666667, 0.6666666666666667, 0.6666666666666667, 0.6666666666666667, 0.6666666666666667, 0.6666666666666667, 0.6666666666666667, 0.6666666666666667, 0.6866666666666668, 0.7, 0.78, 0.7733333333333333, 0.7733333333333333, 0.7866666666666667, 0.8533333333333333, 0.86, 0.8933333333333333, 0.9266666666666667, 0.9266666666666667, 0.9266666666666667, 0.9266666666666667, 0.9266666666666667, 0.9266666666666667, 0.9266666666666667, 0.9266666666666667, 0.9266666666666667, 0.9266666666666667, 0.9266666666666667, 0.9266666666666667, 0.9266666666666667, 0.9333333333333333, 0.9333333333333333, 0.9333333333333333]

norm_1_original_identity_scores = [0.33333333333333337, 0.7466666666666667, 0.8800000000000001, 0.8933333333333333, 0.8933333333333333, 0.8800000000000001, 0.8866666666666667, 0.8666666666666668, 0.8800000000000001, 0.8733333333333334, 0.8933333333333333, 0.8866666666666667, 0.8866666666666667, 0.8933333333333333, 0.9066666666666668, 0.9066666666666668, 0.9, 0.9066666666666668, 0.9066666666666668, 0.8933333333333333, 0.9066666666666668, 0.9133333333333334, 0.9133333333333334, 0.9133333333333334, 0.9266666666666667, 0.9266666666666667, 0.9333333333333333, 0.9333333333333333, 0.9400000000000001, 0.9400000000000001, 0.9400000000000001, 0.9466666666666667, 0.9533333333333334, 0.9533333333333334, 0.9466666666666667, 0.9533333333333334, 0.9600000000000002, 0.9600000000000002, 0.9600000000000002, 0.9600000000000002, 0.9600000000000002, 0.9600000000000002, 0.9600000000000002, 0.9666666666666668, 0.9666666666666668, 0.9666666666666668, 0.9666666666666668, 0.9666666666666668, 0.9666666666666668, 0.9666666666666668]

norm_1_original_scores = [0.33333333333333337, 0.7266666666666667, 0.76, 0.7733333333333333, 0.8, 0.7866666666666667, 0.8, 0.8000000000000002, 0.8200000000000001, 0.8266666666666668, 0.8466666666666667, 0.8399999999999999, 0.8533333333333335, 0.8666666666666668, 0.8866666666666667, 0.9, 0.9066666666666666, 0.9133333333333333, 0.9199999999999999, 0.9133333333333333, 0.9066666666666666, 0.9133333333333334, 0.9200000000000002, 0.9400000000000001, 0.9466666666666667, 0.9466666666666667, 0.9466666666666667, 0.9533333333333335, 0.9533333333333335, 0.9533333333333335, 0.9533333333333335, 0.9533333333333335, 0.9533333333333335, 0.9533333333333335, 0.9533333333333335, 0.9533333333333335, 0.9533333333333335, 0.9533333333333335, 0.9533333333333335, 0.9466666666666667, 0.9466666666666667, 0.9533333333333334, 0.9533333333333334, 0.9533333333333334, 0.9533333333333334, 0.9533333333333334, 0.9533333333333334, 0.9533333333333334, 0.9533333333333334, 0.9533333333333334]

norm_1_proposed_scores = [0.33333333333333337, 0.5733333333333334, 0.64, 0.6533333333333334, 0.7, 0.74, 0.7866666666666667, 0.8266666666666665, 0.8466666666666667, 0.8533333333333333, 0.86, 0.8666666666666666, 0.8733333333333333, 0.8733333333333333, 0.8733333333333333, 0.8733333333333333, 0.8666666666666666, 0.8666666666666666, 0.8666666666666666, 0.8666666666666666, 0.8666666666666666, 0.8666666666666666, 0.8666666666666666, 0.8666666666666666, 0.8666666666666666, 0.8666666666666666, 0.8666666666666666, 0.8666666666666666, 0.8666666666666666, 0.8666666666666666, 0.8666666666666666, 0.8666666666666666, 0.8666666666666666, 0.8666666666666666, 0.8666666666666666, 0.8666666666666666, 0.8666666666666666, 0.8666666666666666, 0.8666666666666666, 0.8800000000000001, 0.8733333333333334, 0.8866666666666667, 0.8866666666666667, 0.8933333333333333, 0.8866666666666667, 0.8866666666666667, 0.9, 0.9200000000000002, 0.9200000000000002, 0.9200000000000002]

# %%
all_scores = [norm_0_original_identity_scores, norm_0_original_scores, norm_0_proposed_scores, norm_1_original_identity_scores, norm_1_original_scores, norm_1_proposed_scores]

# %%
definitions_order = [
    "Normalize Axis=0, Original, With Identity",
    "Normalize Axis=0, Original, Without",
    "Normalize Axis=0, Proposed",
    "Normalize Axis=1, Original, With Identity",
    "Normalize Axis=1, Original, Without Identity",
    "Normalize Axis=1, Proposed"]

# %%
epochs = list(range(1, 1000, 20))
all_epochs = [epochs, epochs, epochs, epochs, epochs, epochs]

# %% [markdown]
# # Class Zero

# %%
norm_0_original_identity_class_0 = [0.08843541774929638, 0.08886192580692531, 0.08886192580692531, 0.08886192580692531, 0.08886192580692531, 0.08886192580692531, 0.08886192580692531, 0.08886192580692531, 0.08886192580692531, 0.08886192580692531, 0.08886192580692531, 0.08886192580692531, 0.08886192580692531, 0.08886192580692531, 0.3452762949605258, 0.3534085521243011, 0.3590572839962877, 0.3605833856604989, 0.3652482662231365, 0.3670898370657644, 0.36830135296194244, 0.3690020266839623, 0.3692518457758499, 0.36932162227718646, 0.3692062082360477, 0.3690025621323646, 0.3687844788533, 0.368293244774551, 0.3679976179997435, 0.3677321088597251, 0.3677321088597251, 0.3666827041376618, 0.3663475205837461, 0.3661365828546556, 0.3657816186504065, 0.36538603954833015, 0.36499831550750766, 0.36470203297475173, 0.36413108387910087, 0.3638791293183047, 0.36384183431487954, 0.36376479826202884, 0.3636395918950542, 0.3632186801207224, 0.3630117436735772, 0.3628973262854359, 0.3628973262854359, 0.36276851913280395, 0.3623811827100286, 0.36193165431006735]

norm_1_original_class_2 = [0.31030840500858686, 0.3497343369134852, 0.3539761962165865, 0.3567348260227109, 0.3590249333238686, 0.3611181553749111, 0.3618500542134081, 0.36272852320258053, 0.36290522698585836, 0.36290522698585836, 0.36290522698585836, 0.36297048401952015, 0.3627201000461462, 0.36263532482141003, 0.3624390458169854, 0.3622562055495655, 0.3622562055495655, 0.36216972996068575, 0.36212589952575847, 0.36197862412953474, 0.36197862412953474, 0.3617794203245678, 0.3617794203245678, 0.3617794203245678, 0.3617794203245678, 0.3617794203245678, 0.3617794203245678, 0.3617794203245678, 0.3617794203245678, 0.3617794203245678, 0.3617794203245678, 0.3617794203245678, 0.3617794203245678, 0.3617794203245678, 0.3617794203245678, 0.3617794203245678, 0.3617794203245678, 0.3617794203245678, 0.3617794203245678, 0.3617794203245678, 0.3617794203245678, 0.3617794203245678, 0.3617794203245678, 0.3617794203245678, 0.3617794203245678, 0.3617794203245678, 0.3617794203245678, 0.3617794203245678, 0.3617794203245678, 0.3617794203245678]

norm_1_proposed_class_2 = [0.27342901673118564, 0.21865199600897595, 0.21618004178864267, 0.21449943104029323, 0.21383949993013926, 0.21177922241563413, 0.2113309552881497, 0.20573294774620923, 0.20033337069873514, 0.19853371214233653, 0.19149916820074014, 0.1857802728839322, 0.180798685416448, 0.17837087445022012, 0.17136883714936188, 0.16895385936851307, 0.16185363548085657, 0.16043247325777946, 0.1596544749131314, 0.1596544749131314, 0.1596544749131314, 0.1596544749131314, 0.1596544749131314, 0.1596544749131314, 0.1596544749131314, 0.1596544749131314, 0.1596544749131314, 0.1596544749131314, 0.1596544749131314, 0.1596544749131314, 0.1596544749131314, 0.1596544749131314, 0.1596544749131314, 0.1596544749131314, 0.1596544749131314, 0.1596544749131314, 0.1596544749131314, 0.1596544749131314, 0.1596544749131314, 0.1929802218717582, 0.23330517907624165, 0.2734587413391497, 0.2917722618220207, 0.31291715802209225, 0.312941786061398, 0.312941786061398, 0.33283687878677143, 0.33284323209892286, 0.33284323209892286, 0.33284323209892286]

# %%
all_class_2 = [norm_0_original_identity_class_2, norm_0_original_class_2, norm_0_proposed_class_2, norm_1_original_identity_class_2, norm_1_original_class_2, norm_1_proposed_class_2]
plot_graph_mult_lines(all_class_2, all_scores, "Accuracy", "Negativity", definitions_order, title="Negativity evolution according to accuracy for Class 2 on Iris dataset.", step=1)

# %% [markdown]
# # All classes

# %%
fig, axs = plt.subplots(1, 3, figsize=(15, 5))
plot_graph_mult_lines(all_class_0, all_scores, "Accuracy", "Negativity", definitions_order, title="Class 0", step=5, ax=axs[0], plot=False)
plot_graph_mult_lines(all_class_1, all_scores, "Accuracy", "Negativity", definitions_order, title="Class 1", step=5, ax=axs[1], plot=False)
plot_graph_mult_lines(all_class_2, all_scores, "Accuracy", "Negativity", definitions_order, title="Class 2", step=5, ax=axs[2], plot=False)
plt.show()

# %%
fig, axs = plt.subplots(1, 3, figsize=(15, 5))
plot_graph_mult_lines(all_class_0, all_epochs, "Negativity", "Epochs", definitions_order, title="Class 0", step=1, ax=axs[0], plot=False)
plot_graph_mult_lines(all_class_1, all_epochs, "Negativity", "Epochs", definitions_order, title="Class 1", step=1, ax=axs[1], plot=False)
plot_graph_mult_lines(all_class_2, all_epochs, "Negativity", "Epochs", definitions_order, title="Class 2", step=1, ax=axs[2], plot=False)
plt.show()

# %% [markdown]
# # Iris evaluation

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.decomposition import PCA

# Load the Iris dataset
iris = load_iris()
data = iris.data
data = PCA(n_components=2).fit_transform(data)
target = iris.target
target_names = ["Class " + str(i) + ": " + iris.target_names[i] for i in range(len(set(target)))]

# Create a scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(data[:, 0], data[:, 1], c=target, cmap='viridis')
plt.xlabel('PCA Component 0')
plt.ylabel('PCA Component 1')
plt.title('2-PCA Analysis of Iris Dataset')
plt.colorbar(label='Species', ticks=range(len(target_names)), format=lambda x, y: target_names[x])
plt.show()
# Out:
# Intel(R) Extension for Scikit-learn* enabled (https://github.com/intel/scikit-learn-intelex)

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris

# Load the Iris dataset
iris = load_iris()
data = iris.data
target = iris.target
target_names = ["Class " + str(i) + ": " + iris.target_names[i] for i in range(len(set(target)))]

# Create a scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(data[:, 0], data[:, 1], c=target, cmap='viridis')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Sepal Width (cm)')
plt.title('Sepal Length vs. Sepal Width')
plt.colorbar(label='Species', ticks=range(len(target_names)), format=lambda x, y: target_names[x])
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris

# Load the Iris dataset
iris = load_iris()
data = iris.data
target = iris.target
target_names = ["Class " + str(i) + ": " + iris.target_names[i] for i in range(len(set(target)))]

# Create a scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(data[:, 2], data[:, 3], c=target, cmap='viridis')
plt.xlabel('Petal Length (cm)')
plt.ylabel('Petal Width (cm)')
plt.title('Petal Length vs. Petal Width')
plt.colorbar(label='Species', ticks=range(len(target_names)), format=lambda x, y: target_names[x])
plt.show()
