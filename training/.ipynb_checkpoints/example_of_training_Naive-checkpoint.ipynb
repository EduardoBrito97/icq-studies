# %% [markdown]
# ## Training execution of the quantum classifier inspired in open quantum system
# ## Dataset: Naive

# %%
import sys, os
sys.path.append(os.path.abspath('../classifiers'))
from classifiers_ICQ import iqc_classifier
from iqc_classifier_training import IQCClassifier

from sklearn.multiclass import OneVsOneClassifier, OneVsRestClassifier
import numpy as np


X = np.array([[0,0], [0.5,0.5], [0.9, 0.9]])
y = np.array([[0], [1],[2]])

classifier_function = iqc_classifier
dic_classifier_params = {}
dic_classifier_params["sigma_q_params"] = [1,1,1,0]
dic_classifier_params["use_polar_coordinates_on_sigma_q"] = False
dic_classifier_params["load_inputvector_env_state"] = False

dic_training_params = {"max_iter": 100,
    "accuracy_succ": 0.9,
    "plot_graphs_and_metrics": True,
    "plot_graphs_in_classifier": True,
    "random_seed": 1,
    "learning_rate": 0.1,
    "refit_db":True,
    "reset_weights_epoch":0,
    "do_classes_refit":True,
    "batch":False}

clf = OneVsRestClassifier(IQCClassifier(
            classifier_function=classifier_function,
            dic_classifier_params=dic_classifier_params,
            dic_training_params=dic_training_params))

# %%
clf.fit(X, y)
# Out:
# best weight [-0.16595599+0.j  0.44064899+0.j]
# best accuracy 0.5
# best weight [2.17587419+1.70046269e-17j 2.78247917+1.70046269e-17j]
# best accuracy 1.0
# best weight [1.24466999+7.8843182e-18j 1.85127496+7.8843182e-18j]
# best accuracy 1.0
# OneVsRestClassifier(estimator=IQCClassifier(classifier_function=<function iqc_classifier at 0x7fe79346e430>,
#                                             dic_classifier_params={'load_inputvector_env_state': False,
#                                                                    'sigma_q_params': [1,
#                                                                                       1,
#                                                                                       1,
#                                                                                       0],
#                                                                    'use_polar_coordinates_on_sigma_q': False},
#                                             dic_training_params={'accuracy_succ': 0.9,
#                                                                  'batch': False,
#                                                                  'do_classes_refit': True,
#                                                                  'learning_rate': 0.1,
#                                                                  'max_iter': 100,
#                                                                  'plot_graphs_and_metrics': True,
#                                                                  'plot_graphs_in_classifier': True,
#                                                                  'random_seed': 1,
#                                                                  'refit_db': True,
#                                                                  'reset_weights_epoch': 0}))
